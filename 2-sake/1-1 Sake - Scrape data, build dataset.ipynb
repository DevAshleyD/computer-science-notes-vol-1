# %% [markdown]
# # Scrape data, build dataset
#
# http://www.sakayanyc.com/shop_all.php?pg=all
# https://www.sakeno.com/ranking/
# https://www.saketime.jp/ranking/

# %%
import requests
import pandas as pd
import re
import numpy as np
import os

import math
import statistics

from bs4 import BeautifulSoup

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.rcParams['pdf.fonttype'] = 42

# %matplotlib inline

# %%
url = f'http://www.sakayanyc.com/shop_all.php?pg=all'
response = requests.get(url)
doc = BeautifulSoup(response.text)

# %%
sakes = doc.find_all('td', style='width: 140px; vertical-align: top; padding-bottom: 20px')
rows = []

# the last 'td' on the website is not an actual product, so skip it
for sake in sakes[:-1]:
    row = {}
    row['name'] = sake.find(class_='shop_browse_title').text.strip()
    info = sake.find(class_='shop_browse_info').text.strip()
    row['sake_type'] = info.split('$')[0]
    row['cost'] = info.split('$')[1]
    row['slug'] = sake.a['href']
    rows.append(row)

# %%
df = pd.DataFrame(rows)

# %%
df.head(3)
# Out:
#            cost                                          name  \
# 0  38.99/720 ml                                 Aka Kirishima
# 1  10.99/180 ml                              Akishika "Bambi"
# 2  15.99/300 ml  Akitabare Koshiki Junzukuri "Northern Skies"
#
#                  sake_type                      slug
# 0  (Imo Shochu - Miyazaki)  shop_all.php?prod_id=242
# 1         (Junmai - Osaka)  shop_all.php?prod_id=206
# 2         (Junmai - Akita)  shop_all.php?prod_id=163

# %% [markdown]
# ## Clean up the data
#
# * get rid of () in sake_type
# * sake_type -- break it up into the actual sake type and the prefecture where it's from

# %%
df.head(1)
# Out:
#            cost           name                sake_type  \
# 0  38.99/720 ml  Aka Kirishima  (Imo Shochu - Miyazaki)
#
#                        slug
# 0  shop_all.php?prod_id=242

# %%
df['sake_type'] = df.sake_type.str.replace('(', '')
df['sake_type'] = df.sake_type.str.replace(')', '')
df.sake_type.head(3)
# Out:
# 0    Imo Shochu - Miyazaki
# 1           Junmai - Osaka
# 2           Junmai - Akita
# Name: sake_type, dtype: object

# %%
df['sake_type_cleaned'] = df.sake_type.str.split(' - ').str.get(0)
df['prefecture'] = df.sake_type.str.split(' - ').str.get(1)

# %%
df['sake_type_cleaned'] = df['sake_type_cleaned'].str.strip()
df['sake_type_cleaned'].value_counts()
# Out:
# Junmai Ginjo                              47
# Junmai                                    28
# Junmai Daiginjo                           25
# Tokubetsu Junmai                          17
# Daiginjo                                   9
# Mugi Shochu                                8
# Imo Shochu                                 8
# Ginjo                                      7
# Junmai Kimoto                              5
# Junmai Yamahai                             5
# Junmai Yamahai                             4
# Honjozo                                    4
# Junmai Kimoto                              3
# Junmai Daiginjo Muroka Genshu              2
# Kome Shochu                                2
# Junmai Daiginjo Yamahai                    2
# Awamori                                    2
# Junmai Daiginjo Kimoto                     2
# Tokubetsu Junmai Kimoto                    2
# Ginjo Nama Genshu                          2
# Junmai Ginjo Nigori                        1
# Nama Nama Genshu                           1
# Ginjo Nigori                               1
# Nigori Tokubetsu Junmai                    1
# Umeshu                                     1
# Junmai Ginjo Umeshu                        1
# Tokubetsu Junmai Yamahai                   1
# Junmai Daiginjo Nama Genshu                1
# Nigori Sparkling                           1
# Junmai Ginjo Nama Genshu                   1
# Tokubetsu Junmai Yamahai Muroka Genshu     1
# Ume                                        1
# Kimoto Tokubetsu Junmai                    1
# Futsu-shu                                  1
# Junmai Genshu                              1
# Junmai Ginjo Nigori                        1
# Tokubetsu Junmai Nigori                    1
# Tokubetsu Honjozo                          1
# Nigori Genshu                              1
# Taru Futsu                                 1
# Green Tea Shochu                           1
# Junmai Koshu                               1
# Sesame Shochu                              1
# Yuzu                                       1
# Sparkling                                  1
# Junmai Ginjo Nama                          1
# Honjozo Nama Genshu Nama                   1
# Junmai Kimoto Nama                         1
# Junmai Ginjo Yamahai                       1
# Shiso Shochu                               1
# Sparkling Junmai                           1
# Name: sake_type_cleaned, dtype: int64

# %%
df['cost_cleaned'] = df.cost.str.split('/').str.get(0)

# %%
df['cost_cleaned'] = df.cost_cleaned.astype(float)

# %%
df['vol'] = df.cost.str.split('/').str.get(1).str.replace(' ml', '')
df['vol'] = df.vol.astype(float)

# %%
df.dtypes
# Out:
# cost                  object
# name                  object
# sake_type             object
# slug                  object
# sake_type_cleaned     object
# prefecture            object
# cost_cleaned         float64
# vol                  float64
# dtype: object

# %%
df.head(2)
# Out:
#            cost              name              sake_type  \
# 0  38.99/720 ml     Aka Kirishima  Imo Shochu - Miyazaki
# 1  10.99/180 ml  Akishika "Bambi"         Junmai - Osaka
#
#                        slug sake_type_cleaned prefecture  cost_cleaned    vol
# 0  shop_all.php?prod_id=242        Imo Shochu   Miyazaki         38.99  720.0
# 1  shop_all.php?prod_id=206            Junmai      Osaka         10.99  180.0

# %% [markdown]
# # Get rid of umeshu, ume, yuzu, and awamori. I just want sake.

# %%
df = df.sort_values('sake_type_cleaned').reset_index()

# %%
df.tail(5)
# Out:
#      index          cost                      name  \
# 210    155  30.99/720 ml                    Souden
# 211    103  48.99/720 ml   Mana 1751 "True Vision"
# 212    196  30.99/750 ml  Ume no Yado Aragoshi Ume
# 213    110  54.99/750 ml         Mito no Kairakuen
# 214    195  30.99/750 ml               Ume no Yado
#
#                                           sake_type                      slug  \
# 210              Tokubetsu Junmai Yamahai - Fukuoka  shop_all.php?prod_id=296
# 211  Tokubetsu Junmai Yamahai Muroka Genshu - Fukui  shop_all.php?prod_id=300
# 212                                      Ume - Nara  shop_all.php?prod_id=169
# 213                                Umeshu - Ibaraki  shop_all.php?prod_id=165
# 214                                     Yuzu - Nara  shop_all.php?prod_id=170
#
#                           sake_type_cleaned prefecture  cost_cleaned    vol
# 210                Tokubetsu Junmai Yamahai    Fukuoka         30.99  720.0
# 211  Tokubetsu Junmai Yamahai Muroka Genshu      Fukui         48.99  720.0
# 212                                     Ume       Nara         30.99  750.0
# 213                                  Umeshu    Ibaraki         54.99  750.0
# 214                                    Yuzu       Nara         30.99  750.0

# %%
df.head(5)
# Out:
#    index           cost                      name          sake_type  \
# 0    214   53.99/750 ml              Zuisen Hiryu  Awamori - Okinawa
# 1    213   34.99/750 ml  Zuisen "Hakuryu" Awamori  Awamori - Okinawa
# 2    106  118.99/720 ml          Masumi  Yumedono  Daiginjo - Nagano
# 3    116   70.99/720 ml               Nanbu Bijin   Daiginjo - Iwate
# 4    160   88.99/720 ml                Suirakuten   Daiginjo - Akita
#
#                        slug sake_type_cleaned prefecture  cost_cleaned    vol
# 0  shop_all.php?prod_id=237           Awamori    Okinawa         53.99  750.0
# 1   shop_all.php?prod_id=95           Awamori    Okinawa         34.99  750.0
# 2  shop_all.php?prod_id=194          Daiginjo     Nagano        118.99  720.0
# 3  shop_all.php?prod_id=195          Daiginjo      Iwate         70.99  720.0
# 4  shop_all.php?prod_id=151          Daiginjo      Akita         88.99  720.0

# %%
df_sake = df[3:-3]

# %%
df_sake.sake_type_cleaned.value_counts()
# Out:
# Junmai Ginjo                              47
# Junmai                                    28
# Junmai Daiginjo                           25
# Tokubetsu Junmai                          17
# Daiginjo                                   8
# Mugi Shochu                                8
# Imo Shochu                                 8
# Ginjo                                      7
# Junmai Yamahai                             5
# Junmai Kimoto                              5
# Junmai Yamahai                             4
# Honjozo                                    4
# Junmai Kimoto                              3
# Tokubetsu Junmai Kimoto                    2
# Junmai Daiginjo Yamahai                    2
# Ginjo Nama Genshu                          2
# Junmai Daiginjo Muroka Genshu              2
# Kome Shochu                                2
# Junmai Daiginjo Kimoto                     2
# Junmai Kimoto Nama                         1
# Tokubetsu Junmai Nigori                    1
# Tokubetsu Junmai Yamahai                   1
# Nigori Tokubetsu Junmai                    1
# Sparkling Junmai                           1
# Junmai Ginjo Nama Genshu                   1
# Tokubetsu Junmai Yamahai Muroka Genshu     1
# Honjozo Nama Genshu Nama                   1
# Junmai Ginjo Nama                          1
# Nama Nama Genshu                           1
# Junmai Daiginjo Nama Genshu                1
# Nigori Sparkling                           1
# Shiso Shochu                               1
# Taru Futsu                                 1
# Nigori Genshu                              1
# Junmai Ginjo Nigori                        1
# Junmai Ginjo Nigori                        1
# Junmai Genshu                              1
# Sesame Shochu                              1
# Junmai Ginjo Yamahai                       1
# Ginjo Nigori                               1
# Green Tea Shochu                           1
# Kimoto Tokubetsu Junmai                    1
# Junmai Koshu                               1
# Sparkling                                  1
# Tokubetsu Honjozo                          1
# Junmai Ginjo Umeshu                        1
# Futsu-shu                                  1
# Name: sake_type_cleaned, dtype: int64

# %% [markdown]
# ## Clean up sake_type to make the categories consistent. Also, get rid of shochu & bottles that aren't 720ml

# %%
df_sake = df_sake[df_sake.sake_type_cleaned.str.contains('Shochu') == False]

# %%
df_sake = df_sake[df_sake.cost.str.contains('720')].reset_index()

# %%
df_sake
# Out:
#      level_0  index           cost  \
# 0          3    116   70.99/720 ml
# 1          4    160   88.99/720 ml
# 2          6     78   89.99/720 ml
# 3          7    181   55.99/720 ml
# 4          8     68   72.99/720 ml
# 5          9    179   80.99/720 ml
# 6         10     91  107.99/720 ml
# 7         11    211   24.99/720 ml
# 8         12    137   44.99/720 ml
# 9         13     27   40.99/720 ml
# 16                                  Honjozo   Yamagata         26.99  720.0
# 17                                  Honjozo     Miyagi         28.99  720.0
# 18                                  Honjozo   Yamagata         29.99  720.0
# 19                                   Junmai     Nagano         32.99  720.0
# 20                                   Junmai    Okayama         35.99  720.0
# 21                                   Junmai        Mie         41.99  720.0
# 22                                   Junmai      Fukui         34.99  720.0
# 23                                   Junmai    Shimane         34.99  720.0
# 24                                   Junmai      Shiga         38.99  720.0
# 25                                   Junmai       Saga         38.99  720.0
# 26                                   Junmai   Yamagata         33.99  720.0
# 27                                   Junmai       Saga         38.99  720.0
# 28                                   Junmai      Gunma         32.99  720.0
# 29                                   Junmai  Fukushima         34.99  720.0
# ..                                      ...        ...           ...    ...
# 136                           Junmai Kimoto      Tokyo         66.99  720.0
# 137                      Junmai Kimoto Nama      Kyoto         36.99  720.0
# 138                          Junmai Yamahai   Ishikawa         34.99  720.0
# 139                          Junmai Yamahai   Ishikawa         32.99  720.0
# 140                          Junmai Yamahai   Ishikawa         47.99  720.0
# 141                          Junmai Yamahai    Fukuoka         47.99  720.0
# 142                 Kimoto Tokubetsu Junmai      Kyoto         33.99  720.0
# 143                              Taru Futsu       Nara         26.99  720.0
# 144                       Tokubetsu Honjozo     Toyama         25.99  720.0
# 145                        Tokubetsu Junmai     Aomori         47.99  720.0
# 146                        Tokubetsu Junmai  Yamaguchi         44.99  720.0
# 147                        Tokubetsu Junmai    Tottori         37.99  720.0
# 148                        Tokubetsu Junmai    Ibaraki         38.99  720.0
# 149                        Tokubetsu Junmai  Fukushima         30.99  720.0
# 150                        Tokubetsu Junmai      Kochi         31.99  720.0
# 151                        Tokubetsu Junmai     Miyagi         32.99  720.0
# 152                        Tokubetsu Junmai      Iwate         35.99  720.0
# 153                        Tokubetsu Junmai    Niigata         31.99  720.0
# 154                        Tokubetsu Junmai   Hokkaido         35.99  720.0
# 155                        Tokubetsu Junmai    Tottori         32.99  720.0
# 156                        Tokubetsu Junmai      Kochi         51.99  720.0
# 157                        Tokubetsu Junmai      Kochi         25.99  720.0
# 158                        Tokubetsu Junmai      Akita         43.99  720.0
# 159                        Tokubetsu Junmai     Miyagi         48.99  720.0
# 160                        Tokubetsu Junmai       Oita         41.99  720.0
# 161                 Tokubetsu Junmai Kimoto    Tochigi         38.99  720.0
# 162                 Tokubetsu Junmai Kimoto      Hyogo         19.99  720.0
# 163                 Tokubetsu Junmai Nigori    Shimane         41.99  720.0
# 164                Tokubetsu Junmai Yamahai    Fukuoka         30.99  720.0
# 165  Tokubetsu Junmai Yamahai Muroka Genshu      Fukui         48.99  720.0
#
# [166 rows x 10 columns]

# %% [markdown]
# # Scrape more details for each sake
#
#
# * rice
# * rice polish
# * alcohol
# * SMV
# * acidity
# * amino_acid

# %% [markdown]
# ## Scrape details for one sake

# %%
slug = df_sake.slug[0]
url = f'http://www.sakayanyc.com/{slug}'
response = requests.get(url)
doc = BeautifulSoup(response.text)

infos = doc.find_all(alt='@')
details = []

for info in infos[:7]:
    info = info.next_element.strip()
    details.append(info)

rice = details[0].split(':')[1].strip()
polish = details[1].split(':')[1].strip()
alcohol = details[2].split(':')[1].strip()
yeast = details[3].split(':')[1].strip()
SMV = details[4].split(':')[1].strip()
acidity = details[5].split(':')[1].strip()
amino_acid = details[6].split(':')[1].strip()

# %% [markdown]
# ## Scrape info for all sake

# %%
rows = []
for slug in df_sake.slug:
    url = f'http://www.sakayanyc.com/{slug}'
    response = requests.get(url)
    doc = BeautifulSoup(response.text)

    infos = doc.find_all(alt='@')
    details = []

    for info in infos[:7]:
        info = info.next_element.strip()
        details.append(info)
        
    row = {}
    row['slug'] = slug
    row['rice'] = details[0].split(':')[1].strip()
    row['polish'] = details[1].split(':')[1].strip()
    row['alcohol'] = details[2].split(':')[1].strip()
    row['yeast'] = details[3].split(':')[1].strip()
    row['SMV'] = details[4].split(':')[1].strip()
    row['acidity'] = details[5].split(':')[1].strip()
    row['amino_acid'] = details[6].split(':')[1].strip()
    
    rows.append(row)

# %%
df_info = pd.DataFrame(rows)

# %%
df_info.head(1)
# Out:
#   SMV acidity alcohol amino_acid polish       rice                      slug  \
# 0  +5     1.3  16-17%         na    40%  Gin Otome  shop_all.php?prod_id=195
#
#               yeast
# 0  Iwate #2 & #1601

# %%
df_sake.head(1)
# Out:
#    level_0  index          cost         name         sake_type  \
# 0        3    116  70.99/720 ml  Nanbu Bijin  Daiginjo - Iwate
#
#                        slug sake_type_cleaned prefecture  cost_cleaned    vol
# 0  shop_all.php?prod_id=195          Daiginjo      Iwate         70.99  720.0

# %% [markdown]
# # Merge dataframes

# %%
merged = df_sake.merge(df_info, left_on='slug', right_on='slug')
merged.head(2)
# Out:
#    level_0  index          cost         name         sake_type  \
# 0        3    116  70.99/720 ml  Nanbu Bijin  Daiginjo - Iwate
# 1        4    160  88.99/720 ml   Suirakuten  Daiginjo - Akita
#
#                        slug sake_type_cleaned prefecture  cost_cleaned    vol  \
# 0  shop_all.php?prod_id=195          Daiginjo      Iwate         70.99  720.0
# 1  shop_all.php?prod_id=151          Daiginjo      Akita         88.99  720.0
#
#        SMV    acidity alcohol amino_acid polish            rice  \
# 0       +5        1.3  16-17%         na    40%       Gin Otome
# 1  +3 - +5  1.1 - 1.3  15-16%         na    38%  Yamada Nishiki
#
#               yeast
# 0  Iwate #2 & #1601
# 1                #9

# %%
# Get rid of extraneous columns
merged = merged.loc[:, 'cost':]

# %% [markdown]
# ## Clean up sake_type so they fall under the main, legal categories used in Japan
#
# Categories should be:
#
# {'Daiginjo',
#  'Futsu-shu',
#  'Ginjo',
#  'Honjozo',
#  'Junmai',
#  'Junmai Daiginjo',
#  'Junmai Ginjo',
#  'Tokubetsu Honjozo',
#  'Tokubetsu Junmai'}
#
#  * Get rid of Umeshu

# %%
merged.sake_type_cleaned.unique()
# Out:
# array(['Daiginjo', 'Futsu-shu', 'Ginjo', 'Ginjo Nama Genshu', 'Honjozo',
#        'Junmai', 'Junmai Daiginjo', 'Junmai Daiginjo Muroka Genshu',
#        'Junmai Daiginjo Nama Genshu', 'Junmai Daiginjo\xa0Kimoto',
#        'Junmai Daiginjo\xa0Yamahai', 'Junmai Genshu', 'Junmai Ginjo',
#        'Junmai Ginjo Nama', 'Junmai Ginjo Nama Genshu',
#        'Junmai Ginjo Nigori', 'Junmai Ginjo Yamahai',
#        'Junmai Ginjo\xa0Umeshu', 'Junmai Kimoto', 'Junmai Yamahai',
#        'Junmai\xa0Kimoto', 'Junmai\xa0Kimoto\xa0Nama',
#        'Junmai\xa0Yamahai', 'Kimoto\xa0Tokubetsu Junmai', 'Taru Futsu',
#        'Tokubetsu Honjozo', 'Tokubetsu Junmai', 'Tokubetsu Junmai Kimoto',
#        'Tokubetsu Junmai Nigori', 'Tokubetsu Junmai Yamahai',
#        'Tokubetsu Junmai Yamahai Muroka Genshu'], dtype=object)

# %%
sake_cleaned = []
for sake in merged.sake_type_cleaned:
    if 'Yamahai' in sake:
        sake = sake.replace('Yamahai', '')
    elif sake == 'Ginjo Nama Genshu':
        sake = 'Ginjo Genshu'
    elif sake == 'Tokubetsu Junmai Kimoto':
        sake = 'Tokubetsu Junmai'
    elif sake == 'Kimoto\xa0Tokubetsu Junmai':
        sake = 'Tokubetsu Junmai'
    elif sake == 'Junmai Daiginjo\xa0Kimoto':
        sake = 'Junmai Daiginjo'
    elif sake == 'Junmai Daiginjo\xa0Yamahai':
        sake = 'Junmai Daiginjo'       
    elif sake == 'Junmai\xa0Kimoto\xa0Nama':
        sake = 'Junmai Nama'
    elif sake == 'Junmai\xa0Kimoto':
        sake = 'Junmai'
    elif sake == 'Taru Futsu':
        sake = 'Futsu-shu'
    elif 'Kimoto' in sake:
        sake = sake.replace('Kimoto', '').strip()
    elif 'Yamahai' in sake:
        sake = sake.replace('Yamahai', '').strip()
    elif 'Muroka Genshu' in sake:
        sake = sake.replace('Muroka Genshu', 'Genshu').strip()
    else:
        sake = sake.strip()
    sake_cleaned.append(sake)

# %%
merged['sake_type_cleaned'] = sake_cleaned
merged.sake_type_cleaned.value_counts()
# Out:
# Junmai Ginjo                       44
# Junmai                             33
# Junmai Daiginjo                    25
# Tokubetsu Junmai                   19
# Ginjo                               7
# Daiginjo                            7
# Junmai                              5
# Junmai                              4
# Honjozo                             3
# Junmai Daiginjo Genshu              2
# Junmai Daiginjo                     2
# Futsu-shu                           2
# Tokubetsu Junmai  Muroka Genshu     1
# Junmai Daiginjo Nama Genshu         1
# Junmai Genshu                       1
# Tokubetsu Junmai                    1
# Junmai Ginjo Nama Genshu            1
# Junmai Ginjo Nigori                 1
# Tokubetsu Junmai Nigori             1
# Junmai Ginjo Umeshu                 1
# Junmai Ginjo Nama                   1
# Ginjo Genshu                        1
# Tokubetsu Honjozo                   1
# Junmai Nama                         1
# Junmai Ginjo                        1
# Name: sake_type_cleaned, dtype: int64

# %% [markdown]
# # Actually, I'm going to narrow down the categories more

# %%
sake_cleaned = []

for sake in merged.sake_type_cleaned:
    if sake == 'Junmai Daiginjo Genshu':
        sake = 'Junmai Daiginjo'
    elif 'Nama' in sake:
        sake = sake.replace('Nama', '').strip()
    elif 'Genshu' in sake:
        sake = sake.replace(' Genshu', '')
    elif 'Nigori' in sake:
        sake = sake.replace(' Nigori', '')
    else:
        sake = sake.strip()
    sake_cleaned.append(sake)

# %%
sake_cleaned2 = []
for sake in sake_cleaned:
    if sake == 'Tokubetsu Junmai  Muroka':
        sake = 'Tokubetsu Junmai'
    else:
        sake = sake.strip()
    sake_cleaned2.append(sake)

# %%
set(sake_cleaned2)
# Out:
# {'Daiginjo',
#  'Futsu-shu',
#  'Ginjo',
#  'Honjozo',
#  'Junmai',
#  'Junmai Daiginjo',
#  'Junmai Daiginjo  Genshu',
#  'Junmai Ginjo',
#  'Junmai Ginjo  Genshu',
#  'Junmai Ginjo\xa0Umeshu',
#  'Tokubetsu Honjozo',
#  'Tokubetsu Junmai'}

# %%
merged['sake_type_cleaned'] = sake_cleaned2

# %% [markdown]
# ## Add tags for nama, genshu, nigori

# %%
merged['nama'] = merged.sake_type.str.contains("Nama").astype(int)
merged['nigori'] = merged.sake_type.str.contains("Nigori").astype(int)
merged['genshu'] = merged.sake_type.str.contains("Genshu").astype(int)

# %% [markdown]
# ## Get rid of the one umeshu

# %%
merged[merged.sake_type.str.contains('Umeshu')]
# Out:
#              cost          name                      sake_type  \
# 123  57.99/720 ml  Kakurei Plum  Junmai Ginjo Umeshu - Niigata
#
#                         slug    sake_type_cleaned prefecture  cost_cleaned  \
# 123  shop_all.php?prod_id=39  Junmai Ginjo Umeshu    Niigata         57.99
#
#        vol SMV acidity alcohol amino_acid polish            rice yeast  nama  \
# 123  720.0  na      na   9-10%         na    55%  Miyama Nishiki    na     0
#
#      nigori  genshu
# 123       0       0

# %%
merged = merged[merged.sake_type.str.contains('Umeshu') == False]

# %% [markdown]
# # Change datatype to float for SMV, acidity, alcohol, amino_acid, polish

# %%
merged.dtypes
# Out:
# cost                  object
# name                  object
# sake_type             object
# slug                  object
# sake_type_cleaned     object
# prefecture            object
# cost_cleaned         float64
# vol                  float64
# SMV                   object
# acidity               object
# alcohol               object
# amino_acid            object
# polish                object
# rice                  object
# yeast                 object
# nama                   int64
# nigori                 int64
# genshu                 int64
# dtype: object

# %% [markdown]
# ## Turn n/a and na into np.nan & get rid of row 147, which has an invalid SMV

# %%
merged = merged[merged.SMV != '#9']

# %%
# merged.SMV.value_counts(dropna=False)

# %%
merged[merged.SMV.str.contains(' - ')]
# Out:
#              cost                 name                sake_type  \
# 1    88.99/720 ml           Suirakuten         Daiginjo - Akita
# 61   64.99/720 ml            Chokaisan  Junmai Daiginjo - Akita
# 107  54.99/720 ml  Tenryo "Hidahomare"      Junmai Ginjo - Gifu
#
#                          slug sake_type_cleaned prefecture  cost_cleaned  \
# 1    shop_all.php?prod_id=151          Daiginjo      Akita         88.99
# 61   shop_all.php?prod_id=153   Junmai Daiginjo      Akita         64.99
# 107  shop_all.php?prod_id=260      Junmai Ginjo       Gifu         54.99
#
#        vol      SMV    acidity alcohol amino_acid polish            rice  \
# 1    720.0  +3 - +5  1.1 - 1.3  15-16%         na    38%  Yamada Nishiki
# 61   720.0  +1 - +3  1.3 - 1.5  15-16%         na    50%  Miyama Nishiki
# 107  720.0  +3 - +5    1.3-1.5  15-16%    1.1-1.3    50%      Hidahomare
#
#                       yeast  nama  nigori  genshu
# 1                        #9     0       0       0
# 61       Akita flower yeast     0       0       0
# 107  Hana Yeast "Nadeshiko"     0       0       0

# %%
merged['SMV_cleaned'] = merged.SMV
merged['SMV_cleaned'] = merged.SMV_cleaned.replace({'+3 - +5': '4', '+1 - +3':'2', '+':''})
merged['SMV_cleaned'] = merged.SMV_cleaned.str.replace('+','')
merged['SMV_cleaned'] = merged.SMV_cleaned.replace(r'n/?a', np.nan, regex=True)
merged['SMV_cleaned'] = merged.SMV_cleaned.astype(float)

# %%
merged.dtypes
# Out:
# cost                  object
# name                  object
# sake_type             object
# slug                  object
# sake_type_cleaned     object
# prefecture            object
# cost_cleaned         float64
# vol                  float64
# SMV                   object
# acidity               object
# alcohol               object
# amino_acid            object
# polish                object
# rice                  object
# yeast                 object
# nama                   int64
# nigori                 int64
# genshu                 int64
# SMV_cleaned          float64
# dtype: object

# %%
merged.SMV_cleaned.value_counts(dropna=False)
# Out:
#  3.0     35
#  4.0     26
#  2.0     21
#  5.0     20
#  1.0     14
#  0.0      6
#  3.5      5
#  NaN      5
#  6.0      4
#  12.0     4
# -2.0      3
# -1.0      3
#  1.5      2
#  10.0     2
#  15.0     2
#  2.5      1
#  9.5      1
# -3.0      1
#  5.5      1
#  4.5      1
#  7.0      1
#  6.5      1
# -4.0      1
# -10.0     1
#  0.5      1
#  8.0      1
# -7.0      1
# Name: SMV_cleaned, dtype: int64

# %% [markdown]
# ## Clean acidity

# %%
merged.acidity.value_counts(dropna=False)
# Out:
# 1.4          26
# 1.5          24
# 1.6          17
# 1.3          16
# 1.2          15
# 1.8          13
# 1.7          12
# n/a           9
# 1.9           9
# na            8
# 1.0           3
# 2.1           2
# 2.6           2
# 2.2           2
# 1.4-1.7       1
# 1.1           1
# 1.3-1.5       1
# 1.1 - 1.3     1
# 1.35          1
# 1.3 - 1.5     1
# Name: acidity, dtype: int64

# %%
merged['acidity_cleaned'] = merged.acidity.replace({'1.4-1.7': '1.55', 
                                                    '1.3 - 1.5':'1.4', 
                                                    '1.1 - 1.3':'1.2',
                                                    '1.3-1.5':'1.4'})

merged['acidity_cleaned'] = merged.acidity_cleaned.replace(r'n/?a', np.nan, regex=True)
merged['acidity_cleaned'] = merged.acidity_cleaned.astype(float)

# %% [markdown]
# ## Clean alcohol

# %%
merged['alcohol_cleaned'] = merged.alcohol.str[:-1]

# %%
for idx, alc in enumerate(merged.alcohol_cleaned.str.split('-')):
    try:
        if len(alc) == 2:
            alc = (int(alc[0]) + int(alc[1])) / 2
            merged.alcohol_cleaned.iloc[idx] = alc
        else:
            alc = int(alc)
            merged.alcohol_cleaned.iloc[idx] = alc
    except:
        pass
# Out:
# /Users/minami/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
merged['alcohol_cleaned'] = merged.alcohol_cleaned.astype(float)

# %%
merged.dtypes
# Out:
# cost                  object
# name                  object
# sake_type             object
# slug                  object
# sake_type_cleaned     object
# prefecture            object
# cost_cleaned         float64
# vol                  float64
# SMV                   object
# acidity               object
# alcohol               object
# amino_acid            object
# polish                object
# rice                  object
# yeast                 object
# nama                   int64
# nigori                 int64
# genshu                 int64
# SMV_cleaned          float64
# acidity_cleaned      float64
# alcohol_cleaned      float64
# dtype: object

# %% [markdown]
# ## Clean amino_acid

# %%
merged.amino_acid.value_counts()
# Out:
# na         86
# n/a        21
#            10
# 1.0         7
# 1.2         7
# 1.3         6
# 1.1         4
# 0.9         4
# 1.6         3
# 1           3
# 1.4         3
# 0.8         2
# 1.8         2
# 2.0         2
# 1.2-1.4     1
# 1.1-1.3     1
# 1.7         1
# 2           1
# Name: amino_acid, dtype: int64

# %%
merged['amino_acid_cleaned'] = merged.amino_acid

# %%
merged['amino_acid_cleaned'] = merged.amino_acid_cleaned.replace({'1.1-1.3': '1.2', 
                                                    '1.2-1.4':'1.3', '':np.nan})

# %%
merged['amino_acid_cleaned'] = merged.amino_acid_cleaned.replace(r'n/?a', np.nan, regex=True)

# %%
merged.amino_acid_cleaned.value_counts()
# Out:
# 1.2    8
# 1.0    7
# 1.3    7
# 1.1    4
# 0.9    4
# 1.4    3
# 1      3
# 1.6    3
# 1.8    2
# 0.8    2
# 2.0    2
# 1.7    1
# 2      1
# Name: amino_acid_cleaned, dtype: int64

# %%
merged['amino_acid_cleaned'] = merged.amino_acid_cleaned.astype(float)

# %% [markdown]
# ## Clean polish

# %%
merged.polish.value_counts()
# Out:
# 50%                          40
# 60%                          31
# 55%                          30
# 65%                          16
# 40%                           9
# 70%                           6
# 45%                           5
# 58%                           4
# 35%                           3
# 48%                           3
# 57%                           2
# 38%                           2
# 75%                           2
# 49%                           1
# 33%                           1
# 66%                           1
# Super flat rice polishing     1
# 90%                           1
# na                            1
# 64%                           1
# 18%                           1
# 68%                           1
# 23%                           1
#                               1
# Name: polish, dtype: int64

# %%
merged['polish_cleaned'] = merged.polish.replace({'%': '',
                                                  'Super flat rice polishing':np.nan,
                                                  '':np.nan,
                                                 'na':np.nan})

# %%
merged['polish_cleaned'] = merged.polish_cleaned.str[:-1]

# %%
merged.polish_cleaned.value_counts(dropna=False)
# Out:
# 50     40
# 60     31
# 55     30
# 65     16
# 40      9
# 70      6
# 45      5
# 58      4
# 48      3
# 35      3
# NaN     3
# 75      2
# 38      2
# 57      2
# 64      1
# 49      1
# 68      1
# 33      1
# 18      1
# 23      1
# 66      1
# 90      1
# Name: polish_cleaned, dtype: int64

# %%
merged['polish_cleaned'] = merged.polish_cleaned.astype(float)

# %%
merged = merged.drop(columns='cost')
merged
# Out:
#                                                   name  \
# 0                                          Nanbu Bijin
# 1                                           Suirakuten
# 2                                                  Ken
# 3                              Tedorigawa "Ikina Onna"
# 4                                              Kakurei
# 150                     KA-1    0      0       0          4.0
# 151                     #901    0      0       0          1.0
# 152                       #9    0      0       0          5.0
# 153            AkitaKonno #2    0      0       0          5.0
# 154              Yamagata KA    0      0       0         10.0
# 155                       #9    0      0       0          3.0
# 156                       #9    0      0       0          8.0
# 157                       na    0      0       0          7.0
# 158                     AK-1    0      0       0          4.0
# 159              Proprietary    0      0       0          3.0
# 160                      n/a    0      0       0         -2.0
# 161                       #9    0      0       0          4.0
# 162              Proprietary    0      0       0          2.0
# 163                       #9    0      1       0          3.0
# 164                      n/a    0      0       0         -3.0
# 165                    FK301    0      0       1          1.0
#
#      acidity_cleaned  alcohol_cleaned  amino_acid_cleaned  polish_cleaned
# 0               1.30             16.5                 NaN            40.0
# 1               1.20             15.5                 NaN            38.0
# 2               1.20             15.9                 NaN            40.0
# 3               1.20             16.2                 NaN            40.0
# 4               1.50             15.5                 0.9            48.0
# 5                NaN             17.0                 NaN            50.0
# 6               1.20             15.5                 NaN            40.0
# 7               1.30             15.0                 1.0            68.0
# 8               1.30             16.5                 NaN            50.0
# 9               1.40             17.5                 NaN            50.0
# 10              1.00             15.5                 NaN            55.0
# 11              1.30             15.5                 NaN            60.0
# 12               NaN             15.5                 NaN            50.0
# 13              1.00             15.5                 NaN            50.0
# 14              1.30             15.5                 NaN            50.0
# 15              1.70             18.5                 1.6            58.0
# 16               NaN             15.3                 NaN             NaN
# 17              1.20             15.5                 NaN            65.0
# 18              1.00             14.8                 0.9            65.0
# 19              1.50             15.0                 NaN            60.0
# 20              1.50             16.5                 NaN            60.0
# 21              2.60             17.0                 1.7            90.0
# 22              1.30             14.5                 NaN            65.0
# 23              1.80             16.0                 1.2            70.0
# 24              1.40             15.5                 NaN            60.0
# 25              1.70             17.0                 NaN            75.0
# 26              1.40             14.5                 NaN            60.0
# 27              1.70             17.0                 NaN            65.0
# 28              1.80             16.5                 1.6            60.0
# 29              1.40             16.5                 NaN            55.0
# ..               ...              ...                 ...             ...
# 135             1.40             15.3                 1.6            60.0
# 136             2.10             15.5                 1.2            65.0
# 137             2.60             19.5                 NaN            66.0
# 138             1.50             15.5                 NaN            65.0
# 139             1.90             15.8                 1.8            60.0
# 140             1.90             15.0                 NaN            65.0
# 141             1.90             16.0                 NaN            70.0
# 142             1.90             16.5                 NaN            60.0
# 143             1.20             15.5                 1.0            70.0
# 144              NaN             15.5                 NaN            58.0
# 145              NaN             15.5                 NaN            55.0
# 146             1.60             15.5                 NaN            60.0
# 148             1.50             15.5                 1.1            55.0
# 149             1.40             15.5                 NaN            60.0
# 150             1.60             15.5                 NaN            60.0
# 151             1.50             15.5                 NaN            55.0
# 152             1.50             15.5                 NaN            55.0
# 153             1.40             15.5                 1.3            60.0
# 154             1.60             15.5                 NaN            60.0
# 155             1.50             15.5                 NaN            55.0
# 156             1.40             15.6                 NaN            57.0
# 157             1.60             15.5                 1.2            55.0
# 158             1.50             15.8                 NaN            55.0
# 159             1.80             15.5                 1.3            60.0
# 160             1.35             15.5                 2.0            60.0
# 161             1.80             15.0                 NaN            60.0
# 162             1.80             14.5                 NaN            70.0
# 163             1.60             15.5                 NaN            55.0
# 164              NaN             15.5                 NaN            60.0
# 165             1.70             16.5                 NaN            60.0
#
# [164 rows x 22 columns]

# %%
merged.dtypes
# Out:
# name                   object
# sake_type              object
# slug                   object
# sake_type_cleaned      object
# prefecture             object
# cost_cleaned          float64
# vol                   float64
# SMV                    object
# acidity                object
# alcohol                object
# amino_acid             object
# polish                 object
# rice                   object
# yeast                  object
# nama                    int64
# nigori                  int64
# genshu                  int64
# SMV_cleaned           float64
# acidity_cleaned       float64
# alcohol_cleaned       float64
# amino_acid_cleaned    float64
# polish_cleaned        float64
# dtype: object

# %%
merged.to_csv('sake_info.csv', index=False)

# %% [markdown]
# # Make bins for rich/light, sweet/dry

# %%
df = pd.read_csv('sake_info.csv')

# %%
df['SMV_dry_sweet_bins'] = pd.cut(df.SMV_cleaned, bins = [-10, -5.9, -3.4, -1.4, 1.4, 3.4, 5.9, 15])

# %%
df['SMV_dry_sweet'] = pd.cut(df.SMV_cleaned, bins = [-10, -5.9, -3.4, -1.4, 1.4, 3.4, 5.9, 15],
      labels=['0very_sweet', '1sweet', '2slightly_sweet', '3neutral',
              '4slightly_dry', '5dry', '6very_dry'])

# %%
df['SMV_dry_sweet'].value_counts()
# Out:
# 4slightly_dry      59
# 5dry               53
# 3neutral           24
# 6very_dry          16
# 2slightly_sweet     4
# 1sweet              1
# 0very_sweet         1
# Name: SMV_dry_sweet, dtype: int64

# %%
df.acidity_cleaned.describe()
# Out:
# count    147.000000
# mean       1.524490
# std        0.269282
# min        1.000000
# 25%        1.375000
# 50%        1.500000
# 75%        1.700000
# max        2.600000
# Name: acidity_cleaned, dtype: float64

# %%
df['acidity_richness_bins'] = pd.cut(df.acidity_cleaned, bins = [1, 1.2, 1.4, 1.6, 1.8, 2.6])

# %%
df['acidity_richness'] = pd.cut(df.acidity_cleaned, bins = [1, 1.2, 1.4, 1.6, 1.8, 2.6],
      labels = ['0very_light', '1light', '2neutral', '3rich', '4very_rich'])

# %%
df.acidity_richness.value_counts()
# Out:
# 1light         45
# 2neutral       42
# 3rich          25
# 0very_light    17
# 4very_rich     15
# Name: acidity_richness, dtype: int64

# %%
df.sake_type_cleaned.value_counts()
# Out:
# Junmai Ginjo               47
# Junmai                     44
# Junmai Daiginjo            29
# Tokubetsu Junmai           21
# Ginjo                       8
# Daiginjo                    7
# Honjozo                     3
# Futsu-shu                   2
# Junmai Ginjo  Genshu        1
# Junmai Daiginjo  Genshu     1
# Tokubetsu Honjozo           1
# Name: sake_type_cleaned, dtype: int64

# %%
df.to_csv('sake_info.csv', index=False)

# %% [markdown]
# # Clean up rice types

# %%
df = pd.read_csv('sake_info.csv')

# %%
df['yamada_nishiki'] = df.rice.str.contains("Yamada Nishiki").astype(int)
df['gohyaku_mangoku'] = df.rice.str.contains("Gohyaku Mangoku").astype(int)

# %%
df.to_csv('sake_info.csv', index=False)
