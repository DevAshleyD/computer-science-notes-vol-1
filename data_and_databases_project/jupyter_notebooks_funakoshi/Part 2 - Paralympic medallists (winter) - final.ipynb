# %% [markdown]
# # Lede Summer 2019 Project - Part 2
# ## Make a database of female and male Paralympic all-time medallists (winter)
# * get years only, not start_year and end_year

# %%
import requests
import pandas as pd
import re
import numpy as np
import os

import itertools

from bs4 import BeautifulSoup
from selenium import webdriver

# %% [markdown]
# #### LINKS:
# Summer:
# https://www.paralympic.org/sdms4/hira/web/multiMedallists/type/summer
#
# Winter:
# https://www.paralympic.org/sdms4/hira/web/multiMedallists/type/winter

# %%
url = 'https://www.paralympic.org/sdms4/hira/web/multiMedallists/type/winter'
response = requests.get(url)
para_doc = BeautifulSoup(response.text)

# %% [markdown]
# ### Get names of paralympic athletes

# %%
# Get athlete names (full name)
para_info = para_doc.find_all('tr')
full_name = []

for athlete in para_info:
    try:
        full_name.append(athlete.find_all('td')[1].string)
    except:
        pass
# full_name

# %%
# Get athlete LAST names
para_info = para_doc.find_all('tr')
last_names = []

for name in full_name:
    last_names.append(re.findall(r'([A-Z]+[ -]?[A-Z]{2,}).*', name)[0])

# last_names

# %%
# Get athlete FIRST names
para_info = para_doc.find_all('tr')
first_names = []

for name in full_name:
    first_names.append(re.findall(r'[A-Z]+ (.*)', name)[0])
    
# first_names

# %% [markdown]
# ### Get citizenship (country code) of paralympic athletes

# %%
# Get citizenships of paralympic athletes

para_info = para_doc.find_all('tr')
para_citizenship = []

for athlete in para_info:
    try:
        citizenship = athlete.find_all('td')[3]
        no_citizenship = len(citizenship.find_all('a'))    
        if no_citizenship == 1:
            para_citizenship.append(citizenship.text)

    ## Check for multinationals
        elif no_citizenship == 2:
            multi = []
            multi.append(citizenship.text[:3])
            multi.append(citizenship.text[3:])
            para_citizenship.append(multi)
        else:
            print('Not single or dual citizenship, or there is some other problem')
    except:
        pass
    
# para_citizenship

# %% [markdown]
# ### Get the year/s during which the paralympic medallists competed

# %%
para_info = para_doc.find_all('tr')

years_dict = {}
years = []
for athlete in para_info:
    try:
        year = athlete.find_all('td')[4].string
        years.append(year)
    except:
        pass
# years
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-efbf1044495f> in <module>
# ----> 1 para_info = para_doc.find_all('tr')
#       2
#       3 years_dict = {}
#       4 years = []
#       5 for athlete in para_info:
#
# NameError: name 'para_doc' is not defined

# %% [markdown]
# ### Get total number of medals for paralympic athletes

# %%
para_info = para_doc.find_all('tr')
medals_total = []

for athlete in para_info:
    try:
        medals_total.append(athlete.find_all('td')[8].text)
    except:
        pass

# medals_total

# %% [markdown]
# ### Gold medals for paralympic athletes

# %%
para_info = para_doc.find_all('tr')
medals_gold = []

for athlete in para_info:
    try:
        medals_gold.append(athlete.find_all('td')[5].text)
    except:
        pass

# medals_gold

# %% [markdown]
# ### Silver medals for paralympic athletes

# %%
para_info = para_doc.find_all('tr')
medals_silver = []

for athlete in para_info:
    try:
        medals_silver.append(athlete.find_all('td')[6].text)
    except:
        pass

# medals_silver

# %% [markdown]
# ### Bronze medals for paralympic athletes

# %%
para_info = para_doc.find_all('tr')
medals_bronze = []

for athlete in para_info:
    try:
        medals_bronze.append(athlete.find_all('td')[7].text)
    except:
        pass

# medals_bronze

# %% [markdown]
# ### Assign gender for para athletes

# %%
para_info = para_doc.find_all('tr')
gender = []

for athlete in para_info:
    try:
        gender.append(athlete.find_previous('h2').text.strip())
    except:
        pass

# gender

# %% [markdown]
# ### Put all para info into one list of dictionaries, then into a dataframe

# %%
para_info = para_doc.find_all('tr')
rows = []

for athlete in para_info:
    row = {}
    try:
        full_name = athlete.find_all('td')[1].string
        row['full_name'] = full_name
        row['last_name'] = re.findall(r'([A-Z]+[ -]?[A-Z]{2,}).*', full_name)[0]
        row['first_name'] = re.findall(r'[A-Z]+ (.*)', full_name)[0]
        
        row['medals_total'] = athlete.find_all('td')[8].text.strip()
        row['medals_gold'] = athlete.find_all('td')[5].text.strip()
        row['medals_silver'] = athlete.find_all('td')[6].text.strip()
        row['medals_bronze'] = athlete.find_all('td')[7].text.strip()
        
        row['gender'] = athlete.find_previous('h2').text.strip()
        row['other_info'] = ''
        row['alternate_name'] = ''
        
        years = athlete.find_all('td')[4].string
        row['years'] = years

        citizenship = athlete.find_all('td')[3]
        no_citizenship = len(citizenship.find_all('a'))    
        if no_citizenship == 1:
            row['citizenship'] = citizenship.text.strip()

    ## Check for multinationals
        elif no_citizenship == 2:
            if 'NPA' in citizenship.text.strip():
                row['citizenship'] = citizenship.text[:3]
            elif 'CZE' in citizenship.text.strip():
                row['citizenship'] = citizenship.text[:3]
            elif 'GER' in citizenship.text.strip():
                row['citizenship'] = citizenship.text[:3]
        else:
            row['citizenship'] = 'Not single or dual citizenship, or there is some other problem'
    except:
        pass
    rows.append(row)

rows
# Out:
# [{},
#  {'full_name': 'SCHOENFELDER Gerd',
#   'last_name': 'SCHOENFELDER',
#   'first_name': 'Gerd',
#   'medals_total': '22',
#   'medals_gold': '16',
#   'medals_silver': '4',
#   'medals_bronze': '2',
#   'gender': 'Men',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1992-2010',
#   'citizenship': 'GER'},
#  {'full_name': 'LUNDSTROEM Knut',
#   'last_name': 'LUNDSTROEM',
#   'first_name': 'Knut',
#   'medals_total': '21',
#   'medals_gold': '14',
#   'medals_silver': '5',
#   'medals_bronze': '2',
#   'gender': 'Men',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1988-1998',
#   'citizenship': 'NOR'},
#  {'full_name': 'HOEFLE Frank',
#   'last_name': 'HOEFLE',
#   'first_name': 'Frank',
#   'medals_total': '21',
#   'medals_gold': '13',
#   'medals_silver': '5',
#   'medals_bronze': '3',
#   'gender': 'Men',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1988-2006',
#   'citizenship': 'FRG'},
#  {'full_name': 'MCKEEVER Brian',
#   'last_name': 'MCKEEVER',
#   'first_name': 'Brian',
#   'medals_total': '17',
#   'medals_gold': '13',
#   'medals_silver': '2',
#   'medals_bronze': '2',
#   'gender': 'Men',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '2002-2018',
#   'citizenship': 'CAN'},
#  {'full_name': 'HEINZMANN Rolf',
#   'last_name': 'HEINZMANN',
#   'first_name': 'Rolf',
#   'medals_total': '14',
#   'medals_gold': '12',
#   'medals_silver': '2',
#   'medals_bronze': '0',
#   'gender': 'Men',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1980-2002',
#   'citizenship': 'SUI'},
#  {'full_name': 'GRIP Jouko',
#   'last_name': 'GRIP',
#   'first_name': 'Jouko',
#   'medals_total': '15',
#   'medals_gold': '10',
#   'medals_silver': '5',
#   'medals_bronze': '0',
#   'gender': 'Men',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1980-1994',
#   'citizenship': 'FIN'},
#  {'full_name': 'LOEVAAS Terje',
#   'last_name': 'LOEVAAS',
#   'first_name': 'Terje',
#   'medals_total': '13',
#   'medals_gold': '10',
#   'medals_silver': '3',
#   'medals_bronze': '0',
#   'gender': 'Men',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1980-1994',
#   'citizenship': 'NOR'},
#  {'full_name': 'BRAXENTHALER Martin',
#   'last_name': 'BRAXENTHALER',
#   'first_name': 'Martin',
#   'medals_total': '12',
#   'medals_gold': '10',
#   'medals_silver': '1',
#   'medals_bronze': '1',
#   'gender': 'Men',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1998-2010',
#   'citizenship': 'GER'},
#  {'full_name': 'AALIEN Hans Anton',
#   'last_name': 'AALIEN',
#   'first_name': 'Hans Anton',
#   'medals_total': '9',
#   'medals_gold': '7',
#   'medals_silver': '1',
#   'medals_bronze': '1',
#   'gender': 'Men',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1980-1988',
#   'citizenship': 'NOR'},
#  {'full_name': 'PEDERSEN Cato Zahl',
#   'last_name': 'PEDERSEN',
#   'first_name': 'Cato Zahl',
#   'medals_total': '8',
#   'medals_gold': '7',
#   'medals_silver': '1',
#   'medals_bronze': '0',
#   'gender': 'Men',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1980-1994',
#   'citizenship': 'NOR'},
#  {'full_name': 'SANDBRAATEN Erik',
#   'last_name': 'SANDBRAATEN',
#   'first_name': 'Erik',
#   'medals_total': '18',
#   'medals_gold': '6',
#   'medals_silver': '7',
#   'medals_bronze': '5',
#   'gender': 'Men',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1980-2002',
#   'citizenship': 'NOR'},
#  {'full_name': 'BURN Hans',
#   'last_name': 'BURN',
#   'first_name': 'Hans',
#   'medals_total': '14',
#   'medals_gold': '6',
#   'medals_silver': '5',
#   'medals_bronze': '3',
#   'gender': 'Men',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1988-2002',
#   'citizenship': 'SUI'},
#  {'full_name': 'SANKILAMPI Pertti',
#   'last_name': 'SANKILAMPI',
#   'first_name': 'Pertti',
#   'medals_total': '12',
#   'medals_gold': '6',
#   'medals_silver': '4',
#   'medals_bronze': '2',
#   'gender': 'Men',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1976-1988',
#   'citizenship': 'FIN'},
#  {'full_name': 'MANNINO Greg',
#   'last_name': 'MANNINO',
#   'first_name': 'Greg',
#   'medals_total': '12',
#   'medals_gold': '6',
#   'medals_silver': '4',
#   'medals_bronze': '2',
#   'gender': 'Men',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1988-1998',
#   'citizenship': 'USA'},
#  {'full_name': 'BAUDEAN Bernard',
#   'last_name': 'BAUDEAN',
#   'first_name': 'Bernard',
#   'medals_total': '11',
#   'medals_gold': '6',
#   'medals_silver': '4',
#   'medals_bronze': '1',
#   'gender': 'Men',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1976-1994',
#   'citizenship': 'FRA'},
#  {'full_name': 'LUKYANENKO Vitaliy',
#   'last_name': 'LUKYANENKO',
#   'first_name': 'Vitaliy',
#   'medals_total': '13',
#   'medals_gold': '6',
#   'medals_silver': '3',
#   'medals_bronze': '4',
#   'gender': 'Men',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '2002-2018',
#   'citizenship': 'UKR'},
#  {'full_name': 'MILTON Michael',
#   'last_name': 'MILTON',
#   'first_name': 'Michael',
#   'medals_total': '11',
#   'medals_gold': '6',
#   'medals_silver': '3',
#   'medals_bronze': '2',
#   'gender': 'Men',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1992-2006',
#   'citizenship': 'AUS'},
#  {'full_name': 'MOURIC Tristan',
#   'last_name': 'MOURIC',
#   'first_name': 'Tristan',
#   'medals_total': '10',
#   'medals_gold': '6',
#   'medals_silver': '3',
#   'medals_bronze': '1',
#   'gender': 'Men',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1984-1994',
#   'citizenship': 'FRA'},
#  {'full_name': 'SHILOV Sergey',
#   'last_name': 'SHILOV',
#   'first_name': 'Sergey',
#   'medals_total': '10',
#   'medals_gold': '6',
#   'medals_silver': '3',
#   'medals_bronze': '1',
#   'gender': 'Men',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1998-2010',
#   'citizenship': 'RUS'},
#  {'full_name': 'KOUPTCHINSKI Valeri',
#   'last_name': 'KOUPTCHINSKI',
#   'first_name': 'Valeri',
#   'medals_total': '10',
#   'medals_gold': '6',
#   'medals_silver': '2',
#   'medals_bronze': '2',
#   'gender': 'Men',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1994-2002',
#   'citizenship': 'RUS'},
#  {},
#  {'full_name': 'MYKLEBUST Ragnhild',
#   'last_name': 'MYKLEBUST',
#   'first_name': 'Ragnhild',
#   'medals_total': '27',
#   'medals_gold': '22',
#   'medals_silver': '3',
#   'medals_bronze': '2',
#   'gender': 'Women',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1988-2002',
#   'citizenship': 'NOR'},
#  {'full_name': 'MOELLER Reinhild',
#   'last_name': 'MOELLER',
#   'first_name': 'Reinhild',
#   'medals_total': '19',
#   'medals_gold': '16',
#   'medals_silver': '2',
#   'medals_bronze': '1',
#   'gender': 'Women',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1980-2006',
#   'citizenship': 'FRG'},
#  {'full_name': 'BENTELE Verena',
#   'last_name': 'BENTELE',
#   'first_name': 'Verena',
#   'medals_total': '16',
#   'medals_gold': '12',
#   'medals_silver': '2',
#   'medals_bronze': '2',
#   'gender': 'Women',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1998-2010',
#   'citizenship': 'GER'},
#  {'full_name': 'WILL Sarah',
#   'last_name': 'WILL',
#   'first_name': 'Sarah',
#   'medals_total': '13',
#   'medals_gold': '12',
#   'medals_silver': '1',
#   'medals_bronze': '0',
#   'gender': 'Women',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1992-2002',
#   'citizenship': 'USA'},
#  {'full_name': 'MJAASUND OEJEN Brit',
#   'last_name': 'MJAASUND OEJEN',
#   'first_name': 'OEJEN Brit',
#   'medals_total': '14',
#   'medals_gold': '10',
#   'medals_silver': '3',
#   'medals_bronze': '1',
#   'gender': 'Women',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1980-1994',
#   'citizenship': 'NOR'},
#  {'full_name': 'FARKASOVA Henrieta',
#   'last_name': 'FARKASOVA',
#   'first_name': 'Henrieta',
#   'medals_total': '12',
#   'medals_gold': '9',
#   'medals_silver': '2',
#   'medals_bronze': '1',
#   'gender': 'Women',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '2010-2018',
#   'citizenship': 'SVK'},
#  {'full_name': 'WOOLSTENCROFT Lauren',
#   'last_name': 'WOOLSTENCROFT',
#   'first_name': 'Lauren',
#   'medals_total': '10',
#   'medals_gold': '8',
#   'medals_silver': '1',
#   'medals_bronze': '1',
#   'gender': 'Women',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '2002-2010',
#   'citizenship': 'CAN'},
#  {'full_name': 'BOCHET Marie',
#   'last_name': 'BOCHET',
#   'first_name': 'Marie',
#   'medals_total': '8',
#   'medals_gold': '8',
#   'medals_silver': '0',
#   'medals_bronze': '0',
#   'gender': 'Women',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '2014-2018',
#   'citizenship': 'FRA'},
#  {'full_name': 'MILENINA Anna',
#   'last_name': 'MILENINA',
#   'first_name': 'Anna',
#   'medals_total': '17',
#   'medals_gold': '7',
#   'medals_silver': '8',
#   'medals_bronze': '2',
#   'gender': 'Women',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '2006-2018',
#   'citizenship': 'NPA'},
#  {'full_name': 'BILLMEIER Sarah',
#   'last_name': 'BILLMEIER',
#   'first_name': 'Sarah',
#   'medals_total': '13',
#   'medals_gold': '7',
#   'medals_silver': '5',
#   'medals_bronze': '1',
#   'gender': 'Women',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1992-2002',
#   'citizenship': 'USA'},
#  {'full_name': 'SCHAFFELHUBER Anna',
#   'last_name': 'SCHAFFELHUBER',
#   'first_name': 'Anna',
#   'medals_total': '9',
#   'medals_gold': '7',
#   'medals_silver': '1',
#   'medals_bronze': '1',
#   'gender': 'Women',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '2010-2018',
#   'citizenship': 'GER'},
#  {'full_name': 'GUSTAFSON Nancy',
#   'last_name': 'GUSTAFSON',
#   'first_name': 'Nancy',
#   'medals_total': '8',
#   'medals_gold': '7',
#   'medals_silver': '1',
#   'medals_bronze': '0',
#   'gender': 'Women',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1988-1994',
#   'citizenship': 'USA'},
#  {'full_name': 'LYSOVA Mikhalina',
#   'last_name': 'LYSOVA',
#   'first_name': 'Mikhalina',
#   'medals_total': '17',
#   'medals_gold': '6',
#   'medals_silver': '8',
#   'medals_bronze': '3',
#   'gender': 'Women',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '2010-2018',
#   'citizenship': 'NPA'},
#  {'full_name': 'TERVONEN Tanja',
#   'last_name': 'TERVONEN',
#   'first_name': 'Tanja',
#   'medals_total': '7',
#   'medals_gold': '6',
#   'medals_silver': '1',
#   'medals_bronze': '0',
#   'gender': 'Women',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1988-1994',
#   'citizenship': 'FIN'},
#  {'full_name': 'KARI Tanja',
#   'last_name': 'KARI',
#   'first_name': 'Tanja',
#   'medals_total': '7',
#   'medals_gold': '6',
#   'medals_silver': '0',
#   'medals_bronze': '1',
#   'gender': 'Women',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1998-2002',
#   'citizenship': 'FIN'},
#  {'full_name': 'SUND Birgitta',
#   'last_name': 'SUND',
#   'first_name': 'Birgitta',
#   'medals_total': '6',
#   'medals_gold': '6',
#   'medals_silver': '0',
#   'medals_bronze': '0',
#   'gender': 'Women',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1976-1980',
#   'citizenship': 'SWE'},
#  {'full_name': 'IURKOVSKA Olena',
#   'last_name': 'IURKOVSKA',
#   'first_name': 'Olena',
#   'medals_total': '18',
#   'medals_gold': '5',
#   'medals_silver': '6',
#   'medals_bronze': '7',
#   'gender': 'Women',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '2002-2014',
#   'citizenship': 'UKR'},
#  {'full_name': 'TEPLA Katerina',
#   'last_name': 'TEPLA',
#   'first_name': 'Katerina',
#   'medals_total': '9',
#   'medals_gold': '5',
#   'medals_silver': '4',
#   'medals_bronze': '0',
#   'gender': 'Women',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1992-2002',
#   'citizenship': 'CZE'},
#  {'full_name': 'SCHNEIDER Annemie',
#   'last_name': 'SCHNEIDER',
#   'first_name': 'Annemie',
#   'medals_total': '8',
#   'medals_gold': '5',
#   'medals_silver': '1',
#   'medals_bronze': '2',
#   'gender': 'Women',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1976-1994',
#   'citizenship': 'FRG'},
#  {'full_name': 'HASLACHER Danja',
#   'last_name': 'HASLACHER',
#   'first_name': 'Danja',
#   'medals_total': '6',
#   'medals_gold': '5',
#   'medals_silver': '0',
#   'medals_bronze': '1',
#   'gender': 'Women',
#   'other_info': '',
#   'alternate_name': '',
#   'years': '1998-2006',
#   'citizenship': 'AUT'}]

# %%
# Remove empty rows
rows = list(filter(None,rows))

# %%
df_winter = pd.DataFrame(rows)
df_winter
# Out:
#    alternate_name citizenship  first_name             full_name gender  \
# 0                         GER        Gerd     SCHOENFELDER Gerd    Men
# 1                         NOR        Knut       LUNDSTROEM Knut    Men
# 2                         FRG       Frank          HOEFLE Frank    Men
# 3                         CAN       Brian        MCKEEVER Brian    Men
# 4                         SUI        Rolf        HEINZMANN Rolf    Men
# 5                         FIN       Jouko            GRIP Jouko    Men
# 6                         NOR       Terje         LOEVAAS Terje    Men
# 7                         GER      Martin   BRAXENTHALER Martin    Men
# 8                         NOR  Hans Anton     AALIEN Hans Anton    Men
# 9                         NOR   Cato Zahl    PEDERSEN Cato Zahl    Men
# 10                        NOR        Erik      SANDBRAATEN Erik    Men
# 11                        SUI        Hans             BURN Hans    Men
# 12                        FIN      Pertti     SANKILAMPI Pertti    Men
# 13                        USA        Greg          MANNINO Greg    Men
# 14                        FRA     Bernard       BAUDEAN Bernard    Men
# 15                        UKR     Vitaliy    LUKYANENKO Vitaliy    Men
# 16                        AUS     Michael        MILTON Michael    Men
# 17                        FRA     Tristan        MOURIC Tristan    Men
# 18                        RUS      Sergey         SHILOV Sergey    Men
# 19                        RUS      Valeri   KOUPTCHINSKI Valeri    Men
# 20                        NOR    Ragnhild    MYKLEBUST Ragnhild  Women
# 21                        FRG    Reinhild      MOELLER Reinhild  Women
# 22                        GER      Verena        BENTELE Verena  Women
# 23                        USA       Sarah            WILL Sarah  Women
# 24                        NOR  OEJEN Brit   MJAASUND OEJEN Brit  Women
# 25                        SVK    Henrieta    FARKASOVA Henrieta  Women
# 26                        CAN      Lauren  WOOLSTENCROFT Lauren  Women
# 27                        FRA       Marie          BOCHET Marie  Women
# 28                        NPA        Anna         MILENINA Anna  Women
# 29                        USA       Sarah       BILLMEIER Sarah  Women
# 30                        GER        Anna    SCHAFFELHUBER Anna  Women
# 31                        USA       Nancy       GUSTAFSON Nancy  Women
# 32                        NPA   Mikhalina      LYSOVA Mikhalina  Women
# 33                        FIN       Tanja        TERVONEN Tanja  Women
# 34                        FIN       Tanja            KARI Tanja  Women
# 35                        SWE    Birgitta         SUND Birgitta  Women
# 36                        UKR       Olena       IURKOVSKA Olena  Women
# 37                        CZE    Katerina        TEPLA Katerina  Women
# 38                        FRG     Annemie     SCHNEIDER Annemie  Women
# 39                        AUT       Danja       HASLACHER Danja  Women
#
#          last_name medals_bronze medals_gold medals_silver medals_total  \
# 0     SCHOENFELDER             2          16             4           22
# 1       LUNDSTROEM             2          14             5           21
# 2           HOEFLE             3          13             5           21
# 3         MCKEEVER             2          13             2           17
# 4        HEINZMANN             0          12             2           14
# 5             GRIP             0          10             5           15
# 6          LOEVAAS             0          10             3           13
# 7     BRAXENTHALER             1          10             1           12
# 8           AALIEN             1           7             1            9
# 9         PEDERSEN             0           7             1            8
# 10     SANDBRAATEN             5           6             7           18
# 11            BURN             3           6             5           14
# 12      SANKILAMPI             2           6             4           12
# 13         MANNINO             2           6             4           12
# 14         BAUDEAN             1           6             4           11
# 15      LUKYANENKO             4           6             3           13
# 16          MILTON             2           6             3           11
# 17          MOURIC             1           6             3           10
# 18          SHILOV             1           6             3           10
# 19    KOUPTCHINSKI             2           6             2           10
# 20       MYKLEBUST             2          22             3           27
# 21         MOELLER             1          16             2           19
# 22         BENTELE             2          12             2           16
# 23            WILL             0          12             1           13
# 24  MJAASUND OEJEN             1          10             3           14
# 25       FARKASOVA             1           9             2           12
# 26   WOOLSTENCROFT             1           8             1           10
# 27          BOCHET             0           8             0            8
# 28        MILENINA             2           7             8           17
# 29       BILLMEIER             1           7             5           13
# 30   SCHAFFELHUBER             1           7             1            9
# 31       GUSTAFSON             0           7             1            8
# 32          LYSOVA             3           6             8           17
# 33        TERVONEN             0           6             1            7
# 34            KARI             1           6             0            7
# 35            SUND             0           6             0            6
# 36       IURKOVSKA             7           5             6           18
# 37           TEPLA             0           5             4            9
# 38       SCHNEIDER             2           5             1            8
# 39       HASLACHER             1           5             0            6
#
#    other_info      years
# 0              1992-2010
# 1              1988-1998
# 2              1988-2006
# 3              2002-2018
# 4              1980-2002
# 5              1980-1994
# 6              1980-1994
# 7              1998-2010
# 8              1980-1988
# 9              1980-1994
# 10             1980-2002
# 11             1988-2002
# 12             1976-1988
# 13             1988-1998
# 14             1976-1994
# 15             2002-2018
# 16             1992-2006
# 17             1984-1994
# 18             1998-2010
# 19             1994-2002
# 20             1988-2002
# 21             1980-2006
# 22             1998-2010
# 23             1992-2002
# 24             1980-1994
# 25             2010-2018
# 26             2002-2010
# 27             2014-2018
# 28             2006-2018
# 29             1992-2002
# 30             2010-2018
# 31             1988-1994
# 32             2010-2018
# 33             1988-1994
# 34             1998-2002
# 35             1976-1980
# 36             2002-2014
# 37             1992-2002
# 38             1976-1994
# 39             1998-2006

# %%
df_winter.to_csv('para_winter.csv', index=False)

# %% [markdown]
# ## The sport event is missing from this website!
# * Add events for every athlete in a new text file

# %%
event = pd.read_csv('para_winter_events.txt', sep=',')
# event

# %%
merged = df_winter.merge(event, left_on='full_name', right_on='name')
merged = merged.drop(columns = 'name')

# %%
merged.tail(3)
# Out:
#    alternate_name citizenship first_name          full_name gender  last_name  \
# 36                        CZE   Katerina     TEPLA Katerina  Women      TEPLA
# 37                        FRG    Annemie  SCHNEIDER Annemie  Women  SCHNEIDER
# 38                        AUT      Danja    HASLACHER Danja  Women  HASLACHER
#
#    medals_bronze medals_gold medals_silver medals_total other_info      years  \
# 36             0           5             4            9             1992-2002
# 37             2           5             1            8             1976-1994
# 38             1           5             0            6             1998-2006
#
#                  event
# 36  Para alpine skiing
# 37  Para alpine skiing
# 38  Para alpine skiing

# %%
merged['game_type'] = 'Paralympic'
merged['season'] = 'Winter'

# %% [markdown]
# ## Clean full_name for Paralympic athletes so that it's formatted as first_name LAST_NAME

# %%
merged['full_name'] = merged.first_name + ' ' + merged.last_name
merged
# Out:
#    alternate_name citizenship  first_name             full_name gender  \
# 0                         GER        Gerd     Gerd SCHOENFELDER    Men
# 1                         NOR        Knut       Knut LUNDSTROEM    Men
# 2                         FRG       Frank          Frank HOEFLE    Men
# 3                         CAN       Brian        Brian MCKEEVER    Men
# 4                         SUI        Rolf        Rolf HEINZMANN    Men
# 5                         FIN       Jouko            Jouko GRIP    Men
# 6                         NOR       Terje         Terje LOEVAAS    Men
# 7                         GER      Martin   Martin BRAXENTHALER    Men
# 8                         NOR  Hans Anton     Hans Anton AALIEN    Men
# 9                         NOR   Cato Zahl    Cato Zahl PEDERSEN    Men
# 10                        NOR        Erik      Erik SANDBRAATEN    Men
# 11                        SUI        Hans             Hans BURN    Men
# 12                        FIN      Pertti     Pertti SANKILAMPI    Men
# 13                        USA        Greg          Greg MANNINO    Men
# 14                        FRA     Bernard       Bernard BAUDEAN    Men
# 15                        UKR     Vitaliy    Vitaliy LUKYANENKO    Men
# 16                        AUS     Michael        Michael MILTON    Men
# 17                        FRA     Tristan        Tristan MOURIC    Men
# 18                        RUS      Sergey         Sergey SHILOV    Men
# 19                        RUS      Valeri   Valeri KOUPTCHINSKI    Men
# 20                        NOR    Ragnhild    Ragnhild MYKLEBUST  Women
# 21                        FRG    Reinhild      Reinhild MOELLER  Women
# 22                        GER      Verena        Verena BENTELE  Women
# 23                        USA       Sarah            Sarah WILL  Women
# 24                        SVK    Henrieta    Henrieta FARKASOVA  Women
# 25                        CAN      Lauren  Lauren WOOLSTENCROFT  Women
# 26                        FRA       Marie          Marie BOCHET  Women
# 27                        NPA        Anna         Anna MILENINA  Women
# 28                        USA       Sarah       Sarah BILLMEIER  Women
# 29                        GER        Anna    Anna SCHAFFELHUBER  Women
# 30                        USA       Nancy       Nancy GUSTAFSON  Women
# 31                        NPA   Mikhalina      Mikhalina LYSOVA  Women
# 32                        FIN       Tanja        Tanja TERVONEN  Women
# 33                        FIN       Tanja            Tanja KARI  Women
# 34                        SWE    Birgitta         Birgitta SUND  Women
# 35                        UKR       Olena       Olena IURKOVSKA  Women
# 36                        CZE    Katerina        Katerina TEPLA  Women
# 37                        FRG     Annemie     Annemie SCHNEIDER  Women
# 38                        AUT       Danja       Danja HASLACHER  Women
#
#         last_name medals_bronze medals_gold medals_silver medals_total  \
# 0    SCHOENFELDER             2          16             4           22
# 1      LUNDSTROEM             2          14             5           21
# 2          HOEFLE             3          13             5           21
# 3        MCKEEVER             2          13             2           17
# 4       HEINZMANN             0          12             2           14
# 5            GRIP             0          10             5           15
# 6         LOEVAAS             0          10             3           13
# 7    BRAXENTHALER             1          10             1           12
# 8          AALIEN             1           7             1            9
# 9        PEDERSEN             0           7             1            8
# 10    SANDBRAATEN             5           6             7           18
# 11           BURN             3           6             5           14
# 12     SANKILAMPI             2           6             4           12
# 13        MANNINO             2           6             4           12
# 14        BAUDEAN             1           6             4           11
# 15     LUKYANENKO             4           6             3           13
# 16         MILTON             2           6             3           11
# 17         MOURIC             1           6             3           10
# 18         SHILOV             1           6             3           10
# 19   KOUPTCHINSKI             2           6             2           10
# 20      MYKLEBUST             2          22             3           27
# 21        MOELLER             1          16             2           19
# 22        BENTELE             2          12             2           16
# 23           WILL             0          12             1           13
# 24      FARKASOVA             1           9             2           12
# 25  WOOLSTENCROFT             1           8             1           10
# 26         BOCHET             0           8             0            8
# 27       MILENINA             2           7             8           17
# 28      BILLMEIER             1           7             5           13
# 29  SCHAFFELHUBER             1           7             1            9
# 30      GUSTAFSON             0           7             1            8
# 31         LYSOVA             3           6             8           17
# 32       TERVONEN             0           6             1            7
# 33           KARI             1           6             0            7
# 34           SUND             0           6             0            6
# 35      IURKOVSKA             7           5             6           18
# 36          TEPLA             0           5             4            9
# 37      SCHNEIDER             2           5             1            8
# 38      HASLACHER             1           5             0            6
#
#    other_info      years                                              event  \
# 0              1992-2010                                 Para alpine skiing
# 1              1988-1998  Para cross-country skiing | ice sledge speed r...
# 2              1988-2006  Para biathlon | cross-country skiing | cycling...
# 3              2002-2018              Para biathlon | cross-country skiing
# 4              1980-2002                                 Para alpine skiing
# 5              1980-1994  Para biathlon | cross-country skiing | athleti...
# 6              1980-1994                          Para cross-country skiing
# 7              1998-2010                                Para alpine skiing
# 8              1980-1988  Para cross-country skiing | swimming (Summer O...
# 9              1980-1994  Para alpine skiing | cross-country skiing | at...
# 10             1980-2002  Para ice sledge speed racing | cross-country s...
# 11             1988-2002                                 Para alpine skiing
# 12             1976-1988                          Para cross-country skiing
# 13             1988-1998                                 Para alpine skiing
# 14             1976-1994                                 Para alpine skiing
# 15             2002-2018               Para biathlon | cross-country skiing
# 16             1992-2006                       Para alpine skiing | cycling
# 17             1984-1994                                 Para alpine skiing
# 18             1998-2010                          Para cross-country skiing
# 19             1994-2002                          Para cross-country skiing
# 20             1988-2002  Para biathlon | cross-country skiing | ice sle...
# 21             1980-2006               Para biathlon | cross-country skiing
# 22             1998-2010                                 Para alpine skiing
# 23             1992-2002                                 Para alpine skiing
# 24             2010-2018                                 Para alpine skiing
# 25             2002-2010                                 Para alpine skiing
# 26             2014-2018                                 Para alpine skiing
# 27             2006-2018               Para biathlon | cross-country skiing
# 28             1992-2002                                 Para alpine skiing
# 29             2010-2018                                 Para alpine skiing
# 30             1988-1994                                 Para alpine skiing
# 31             2010-2018               Para biathlon | cross-country skiing
# 32             1988-1994                          Para cross-country skiing
# 33             1998-2002                          Para cross-country skiing
# 34             1976-1980                          Para cross-country skiing
# 35             2002-2014               Para biathlon | cross-country skiing
# 36             1992-2002                                 Para alpine skiing
# 37             1976-1994                                 Para alpine skiing
# 38             1998-2006                                 Para alpine skiing
#
#      game_type  season
# 0   Paralympic  Winter
# 1   Paralympic  Winter
# 2   Paralympic  Winter
# 3   Paralympic  Winter
# 4   Paralympic  Winter
# 5   Paralympic  Winter
# 6   Paralympic  Winter
# 7   Paralympic  Winter
# 8   Paralympic  Winter
# 9   Paralympic  Winter
# 10  Paralympic  Winter
# 11  Paralympic  Winter
# 12  Paralympic  Winter
# 13  Paralympic  Winter
# 14  Paralympic  Winter
# 15  Paralympic  Winter
# 16  Paralympic  Winter
# 17  Paralympic  Winter
# 18  Paralympic  Winter
# 19  Paralympic  Winter
# 20  Paralympic  Winter
# 21  Paralympic  Winter
# 22  Paralympic  Winter
# 23  Paralympic  Winter
# 24  Paralympic  Winter
# 25  Paralympic  Winter
# 26  Paralympic  Winter
# 27  Paralympic  Winter
# 28  Paralympic  Winter
# 29  Paralympic  Winter
# 30  Paralympic  Winter
# 31  Paralympic  Winter
# 32  Paralympic  Winter
# 33  Paralympic  Winter
# 34  Paralympic  Winter
# 35  Paralympic  Winter
# 36  Paralympic  Winter
# 37  Paralympic  Winter
# 38  Paralympic  Winter

# %%
merged.to_csv('para_winter_complete.csv', index=False)
