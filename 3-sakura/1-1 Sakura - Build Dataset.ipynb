# %% [markdown]
# # Build dataset

# %% [markdown]
# start date:
# https://www.data.jma.go.jp/sakura/data/sakura003_06.html
#
# full bloom:
# https://www.data.jma.go.jp/sakura/data/sakura004_06.html
#
# temp data:
# March temp data?
#
# http://www.st.nanzan-u.ac.jp/info/gr-thesis/ms/2007/03mm081.pdf
#
# https://www.economist.com/graphic-detail/2017/04/07/japans-cherry-blossoms-are-emerging-increasingly-early

# %%
import pandas as pd
import re
import numpy as np

import math
import statistics

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.rcParams['pdf.fonttype'] = 42

# %matplotlib inline

pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 1000)

# %% [markdown]
# # Clean the table romth JMA agency in text edtior.
#
# Merge the dataframes so I have one for the start date of sakura blossoms, and one for the full bloom

# %%
start1 = pd.read_csv('sakura-start-2001-2010.csv', dtype=object)
start1.shape
# Out:
# (102, 13)

# %%
start2 = pd.read_csv('sakura-start-2011-2019.csv', dtype=object)
start2.shape
# Out:
# (58, 12)

# %%
start = start2.merge(start1, how='left', on='loc')
start
# Out:
#      loc         2011         2012  2013  2014  2015  2016  2017  2018  2019  \
# 0     稚内         0519         0514  0526  0511  0503  0513  0509  0512  0507
# 1     旭川         0509          052  0518  0502  0427  0503   053  0430  0501
# 2     網走         0516         0503  0525  0507  0430  0508   055  0502   055
# 3     札幌         0507          051  0513  0429  0422  0425  0428  0426  0424
# 4     帯広         0503          055  0510  0427  0426  0430  0501  0427  0428
# 5     釧路         0518         0517  0523  0512  0506  0510  0514  0512  0509
# 6     室蘭         0506          059  0516  0429  0428  0425  0502  0429  0429
# 7     函館         0502          052  0508  0428  0421  0424  0427  0425  0424
# 8     青森         0425         0429  0429  0422  0414  0417  0417  0419  0418
# 9     秋田         0423         0424  0423  0420  0411  0414  0416  0417  0416
# 10    盛岡         0420         0424  0423  0413  0409  0411  0417  0417  0418
# 11    山形         0418         0423  0415  0414  0410  0406  0414  0404  0412
# 12    仙台         0412         0418  0409   047  0403   041  0407  0330  0405
# 13    福島         0412         0416  0405   048  0402  0330  0408  0329  0405
# 14    新潟         0414         0416  0407   047  0402   043  0408   043  0405
# 15    金沢         0407         0410  0330  0401  0331  0330  0404  0329  0401
# 16    富山         0408         0412  0329  0402   041  0329  0405  0327  0328
# 17    長野         0415         0418  0406  0411  0404   043  0414  0402  0413
# 18   宇都宮         0406          048  0321  0329  0330  0328  0403  0326  0328
# 19    福井         0407         0410  0328  0331  0331  0327  0405  0329  0328
# 20    前橋         0403          048  0322  0329  0328  0323  0402  0325  0327
# 21    熊谷         0401          044  0319  0328  0327  0323  0328  0322  0325
# 22    水戸         0406          046  0321  0329  0330  0328  0403  0325  0327
# 23    岐阜         0328         0330  0321  0324  0323  0320  0328  0319  0322
# 24   名古屋         0327         0330  0319  0324  0321  0319  0328  0319  0322
# 25    甲府         0329         0401  0319  0328  0325  0323  0330  0323  0327
# 26    銚子         0404          042  0321  0329  0330  0401   041  0320  0325
# 27     津         0401          044  0325  0327  0329  0328  0403  0326  0328
# 28    静岡         0320         0324  0317  0324  0322  0327  0402  0318  0328
...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#    not_someino_yoshino_y
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17                   NaN
# 18                   NaN
# 19                   NaN
# 20                   NaN
# 21                   NaN
# 22                   NaN
# 23                   NaN
# 24                   NaN
# 25                   NaN
# 26                   NaN
# 27                   NaN
# 28                   NaN
# 29                   NaN
# 30                   NaN
# 31                   NaN
# 32                   NaN
# 33                   NaN
# 34                   NaN
# 35                   NaN
# 36                   NaN
# 37                   NaN
# 38                   NaN
# 39                   NaN
# 40                   NaN
# 41                   NaN
# 42                   NaN
# 43                   NaN
# 44                   NaN
# 45                   NaN
# 46                   NaN
# 47                   NaN
# 48                   NaN
# 49                   NaN
# 50                   NaN
# 51                   NaN
# 52                   NaN
# 53                   NaN
# 54                   NaN
# 55                   NaN
# 56                   NaN
# 57                   NaN
#
# [58 rows x 24 columns]

# %%
start.shape
# Out:
# (58, 24)

# %%
full_1 = pd.read_csv('sakura-full-2001-2010_corected.csv', dtype=object)
full_1.shape
# Out:
# (102, 13)

# %%
full_2 = pd.read_csv('sakura-full-2011-2019.csv', dtype=object)
full_2.shape
# Out:
# (58, 12)

# %%
full = full_2.merge(full_1, how='left', on='loc')

# %%
start = start.drop(columns=['not_someino_yoshino_x', 'not_someino_yoshino_y', 'avg_y', 'avg_x'])
start.head(1)

# %%
full = full.drop(columns=['not_someino_yoshino_x', 'not_someino_yoshino_y', 'avg_y', 'avg_x'])
full.head(1)

# %%
full.to_csv('full.csv', index=False)
start.to_csv('start.csv', index=False)

# %%
start.shape
# Out:
# (58, 20)

# %% [markdown]
# # Scrape coordinates and English name of cities from Google

# %%
from bs4 import BeautifulSoup
import requests

# %%
names = pd.read_csv('data/location-name.csv')
cities = list(names['loc'])

# %% [markdown]
# ## Try scraping the city name in English & coordinates for one city

# %%
city = cities[10]

url = f'https://www.google.com/search?q={city}座標'
response = requests.get(url)
doc = BeautifulSoup(response.text)

city_eng = doc.find(class_='BNeawe').text.strip()
coord = doc.find(class_='BNeawe iBp4i AP7Wnd').text.strip()
print(city_eng)
print(coord)
# Out:
# Morioka
# 39.7020° N, 141.1543° E

# %% [markdown]
# ## Scrape city name (English) and corodinates for all cities

# %%
rows = []
errors = []

for city in cities:
    row = {}
    error = {}
    try:
        url = f'https://www.google.com/search?q={city}座標'
        response = requests.get(url)
        doc = BeautifulSoup(response.text)
        row['city'] = city
        row['city_eng'] = doc.find(class_='BNeawe').text.strip()
        row['coord'] = doc.find(class_='BNeawe iBp4i AP7Wnd').text.strip()
        rows.append(row)
    except:
        error['city'] = city
        error['city_eng'] = 'ERROR'
        error['coord'] = 'ERROR'
        print(city)
        errors.append(error)
# Out:
# 津
# 松江
# 名瀬

# %%
# Manually plug in numbers for these ones
errors
# Out:
# [{'city': '津', 'city_eng': 'ERROR', 'coord': 'ERROR'},
#  {'city': '松江', 'city_eng': 'ERROR', 'coord': 'ERROR'},
#  {'city': '名瀬', 'city_eng': 'ERROR', 'coord': 'ERROR'}]

# %% [markdown]
# ## Add the three missing data points & clean up coordiantes in text editor
#
# * Break up coords into lat/long and clean up
# * add data points

# %%
df = pd.DataFrame(rows)
df.to_csv('city-eng-coord.csv', index=False)

# %%
temp3 = pd.read_csv('data/temp3-cleaned.csv')
temp3.head(5)
# Out:
#         稚内_temp       稚内     稚内.1  旭川_temp       旭川     旭川.1  網走_temp  \
# 年月      平均気温(℃)  平均気温(℃)  平均気温(℃)  平均気温(℃)  平均気温(℃)  平均気温(℃)  平均気温(℃)
# 2001/3     -2.4        8        1     -2.9        8        1     -3.0
# 2001/4      4.7        8        1      6.1        8        1      6.2
# 2002/3      0.5        8        1      0.0        8        1     -0.3
# 2002/4      6.8        8        1      8.5        8        1      6.9
#
#              網走     網走.1  札幌_temp  ...     那覇.1   津_temp        津      津.1  \
# 年月      平均気温(℃)  平均気温(℃)  平均気温(℃)  ...  平均気温(℃)  平均気温(℃)  平均気温(℃)  平均気温(℃)
# 2001/3        8        1      0.2  ...        1      8.5        8        1
# 2001/4        8        1      8.3  ...        1     14.0        8        1
# 2002/3        8        1      2.5  ...        1     10.5        8        1
# 2002/4        8        1      9.6  ...        1     15.3        8        1
#
#         名瀬_temp       名瀬     名瀬.1  松江_temp       松江     松江.1
# 年月      平均気温(℃)  平均気温(℃)  平均気温(℃)  平均気温(℃)  平均気温(℃)  平均気温(℃)
# 2001/3     16.2        8        1      7.7        8        1
# 2001/4     19.7        8        1     13.2        8        1
# 2002/3     17.8        8        1      9.6        8        1
# 2002/4     20.6        8        1     14.7        8        1
#
# [5 rows x 174 columns]

# %%
cols = list(temp3.columns)
cols_cleaned = []
cols_drop = []

for col in cols:
    if '_temp' in col:
        cols_cleaned.append(col)
    else:
        cols_drop.append(col)
        
temp3 = temp3.drop(columns=cols_drop)
temp = temp3[1:]

# %% [markdown]
# ## Transpose the dataframe so that cities are rows, and dates are columns

# %%
temp_transposed = temp.T
temp_clean = temp_transposed.loc[:,'2001/3'::2]

# %%
temp_clean.to_csv('temp_cleaned.csv', index=False)

# %% [markdown]
# ## Clean up:
#
# * Add city names to temp_cleaned.csv so I can merge on the city names
# * Edit column names in full & start csv >> 2001_start, 2001_full, etc in text editor
# * Add year to every date so it's formatted 2001-01-01

# %%
temp_index = list(temp_clean.index)
index_clean = []

for city in temp_index:
    city = city.split('_')[0]
    index_clean.append(city)

# %%
temp_clean['city'] = index_clean
# Out:
# /Users/minami/.pyenv/versions/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Re-import the manually edited csv

# %%
start = pd.read_csv('data/start_cleaned.csv', dtype=object)
full = pd.read_csv('data/full_cleaned.csv', dtype=object)

# %%
temp_clean.shape
# Out:
# (58, 20)

# %%
start.shape
# Out:
# (58, 20)

# %%
full.shape
# Out:
# (58, 20)

# %% [markdown]
# ## Merge dataframes

# %%
merged = start.merge(full, on='loc')
merged.head(5)
# Out:
#   loc 2011_start 2012_start 2013_start 2014_start 2015_start 2016_start  \
# 0  稚内       0519       0514       0526       0511       0503       0513
# 1  旭川       0509        052       0518       0502       0427       0503
# 2  網走       0516       0503       0525       0507       0430       0508
# 3  札幌       0507        051       0513       0429       0422       0425
# 4  帯広       0503        055       0510       0427       0426       0430
#
#   2017_start 2018_start 2019_start  ... 2001_full 2002_full 2003_full  \
# 0       0509       0512       0507  ...      0519      0502      0514
# 1        053       0430       0501  ...      0507      0425      0504
# 2        055       0502        055  ...      0513      0501      0512
# 3       0428       0426       0424  ...      0505      0425      0504
# 4       0501       0427       0428  ...      0501      0427      0503
#
#   2004_full 2005_full 2006_full 2007_full 2008_full 2009_full 2010_full
# 0      0512      0528      0520      0517      0505      0512      0525
# 1      0509      0517      0512      0508      0426      0504      0513
# 2      0513      0525      0517      0516      0505      0507      0518
# 3      0509      0516      0512      0508      0425      0504      0514
# 4      0508      0510      0512      0508      0430      0504      0511
#
# [5 rows x 39 columns]

# %%
merged = merged.merge(temp_clean, left_on='loc', right_on='city')
merged.head(3)
# Out:
#   loc 2011_start 2012_start 2013_start 2014_start 2015_start 2016_start  \
# 0  稚内       0519       0514       0526       0511       0503       0513
# 1  旭川       0509        052       0518       0502       0427       0503
# 2  網走       0516       0503       0525       0507       0430       0508
#
#   2017_start 2018_start 2019_start  ... 2011/3 2012/3 2013/3 2014/3 2015/3  \
# 0       0509       0512       0507  ...   -0.6   -2.4   -1.3   -1.2    2.3
# 1        053       0430       0501  ...   -2.1   -2.8   -2.1   -2.2    1.7
# 2        055       0502        055  ...   -1.3   -2.3   -1.6   -1.8    1.5
#
#   2016/3 2017/3 2018/3 2019/3 city
# 0    0.5   -0.4    0.1    0.1   稚内
# 1   -0.6   -1.2   -0.1   -0.5   旭川
# 2   -0.4   -1.5    0.3   -0.7   網走
#
# [3 rows x 59 columns]

# %%
coord = pd.read_csv('data/city-eng-coord-cleaned.csv')
coord.head(1)
# Out:
#   city  city_eng  latitude  longitude
# 0   稚内  Wakkanai   45.4156   141.6734

# %%
merged = merged.merge(coord, on='city')
merged.head(2)
# Out:
#   loc 2011_start 2012_start 2013_start 2014_start 2015_start 2016_start  \
# 0  稚内       0519       0514       0526       0511       0503       0513
# 1  旭川       0509        052       0518       0502       0427       0503
#
#   2017_start 2018_start 2019_start  ... 2014/3 2015/3 2016/3 2017/3 2018/3  \
# 0       0509       0512       0507  ...   -1.2    2.3    0.5   -0.4    0.1
# 1        053       0430       0501  ...   -2.2    1.7   -0.6   -1.2   -0.1
#
#   2019/3 city   city_eng latitude longitude
# 0    0.1   稚内   Wakkanai  45.4156  141.6734
# 1   -0.5   旭川  Asahikawa  43.7709  142.3650
#
# [2 rows x 62 columns]

# %%
merged = merged.drop(columns='loc')
merged.columns
# Out:
# Index(['2011_start', '2012_start', '2013_start', '2014_start', '2015_start',
#        '2016_start', '2017_start', '2018_start', '2019_start', '2001_start',
#        '2002_start', '2003_start', '2004_start', '2005_start', '2006_start',
#        '2007_start', '2008_start', '2009_start', '2010_start', '2011_full',
#        '2012_full', '2013_full', '2014_full', '2015_full', '2016_full',
#        '2017_full', '2018_full', '2019_full', '2001_full', '2002_full',
#        '2003_full', '2004_full', '2005_full', '2006_full', '2007_full',
#        '2008_full', '2009_full', '2010_full', '2001/3', '2002/3', '2003/3',
#        '2004/3', '2005/3', '2006/3', '2007/3', '2008/3', '2009/3', '2010/3',
#        '2011/3', '2012/3', '2013/3', '2014/3', '2015/3', '2016/3', '2017/3',
#        '2018/3', '2019/3', 'city', 'city_eng', 'latitude', 'longitude'],
#       dtype='object')

# %%
merged.to_csv('data/sakura_complete.csv', index=False)
