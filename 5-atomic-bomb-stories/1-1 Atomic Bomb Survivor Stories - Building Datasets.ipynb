# %% [markdown]
# # Build dataset of survivor bios
#
#
# 広島平和記念資料館 被爆者証言ビデオ
# * 692 bios
# * http://a-bombdb.pcf.city.hiroshima.jp/pdbj/list/page/1?cls=col_testify&DISPNUM=100&searchType=5&reSearchKey=&SORT5=&SORTORDER5=&pageDivision=49&sdist=&sage=&ssex=
#
#
# 広島館・長崎館・広島資料館
# * 638 bios
# * https://www.global-peace.go.jp/picture/pic_kekka.php
#
# 長崎市平和・原爆 家族証言者
# * https://nagasakipeace.jp/japanese/peace/keisyo/profile.html

# %%
import requests
import pandas as pd
import re
import numpy as np
import os

from bs4 import BeautifulSoup

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.rcParams['pdf.fonttype'] = 42

# %matplotlib inline

pd.set_option('display.max_rows', 10000)

# headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:47.0) Gecko/20100101 Firefox/47.0'}

# %% [markdown]
# # Scrape HIROSHIMA bios only
#
# http://a-bombdb.pcf.city.hiroshima.jp/pdbj/list/page/1?cls=col_testify&DISPNUM=100&searchType=5&reSearchKey=&SORT5=&SORTORDER5=&pageDivision=49&sdist=&sage=&ssex=

# %% [markdown]
# ## Scrape just the basic info for one page
#
# There are 7 pages total, 692 bios

# %%
page= 1 
url = f'http://a-bombdb.pcf.city.hiroshima.jp/pdbj/list/page/{page}?cls=col_testify&DISPNUM=100&searchType=5&reSearchKey=&SORT5=&SORTORDER5=&pageDivision=49&sdist=&sage=&ssex='
response = requests.get(url)
doc = BeautifulSoup(response.text)

main_url = 'http://a-bombdb.pcf.city.hiroshima.jp'

# %%
# Get info for one survivor

survivors = doc.find_all('tr')[1:]
name = survivors[0].a.text.replace('\u3000','|').strip()
slug = survivors[0].a['href']
sex = survivors[0].find_all('td')[1].text.strip()
age_exposure = survivors[0].find_all('td')[3].text.replace('歳','').strip()
status_then = survivors[0].find_all('td')[4].text.strip()
code = survivors[0].find_all('td')[5].text.strip()
production_date = survivors[0].find_all('td')[6].text.strip()

# %%
# Get info for all survivors on page 1

rows = []
for survivor in survivors:
    row = {}
    row['name'] = survivor.a.text.replace('\u3000','|').strip()
    row['id'] = int(survivor.find('th').text.strip())
    row['slug'] = survivor.a['href']
    row['sex'] = survivor.find_all('td')[1].text.strip()
    row['age_exposure'] = survivor.find_all('td')[3].text.replace('歳','').strip()
    row['status_then'] = survivor.find_all('td')[4].text.strip()
    row['code'] = survivor.find_all('td')[5].text.strip()
    row['production_date'] = survivor.find_all('td')[6].text.strip()
    rows.append(row)
rows
# Out:
# [{'name': '青山|恭子',
#   'slug': '/pdbj/detail/207680',
#   'sex': '女性',
#   'age_exposure': '21',
#   'status_then': '教職員',
#   'code': 'VS00366',
#   'production_date': '1993/08/01'},
#  {'name': '秋田|サチヱ',
#   'slug': '/pdbj/detail/207588',
#   'sex': '女性',
#   'age_exposure': '14',
#   'status_then': '学生',
#   'code': 'VS00678',
#   'production_date': '2000/03/31'},
#  {'name': '秋田|ひとし',
#   'slug': '/pdbj/detail/208156',
#   'sex': '男性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00929',
#   'production_date': '2009/03/31'},
#  {'name': '秋山|重雄',
#   'slug': '/pdbj/detail/208155',
#   'sex': '男性',
#   'age_exposure': '21',
#   'status_then': '学生',
#   'code': 'VS00901-13',
#   'production_date': '2005/09/08'},
#  {'name': '浅野|温生',
#   'slug': '/pdbj/detail/208185',
#   'sex': '男性',
#   'age_exposure': '13',
#   'status_then': '学生（中学校2年生）',
#   'code': 'VS00937',
#   'production_date': '2009/03/31'},
#  {'name': '旭|勝子',
#   'slug': '/pdbj/detail/207223',
#   'sex': '女性',
#   'age_exposure': '30',
#   'status_then': '主婦',
#   'code': 'VS00466',
#   'production_date': '1995/08/01'},
#  {'name': '東|ミヨノ',
#   'slug': '/pdbj/detail/273357',
#   'sex': '女性',
#   'age_exposure': '24',
#   'status_then': '専業主婦',
#   'code': 'VS01085',
#   'production_date': '2019/02/28'},
#  {'name': '阿部|静子',
#   'slug': '/pdbj/detail/206965',
#   'sex': '女性',
#   'age_exposure': '18',
#   'status_then': '',
#   'code': 'VS00072',
#   'production_date': '1987/08/01'},
#  {'name': '安部|初子',
#   'slug': '/pdbj/detail/208302',
#   'sex': '女性',
#   'age_exposure': '24',
#   'status_then': '',
#   'code': 'VS00968',
#   'production_date': '2011/03/31'},
#  {'name': '天野|貢',
#   'slug': '/pdbj/detail/208198',
#   'sex': '男性',
#   'age_exposure': '22',
#   'status_then': '公務員',
#   'code': 'VS00862',
#   'production_date': '2006/03/31'},
#  {'name': '天野|峰子',
#   'slug': '/pdbj/detail/207250',
#   'sex': '女性',
#   'age_exposure': '13',
#   'status_then': '学生',
#   'code': 'VS00510',
#   'production_date': '1996/09/30'},
#  {'name': '天野|芳子',
#   'slug': '/pdbj/detail/207747',
#   'sex': '女性',
#   'age_exposure': '23',
#   'status_then': '主婦',
#   'code': 'VS00808',
#   'production_date': '2003/03/31'},
#  {'name': '新井|俊一郎',
#   'slug': '/pdbj/detail/208165',
#   'sex': '男性',
#   'age_exposure': '13',
#   'status_then': '学生（中学校1年生）',
#   'code': 'VS00882',
#   'production_date': '2007/03/31'},
#  {'name': '新井|昇',
#   'slug': '/pdbj/detail/207639',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '会社員',
#   'code': 'VS00805',
#   'production_date': '2003/03/31'},
#  {'name': '有崎|劭治',
#   'slug': '/pdbj/detail/207825',
#   'sex': '男性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00209',
#   'production_date': '1990/08/01'},
#  {'name': '粟村|逸三',
#   'slug': '/pdbj/detail/207073',
#   'sex': '男性',
#   'age_exposure': '30',
#   'status_then': '軍人',
#   'code': 'VS00222',
#   'production_date': '1990/08/01'},
#  {'name': '阿武|百合子',
#   'slug': '/pdbj/detail/208388',
#   'sex': '女性',
#   'age_exposure': '19',
#   'status_then': '教職員（臨時教師）',
#   'code': 'VS01029',
#   'production_date': '2015/03/31'},
#  {'name': '李|鐘根',
#   'slug': '/pdbj/detail/243778',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '',
#   'code': 'VS01036',
#   'production_date': '2016/03/31'},
#  {'name': '飯田|暁',
#   'slug': '/pdbj/detail/208330',
#   'sex': '男性',
#   'age_exposure': '7',
#   'status_then': '学生（国民学校1年生）',
#   'code': 'VS00996',
#   'production_date': '2012/03/31'},
#  {'name': '飯村|卓',
#   'slug': '/pdbj/detail/207391',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '学生',
#   'code': 'VS00733',
#   'production_date': '2001/03/31'},
#  {'name': '壱岐|弘',
#   'slug': '/pdbj/detail/208095',
#   'sex': '男性',
#   'age_exposure': '21',
#   'status_then': '学生',
#   'code': 'VS00901-05',
#   'production_date': '2005/09/08'},
#  {'name': '池庄司（久保）|トミ子',
#   'slug': '/pdbj/detail/207130',
#   'sex': '女性',
#   'age_exposure': '17',
#   'status_then': '看護婦（看護学生）',
#   'code': 'VS00303',
#   'production_date': '1992/08/01'},
#  {'name': '池田|精子',
#   'slug': '/pdbj/detail/206998',
#   'sex': '女性',
#   'age_exposure': '12',
#   'status_then': '学生',
#   'code': 'VS00119',
#   'production_date': '1988/08/01'},
#  {'name': '伊澤|澄子',
#   'slug': '/pdbj/detail/207844',
#   'sex': '女性',
#   'age_exposure': '28',
#   'status_then': '公務員',
#   'code': 'VS00302',
#   'production_date': '1992/08/01'},
#  {'name': '石川|文恵',
#   'slug': '/pdbj/detail/206940',
#   'sex': '女性',
#   'age_exposure': '16',
#   'status_then': '学生',
#   'code': 'VS00042',
#   'production_date': '1986/08/01'},
#  {'name': '石﨑|幸子',
#   'slug': '/pdbj/detail/208294',
#   'sex': '女性',
#   'age_exposure': '13',
#   'status_then': '',
#   'code': 'VS00959',
#   'production_date': '2010/03/31'},
#  {'name': '石田|明',
#   'slug': '/pdbj/detail/206947',
#   'sex': '男性',
#   'age_exposure': '17',
#   'status_then': '軍人（陸軍少年航空兵）',
#   'code': 'VS00050-01',
#   'production_date': '1986/08/01'},
#  {'name': '石田|晟',
#   'slug': '/pdbj/detail/207408',
#   'sex': '男性',
#   'age_exposure': '13',
#   'status_then': '学生（中学校2年生）',
#   'code': 'VS00770',
#   'production_date': '2002/03/29'},
#  {'name': '石田|民生',
#   'slug': '/pdbj/detail/207685',
#   'sex': '男性',
#   'age_exposure': '15',
#   'status_then': '軍人',
#   'code': 'VS00138',
#   'production_date': '1988/08/01'},
#  {'name': '石田|正己',
#   'slug': '/pdbj/detail/207684',
#   'sex': '男性',
#   'age_exposure': '45',
#   'status_then': '教職員（校長）',
#   'code': 'VS00081',
#   'production_date': '1987/08/01'},
#  {'name': '泉|寛治',
#   'slug': '/pdbj/detail/208299',
#   'sex': '男性',
#   'age_exposure': '5',
#   'status_then': '',
#   'code': 'VS00964',
#   'production_date': '2011/03/31'},
#  {'name': '伊勢|千枝子',
#   'slug': '/pdbj/detail/207325',
#   'sex': '女性',
#   'age_exposure': '32',
#   'status_then': '主婦',
#   'code': 'VS00623',
#   'production_date': '1999/03/31'},
#  {'name': '板野|鹿郎',
#   'slug': '/pdbj/detail/207068',
#   'sex': '男性',
#   'age_exposure': '33',
#   'status_then': '会社員',
#   'code': 'VS00214',
#   'production_date': '1990/08/01'},
#  {'name': '板村|幸子',
#   'slug': '/pdbj/detail/207106',
#   'sex': '女性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00260',
#   'production_date': '1991/08/01'},
#  {'name': '市原|礼子',
#   'slug': '/pdbj/detail/207571',
#   'sex': '女性',
#   'age_exposure': '10',
#   'status_then': '学生',
#   'code': 'VS00693',
#   'production_date': '2000/03/31'},
#  {'name': '出本|幸子',
#   'slug': '/pdbj/detail/207069',
#   'sex': '女性',
#   'age_exposure': '14',
#   'status_then': '看護婦',
#   'code': 'VS00217',
#   'production_date': '1990/08/01'},
#  {'name': '伊藤|薫',
#   'slug': '/pdbj/detail/207175',
#   'sex': '男性',
#   'age_exposure': '31',
#   'status_then': '会社員',
#   'code': 'VS00381',
#   'production_date': '1993/08/01'},
#  {'name': '井東|幸次',
#   'slug': '/pdbj/detail/208240',
#   'sex': '男性',
#   'age_exposure': '21',
#   'status_then': '学生',
#   'code': 'VS00901-03',
#   'production_date': '2005/09/08'},
#  {'name': '伊藤|サカヱ',
#   'slug': '/pdbj/detail/207843',
#   'sex': '女性',
#   'age_exposure': '34',
#   'status_then': '',
#   'code': 'VS00124',
#   'production_date': '1988/08/01'},
#  {'name': '伊藤|次郎',
#   'slug': '/pdbj/detail/207018',
#   'sex': '男性',
#   'age_exposure': '24',
#   'status_then': '軍人',
#   'code': 'VS00151',
#   'production_date': '1989/08/01'},
#  {'name': '伊藤|義幸',
#   'slug': '/pdbj/detail/208304',
#   'sex': '男性',
#   'age_exposure': '19',
#   'status_then': '',
#   'code': 'VS00970',
#   'production_date': '2011/03/31'},
#  {'name': '糸賀|志伸',
#   'slug': '/pdbj/detail/254737',
#   'sex': '男性',
#   'age_exposure': '4',
#   'status_then': '',
#   'code': 'VS01058',
#   'production_date': '2017/02/28'},
#  {'name': '井上|国三',
#   'slug': '/pdbj/detail/207261',
#   'sex': '男性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00532',
#   'production_date': '1996/09/30'},
#  {'name': '井上|良候',
#   'slug': '/pdbj/detail/207848',
#   'sex': '男性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00348',
#   'production_date': '1992/08/01'},
#  {'name': '井口|健',
#   'slug': '/pdbj/detail/208334',
#   'sex': '男性',
#   'age_exposure': '14',
#   'status_then': '学生（山陽中学生2年生）',
#   'code': 'VS01000',
#   'production_date': '2012/03/31'},
#  {'name': '今井|敏郎',
#   'slug': '/pdbj/detail/207123',
#   'sex': '',
#   'age_exposure': '34',
#   'status_then': '',
#   'code': 'VS00290',
#   'production_date': '1991/08/01'},
#  {'name': '今川|利春',
#   'slug': '/pdbj/detail/207881',
#   'sex': '男性',
#   'age_exposure': '21',
#   'status_then': '軍人',
#   'code': 'VS00775',
#   'production_date': '2002/03/29'},
#  {'name': '岩田|和子',
#   'slug': '/pdbj/detail/207190',
#   'sex': '女性',
#   'age_exposure': '29',
#   'status_then': '主婦',
#   'code': 'VS00401',
#   'production_date': '1994/08/01'},
#  {'name': '岩田|整三',
#   'slug': '/pdbj/detail/207891',
#   'sex': '男性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00809',
#   'production_date': '2003/03/31'},
#  {'name': '岩田|守雄',
#   'slug': '/pdbj/detail/207308',
#   'sex': '男性',
#   'age_exposure': '11',
#   'status_then': '学生',
#   'code': 'VS00597',
#   'production_date': '1998/02/28'},
#  {'name': '岩本|節子',
#   'slug': '/pdbj/detail/207892',
#   'sex': '女性',
#   'age_exposure': '13',
#   'status_then': '学生',
#   'code': 'VS00273',
#   'production_date': '1991/08/01'},
#  {'name': '上岡|雅',
#   'slug': '/pdbj/detail/207630',
#   'sex': '男性',
#   'age_exposure': '24',
#   'status_then': '公務員',
#   'code': 'VS00340',
#   'production_date': '1992/08/01'},
#  {'name': '植木|澄子',
#   'slug': '/pdbj/detail/208349',
#   'sex': '女性',
#   'age_exposure': '17',
#   'status_then': '学生（女学校5年生）',
#   'code': 'VS01014',
#   'production_date': '2014/02/28'},
#  {'name': '上杉|綾子',
#   'slug': '/pdbj/detail/207631',
#   'sex': '女性',
#   'age_exposure': '45',
#   'status_then': '主婦',
#   'code': 'VS00304',
#   'production_date': '1992/08/01'},
#  {'name': '上薗|志水',
#   'slug': '/pdbj/detail/207048',
#   'sex': '男性',
#   'age_exposure': '29',
#   'status_then': '僧侶',
#   'code': 'VS00190',
#   'production_date': '1989/08/01'},
#  {'name': '植囿|澄子',
#   'slug': '/pdbj/detail/265006',
#   'sex': '女性',
#   'age_exposure': '19',
#   'status_then': '女子挺身隊',
#   'code': 'VS01070',
#   'production_date': '2018/02/28'},
#  {'name': '上田|静人',
#   'slug': '/pdbj/detail/206930',
#   'sex': '男性',
#   'age_exposure': '28',
#   'status_then': '会社員',
#   'code': 'VS00021',
#   'production_date': '1986/08/01'},
#  {'name': '植田|規子',
#   'slug': '/pdbj/detail/207638',
#   'sex': '女性',
#   'age_exposure': '13',
#   'status_then': '学生',
#   'code': 'VS00234',
#   'production_date': '1990/08/01'},
#  {'name': '上田|正紀',
#   'slug': '/pdbj/detail/207633',
#   'sex': '男性',
#   'age_exposure': '17',
#   'status_then': '',
#   'code': 'VS00144',
#   'production_date': '1988/08/01'},
#  {'name': '上野|照子',
#   'slug': '/pdbj/detail/207635',
#   'sex': '女性',
#   'age_exposure': '15',
#   'status_then': '看護婦（看護学生）',
#   'code': 'VS00455',
#   'production_date': '1995/08/01'},
#  {'name': '上野|ハルエ',
#   'slug': '/pdbj/detail/207634',
#   'sex': '女性',
#   'age_exposure': '21',
#   'status_then': '公務員',
#   'code': 'VS00436',
#   'production_date': '1994/08/01'},
#  {'name': '上野|求',
#   'slug': '/pdbj/detail/208313',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '',
#   'code': 'VS00979',
#   'production_date': '2011/03/31'},
#  {'name': '上山|和子',
#   'slug': '/pdbj/detail/208163',
#   'sex': '女性',
#   'age_exposure': '11',
#   'status_then': '学生（国民学校6年生）',
#   'code': 'VS00942',
#   'production_date': '2009/03/31'},
#  {'name': '浮田|俊郎',
#   'slug': '/pdbj/detail/207785',
#   'sex': '男性',
#   'age_exposure': '13',
#   'status_then': '',
#   'code': 'VS00662',
#   'production_date': '2000/03/31'},
#  {'name': '宇佐川|良孝',
#   'slug': '/pdbj/detail/207852',
#   'sex': '男性',
#   'age_exposure': '14',
#   'status_then': '公務員',
#   'code': 'VS00761',
#   'production_date': '2002/03/29'},
#  {'name': '潮|富江',
#   'slug': '/pdbj/detail/255016',
#   'sex': '女性',
#   'age_exposure': '14',
#   'status_then': '学生',
#   'code': 'VS01067',
#   'production_date': '2017/02/28'},
#  {'name': '宇根|利枝',
#   'slug': '/pdbj/detail/207850',
#   'sex': '女性',
#   'age_exposure': '26',
#   'status_then': '軍関係',
#   'code': 'VS00306',
#   'production_date': '1992/08/01'},
#  {'name': '畝|義信',
#   'slug': '/pdbj/detail/206977',
#   'sex': '男性',
#   'age_exposure': '23',
#   'status_then': '会社員（工場長）',
#   'code': 'VS00092',
#   'production_date': '1987/08/01'},
#  {'name': '梅田|義文',
#   'slug': '/pdbj/detail/206932',
#   'sex': '男性',
#   'age_exposure': '31',
#   'status_then': '歯科医',
#   'code': 'VS00025',
#   'production_date': '1986/08/01'},
#  {'name': '江川|政市',
#   'slug': '/pdbj/detail/208289',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '',
#   'code': 'VS00954',
#   'production_date': '2010/03/31'},
#  {'name': '江川|優',
#   'slug': '/pdbj/detail/207353',
#   'sex': '男性',
#   'age_exposure': '12',
#   'status_then': '学生（国民学校6年生）',
#   'code': 'VS00670',
#   'production_date': '2000/03/31'},
#  {'name': '江種|祐司',
#   'slug': '/pdbj/detail/207264',
#   'sex': '男性',
#   'age_exposure': '17',
#   'status_then': '学生（本科1年生）',
#   'code': 'VS00539',
#   'production_date': '1996/09/30'},
#  {'name': '枝松|きみ子',
#   'slug': '/pdbj/detail/207573',
#   'sex': '女性',
#   'age_exposure': '19',
#   'status_then': '公務員',
#   'code': 'VS00793',
#   'production_date': '2002/03/29'},
#  {'name': '煙石（土井）二三枝',
#   'slug': '/pdbj/detail/206925',
#   'sex': '女性',
#   'age_exposure': '24',
#   'status_then': '公務員',
#   'code': 'VS00011',
#   'production_date': '1986/08/01'},
#  {'name': '塩冶|節子',
#   'slug': '/pdbj/detail/208247',
#   'sex': '女性',
#   'age_exposure': '5',
#   'status_then': '',
#   'code': 'VS00884',
#   'production_date': '2007/03/31'},
#  {'name': '呉|炳洙',
#   'slug': '/pdbj/detail/207247',
#   'sex': '男性',
#   'age_exposure': '14',
#   'status_then': '学生（国民学校6年生）',
#   'code': 'VS00505',
#   'production_date': '1996/09/30'},
#  {'name': '呉|鳳寿',
#   'slug': '/pdbj/detail/207915',
#   'sex': '男性',
#   'age_exposure': '37',
#   'status_then': '',
#   'code': 'VS00192',
#   'production_date': '1989/08/01'},
#  {'name': '大咲|春雄',
#   'slug': '/pdbj/detail/244041',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '学生（崇徳中学校3年生）',
#   'code': 'VS01039',
#   'production_date': '2016/03/31'},
#  {'name': '大田|潤子',
#   'slug': '/pdbj/detail/208350',
#   'sex': '女性',
#   'age_exposure': '14',
#   'status_then': '学生（女学校3年生）',
#   'code': 'VS01015',
#   'production_date': '2014/02/28'},
#  {'name': '大谷|勝彦',
#   'slug': '/pdbj/detail/207703',
#   'sex': '男性',
#   'age_exposure': '26',
#   'status_then': '会社員',
#   'code': 'VS00396',
#   'production_date': '1993/08/01'},
#  {'name': '大谷|邦隆',
#   'slug': '/pdbj/detail/207704',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '学生',
#   'code': 'VS00736',
#   'production_date': '2001/03/31'},
#  {'name': '大塚|宗元',
#   'slug': '/pdbj/detail/207020',
#   'sex': '男性',
#   'age_exposure': '23',
#   'status_then': '軍人',
#   'code': 'VS00153',
#   'production_date': '1989/08/01'},
#  {'name': '大戸|絹江',
#   'slug': '/pdbj/detail/207702',
#   'sex': '女性',
#   'age_exposure': '19',
#   'status_then': '公務員',
#   'code': 'VS00776',
#   'production_date': '2002/03/29'},
#  {'name': '大野|逸美',
#   'slug': '/pdbj/detail/208193',
#   'sex': '男性',
#   'age_exposure': '14',
#   'status_then': '',
#   'code': 'VS00909',
#   'production_date': '2008/03/31'},
#  {'name': '大場|孝子',
#   'slug': '/pdbj/detail/207345',
#   'sex': '女性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00657',
#   'production_date': '2000/03/31'},
#  {'name': '大場|正雄',
#   'slug': '/pdbj/detail/207338',
#   'sex': '男性',
#   'age_exposure': '19',
#   'status_then': '学生',
#   'code': 'VS00643',
#   'production_date': '1999/03/31'},
#  {'name': '大林|ユキエ',
#   'slug': '/pdbj/detail/207232',
#   'sex': '女性',
#   'age_exposure': '26',
#   'status_then': '主婦',
#   'code': 'VS00479',
#   'production_date': '1995/08/01'},
#  {'name': '大林|芳典',
#   'slug': '/pdbj/detail/207707',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '',
#   'code': 'VS00684',
#   'production_date': '2000/03/31'},
#  {'name': '大前|辰男',
#   'slug': '/pdbj/detail/208191',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '公務員',
#   'code': 'VS00885',
#   'production_date': '2007/03/31'},
#  {'name': '大前|正己',
#   'slug': '/pdbj/detail/207146',
#   'sex': '男性',
#   'age_exposure': '32',
#   'status_then': '会社員',
#   'code': 'VS00330',
#   'production_date': '1992/08/01'},
#  {'name': '岡|保',
#   'slug': '/pdbj/detail/208098',
#   'sex': '男性',
#   'age_exposure': '21',
#   'status_then': '学生',
#   'code': 'VS00901-08',
#   'production_date': '2005/09/08'},
#  {'name': '岡|ヨシエ',
#   'slug': '/pdbj/detail/206955',
#   'sex': '女性',
#   'age_exposure': '14',
#   'status_then': '学生',
#   'code': 'VS00054',
#   'production_date': '1987/08/01'},
#  {'name': '岡崎|秀彦',
#   'slug': '/pdbj/detail/207133',
#   'sex': '男性',
#   'age_exposure': '17',
#   'status_then': '学生',
#   'code': 'VS00308',
#   'production_date': '1992/08/01'},
#  {'name': '岡田|昭典',
#   'slug': '/pdbj/detail/208290',
#   'sex': '男性',
#   'age_exposure': '17',
#   'status_then': '',
#   'code': 'VS00955',
#   'production_date': '2010/03/31'},
#  {'name': '岡田|イツヱ',
#   'slug': '/pdbj/detail/208386',
#   'sex': '女性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS01027',
#   'production_date': '2015/03/31'},
#  {'name': '岡田|恵美子',
#   'slug': '/pdbj/detail/207397',
#   'sex': '女性',
#   'age_exposure': '8',
#   'status_then': '学生（尾長国民学校3年）',
#   'code': 'VS00747',
#   'production_date': '2001/03/31'},
#  {'name': '岡田|ヒサヱ',
#   'slug': '/pdbj/detail/208085',
#   'sex': '女性',
#   'age_exposure': '16',
#   'status_then': '',
#   'code': 'VS00886',
#   'production_date': '2007/03/31'},
#  {'name': '岡田|八十吉',
#   'slug': '/pdbj/detail/207154',
#   'sex': '男性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00344',
#   'production_date': '1992/08/01'},
#  {'name': '岡田|能則',
#   'slug': '/pdbj/detail/208250',
#   'sex': '男性',
#   'age_exposure': '17',
#   'status_then': '軍属',
#   'code': 'VS00887',
#   'production_date': '2007/03/31'},
#  {'name': '岡田|六郎',
#   'slug': '/pdbj/detail/207021',
#   'sex': '男性',
#   'age_exposure': '23',
#   'status_then': '軍人',
#   'code': 'VS00154',
#   'production_date': '1989/08/01'}]

# %% [markdown]
# ## Scrape all pages

# %%
pages = list(range(1,8))
rows = []

for page in pages:
    url = f'http://a-bombdb.pcf.city.hiroshima.jp/pdbj/list/page/{page}?cls=col_testify&DISPNUM=100&searchType=5&reSearchKey=&SORT5=&SORTORDER5=&pageDivision=49&sdist=&sage=&ssex='
    response = requests.get(url)
    doc = BeautifulSoup(response.text)
    survivors = doc.find_all('tr')[1:]

    for survivor in survivors:
        row = {}
        row['id'] = int(survivor.find('th').text.strip())
        row['name'] = survivor.a.text.replace('\u3000','|').strip()
        row['slug'] = survivor.a['href']
        row['sex'] = survivor.find_all('td')[1].text.strip()
        row['age_exposure'] = survivor.find_all('td')[3].text.replace('歳','').strip()
        row['status_then'] = survivor.find_all('td')[4].text.strip()
        row['code'] = survivor.find_all('td')[5].text.strip()
        row['production_date'] = survivor.find_all('td')[6].text.strip()
        rows.append(row)
rows
# Out:
# [{'id': 1,
#   'name': '青山|恭子',
#   'slug': '/pdbj/detail/207680',
#   'sex': '女性',
#   'age_exposure': '21',
#   'status_then': '教職員',
#   'code': 'VS00366',
#   'production_date': '1993/08/01'},
#  {'id': 2,
#   'name': '秋田|サチヱ',
#   'slug': '/pdbj/detail/207588',
#   'sex': '女性',
#   'age_exposure': '14',
#   'status_then': '学生',
#   'code': 'VS00678',
#   'production_date': '2000/03/31'},
#  {'id': 3,
#   'name': '秋田|ひとし',
#   'slug': '/pdbj/detail/208156',
#   'sex': '男性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00929',
#   'production_date': '2009/03/31'},
#  {'id': 4,
#   'name': '秋山|重雄',
#   'slug': '/pdbj/detail/208155',
#   'sex': '男性',
#   'age_exposure': '21',
#   'status_then': '学生',
#   'code': 'VS00901-13',
#   'production_date': '2005/09/08'},
#  {'id': 5,
#   'name': '浅野|温生',
#   'slug': '/pdbj/detail/208185',
#   'sex': '男性',
#   'age_exposure': '13',
#   'status_then': '学生（中学校2年生）',
#   'code': 'VS00937',
#   'production_date': '2009/03/31'},
#  {'id': 6,
#   'name': '旭|勝子',
#   'slug': '/pdbj/detail/207223',
#   'sex': '女性',
#   'age_exposure': '30',
#   'status_then': '主婦',
#   'code': 'VS00466',
#   'production_date': '1995/08/01'},
#  {'id': 7,
#   'name': '東|ミヨノ',
#   'slug': '/pdbj/detail/273357',
#   'sex': '女性',
#   'age_exposure': '24',
#   'status_then': '専業主婦',
#   'code': 'VS01085',
#   'production_date': '2019/02/28'},
#  {'id': 8,
#   'name': '阿部|静子',
#   'slug': '/pdbj/detail/206965',
#   'sex': '女性',
#   'age_exposure': '18',
#   'status_then': '',
#   'code': 'VS00072',
#   'production_date': '1987/08/01'},
#  {'id': 9,
#   'name': '安部|初子',
#   'slug': '/pdbj/detail/208302',
#   'sex': '女性',
#   'age_exposure': '24',
#   'status_then': '',
#   'code': 'VS00968',
#   'production_date': '2011/03/31'},
#  {'id': 10,
#   'name': '天野|貢',
#   'slug': '/pdbj/detail/208198',
#   'sex': '男性',
#   'age_exposure': '22',
#   'status_then': '公務員',
#   'code': 'VS00862',
#   'production_date': '2006/03/31'},
#  {'id': 11,
#   'name': '天野|峰子',
#   'slug': '/pdbj/detail/207250',
#   'sex': '女性',
#   'age_exposure': '13',
#   'status_then': '学生',
#   'code': 'VS00510',
#   'production_date': '1996/09/30'},
#  {'id': 12,
#   'name': '天野|芳子',
#   'slug': '/pdbj/detail/207747',
#   'sex': '女性',
#   'age_exposure': '23',
#   'status_then': '主婦',
#   'code': 'VS00808',
#   'production_date': '2003/03/31'},
#  {'id': 13,
#   'name': '新井|俊一郎',
#   'slug': '/pdbj/detail/208165',
#   'sex': '男性',
#   'age_exposure': '13',
#   'status_then': '学生（中学校1年生）',
#   'code': 'VS00882',
#   'production_date': '2007/03/31'},
#  {'id': 14,
#   'name': '新井|昇',
#   'slug': '/pdbj/detail/207639',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '会社員',
#   'code': 'VS00805',
#   'production_date': '2003/03/31'},
#  {'id': 15,
#   'name': '有崎|劭治',
#   'slug': '/pdbj/detail/207825',
#   'sex': '男性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00209',
#   'production_date': '1990/08/01'},
#  {'id': 16,
#   'name': '粟村|逸三',
#   'slug': '/pdbj/detail/207073',
#   'sex': '男性',
#   'age_exposure': '30',
#   'status_then': '軍人',
#   'code': 'VS00222',
#   'production_date': '1990/08/01'},
#  {'id': 17,
#   'name': '阿武|百合子',
#   'slug': '/pdbj/detail/208388',
#   'sex': '女性',
#   'age_exposure': '19',
#   'status_then': '教職員（臨時教師）',
#   'code': 'VS01029',
#   'production_date': '2015/03/31'},
#  {'id': 18,
#   'name': '李|鐘根',
#   'slug': '/pdbj/detail/243778',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '',
#   'code': 'VS01036',
#   'production_date': '2016/03/31'},
#  {'id': 19,
#   'name': '飯田|暁',
#   'slug': '/pdbj/detail/208330',
#   'sex': '男性',
#   'age_exposure': '7',
#   'status_then': '学生（国民学校1年生）',
#   'code': 'VS00996',
#   'production_date': '2012/03/31'},
#  {'id': 20,
#   'name': '飯村|卓',
#   'slug': '/pdbj/detail/207391',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '学生',
#   'code': 'VS00733',
#   'production_date': '2001/03/31'},
#  {'id': 21,
#   'name': '壱岐|弘',
#   'slug': '/pdbj/detail/208095',
#   'sex': '男性',
#   'age_exposure': '21',
#   'status_then': '学生',
#   'code': 'VS00901-05',
#   'production_date': '2005/09/08'},
#  {'id': 22,
#   'name': '池庄司（久保）|トミ子',
#   'slug': '/pdbj/detail/207130',
#   'sex': '女性',
#   'age_exposure': '17',
#   'status_then': '看護婦（看護学生）',
#   'code': 'VS00303',
#   'production_date': '1992/08/01'},
#  {'id': 23,
#   'name': '池田|精子',
#   'slug': '/pdbj/detail/206998',
#   'sex': '女性',
#   'age_exposure': '12',
#   'status_then': '学生',
#   'code': 'VS00119',
#   'production_date': '1988/08/01'},
#  {'id': 24,
#   'name': '伊澤|澄子',
#   'slug': '/pdbj/detail/207844',
#   'sex': '女性',
#   'age_exposure': '28',
#   'status_then': '公務員',
#   'code': 'VS00302',
#   'production_date': '1992/08/01'},
#  {'id': 25,
#   'name': '石川|文恵',
#   'slug': '/pdbj/detail/206940',
#   'sex': '女性',
#   'age_exposure': '16',
#   'status_then': '学生',
#   'code': 'VS00042',
#   'production_date': '1986/08/01'},
#  {'id': 26,
#   'name': '石﨑|幸子',
#   'slug': '/pdbj/detail/208294',
#   'sex': '女性',
#   'age_exposure': '13',
#   'status_then': '',
#   'code': 'VS00959',
#   'production_date': '2010/03/31'},
#  {'id': 27,
#   'name': '石田|明',
#   'slug': '/pdbj/detail/206947',
#   'sex': '男性',
#   'age_exposure': '17',
#   'status_then': '軍人（陸軍少年航空兵）',
#   'code': 'VS00050-01',
#   'production_date': '1986/08/01'},
#  {'id': 28,
#   'name': '石田|晟',
#   'slug': '/pdbj/detail/207408',
#   'sex': '男性',
#   'age_exposure': '13',
#   'status_then': '学生（中学校2年生）',
#   'code': 'VS00770',
#   'production_date': '2002/03/29'},
#  {'id': 29,
#   'name': '石田|民生',
#   'slug': '/pdbj/detail/207685',
#   'sex': '男性',
#   'age_exposure': '15',
#   'status_then': '軍人',
#   'code': 'VS00138',
#   'production_date': '1988/08/01'},
#  {'id': 30,
#   'name': '石田|正己',
#   'slug': '/pdbj/detail/207684',
#   'sex': '男性',
#   'age_exposure': '45',
#   'status_then': '教職員（校長）',
#   'code': 'VS00081',
#   'production_date': '1987/08/01'},
#  {'id': 31,
#   'name': '泉|寛治',
#   'slug': '/pdbj/detail/208299',
#   'sex': '男性',
#   'age_exposure': '5',
#   'status_then': '',
#   'code': 'VS00964',
#   'production_date': '2011/03/31'},
#  {'id': 32,
#   'name': '伊勢|千枝子',
#   'slug': '/pdbj/detail/207325',
#   'sex': '女性',
#   'age_exposure': '32',
#   'status_then': '主婦',
#   'code': 'VS00623',
#   'production_date': '1999/03/31'},
#  {'id': 33,
#   'name': '板野|鹿郎',
#   'slug': '/pdbj/detail/207068',
#   'sex': '男性',
#   'age_exposure': '33',
#   'status_then': '会社員',
#   'code': 'VS00214',
#   'production_date': '1990/08/01'},
#  {'id': 34,
#   'name': '板村|幸子',
#   'slug': '/pdbj/detail/207106',
#   'sex': '女性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00260',
#   'production_date': '1991/08/01'},
#  {'id': 35,
#   'name': '市原|礼子',
#   'slug': '/pdbj/detail/207571',
#   'sex': '女性',
#   'age_exposure': '10',
#   'status_then': '学生',
#   'code': 'VS00693',
#   'production_date': '2000/03/31'},
#  {'id': 36,
#   'name': '出本|幸子',
#   'slug': '/pdbj/detail/207069',
#   'sex': '女性',
#   'age_exposure': '14',
#   'status_then': '看護婦',
#   'code': 'VS00217',
#   'production_date': '1990/08/01'},
#  {'id': 37,
#   'name': '伊藤|薫',
#   'slug': '/pdbj/detail/207175',
#   'sex': '男性',
#   'age_exposure': '31',
#   'status_then': '会社員',
#   'code': 'VS00381',
#   'production_date': '1993/08/01'},
#  {'id': 38,
#   'name': '井東|幸次',
#   'slug': '/pdbj/detail/208240',
#   'sex': '男性',
#   'age_exposure': '21',
#   'status_then': '学生',
#   'code': 'VS00901-03',
#   'production_date': '2005/09/08'},
#  {'id': 39,
#   'name': '伊藤|サカヱ',
#   'slug': '/pdbj/detail/207843',
#   'sex': '女性',
#   'age_exposure': '34',
#   'status_then': '',
#   'code': 'VS00124',
#   'production_date': '1988/08/01'},
#  {'id': 40,
#   'name': '伊藤|次郎',
#   'slug': '/pdbj/detail/207018',
#   'sex': '男性',
#   'age_exposure': '24',
#   'status_then': '軍人',
#   'code': 'VS00151',
#   'production_date': '1989/08/01'},
#  {'id': 41,
#   'name': '伊藤|義幸',
#   'slug': '/pdbj/detail/208304',
#   'sex': '男性',
#   'age_exposure': '19',
#   'status_then': '',
#   'code': 'VS00970',
#   'production_date': '2011/03/31'},
#  {'id': 42,
#   'name': '糸賀|志伸',
#   'slug': '/pdbj/detail/254737',
#   'sex': '男性',
#   'age_exposure': '4',
#   'status_then': '',
#   'code': 'VS01058',
#   'production_date': '2017/02/28'},
#  {'id': 43,
#   'name': '井上|国三',
#   'slug': '/pdbj/detail/207261',
#   'sex': '男性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00532',
#   'production_date': '1996/09/30'},
#  {'id': 44,
#   'name': '井上|良候',
#   'slug': '/pdbj/detail/207848',
#   'sex': '男性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00348',
#   'production_date': '1992/08/01'},
#  {'id': 45,
#   'name': '井口|健',
#   'slug': '/pdbj/detail/208334',
#   'sex': '男性',
#   'age_exposure': '14',
#   'status_then': '学生（山陽中学生2年生）',
#   'code': 'VS01000',
#   'production_date': '2012/03/31'},
#  {'id': 46,
#   'name': '今井|敏郎',
#   'slug': '/pdbj/detail/207123',
#   'sex': '',
#   'age_exposure': '34',
#   'status_then': '',
#   'code': 'VS00290',
#   'production_date': '1991/08/01'},
#  {'id': 47,
#   'name': '今川|利春',
#   'slug': '/pdbj/detail/207881',
#   'sex': '男性',
#   'age_exposure': '21',
#   'status_then': '軍人',
#   'code': 'VS00775',
#   'production_date': '2002/03/29'},
#  {'id': 48,
#   'name': '岩田|和子',
#   'slug': '/pdbj/detail/207190',
#   'sex': '女性',
#   'age_exposure': '29',
#   'status_then': '主婦',
#   'code': 'VS00401',
#   'production_date': '1994/08/01'},
#  {'id': 49,
#   'name': '岩田|整三',
#   'slug': '/pdbj/detail/207891',
#   'sex': '男性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00809',
#   'production_date': '2003/03/31'},
#  {'id': 50,
#   'name': '岩田|守雄',
#   'slug': '/pdbj/detail/207308',
#   'sex': '男性',
#   'age_exposure': '11',
#   'status_then': '学生',
#   'code': 'VS00597',
#   'production_date': '1998/02/28'},
#  {'id': 51,
#   'name': '岩本|節子',
#   'slug': '/pdbj/detail/207892',
#   'sex': '女性',
#   'age_exposure': '13',
#   'status_then': '学生',
#   'code': 'VS00273',
#   'production_date': '1991/08/01'},
#  {'id': 52,
#   'name': '上岡|雅',
#   'slug': '/pdbj/detail/207630',
#   'sex': '男性',
#   'age_exposure': '24',
#   'status_then': '公務員',
#   'code': 'VS00340',
#   'production_date': '1992/08/01'},
#  {'id': 53,
#   'name': '植木|澄子',
#   'slug': '/pdbj/detail/208349',
#   'sex': '女性',
#   'age_exposure': '17',
#   'status_then': '学生（女学校5年生）',
#   'code': 'VS01014',
#   'production_date': '2014/02/28'},
#  {'id': 54,
#   'name': '上杉|綾子',
#   'slug': '/pdbj/detail/207631',
#   'sex': '女性',
#   'age_exposure': '45',
#   'status_then': '主婦',
#   'code': 'VS00304',
#   'production_date': '1992/08/01'},
#  {'id': 55,
#   'name': '上薗|志水',
#   'slug': '/pdbj/detail/207048',
#   'sex': '男性',
#   'age_exposure': '29',
#   'status_then': '僧侶',
#   'code': 'VS00190',
#   'production_date': '1989/08/01'},
#  {'id': 56,
#   'name': '植囿|澄子',
#   'slug': '/pdbj/detail/265006',
#   'sex': '女性',
#   'age_exposure': '19',
#   'status_then': '女子挺身隊',
#   'code': 'VS01070',
#   'production_date': '2018/02/28'},
#  {'id': 57,
#   'name': '上田|静人',
#   'slug': '/pdbj/detail/206930',
#   'sex': '男性',
#   'age_exposure': '28',
#   'status_then': '会社員',
#   'code': 'VS00021',
#   'production_date': '1986/08/01'},
#  {'id': 58,
#   'name': '植田|規子',
#   'slug': '/pdbj/detail/207638',
#   'sex': '女性',
#   'age_exposure': '13',
#   'status_then': '学生',
#   'code': 'VS00234',
#   'production_date': '1990/08/01'},
#  {'id': 59,
#   'name': '上田|正紀',
#   'slug': '/pdbj/detail/207633',
#   'sex': '男性',
#   'age_exposure': '17',
#   'status_then': '',
#   'code': 'VS00144',
#   'production_date': '1988/08/01'},
#  {'id': 60,
#   'name': '上野|照子',
#   'slug': '/pdbj/detail/207635',
#   'sex': '女性',
#   'age_exposure': '15',
#   'status_then': '看護婦（看護学生）',
#   'code': 'VS00455',
#   'production_date': '1995/08/01'},
#  {'id': 61,
#   'name': '上野|ハルエ',
#   'slug': '/pdbj/detail/207634',
#   'sex': '女性',
#   'age_exposure': '21',
#   'status_then': '公務員',
#   'code': 'VS00436',
#   'production_date': '1994/08/01'},
#  {'id': 62,
#   'name': '上野|求',
#   'slug': '/pdbj/detail/208313',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '',
#   'code': 'VS00979',
#   'production_date': '2011/03/31'},
#  {'id': 63,
#   'name': '上山|和子',
#   'slug': '/pdbj/detail/208163',
#   'sex': '女性',
#   'age_exposure': '11',
#   'status_then': '学生（国民学校6年生）',
#   'code': 'VS00942',
#   'production_date': '2009/03/31'},
#  {'id': 64,
#   'name': '浮田|俊郎',
#   'slug': '/pdbj/detail/207785',
#   'sex': '男性',
#   'age_exposure': '13',
#   'status_then': '',
#   'code': 'VS00662',
#   'production_date': '2000/03/31'},
#  {'id': 65,
#   'name': '宇佐川|良孝',
#   'slug': '/pdbj/detail/207852',
#   'sex': '男性',
#   'age_exposure': '14',
#   'status_then': '公務員',
#   'code': 'VS00761',
#   'production_date': '2002/03/29'},
#  {'id': 66,
#   'name': '潮|富江',
#   'slug': '/pdbj/detail/255016',
#   'sex': '女性',
#   'age_exposure': '14',
#   'status_then': '学生',
#   'code': 'VS01067',
#   'production_date': '2017/02/28'},
#  {'id': 67,
#   'name': '宇根|利枝',
#   'slug': '/pdbj/detail/207850',
#   'sex': '女性',
#   'age_exposure': '26',
#   'status_then': '軍関係',
#   'code': 'VS00306',
#   'production_date': '1992/08/01'},
#  {'id': 68,
#   'name': '畝|義信',
#   'slug': '/pdbj/detail/206977',
#   'sex': '男性',
#   'age_exposure': '23',
#   'status_then': '会社員（工場長）',
#   'code': 'VS00092',
#   'production_date': '1987/08/01'},
#  {'id': 69,
#   'name': '梅田|義文',
#   'slug': '/pdbj/detail/206932',
#   'sex': '男性',
#   'age_exposure': '31',
#   'status_then': '歯科医',
#   'code': 'VS00025',
#   'production_date': '1986/08/01'},
#  {'id': 70,
#   'name': '江川|政市',
#   'slug': '/pdbj/detail/208289',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '',
#   'code': 'VS00954',
#   'production_date': '2010/03/31'},
#  {'id': 71,
#   'name': '江川|優',
#   'slug': '/pdbj/detail/207353',
#   'sex': '男性',
#   'age_exposure': '12',
#   'status_then': '学生（国民学校6年生）',
#   'code': 'VS00670',
#   'production_date': '2000/03/31'},
#  {'id': 72,
#   'name': '江種|祐司',
#   'slug': '/pdbj/detail/207264',
#   'sex': '男性',
#   'age_exposure': '17',
#   'status_then': '学生（本科1年生）',
#   'code': 'VS00539',
#   'production_date': '1996/09/30'},
#  {'id': 73,
#   'name': '枝松|きみ子',
#   'slug': '/pdbj/detail/207573',
#   'sex': '女性',
#   'age_exposure': '19',
#   'status_then': '公務員',
#   'code': 'VS00793',
#   'production_date': '2002/03/29'},
#  {'id': 74,
#   'name': '煙石（土井）二三枝',
#   'slug': '/pdbj/detail/206925',
#   'sex': '女性',
#   'age_exposure': '24',
#   'status_then': '公務員',
#   'code': 'VS00011',
#   'production_date': '1986/08/01'},
#  {'id': 75,
#   'name': '塩冶|節子',
#   'slug': '/pdbj/detail/208247',
#   'sex': '女性',
#   'age_exposure': '5',
#   'status_then': '',
#   'code': 'VS00884',
#   'production_date': '2007/03/31'},
#  {'id': 76,
#   'name': '呉|炳洙',
#   'slug': '/pdbj/detail/207247',
#   'sex': '男性',
#   'age_exposure': '14',
#   'status_then': '学生（国民学校6年生）',
#   'code': 'VS00505',
#   'production_date': '1996/09/30'},
#  {'id': 77,
#   'name': '呉|鳳寿',
#   'slug': '/pdbj/detail/207915',
#   'sex': '男性',
#   'age_exposure': '37',
#   'status_then': '',
#   'code': 'VS00192',
#   'production_date': '1989/08/01'},
#  {'id': 78,
#   'name': '大咲|春雄',
#   'slug': '/pdbj/detail/244041',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '学生（崇徳中学校3年生）',
#   'code': 'VS01039',
#   'production_date': '2016/03/31'},
#  {'id': 79,
#   'name': '大田|潤子',
#   'slug': '/pdbj/detail/208350',
#   'sex': '女性',
#   'age_exposure': '14',
#   'status_then': '学生（女学校3年生）',
#   'code': 'VS01015',
#   'production_date': '2014/02/28'},
#  {'id': 80,
#   'name': '大谷|勝彦',
#   'slug': '/pdbj/detail/207703',
#   'sex': '男性',
#   'age_exposure': '26',
#   'status_then': '会社員',
#   'code': 'VS00396',
#   'production_date': '1993/08/01'},
#  {'id': 81,
#   'name': '大谷|邦隆',
#   'slug': '/pdbj/detail/207704',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '学生',
#   'code': 'VS00736',
#   'production_date': '2001/03/31'},
#  {'id': 82,
#   'name': '大塚|宗元',
#   'slug': '/pdbj/detail/207020',
#   'sex': '男性',
#   'age_exposure': '23',
#   'status_then': '軍人',
#   'code': 'VS00153',
#   'production_date': '1989/08/01'},
#  {'id': 83,
#   'name': '大戸|絹江',
#   'slug': '/pdbj/detail/207702',
#   'sex': '女性',
#   'age_exposure': '19',
#   'status_then': '公務員',
#   'code': 'VS00776',
#   'production_date': '2002/03/29'},
#  {'id': 84,
#   'name': '大野|逸美',
#   'slug': '/pdbj/detail/208193',
#   'sex': '男性',
#   'age_exposure': '14',
#   'status_then': '',
#   'code': 'VS00909',
#   'production_date': '2008/03/31'},
#  {'id': 85,
#   'name': '大場|孝子',
#   'slug': '/pdbj/detail/207345',
#   'sex': '女性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00657',
#   'production_date': '2000/03/31'},
#  {'id': 86,
#   'name': '大場|正雄',
#   'slug': '/pdbj/detail/207338',
#   'sex': '男性',
#   'age_exposure': '19',
#   'status_then': '学生',
#   'code': 'VS00643',
#   'production_date': '1999/03/31'},
#  {'id': 87,
#   'name': '大林|ユキエ',
#   'slug': '/pdbj/detail/207232',
#   'sex': '女性',
#   'age_exposure': '26',
#   'status_then': '主婦',
#   'code': 'VS00479',
#   'production_date': '1995/08/01'},
#  {'id': 88,
#   'name': '大林|芳典',
#   'slug': '/pdbj/detail/207707',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '',
#   'code': 'VS00684',
#   'production_date': '2000/03/31'},
#  {'id': 89,
#   'name': '大前|辰男',
#   'slug': '/pdbj/detail/208191',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '公務員',
#   'code': 'VS00885',
#   'production_date': '2007/03/31'},
#  {'id': 90,
#   'name': '大前|正己',
#   'slug': '/pdbj/detail/207146',
#   'sex': '男性',
#   'age_exposure': '32',
#   'status_then': '会社員',
#   'code': 'VS00330',
#   'production_date': '1992/08/01'},
#  {'id': 91,
#   'name': '岡|保',
#   'slug': '/pdbj/detail/208098',
#   'sex': '男性',
#   'age_exposure': '21',
#   'status_then': '学生',
#   'code': 'VS00901-08',
#   'production_date': '2005/09/08'},
#  {'id': 92,
#   'name': '岡|ヨシエ',
#   'slug': '/pdbj/detail/206955',
#   'sex': '女性',
#   'age_exposure': '14',
#   'status_then': '学生',
#   'code': 'VS00054',
#   'production_date': '1987/08/01'},
#  {'id': 93,
#   'name': '岡崎|秀彦',
#   'slug': '/pdbj/detail/207133',
#   'sex': '男性',
#   'age_exposure': '17',
#   'status_then': '学生',
#   'code': 'VS00308',
#   'production_date': '1992/08/01'},
#  {'id': 94,
#   'name': '岡田|昭典',
#   'slug': '/pdbj/detail/208290',
#   'sex': '男性',
#   'age_exposure': '17',
#   'status_then': '',
#   'code': 'VS00955',
#   'production_date': '2010/03/31'},
#  {'id': 95,
#   'name': '岡田|イツヱ',
#   'slug': '/pdbj/detail/208386',
#   'sex': '女性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS01027',
#   'production_date': '2015/03/31'},
#  {'id': 96,
#   'name': '岡田|恵美子',
#   'slug': '/pdbj/detail/207397',
#   'sex': '女性',
#   'age_exposure': '8',
#   'status_then': '学生（尾長国民学校3年）',
#   'code': 'VS00747',
#   'production_date': '2001/03/31'},
#  {'id': 97,
#   'name': '岡田|ヒサヱ',
#   'slug': '/pdbj/detail/208085',
#   'sex': '女性',
#   'age_exposure': '16',
#   'status_then': '',
#   'code': 'VS00886',
#   'production_date': '2007/03/31'},
#  {'id': 98,
#   'name': '岡田|八十吉',
#   'slug': '/pdbj/detail/207154',
#   'sex': '男性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00344',
#   'production_date': '1992/08/01'},
#  {'id': 99,
#   'name': '岡田|能則',
#   'slug': '/pdbj/detail/208250',
#   'sex': '男性',
#   'age_exposure': '17',
#   'status_then': '軍属',
#   'code': 'VS00887',
#   'production_date': '2007/03/31'},
#  {'id': 100,
#   'name': '岡田|六郎',
#   'slug': '/pdbj/detail/207021',
#   'sex': '男性',
#   'age_exposure': '23',
#   'status_then': '軍人',
#   'code': 'VS00154',
#   'production_date': '1989/08/01'},
#  {'id': 101,
#   'name': '岡野|房江',
#   'slug': '/pdbj/detail/207332',
#   'sex': '女性',
#   'age_exposure': '38',
#   'status_then': '',
#   'code': 'VS00635',
#   'production_date': '1999/03/31'},
#  {'id': 102,
#   'name': '岡之下|要',
#   'slug': '/pdbj/detail/207861',
#   'sex': '男性',
#   'age_exposure': '28',
#   'status_then': '会社員',
#   'code': 'VS00216',
#   'production_date': '1990/08/01'},
#  {'id': 103,
#   'name': '岡村|悦弥',
#   'slug': '/pdbj/detail/208086',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '学生（旧制中学4年生）',
#   'code': 'VS00888',
#   'production_date': '2007/03/31'},
#  {'id': 104,
#   'name': '岡村|恂子',
#   'slug': '/pdbj/detail/208251',
#   'sex': '女性',
#   'age_exposure': '16',
#   'status_then': '学生',
#   'code': 'VS00927',
#   'production_date': '2009/03/31'},
#  {'id': 105,
#   'name': '岡本|剛毅',
#   'slug': '/pdbj/detail/208315',
#   'sex': '男性',
#   'age_exposure': '9',
#   'status_then': '学生（国民学校4年生）',
#   'code': 'VS00981',
#   'production_date': '2011/03/31'},
#  {'id': 106,
#   'name': '岡本|亨',
#   'slug': '/pdbj/detail/208329',
#   'sex': '男性',
#   'age_exposure': '8',
#   'status_then': '',
#   'code': 'VS00995',
#   'production_date': '2012/03/31'},
#  {'id': 107,
#   'name': '岡本|敏行',
#   'slug': '/pdbj/detail/208073',
#   'sex': '男性',
#   'age_exposure': '18',
#   'status_then': '軍属',
#   'code': 'VS00864',
#   'production_date': '2006/03/31'},
#  {'id': 108,
#   'name': '小笠原|春子',
#   'slug': '/pdbj/detail/207595',
#   'sex': '女性',
#   'age_exposure': '13',
#   'status_then': '',
#   'code': 'VS00029',
#   'production_date': '1986/08/01'},
#  {'id': 109,
#   'name': '小方|澄子',
#   'slug': '/pdbj/detail/273368',
#   'sex': '女性',
#   'age_exposure': '13',
#   'status_then': '中学2年生',
#   'code': 'VS01087',
#   'production_date': '2019/02/28'},
#  {'id': 110,
#   'name': '小川|勝澄',
#   'slug': '/pdbj/detail/207603',
#   'sex': '男性',
#   'age_exposure': '17',
#   'status_then': '軍人',
#   'code': 'VS00332',
#   'production_date': '1992/08/01'},
#  {'id': 111,
#   'name': '小川|紀子',
#   'slug': '/pdbj/detail/207602',
#   'sex': '女性',
#   'age_exposure': '12',
#   'status_then': '学生',
#   'code': 'VS00734',
#   'production_date': '2001/03/31'},
#  {'id': 112,
#   'name': '沖本|重雄',
#   'slug': '/pdbj/detail/207065',
#   'sex': '男性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00210',
#   'production_date': '1990/08/01'},
#  {'id': 113,
#   'name': '奥田|榮',
#   'slug': '/pdbj/detail/207343',
#   'sex': '男性',
#   'age_exposure': '8',
#   'status_then': '学生（国民学校3年生）',
#   'code': 'VS00652',
#   'production_date': '2000/03/31'},
#  {'id': 114,
#   'name': '小倉|桂子',
#   'slug': '/pdbj/detail/208346',
#   'sex': '女性',
#   'age_exposure': '8',
#   'status_then': '学生（国民学校2年生）',
#   'code': 'VS01012',
#   'production_date': '2013/03/31'},
#  {'id': 115,
#   'name': '小椋|俊次',
#   'slug': '/pdbj/detail/208322',
#   'sex': '男性',
#   'age_exposure': '14',
#   'status_then': '学生（国民学校高等科）',
#   'code': 'VS00988',
#   'production_date': '2012/03/31'},
#  {'id': 116,
#   'name': '小倉|美代子',
#   'slug': '/pdbj/detail/207234',
#   'sex': '女性',
#   'age_exposure': '22',
#   'status_then': '主婦',
#   'code': 'VS00482',
#   'production_date': '1995/08/01'},
#  {'id': 117,
#   'name': '小倉|要一',
#   'slug': '/pdbj/detail/207237',
#   'sex': '男性',
#   'age_exposure': '26',
#   'status_then': '軍人',
#   'code': 'VS00485',
#   'production_date': '1995/08/01'},
#  {'id': 118,
#   'name': '小田|敬三',
#   'slug': '/pdbj/detail/207611',
#   'sex': '男性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00572',
#   'production_date': '1998/02/28'},
#  {'id': 119,
#   'name': '小田|貞枝',
#   'slug': '/pdbj/detail/273191',
#   'sex': '女性',
#   'age_exposure': '20',
#   'status_then': '公務員（車掌）',
#   'code': 'VS01078',
#   'production_date': '2019/02/28'},
#  {'id': 120,
#   'name': '小田|安彦',
#   'slug': '/pdbj/detail/207610',
#   'sex': '男性',
#   'age_exposure': '22',
#   'status_then': '軍人',
#   'code': 'VS00335',
#   'production_date': '1992/08/01'},
#  {'id': 121,
#   'name': '尾谷|美和子',
#   'slug': '/pdbj/detail/207432',
#   'sex': '女性',
#   'age_exposure': '8',
#   'status_then': '学生（国民学校2年生）',
#   'code': 'VS00817',
#   'production_date': '2003/03/31'},
#  {'id': 122,
#   'name': '尾糠|政美',
#   'slug': '/pdbj/detail/207134',
#   'sex': '男性',
#   'age_exposure': '24',
#   'status_then': '軍人',
#   'code': 'VS00309',
#   'production_date': '1992/08/01'},
#  {'id': 123,
#   'name': '尾上|一男',
#   'slug': '/pdbj/detail/207226',
#   'sex': '男性',
#   'age_exposure': '38',
#   'status_then': '会社員',
#   'code': 'VS00471',
#   'production_date': '1995/08/01'},
#  {'id': 124,
#   'name': '小野岡|義尭',
#   'slug': '/pdbj/detail/207612',
#   'sex': '男性',
#   'age_exposure': '13',
#   'status_then': '学生（商業学校2年生）',
#   'code': 'VS00789',
#   'production_date': '2002/03/29'},
#  {'id': 125,
#   'name': '小野木|明',
#   'slug': '/pdbj/detail/207615',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '学生（中学校2年生）',
#   'code': 'VS00019',
#   'production_date': '1986/08/01'},
#  {'id': 126,
#   'name': '面田|孝子',
#   'slug': '/pdbj/detail/207116',
#   'sex': '女性',
#   'age_exposure': '20',
#   'status_then': '看護婦',
#   'code': 'VS00279',
#   'production_date': '1991/08/01'},
#  {'id': 127,
#   'name': '折川|健',
#   'slug': '/pdbj/detail/208319',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '学生（西条農学校3年生）',
#   'code': 'VS00985',
#   'production_date': '2012/03/31'},
#  {'id': 128,
#   'name': '折免|シゲコ',
#   'slug': '/pdbj/detail/207687',
#   'sex': '女性',
#   'age_exposure': '37',
#   'status_then': '主婦',
#   'code': 'VS00237',
#   'production_date': '1990/08/01'},
#  {'id': 129,
#   'name': '貝川|百合子',
#   'slug': '/pdbj/detail/207872',
#   'sex': '女性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00004',
#   'production_date': '1986/08/01'},
#  {'id': 130,
#   'name': '香川|邦昭',
#   'slug': '/pdbj/detail/207346',
#   'sex': '男性',
#   'age_exposure': '8',
#   'status_then': '学生',
#   'code': 'VS00658',
#   'production_date': '2000/03/31'},
#  {'id': 131,
#   'name': '賀川|智子',
#   'slug': '/pdbj/detail/207871',
#   'sex': '女性',
#   'age_exposure': '18',
#   'status_then': '軍人',
#   'code': 'VS00126',
#   'production_date': '1988/08/01'},
#  {'id': 132,
#   'name': '香川|フミコ',
#   'slug': '/pdbj/detail/207206',
#   'sex': '女性',
#   'age_exposure': '20',
#   'status_then': '主婦',
#   'code': 'VS00432',
#   'production_date': '1994/08/01'},
#  {'id': 133,
#   'name': '鍵本|泉',
#   'slug': '/pdbj/detail/208275',
#   'sex': '男性',
#   'age_exposure': '12',
#   'status_then': '学生',
#   'code': 'VS00940',
#   'production_date': '2009/03/31'},
#  {'id': 134,
#   'name': '郭|貴勲',
#   'slug': '/pdbj/detail/207874',
#   'sex': '男性',
#   'age_exposure': '21',
#   'status_then': '軍人',
#   'code': 'VS00443',
#   'production_date': '1994/08/01'},
#  {'id': 135,
#   'name': '郭|福順',
#   'slug': '/pdbj/detail/206992',
#   'sex': '女性',
#   'age_exposure': '16',
#   'status_then': '',
#   'code': 'VS00106',
#   'production_date': '1988/08/01'},
#  {'id': 136,
#   'name': '笠岡|貞江',
#   'slug': '/pdbj/detail/207363',
#   'sex': '女性',
#   'age_exposure': '13',
#   'status_then': '学生（女学校1年生）',
#   'code': 'VS00689',
#   'production_date': '2000/03/31'},
#  {'id': 137,
#   'name': '柏原|光哉',
#   'slug': '/pdbj/detail/208209',
#   'sex': '男性',
#   'age_exposure': '17',
#   'status_then': '公務員',
#   'code': 'VS00889',
#   'production_date': '2007/03/31'},
#  {'id': 138,
#   'name': '柏|和行',
#   'slug': '/pdbj/detail/207773',
#   'sex': '男性',
#   'age_exposure': '13',
#   'status_then': '学生（国民学校高等科1年）',
#   'code': 'VS00724',
#   'production_date': '2001/03/31'},
#  {'id': 139,
#   'name': '梶本|忠司',
#   'slug': '/pdbj/detail/207889',
#   'sex': '男性',
#   'age_exposure': '13',
#   'status_then': '学生（中学校2年生）',
#   'code': 'VS00679',
#   'production_date': '2000/03/31'},
#  {'id': 140,
#   'name': '梶本|淑子',
#   'slug': '/pdbj/detail/207890',
#   'sex': '女性',
#   'age_exposure': '14',
#   'status_then': '学生（安田高等女学校3年）',
#   'code': 'VS00746',
#   'production_date': '2001/03/31'},
#  {'id': 141,
#   'name': '梶山|雅子',
#   'slug': '/pdbj/detail/207215',
#   'sex': '女性',
#   'age_exposure': '12',
#   'status_then': '学生',
#   'code': 'VS00450',
#   'production_date': '1994/08/01'},
#  {'id': 142,
#   'name': '数村|京子',
#   'slug': '/pdbj/detail/207023',
#   'sex': '女性',
#   'age_exposure': '16',
#   'status_then': '軍人',
#   'code': 'VS00157',
#   'production_date': '1989/08/01'},
#  {'id': 143,
#   'name': '風藤|昭三',
#   'slug': '/pdbj/detail/208113',
#   'sex': '男性',
#   'age_exposure': '17',
#   'status_then': '公務員',
#   'code': 'VS00926',
#   'production_date': '2009/03/31'},
#  {'id': 144,
#   'name': '片岡|脩',
#   'slug': '/pdbj/detail/206991',
#   'sex': '男性',
#   'age_exposure': '13',
#   'status_then': '学生',
#   'code': 'VS00105',
#   'production_date': '1988/08/01'},
#  {'id': 145,
#   'name': '片桐|豊彦',
#   'slug': '/pdbj/detail/207371',
#   'sex': '男性',
#   'age_exposure': '12',
#   'status_then': '学生（国民学校高等科1年）',
#   'code': 'VS00704',
#   'production_date': '2001/03/31'},
#  {'id': 146,
#   'name': '片山|喜美恵',
#   'slug': '/pdbj/detail/207322',
#   'sex': '女性',
#   'age_exposure': '22',
#   'status_then': '',
#   'code': 'VS00620',
#   'production_date': '1999/03/31'},
#  {'id': 147,
#   'name': '勝谷|博敬',
#   'slug': '/pdbj/detail/208325',
#   'sex': '男性',
#   'age_exposure': '12',
#   'status_then': '学生（中学校1年生）',
#   'code': 'VS00991',
#   'production_date': '2012/03/31'},
#  {'id': 148,
#   'name': '桂|将晃',
#   'slug': '/pdbj/detail/208274',
#   'sex': '男性',
#   'age_exposure': '5',
#   'status_then': '',
#   'code': 'VS00915',
#   'production_date': '2008/03/31'},
#  {'id': 149,
#   'name': '加藤|喜久恵',
#   'slug': '/pdbj/detail/207865',
#   'sex': '女性',
#   'age_exposure': '17',
#   'status_then': '公務員（市職員）',
#   'code': 'VS00739',
#   'production_date': '2001/03/31'},
#  {'id': 150,
#   'name': '加藤|久男',
#   'slug': '/pdbj/detail/207295',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '学生',
#   'code': 'VS00582',
#   'production_date': '1998/02/28'},
#  {'id': 151,
#   'name': '加藤|ヒサヨ',
#   'slug': '/pdbj/detail/208059',
#   'sex': '女性',
#   'age_exposure': '27',
#   'status_then': '主婦',
#   'code': 'VS00841',
#   'production_date': '2005/03/31'},
#  {'id': 152,
#   'name': '加藤|浩',
#   'slug': '/pdbj/detail/207433',
#   'sex': '男性',
#   'age_exposure': '14',
#   'status_then': '学生（中学校3年生）',
#   'code': 'VS00818',
#   'production_date': '2003/03/31'},
#  {'id': 153,
#   'name': '加藤|義典',
#   'slug': '/pdbj/detail/207372',
#   'sex': '男性',
#   'age_exposure': '17',
#   'status_then': '学生（広島工業専門学校1年）',
#   'code': 'VS00705',
#   'production_date': '2001/03/31'},
#  {'id': 154,
#   'name': '角川|ミヤ子',
#   'slug': '/pdbj/detail/207873',
#   'sex': '女性',
#   'age_exposure': '18',
#   'status_then': '軍人',
#   'code': 'VS00311',
#   'production_date': '1992/08/01'},
#  {'id': 155,
#   'name': '金井|法子',
#   'slug': '/pdbj/detail/207906',
#   'sex': '女性',
#   'age_exposure': '16',
#   'status_then': '公務員',
#   'code': 'VS00102',
#   'production_date': '1988/08/01'},
#  {'id': 156,
#   'name': '金子|一士',
#   'slug': '/pdbj/detail/207279',
#   'sex': '男性',
#   'age_exposure': '19',
#   'status_then': '会社員',
#   'code': 'VS00562',
#   'production_date': '1998/02/28'},
#  {'id': 157,
#   'name': '金子|堅',
#   'slug': '/pdbj/detail/208061',
#   'sex': '男性',
#   'age_exposure': '19',
#   'status_then': '軍人',
#   'code': 'VS00846',
#   'production_date': '2005/03/31'},
#  {'id': 158,
#   'name': '金子|軍二',
#   'slug': '/pdbj/detail/207088',
#   'sex': '男性',
#   'age_exposure': '40',
#   'status_then': '会社員',
#   'code': 'VS00240',
#   'production_date': '1990/08/01'},
#  {'id': 159,
#   'name': '金子|弘',
#   'slug': '/pdbj/detail/207905',
#   'sex': '男性',
#   'age_exposure': '13',
#   'status_then': '学生',
#   'code': 'VS00362',
#   'production_date': '1993/08/01'},
#  {'id': 160,
#   'name': '金崎|是',
#   'slug': '/pdbj/detail/207100',
#   'sex': '男性',
#   'age_exposure': '28',
#   'status_then': '会社員',
#   'code': 'VS00254',
#   'production_date': '1991/08/01'},
#  {'id': 161,
#   'name': '金山|栄',
#   'slug': '/pdbj/detail/207907',
#   'sex': '女性',
#   'age_exposure': '15',
#   'status_then': '公務員',
#   'code': 'VS00804',
#   'production_date': '2003/03/31'},
#  {'id': 162,
#   'name': '神川|好子',
#   'slug': '/pdbj/detail/207383',
#   'sex': '女性',
#   'age_exposure': '16',
#   'status_then': '学生',
#   'code': 'VS00720',
#   'production_date': '2001/03/31'},
#  {'id': 163,
#   'name': '亀沢|深雪',
#   'slug': '/pdbj/detail/207025',
#   'sex': '女性',
#   'age_exposure': '17',
#   'status_then': '',
#   'code': 'VS00159',
#   'production_date': '1989/08/01'},
#  {'id': 164,
#   'name': '加茂|一三',
#   'slug': '/pdbj/detail/208316',
#   'sex': '男性',
#   'age_exposure': '18',
#   'status_then': '学生（師範学校1年）',
#   'code': 'VS00982',
#   'production_date': '2011/03/31'},
#  {'id': 165,
#   'name': '嘉屋|文子',
#   'slug': '/pdbj/detail/206933',
#   'sex': '女性',
#   'age_exposure': '32',
#   'status_then': '医師',
#   'code': 'VS00027',
#   'production_date': '1986/08/01'},
#  {'id': 166,
#   'name': '唐川|隆三',
#   'slug': '/pdbj/detail/208295',
#   'sex': '男性',
#   'age_exposure': '14',
#   'status_then': '',
#   'code': 'VS00960',
#   'production_date': '2010/03/31'},
#  {'id': 167,
#   'name': '雁金|義男',
#   'slug': '/pdbj/detail/208064',
#   'sex': '男性',
#   'age_exposure': '22',
#   'status_then': '会社員',
#   'code': 'VS00850',
#   'production_date': '2005/03/31'},
#  {'id': 168,
#   'name': '川上|貞光',
#   'slug': '/pdbj/detail/207162',
#   'sex': '男性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00361',
#   'production_date': '1993/08/01'},
#  {'id': 169,
#   'name': '川上|政子',
#   'slug': '/pdbj/detail/207165',
#   'sex': '女性',
#   'age_exposure': '16',
#   'status_then': '看護学生',
#   'code': 'VS00367',
#   'production_date': '1993/08/01'},
#  {'id': 170,
#   'name': '川口|アヤ子',
#   'slug': '/pdbj/detail/207394',
#   'sex': '女性',
#   'age_exposure': '32',
#   'status_then': '家業手伝い',
#   'code': 'VS00740',
#   'production_date': '2001/03/31'},
#  {'id': 171,
#   'name': '川田|一朝',
#   'slug': '/pdbj/detail/207689',
#   'sex': '男性',
#   'age_exposure': '14',
#   'status_then': '学生',
#   'code': 'VS00439',
#   'production_date': '1994/08/01'},
#  {'id': 172,
#   'name': '川西|恒夫',
#   'slug': '/pdbj/detail/207198',
#   'sex': '男性',
#   'age_exposure': '32',
#   'status_then': '会社員',
#   'code': 'VS00417',
#   'production_date': '1994/08/01'},
#  {'id': 173,
#   'name': '川野|昭生',
#   'slug': '/pdbj/detail/207691',
#   'sex': '男性',
#   'age_exposure': '15',
#   'status_then': '軍属',
#   'code': 'VS00831',
#   'production_date': '2004/03/31'},
#  {'id': 174,
#   'name': '川村|淳子',
#   'slug': '/pdbj/detail/207083',
#   'sex': '女性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00232',
#   'production_date': '1990/08/01'},
#  {'id': 175,
#   'name': '河村|照子',
#   'slug': '/pdbj/detail/207340',
#   'sex': '女性',
#   'age_exposure': '18',
#   'status_then': '会社員',
#   'code': 'VS00647',
#   'production_date': '1999/03/31'},
#  {'id': 176,
#   'name': '河村|日出男',
#   'slug': '/pdbj/detail/208254',
#   'sex': '男性',
#   'age_exposure': '21',
#   'status_then': '学生',
#   'code': 'VS00901-11',
#   'production_date': '2005/09/08'},
#  {'id': 177,
#   'name': '川本|省三',
#   'slug': '/pdbj/detail/208340',
#   'sex': '男性',
#   'age_exposure': '11',
#   'status_then': '学生（国民学校6年生）',
#   'code': 'VS01006',
#   'production_date': '2013/03/31'},
#  {'id': 178,
#   'name': '川本|艶子',
#   'slug': '/pdbj/detail/207692',
#   'sex': '女性',
#   'age_exposure': '19',
#   'status_then': '学生',
#   'code': 'VS00637',
#   'production_date': '1999/03/31'},
#  {'id': 179,
#   'name': '川本|政子',
#   'slug': '/pdbj/detail/207312',
#   'sex': '女性',
#   'age_exposure': '27',
#   'status_then': '会社員',
#   'code': 'VS00602',
#   'production_date': '1999/03/31'},
#  {'id': 180,
#   'name': '川本|政子',
#   'slug': '/pdbj/detail/207354',
#   'sex': '女性',
#   'age_exposure': '23',
#   'status_then': '主婦',
#   'code': 'VS00672',
#   'production_date': '2000/03/31'},
#  {'id': 181,
#   'name': '川本|義隆',
#   'slug': '/pdbj/detail/206920',
#   'sex': '男性',
#   'age_exposure': '13',
#   'status_then': '学生',
#   'code': 'VS00005',
#   'production_date': '1986/08/01'},
#  {'id': 182,
#   'name': '姜|周泰',
#   'slug': '/pdbj/detail/208300',
#   'sex': '男性',
#   'age_exposure': '6',
#   'status_then': '',
#   'code': 'VS00965',
#   'production_date': '2011/03/31'},
#  {'id': 183,
#   'name': '姜|文煕',
#   'slug': '/pdbj/detail/207833',
#   'sex': '男性',
#   'age_exposure': '26',
#   'status_then': '会社員',
#   'code': 'VS00142',
#   'production_date': '1988/08/01'},
#  {'id': 184,
#   'name': '神田|一子',
#   'slug': '/pdbj/detail/207289',
#   'sex': '女性',
#   'age_exposure': '23',
#   'status_then': '看護婦',
#   'code': 'VS00575',
#   'production_date': '1998/02/28'},
#  {'id': 185,
#   'name': '神戸|友恵',
#   'slug': '/pdbj/detail/207657',
#   'sex': '女性',
#   'age_exposure': '23',
#   'status_then': '主婦',
#   'code': 'VS00828',
#   'production_date': '2004/03/31'},
#  {'id': 186,
#   'name': '木佐木|輝雄',
#   'slug': '/pdbj/detail/208097',
#   'sex': '男性',
#   'age_exposure': '21',
#   'status_then': '学生',
#   'code': 'VS00901-07',
#   'production_date': '2005/09/08'},
#  {'id': 187,
#   'name': '北|勲',
#   'slug': '/pdbj/detail/207804',
#   'sex': '男性',
#   'age_exposure': '34',
#   'status_then': '公務員',
#   'code': 'VS00041',
#   'production_date': '1986/08/01'},
#  {'id': 188,
#   'name': '北川|勝子',
#   'slug': '/pdbj/detail/208288',
#   'sex': '女性',
#   'age_exposure': '16',
#   'status_then': '',
#   'code': 'VS00953',
#   'production_date': '2010/03/31'},
#  {'id': 189,
#   'name': '北川|建次',
#   'slug': '/pdbj/detail/207350',
#   'sex': '男性',
#   'age_exposure': '10',
#   'status_then': '学生',
#   'code': 'VS00665',
#   'production_date': '2000/03/31'},
#  {'id': 190,
#   'name': '北川|洸太郎',
#   'slug': '/pdbj/detail/208100',
#   'sex': '男性',
#   'age_exposure': '21',
#   'status_then': '学生',
#   'code': 'VS00901-14',
#   'production_date': '2005/09/08'},
#  {'id': 191,
#   'name': '北川|哲',
#   'slug': '/pdbj/detail/207806',
#   'sex': '男性',
#   'age_exposure': '22',
#   'status_then': '会社員',
#   'code': 'VS00107',
#   'production_date': '1988/08/01'},
#  {'id': 192,
#   'name': '衣笠|允子',
#   'slug': '/pdbj/detail/207846',
#   'sex': '女性',
#   'age_exposure': '20',
#   'status_then': '学生',
#   'code': 'VS00820',
#   'production_date': '2003/03/31'},
#  {'id': 193,
#   'name': '木下（益田）稜子',
#   'slug': '/pdbj/detail/207855',
#   'sex': '女性',
#   'age_exposure': '5',
#   'status_then': '主婦',
#   'code': 'VS00659',
#   'production_date': '2000/03/31'},
#  {'id': 194,
#   'name': '木村|巖',
#   'slug': '/pdbj/detail/208323',
#   'sex': '男性',
#   'age_exposure': '13',
#   'status_then': '学生（市立造船工業学校2年生）',
#   'code': 'VS00989',
#   'production_date': '2012/03/31'},
#  {'id': 195,
#   'name': '木村|絹枝',
#   'slug': '/pdbj/detail/207156',
#   'sex': '女性',
#   'age_exposure': '13',
#   'status_then': '学生',
#   'code': 'VS00349',
#   'production_date': '1992/08/01'},
#  {'id': 196,
#   'name': '木村|静香',
#   'slug': '/pdbj/detail/207424',
#   'sex': '女性',
#   'age_exposure': '16',
#   'status_then': '公務員',
#   'code': 'VS00802',
#   'production_date': '2003/03/31'},
#  {'id': 197,
#   'name': '木村|十七吉',
#   'slug': '/pdbj/detail/208066',
#   'sex': '男性',
#   'age_exposure': '8',
#   'status_then': '学生',
#   'code': 'VS00853',
#   'production_date': '2005/03/31'},
#  {'id': 198,
#   'name': '木村|進匡',
#   'slug': '/pdbj/detail/207045',
#   'sex': '男性',
#   'age_exposure': '8',
#   'status_then': '医師',
#   'code': 'VS00185',
#   'production_date': '1989/08/01'},
#  {'id': 199,
#   'name': '木村|秀男',
#   'slug': '/pdbj/detail/208101',
#   'sex': '男性',
#   'age_exposure': '12',
#   'status_then': '',
#   'code': 'VS00902',
#   'production_date': '2008/03/31'},
#  {'id': 200,
#   'name': '木村|裕彦',
#   'slug': '/pdbj/detail/207317',
#   'sex': '男性',
#   'age_exposure': '14',
#   'status_then': '学生',
#   'code': 'VS00611',
#   'production_date': '1999/03/31'},
#  {'id': 201,
#   'name': '木村|保雄',
#   'slug': '/pdbj/detail/207153',
#   'sex': '男性',
#   'age_exposure': '18',
#   'status_then': '僧侶',
#   'code': 'VS00343',
#   'production_date': '1992/08/01'},
#  {'id': 202,
#   'name': '金|尚鳳',
#   'slug': '/pdbj/detail/207258',
#   'sex': '男性',
#   'age_exposure': '18',
#   'status_then': '公務員',
#   'code': 'VS00526',
#   'production_date': '1996/09/30'},
#  {'id': 203,
#   'name': '久我|恒子',
#   'slug': '/pdbj/detail/244064',
#   'sex': '女性',
#   'age_exposure': '15',
#   'status_then': '学生（広島女子高等師範学校付属山中高等女学校4年生）',
#   'code': 'VS01046',
#   'production_date': '2016/03/31'},
#  {'id': 204,
#   'name': '九十歩|克三',
#   'slug': '/pdbj/detail/207164',
#   'sex': '男性',
#   'age_exposure': '15',
#   'status_then': '公務員',
#   'code': 'VS00365',
#   'production_date': '1993/08/01'},
#  {'id': 205,
#   'name': '國重|昌弘',
#   'slug': '/pdbj/detail/208298',
#   'sex': '男性',
#   'age_exposure': '14',
#   'status_then': '',
#   'code': 'VS00963',
#   'production_date': '2011/03/31'},
#  {'id': 206,
#   'name': '国広|茂久',
#   'slug': '/pdbj/detail/208094',
#   'sex': '男性',
#   'age_exposure': '21',
#   'status_then': '学生',
#   'code': 'VS00901-01',
#   'production_date': '2005/09/08'},
#  {'id': 207,
#   'name': '國分|良德',
#   'slug': '/pdbj/detail/207832',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '学生',
#   'code': 'VS00470',
#   'production_date': '1995/08/01'},
#  {'id': 208,
#   'name': '久保|伍',
#   'slug': '/pdbj/detail/208071',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '学生',
#   'code': 'VS00859',
#   'production_date': '2005/03/31'},
#  {'id': 209,
#   'name': '久保|行夫',
#   'slug': '/pdbj/detail/265011',
#   'sex': '男性',
#   'age_exposure': '3',
#   'status_then': '',
#   'code': 'VS01075',
#   'production_date': '2018/02/28'},
#  {'id': 210,
#   'name': '久保浦|寛人',
#   'slug': '/pdbj/detail/207006',
#   'sex': '男性',
#   'age_exposure': '19',
#   'status_then': '公務員',
#   'code': 'VS00135',
#   'production_date': '1988/08/01'},
#  {'id': 211,
#   'name': '久保田|省三',
#   'slug': '/pdbj/detail/207337',
#   'sex': '男性',
#   'age_exposure': '9',
#   'status_then': '学生',
#   'code': 'VS00642',
#   'production_date': '1999/03/31'},
#  {'id': 212,
#   'name': '熊岡|広太郎',
#   'slug': '/pdbj/detail/207136',
#   'sex': '男性',
#   'age_exposure': '27',
#   'status_then': '教職員',
#   'code': 'VS00313',
#   'production_date': '1992/08/01'},
#  {'id': 213,
#   'name': '熊田|照子',
#   'slug': '/pdbj/detail/208088',
#   'sex': '女性',
#   'age_exposure': '8',
#   'status_then': '学生（国民学校2年生）',
#   'code': 'VS00891',
#   'production_date': '2007/03/31'},
#  {'id': 214,
#   'name': '熊野|巧',
#   'slug': '/pdbj/detail/208072',
#   'sex': '男性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00861',
#   'production_date': '2006/03/31'},
#  {'id': 215,
#   'name': '蔵田|淑子',
#   'slug': '/pdbj/detail/207695',
#   'sex': '女性',
#   'age_exposure': '19',
#   'status_then': '会社員',
#   'code': 'VS00604',
#   'production_date': '1999/03/31'},
#  {'id': 216,
#   'name': '蔵本|淳',
#   'slug': '/pdbj/detail/207046',
#   'sex': '男性',
#   'age_exposure': '13',
#   'status_then': '学生',
#   'code': 'VS00186',
#   'production_date': '1989/08/01'},
#  {'id': 217,
#   'name': '倉本|寛司',
#   'slug': '/pdbj/detail/207015',
#   'sex': '男性',
#   'age_exposure': '19',
#   'status_then': '学生',
#   'code': 'VS00147',
#   'production_date': '1988/08/01'},
#  {'id': 218,
#   'name': '栗栖|冨子',
#   'slug': '/pdbj/detail/207209',
#   'sex': '女性',
#   'age_exposure': '14',
#   'status_then': '学生',
#   'code': 'VS00440',
#   'production_date': '1994/08/01'},
#  {'id': 219,
#   'name': '栗栖|勝',
#   'slug': '/pdbj/detail/207409',
#   'sex': '男性',
#   'age_exposure': '19',
#   'status_then': '会社員',
#   'code': 'VS00772',
#   'production_date': '2002/03/29'},
#  {'id': 220,
#   'name': '栗原|アヤコ',
#   'slug': '/pdbj/detail/207425',
#   'sex': '女性',
#   'age_exposure': '17',
#   'status_then': '学生（看護学校1年生）',
#   'code': 'VS00803',
#   'production_date': '2003/03/31'},
#  {'id': 221,
#   'name': '栗原|貞子',
#   'slug': '/pdbj/detail/207009',
#   'sex': '女性',
#   'age_exposure': '32',
#   'status_then': '詩人',
#   'code': 'VS00140',
#   'production_date': '1988/08/01'},
#  {'id': 222,
#   'name': '栗原|明子',
#   'slug': '/pdbj/detail/244094',
#   'sex': '女性',
#   'age_exposure': '19',
#   'status_then': '学生（広島女学院専門学校2年生）',
#   'code': 'VS01052',
#   'production_date': '2016/03/31'},
#  {'id': 223,
#   'name': '黒川|静枝',
#   'slug': '/pdbj/detail/208262',
#   'sex': '女性',
#   'age_exposure': '22',
#   'status_then': '',
#   'code': 'VS00904',
#   'production_date': '2008/03/31'},
#  {'id': 224,
#   'name': '黒川|富子',
#   'slug': '/pdbj/detail/207880',
#   'sex': '女性',
#   'age_exposure': '19',
#   'status_then': '会社員',
#   'code': 'VS00834',
#   'production_date': '2004/03/31'},
#  {'id': 225,
#   'name': '黒川|トモエ',
#   'slug': '/pdbj/detail/208092',
#   'sex': '女性',
#   'age_exposure': '12',
#   'status_then': '学生',
#   'code': 'VS00899',
#   'production_date': '2007/03/31'},
#  {'id': 226,
#   'name': '黒賀|良則',
#   'slug': '/pdbj/detail/254999',
#   'sex': '男性',
#   'age_exposure': '21',
#   'status_then': '軍人',
#   'code': 'VS01061',
#   'production_date': '2017/02/28'},
#  {'id': 227,
#   'name': '黒口|利三',
#   'slug': '/pdbj/detail/208063',
#   'sex': '男性',
#   'age_exposure': '32',
#   'status_then': '自営業',
#   'code': 'VS00849',
#   'production_date': '2005/03/31'},
#  {'id': 228,
#   'name': '桑原|君子',
#   'slug': '/pdbj/detail/208337',
#   'sex': '女性',
#   'age_exposure': '17',
#   'status_then': '',
#   'code': 'VS01003',
#   'production_date': '2013/03/31'},
#  {'id': 229,
#   'name': '桑原|房枝',
#   'slug': '/pdbj/detail/207909',
#   'sex': '女性',
#   'age_exposure': '41',
#   'status_then': '',
#   'code': 'VS00057',
#   'production_date': '1987/08/01'},
#  {'id': 230,
#   'name': '小出|静子',
#   'slug': '/pdbj/detail/244059',
#   'sex': '女性',
#   'age_exposure': '8',
#   'status_then': '学生（戸山国民学校3年生）',
#   'code': 'VS01044',
#   'production_date': '2016/03/31'},
#  {'id': 231,
#   'name': '河内|政子',
#   'slug': '/pdbj/detail/207870',
#   'sex': '女性',
#   'age_exposure': '16',
#   'status_then': '学生',
#   'code': 'VS00438',
#   'production_date': '1994/08/01'},
#  {'id': 232,
#   'name': '河内|光子',
#   'slug': '/pdbj/detail/208306',
#   'sex': '女性',
#   'age_exposure': '13',
#   'status_then': '学生（女学校2年生）',
#   'code': 'VS00972',
#   'production_date': '2011/03/31'},
#  {'id': 233,
#   'name': '河野|昭人',
#   'slug': '/pdbj/detail/265008',
#   'sex': '男性',
#   'age_exposure': '18',
#   'status_then': '広島電気学校2年生',
#   'code': 'VS01072',
#   'production_date': '2018/02/28'},
#  {'id': 234,
#   'name': '河野|キヨ美',
#   'slug': '/pdbj/detail/208255',
#   'sex': '女性',
#   'age_exposure': '14',
#   'status_then': '学生（女学校2年生）',
#   'code': 'VS00934',
#   'production_date': '2009/03/31'},
#  {'id': 235,
#   'name': '河野|ヂツミ',
#   'slug': '/pdbj/detail/207440',
#   'sex': '女性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00832',
#   'production_date': '2004/03/31'},
#  {'id': 236,
#   'name': '河野|正男',
#   'slug': '/pdbj/detail/207182',
#   'sex': '男性',
#   'age_exposure': '29',
#   'status_then': '会社員',
#   'code': 'VS00390',
#   'production_date': '1993/08/01'},
#  {'id': 237,
#   'name': '小谷|佐智枝',
#   'slug': '/pdbj/detail/208292',
#   'sex': '女性',
#   'age_exposure': '14',
#   'status_then': '',
#   'code': 'VS00957',
#   'production_date': '2010/03/31'},
#  {'id': 238,
#   'name': '古玉|静子',
#   'slug': '/pdbj/detail/207913',
#   'sex': '女性',
#   'age_exposure': '16',
#   'status_then': '公務員',
#   'code': 'VS00837',
#   'production_date': '2004/03/31'},
#  {'id': 239,
#   'name': '児玉|匡敏',
#   'slug': '/pdbj/detail/208291',
#   'sex': '男性',
#   'age_exposure': '14',
#   'status_then': '',
#   'code': 'VS00956',
#   'production_date': '2010/03/31'},
#  {'id': 240,
#   'name': '兒玉|光雄',
#   'slug': '/pdbj/detail/273324',
#   'sex': '男性',
#   'age_exposure': '12',
#   'status_then': '中学一年生',
#   'code': 'VS01083',
#   'production_date': '2019/02/28'},
#  {'id': 241,
#   'name': '児玉|年',
#   'slug': '/pdbj/detail/208151',
#   'sex': '男性',
#   'age_exposure': '17',
#   'status_then': '',
#   'code': 'VS00869',
#   'production_date': '2006/03/31'},
#  {'id': 242,
#   'name': '小林|謙二',
#   'slug': '/pdbj/detail/207614',
#   'sex': '男性',
#   'age_exposure': '14',
#   'status_then': '学生',
#   'code': 'VS00288',
#   'production_date': '1991/08/01'},
#  {'id': 243,
#   'name': '駒田|保',
#   'slug': '/pdbj/detail/207355',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '学生',
#   'code': 'VS00674',
#   'production_date': '2000/03/31'},
#  {'id': 244,
#   'name': '小松|清興',
#   'slug': '/pdbj/detail/206936',
#   'sex': '男性',
#   'age_exposure': '9',
#   'status_then': '学生',
#   'code': 'VS00033',
#   'production_date': '1986/08/01'},
#  {'id': 245,
#   'name': '近藤|齊',
#   'slug': '/pdbj/detail/244065',
#   'sex': '男性',
#   'age_exposure': '14',
#   'status_then': '学生（広島市立造船工業学校2年生）',
#   'code': 'VS01047',
#   'production_date': '2016/03/31'},
#  {'id': 246,
#   'name': '近藤|康子',
#   'slug': '/pdbj/detail/208273',
#   'sex': '女性',
#   'age_exposure': '4',
#   'status_then': '',
#   'code': 'VS00907',
#   'production_date': '2008/03/31'},
#  {'id': 247,
#   'name': '佐伯|敏子',
#   'slug': '/pdbj/detail/206943',
#   'sex': '女性',
#   'age_exposure': '26',
#   'status_then': '主婦',
#   'code': 'VS00046',
#   'production_date': '1986/08/01'},
#  {'id': 248,
#   'name': '佐伯|ひさ',
#   'slug': '/pdbj/detail/207434',
#   'sex': '女性',
#   'age_exposure': '26',
#   'status_then': '主婦',
#   'code': 'VS00821',
#   'production_date': '2004/03/31'},
#  {'id': 249,
#   'name': '佐伯|秀春',
#   'slug': '/pdbj/detail/207080',
#   'sex': '男性',
#   'age_exposure': '13',
#   'status_then': '学生',
#   'code': 'VS00229',
#   'production_date': '1990/08/01'},
#  {'id': 250,
#   'name': '細工|環',
#   'slug': '/pdbj/detail/207320',
#   'sex': '男性',
#   'age_exposure': '24',
#   'status_then': '公務員',
#   'code': 'VS00616',
#   'production_date': '1999/03/31'},
#  {'id': 251,
#   'name': '佐伯|一義',
#   'slug': '/pdbj/detail/207316',
#   'sex': '男性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00610',
#   'production_date': '1999/03/31'},
#  {'id': 252,
#   'name': '坂井|武彦',
#   'slug': '/pdbj/detail/206926',
#   'sex': '男性',
#   'age_exposure': '21',
#   'status_then': '軍人',
#   'code': 'VS00013',
#   'production_date': '1986/08/01'},
#  {'id': 253,
#   'name': '坂浦|トミエ',
#   'slug': '/pdbj/detail/208107',
#   'sex': '女性',
#   'age_exposure': '22',
#   'status_then': '',
#   'code': 'VS00914',
#   'production_date': '2008/03/31'},
#  {'id': 254,
#   'name': '坂倉|タカ子',
#   'slug': '/pdbj/detail/207204',
#   'sex': '女性',
#   'age_exposure': '19',
#   'status_then': '看護婦',
#   'code': 'VS00428',
#   'production_date': '1994/08/01'},
#  {'id': 255,
#   'name': '坂田|尚也',
#   'slug': '/pdbj/detail/208116',
#   'sex': '男性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00933',
#   'production_date': '2009/03/31'},
#  {'id': 256,
#   'name': '阪本|晋司',
#   'slug': '/pdbj/detail/207380',
#   'sex': '男性',
#   'age_exposure': '14',
#   'status_then': '学生（県立広島第一中学3年）',
#   'code': 'VS00714',
#   'production_date': '2001/03/31'},
#  {'id': 257,
#   'name': '坂本|文子',
#   'slug': '/pdbj/detail/206959',
#   'sex': '女性',
#   'age_exposure': '37',
#   'status_then': '',
#   'code': 'VS00061',
#   'production_date': '1987/08/01'},
#  {'id': 258,
#   'name': '佐川|英之',
#   'slug': '/pdbj/detail/207301',
#   'sex': '男性',
#   'age_exposure': '17',
#   'status_then': '学生',
#   'code': 'VS00589',
#   'production_date': '1998/02/28'},
#  {'id': 259,
#   'name': '佐川|泰子',
#   'slug': '/pdbj/detail/207398',
#   'sex': '女性',
#   'age_exposure': '14',
#   'status_then': '学生（女学生）',
#   'code': 'VS00749',
# ...
#   'code': 'VS00838',
#   'production_date': '2004/03/31'},
#  {'id': 607,
#   'name': '村田|初枝',
#   'slug': '/pdbj/detail/208344',
#   'sex': '女性',
#   'age_exposure': '27',
#   'status_then': '',
#   'code': 'VS01010',
#   'production_date': '2013/03/31'},
#  {'id': 608,
#   'name': '村田|ヨシエ',
#   'slug': '/pdbj/detail/208188',
#   'sex': '女性',
#   'age_exposure': '17',
#   'status_then': '',
#   'code': 'VS00900',
#   'production_date': '2007/03/31'},
#  {'id': 609,
#   'name': '村山|恵美子',
#   'slug': '/pdbj/detail/273194',
#   'sex': '女性',
#   'age_exposure': '22',
#   'status_then': '専業主婦',
#   'code': 'VS01079',
#   'production_date': '2019/02/28'},
#  {'id': 610,
#   'name': '目見田|武市',
#   'slug': '/pdbj/detail/207820',
#   'sex': '男性',
#   'age_exposure': '28',
#   'status_then': '軍人',
#   'code': 'VS00460',
#   'production_date': '1995/08/01'},
#  {'id': 611,
#   'name': '森|重昭',
#   'slug': '/pdbj/detail/207646',
#   'sex': '男性',
#   'age_exposure': '8',
#   'status_then': '学生',
#   'code': 'VS00253',
#   'production_date': '1991/08/01'},
#  {'id': 612,
#   'name': '森|匡世',
#   'slug': '/pdbj/detail/265010',
#   'sex': '女性',
#   'age_exposure': '19',
#   'status_then': '広島女子専門学校国文科３年生',
#   'code': 'VS01074',
#   'production_date': '2018/02/28'},
#  {'id': 613,
#   'name': '森井|尚賢',
#   'slug': '/pdbj/detail/207642',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '学生',
#   'code': 'VS00495',
#   'production_date': '1995/08/01'},
#  {'id': 614,
#   'name': '森川|定實',
#   'slug': '/pdbj/detail/207651',
#   'sex': '男性',
#   'age_exposure': '30',
#   'status_then': '会社員',
#   'code': 'VS00060',
#   'production_date': '1987/08/01'},
#  {'id': 615,
#   'name': '森川|幸子',
#   'slug': '/pdbj/detail/207647',
#   'sex': '女性',
#   'age_exposure': '14',
#   'status_then': '学生',
#   'code': 'VS00612',
#   'production_date': '1999/03/31'},
#  {'id': 616,
#   'name': '森下|弘',
#   'slug': '/pdbj/detail/207644',
#   'sex': '男性',
#   'age_exposure': '14',
#   'status_then': '学生',
#   'code': 'VS00534',
#   'production_date': '1996/09/30'},
#  {'id': 617,
#   'name': '森田|節子',
#   'slug': '/pdbj/detail/207650',
#   'sex': '女性',
#   'age_exposure': '12',
#   'status_then': '学生',
#   'code': 'VS00721',
#   'production_date': '2001/03/31'},
#  {'id': 618,
#   'name': '森田|司',
#   'slug': '/pdbj/detail/207649',
#   'sex': '男性',
#   'age_exposure': '28',
#   'status_then': '軍人（上等工作兵曹）',
#   'code': 'VS00698',
#   'production_date': '2000/03/31'},
#  {'id': 619,
#   'name': '森田|昇',
#   'slug': '/pdbj/detail/208341',
#   'sex': '男性',
#   'age_exposure': '13',
#   'status_then': '学生（中学校1年生）',
#   'code': 'VS01007',
#   'production_date': '2013/03/31'},
#  {'id': 620,
#   'name': '森滝|市郎',
#   'slug': '/pdbj/detail/207652',
#   'sex': '男性',
#   'age_exposure': '44',
#   'status_then': '会社員',
#   'code': 'VS00086',
#   'production_date': '1987/08/01'},
#  {'id': 621,
#   'name': '森冨|茂雄',
#   'slug': '/pdbj/detail/207313',
#   'sex': '男性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00603',
#   'production_date': '1999/03/31'},
#  {'id': 622,
#   'name': '森永|ヨシエ',
#   'slug': '/pdbj/detail/207643',
#   'sex': '女性',
#   'age_exposure': '20',
#   'status_then': '公務員',
#   'code': 'VS00675',
#   'production_date': '2000/03/31'},
#  {'id': 623,
#   'name': '森本|俊男',
#   'slug': '/pdbj/detail/208297',
#   'sex': '男性',
#   'age_exposure': '6',
#   'status_then': '',
#   'code': 'VS00962',
#   'production_date': '2010/03/31'},
#  {'id': 624,
#   'name': '森本|範雄',
#   'slug': '/pdbj/detail/207118',
#   'sex': '男性',
#   'age_exposure': '17',
#   'status_then': '学生',
#   'code': 'VS00281',
#   'production_date': '1991/08/01'},
#  {'id': 625,
#   'name': '森本|啓稔',
#   'slug': '/pdbj/detail/273198',
#   'sex': '男性',
#   'age_exposure': '13',
#   'status_then': '中学1年生',
#   'code': 'VS01080',
#   'production_date': '2019/02/28'},
#  {'id': 626,
#   'name': '森本|リエ子',
#   'slug': '/pdbj/detail/207217',
#   'sex': '女性',
#   'age_exposure': '19',
#   'status_then': '看護婦',
#   'code': 'VS00456',
#   'production_date': '1995/08/01'},
#  {'id': 627,
#   'name': '護山|純孝',
#   'slug': '/pdbj/detail/207081',
#   'sex': '男性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00230',
#   'production_date': '1990/08/01'},
#  {'id': 628,
#   'name': '諸橋|運治',
#   'slug': '/pdbj/detail/207592',
#   'sex': '男性',
#   'age_exposure': '30',
#   'status_then': '公務員',
#   'code': 'VS00648',
#   'production_date': '1999/03/31'},
#  {'id': 629,
#   'name': '八木|義彦',
#   'slug': '/pdbj/detail/207775',
#   'sex': '男性',
#   'age_exposure': '11',
#   'status_then': '学生（国民学校5年生）',
#   'code': 'VS00768',
#   'production_date': '2002/03/29'},
#  {'id': 630,
#   'name': '安井|清人',
#   'slug': '/pdbj/detail/207841',
#   'sex': '男性',
#   'age_exposure': '17',
#   'status_then': '軍属',
#   'code': 'VS00673',
#   'production_date': '2000/03/31'},
#  {'id': 631,
#   'name': '保田|イサコ',
#   'slug': '/pdbj/detail/207800',
#   'sex': '女性',
#   'age_exposure': '21',
#   'status_then': '会社員',
#   'code': 'VS00351',
#   'production_date': '1993/08/01'},
#  {'id': 632,
#   'name': '安原|義治',
#   'slug': '/pdbj/detail/208303',
#   'sex': '男性',
#   'age_exposure': '17',
#   'status_then': '',
#   'code': 'VS00969',
#   'production_date': '2011/03/31'},
#  {'id': 633,
#   'name': '柳川|トシヱ',
#   'slug': '/pdbj/detail/207390',
#   'sex': '女性',
#   'age_exposure': '21',
#   'status_then': '教職員',
#   'code': 'VS00732',
#   'production_date': '2001/03/31'},
#  {'id': 634,
#   'name': '柳川|良子',
#   'slug': '/pdbj/detail/207294',
#   'sex': '女性',
#   'age_exposure': '16',
#   'status_then': '学生',
#   'code': 'VS00581',
#   'production_date': '1998/02/28'},
#  {'id': 635,
#   'name': '柳|輝雄',
#   'slug': '/pdbj/detail/207822',
#   'sex': '男性',
#   'age_exposure': '21',
#   'status_then': '教職員',
#   'code': 'VS00499',
#   'production_date': '1995/08/01'},
#  {'id': 636,
#   'name': '柳田|圭子',
#   'slug': '/pdbj/detail/207142',
#   'sex': '女性',
#   'age_exposure': '19',
#   'status_then': '公務員',
#   'code': 'VS00325',
#   'production_date': '1992/08/01'},
#  {'id': 637,
#   'name': '柳原|美津子',
#   'slug': '/pdbj/detail/207823',
#   'sex': '女性',
#   'age_exposure': '6',
#   'status_then': '',
#   'code': 'VS00786',
#   'production_date': '2002/03/29'},
#  {'id': 638,
#   'name': '矢野|美耶古',
#   'slug': '/pdbj/detail/208117',
#   'sex': '女性',
#   'age_exposure': '14',
#   'status_then': '学生（女学校2年生）',
#   'code': 'VS00935',
#   'production_date': '2009/03/31'},
#  {'id': 639,
#   'name': '山内|悦子',
#   'slug': '/pdbj/detail/207565',
#   'sex': '女性',
#   'age_exposure': '16',
#   'status_then': '学生',
#   'code': 'VS00601',
#   'production_date': '1999/03/31'},
#  {'id': 640,
#   'name': '山内|昭治郎',
#   'slug': '/pdbj/detail/208356',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '学生（師範学校1年）',
#   'code': 'VS01021',
#   'production_date': '2014/02/28'},
#  {'id': 641,
#   'name': '山岡|秀則',
#   'slug': '/pdbj/detail/207388',
#   'sex': '男性',
#   'age_exposure': '3',
#   'status_then': '',
#   'code': 'VS00729',
#   'production_date': '2001/03/31'},
#  {'id': 642,
#   'name': '山岡|文子',
#   'slug': '/pdbj/detail/207212',
#   'sex': '女性',
#   'age_exposure': '18',
#   'status_then': '看護婦',
#   'code': 'VS00444',
#   'production_date': '1994/08/01'},
#  {'id': 643,
#   'name': '山口|松造',
#   'slug': '/pdbj/detail/207180',
#   'sex': '男性',
#   'age_exposure': '37',
#   'status_then': '会社員',
#   'code': 'VS00388',
#   'production_date': '1993/08/01'},
#  {'id': 644,
#   'name': '山口|光江',
#   'slug': '/pdbj/detail/207410',
#   'sex': '女性',
#   'age_exposure': '19',
#   'status_then': '会社員',
#   'code': 'VS00773',
#   'production_date': '2002/03/29'},
#  {'id': 645,
#   'name': '山崎|寛治',
#   'slug': '/pdbj/detail/207041',
#   'sex': '男性',
#   'age_exposure': '17',
#   'status_then': '学生',
#   'code': 'VS00179',
#   'production_date': '1989/08/01'},
#  {'id': 646,
#   'name': '山崎|静子',
#   'slug': '/pdbj/detail/207556',
#   'sex': '女性',
#   'age_exposure': '28',
#   'status_then': '',
#   'code': 'VS00221',
#   'production_date': '1990/08/01'},
#  {'id': 647,
#   'name': '山下|博子',
#   'slug': '/pdbj/detail/206956',
#   'sex': '女性',
#   'age_exposure': '18',
#   'status_then': '',
#   'code': 'VS00055',
#   'production_date': '1987/08/01'},
#  {'id': 648,
#   'name': '山田|寿美子',
#   'slug': '/pdbj/detail/207306',
#   'sex': '女性',
#   'age_exposure': '2',
#   'status_then': '',
#   'code': 'VS00595',
#   'production_date': '1998/02/28'},
#  {'id': 649,
#   'name': '山田|敏雄',
#   'slug': '/pdbj/detail/207563',
#   'sex': '男性',
#   'age_exposure': '34',
#   'status_then': '教職員',
#   'code': 'VS00212',
#   'production_date': '1990/08/01'},
#  {'id': 650,
#   'name': '山田|基石',
#   'slug': '/pdbj/detail/207562',
#   'sex': '男性',
#   'age_exposure': '17',
#   'status_then': '学生',
#   'code': 'VS00782',
#   'production_date': '2002/03/29'},
#  {'id': 651,
#   'name': '山中|恵美子',
#   'slug': '/pdbj/detail/255012',
#   'sex': '女性',
#   'age_exposure': '11',
#   'status_then': '学生（小学6年生）',
#   'code': 'VS01065',
#   'production_date': '2017/02/28'},
#  {'id': 652,
#   'name': '山中|茂子',
#   'slug': '/pdbj/detail/207560',
#   'sex': '女性',
#   'age_exposure': '16',
#   'status_then': '学生（女学校3年）',
#   'code': 'VS00715',
#   'production_date': '2001/03/31'},
#  {'id': 653,
#   'name': '山根|活次',
#   'slug': '/pdbj/detail/207368',
#   'sex': '男性',
#   'age_exposure': '14',
#   'status_then': '',
#   'code': 'VS00700',
#   'production_date': '2000/03/31'},
#  {'id': 654,
#   'name': '山根|秀子',
#   'slug': '/pdbj/detail/208104',
#   'sex': '女性',
#   'age_exposure': '13',
#   'status_then': '',
#   'code': 'VS00908',
#   'production_date': '2008/03/31'},
#  {'id': 655,
#   'name': '山根|力男',
#   'slug': '/pdbj/detail/206935',
#   'sex': '男性',
#   'age_exposure': '37',
#   'status_then': '公務員',
#   'code': 'VS00032',
#   'production_date': '1986/08/01'},
#  {'id': 656,
#   'name': '山本|定男',
#   'slug': '/pdbj/detail/208392',
#   'sex': '男性',
#   'age_exposure': '14',
#   'status_then': '学生',
#   'code': 'VS01033',
#   'production_date': '2015/03/31'},
#  {'id': 657,
#   'name': '山本|茂',
#   'slug': '/pdbj/detail/207569',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '学生',
#   'code': 'VS00327',
#   'production_date': '1992/08/01'},
#  {'id': 658,
#   'name': '山本|志津子',
#   'slug': '/pdbj/detail/207043',
#   'sex': '女性',
#   'age_exposure': '19',
#   'status_then': '公務員',
#   'code': 'VS00182',
#   'production_date': '1989/08/01'},
#  {'id': 659,
#   'name': '山本|忠代',
#   'slug': '/pdbj/detail/207567',
#   'sex': '女性',
#   'age_exposure': '24',
#   'status_then': '',
#   'code': 'VS00034',
#   'production_date': '1986/08/01'},
#  {'id': 660,
#   'name': '山本|千恵子',
#   'slug': '/pdbj/detail/208309',
#   'sex': '女性',
#   'age_exposure': '25',
#   'status_then': '',
#   'code': 'VS00975',
#   'production_date': '2011/03/31'},
#  {'id': 661,
#   'name': '山本|法子',
#   'slug': '/pdbj/detail/208301',
#   'sex': '女性',
#   'age_exposure': '4',
#   'status_then': '',
#   'code': 'VS00967',
#   'production_date': '2011/03/31'},
#  {'id': 662,
#   'name': '山本|博哉',
#   'slug': '/pdbj/detail/207568',
#   'sex': '男性',
#   'age_exposure': '13',
#   'status_then': '学生',
#   'code': 'VS00815',
#   'production_date': '2003/03/31'},
#  {'id': 663,
#   'name': '山本|玲子',
#   'slug': '/pdbj/detail/208389',
#   'sex': '女性',
#   'age_exposure': '7',
#   'status_then': '学生（国民学校1年生）',
#   'code': 'VS01030',
#   'production_date': '2015/03/31'},
#  {'id': 664,
#   'name': '梁|在植',
#   'slug': '/pdbj/detail/207008',
#   'sex': '男性',
#   'age_exposure': '15',
#   'status_then': '',
#   'code': 'VS00139',
#   'production_date': '1988/08/01'},
#  {'id': 665,
#   'name': '湯川|正夫',
#   'slug': '/pdbj/detail/207075',
#   'sex': '男性',
#   'age_exposure': '33',
#   'status_then': '軍人',
#   'code': 'VS00224',
#   'production_date': '1990/08/01'},
#  {'id': 666,
#   'name': '横田|勝',
#   'slug': '/pdbj/detail/207225',
#   'sex': '男性',
#   'age_exposure': '19',
#   'status_then': '学生',
#   'code': 'VS00469',
#   'production_date': '1995/08/01'},
#  {'id': 667,
#   'name': '横山|圭子',
#   'slug': '/pdbj/detail/207859',
#   'sex': '女性',
#   'age_exposure': '14',
#   'status_then': '学生',
#   'code': 'VS00487',
#   'production_date': '1995/08/01'},
#  {'id': 668,
#   'name': '横山|美恵子',
#   'slug': '/pdbj/detail/208108',
#   'sex': '女性',
#   'age_exposure': '15',
#   'status_then': '',
#   'code': 'VS00916',
#   'production_date': '2008/03/31'},
#  {'id': 669,
#   'name': '𠮷岡|幸雄',
#   'slug': '/pdbj/detail/207297',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '学生',
#   'code': 'VS00585',
#   'production_date': '1998/02/28'},
#  {'id': 670,
#   'name': '吉田|善一',
#   'slug': '/pdbj/detail/208269',
#   'sex': '男性',
#   'age_exposure': '21',
#   'status_then': '学生',
#   'code': 'VS00901-04',
#   'production_date': '2005/09/08'},
#  {'id': 671,
#   'name': '吉田|智加江',
#   'slug': '/pdbj/detail/244054',
#   'sex': '女性',
#   'age_exposure': '6',
#   'status_then': '学生（段原国民学校1年生）',
#   'code': 'VS01042',
#   'production_date': '2016/03/31'},
#  {'id': 672,
#   'name': '芳野|勝行',
#   'slug': '/pdbj/detail/207802',
#   'sex': '男性',
#   'age_exposure': '14',
#   'status_then': '学生',
#   'code': 'VS00826',
#   'production_date': '2004/03/31'},
#  {'id': 673,
#   'name': '吉野|豊子',
#   'slug': '/pdbj/detail/207119',
#   'sex': '女性',
#   'age_exposure': '21',
#   'status_then': '軍人',
#   'code': 'VS00284',
#   'production_date': '1991/08/01'},
#  {'id': 674,
#   'name': '吉村|教子',
#   'slug': '/pdbj/detail/273189',
#   'sex': '女性',
#   'age_exposure': '22',
#   'status_then': '会社員',
#   'code': 'VS01084',
#   'production_date': '2019/02/28'},
#  {'id': 675,
#   'name': '吉村|節子',
#   'slug': '/pdbj/detail/208090',
#   'sex': '女性',
#   'age_exposure': '17',
#   'status_then': '会社員',
#   'code': 'VS00897',
#   'production_date': '2007/03/31'},
#  {'id': 676,
#   'name': '米倉|繁二',
#   'slug': '/pdbj/detail/208091',
#   'sex': '男性',
#   'age_exposure': '12',
#   'status_then': '学生',
#   'code': 'VS00898',
#   'production_date': '2007/03/31'},
#  {'id': 677,
#   'name': '寄金|八百三',
#   'slug': '/pdbj/detail/207403',
#   'sex': '男性',
#   'age_exposure': '14',
#   'status_then': '公務員',
#   'code': 'VS00760',
#   'production_date': '2002/03/29'},
#  {'id': 678,
#   'name': '寄田|享',
#   'slug': '/pdbj/detail/207893',
#   'sex': '男性',
#   'age_exposure': '13',
#   'status_then': '学生（県立広島第一中学1年）',
#   'code': 'VS00713',
#   'production_date': '2001/03/31'},
#  {'id': 679,
#   'name': '李|実根',
#   'slug': '/pdbj/detail/207114',
#   'sex': '男性',
#   'age_exposure': '16',
#   'status_then': '学生',
#   'code': 'VS00275',
#   'production_date': '1991/08/01'},
#  {'id': 680,
#   'name': 'クラウス・ルーメル',
#   'slug': '/pdbj/detail/207055',
#   'sex': '男性',
#   'age_exposure': '28',
#   'status_then': '学生',
#   'code': 'VS00197',
#   'production_date': '1989/08/01'},
#  {'id': 681,
#   'name': '若槻|信子',
#   'slug': '/pdbj/detail/206976',
#   'sex': '女性',
#   'age_exposure': '18',
#   'status_then': '',
#   'code': 'VS00090',
#   'production_date': '1987/08/01'},
#  {'id': 682,
#   'name': '脇|勲',
#   'slug': '/pdbj/detail/208232',
#   'sex': '男性',
#   'age_exposure': '17',
#   'status_then': '',
#   'code': 'VS00917',
#   'production_date': '2008/03/31'},
#  {'id': 683,
#   'name': '脇地|二三',
#   'slug': '/pdbj/detail/207831',
#   'sex': '男性',
#   'age_exposure': '13',
#   'status_then': '学生（県立広島第二中学校2年）',
#   'code': 'VS00741',
#   'production_date': '2001/03/31'},
#  {'id': 684,
#   'name': '脇中|悦子',
#   'slug': '/pdbj/detail/208075',
#   'sex': '女性',
#   'age_exposure': '22',
#   'status_then': '主婦',
#   'code': 'VS00868',
#   'production_date': '2006/03/31'},
#  {'id': 685,
#   'name': '綿崎|直子',
#   'slug': '/pdbj/detail/207300',
#   'sex': '女性',
#   'age_exposure': '10',
#   'status_then': '学生',
#   'code': 'VS00588',
#   'production_date': '1998/02/28'},
#  {'id': 686,
#   'name': '渡部|克彦',
#   'slug': '/pdbj/detail/265005',
#   'sex': '男性',
#   'age_exposure': '12',
#   'status_then': '中学１年生',
#   'code': 'VS01069',
#   'production_date': '2018/02/28'},
#  {'id': 687,
#   'name': '渡辺|俊一',
#   'slug': '/pdbj/detail/208332',
#   'sex': '男性',
#   'age_exposure': '6',
#   'status_then': '',
#   'code': 'VS00998',
#   'production_date': '2012/03/31'},
#  {'id': 688,
#   'name': '渡邉|晋一',
#   'slug': '/pdbj/detail/244047',
#   'sex': '男性',
#   'age_exposure': '17',
#   'status_then': '車掌',
#   'code': 'VS01040',
#   'production_date': '2016/03/31'},
#  {'id': 689,
#   'name': '渡辺|妙子',
#   'slug': '/pdbj/detail/207756',
#   'sex': '女性',
#   'age_exposure': '12',
#   'status_then': '学生（国民学校6年生）',
#   'code': 'VS00785',
#   'production_date': '2002/03/29'},
#  {'id': 690,
#   'name': '渡部|辰雄',
#   'slug': '/pdbj/detail/208074',
#   'sex': '男性',
#   'age_exposure': '17',
#   'status_then': '公務員',
#   'code': 'VS00866',
#   'production_date': '2006/03/31'},
#  {'id': 691,
#   'name': '渡邉|美代子',
#   'slug': '/pdbj/detail/207007',
#   'sex': '女性',
#   'age_exposure': '15',
#   'status_then': '学生',
#   'code': 'VS00137',
#   'production_date': '1988/08/01'},
#  {'id': 692,
#   'name': '和田|功',
#   'slug': '/pdbj/detail/208384',
#   'sex': '男性',
#   'age_exposure': '19',
#   'status_then': '軍人',
#   'code': 'VS01025',
#   'production_date': '2015/03/31'}]

# %%
len(rows)
# Out:
# 692

# %%
df_basic = pd.DataFrame(rows)
df_basic.to_csv('data/survivors_bio_basic.csv', index=False)

# %%
df_basic
# Out:
#     age_exposure        code   id         name production_date sex  \
# 0             21     VS00366    1        青山|恭子      1993/08/01  女性
# 1             14     VS00678    2       秋田|サチヱ      2000/03/31  女性
# 2             15     VS00929    3       秋田|ひとし      2009/03/31  男性
# 3             21  VS00901-13    4        秋山|重雄      2005/09/08  男性
# 4             13     VS00937    5        浅野|温生      2009/03/31  男性
# 5             30     VS00466    6         旭|勝子      1995/08/01  女性
# 6             24     VS01085    7        東|ミヨノ      2019/02/28  女性
# 7             18     VS00072    8        阿部|静子      1987/08/01  女性
# 8             24     VS00968    9        安部|初子      2011/03/31  女性
# 9             22     VS00862   10         天野|貢      2006/03/31  男性
# 10            13     VS00510   11        天野|峰子      1996/09/30  女性
# 11            23     VS00808   12        天野|芳子      2003/03/31  女性
# 12            13     VS00882   13       新井|俊一郎      2007/03/31  男性
# 13            16     VS00805   14         新井|昇      2003/03/31  男性
# 14            15     VS00209   15        有崎|劭治      1990/08/01  男性
# 15            30     VS00222   16        粟村|逸三      1990/08/01  男性
# 16            19     VS01029   17       阿武|百合子      2015/03/31  女性
# 17            16     VS01036   18         李|鐘根      2016/03/31  男性
# 18             7     VS00996   19         飯田|暁      2012/03/31  男性
# 19            16     VS00733   20         飯村|卓      2001/03/31  男性
# 20            21  VS00901-05   21         壱岐|弘      2005/09/08  男性
# 21            17     VS00303   22  池庄司（久保）|トミ子      1992/08/01  女性
# 22            12     VS00119   23        池田|精子      1988/08/01  女性
# 23            28     VS00302   24        伊澤|澄子      1992/08/01  女性
# 24            16     VS00042   25        石川|文恵      1986/08/01  女性
# 25            13     VS00959   26        石﨑|幸子      2010/03/31  女性
# 26            17  VS00050-01   27         石田|明      1986/08/01  男性
# 27            13     VS00770   28         石田|晟      2002/03/29  男性
# 28            15     VS00138   29        石田|民生      1988/08/01  男性
# 29            45     VS00081   30        石田|正己      1987/08/01  男性
# ..           ...         ...  ...          ...             ...  ..
# 662            7     VS01030  663        山本|玲子      2015/03/31  女性
# 663           15     VS00139  664         梁|在植      1988/08/01  男性
# 664           33     VS00224  665        湯川|正夫      1990/08/01  男性
# 665           19     VS00469  666         横田|勝      1995/08/01  男性
# 666           14     VS00487  667        横山|圭子      1995/08/01  女性
# 667           15     VS00916  668       横山|美恵子      2008/03/31  女性
# 668           16     VS00585  669        𠮷岡|幸雄      1998/02/28  男性
# 669           21  VS00901-04  670        吉田|善一      2005/09/08  男性
# 670            6     VS01042  671       吉田|智加江      2016/03/31  女性
# 671           14     VS00826  672        芳野|勝行      2004/03/31  男性
# 672           21     VS00284  673        吉野|豊子      1991/08/01  女性
# 673           22     VS01084  674        吉村|教子      2019/02/28  女性
# 674           17     VS00897  675        吉村|節子      2007/03/31  女性
# 675           12     VS00898  676        米倉|繁二      2007/03/31  男性
# 676           14     VS00760  677       寄金|八百三      2002/03/29  男性
# 677           13     VS00713  678         寄田|享      2001/03/31  男性
# 678           16     VS00275  679         李|実根      1991/08/01  男性
# 679           28     VS00197  680    クラウス・ルーメル      1989/08/01  男性
# 680           18     VS00090  681        若槻|信子      1987/08/01  女性
# 681           17     VS00917  682          脇|勲      2008/03/31  男性
# 682           13     VS00741  683        脇地|二三      2001/03/31  男性
# 683           22     VS00868  684        脇中|悦子      2006/03/31  女性
# 684           10     VS00588  685        綿崎|直子      1998/02/28  女性
# 685           12     VS01069  686        渡部|克彦      2018/02/28  男性
# 686            6     VS00998  687        渡辺|俊一      2012/03/31  男性
# 687           17     VS01040  688        渡邉|晋一      2016/03/31  男性
# 688           12     VS00785  689        渡辺|妙子      2002/03/29  女性
# 689           17     VS00866  690        渡部|辰雄      2006/03/31  男性
# 690           15     VS00137  691       渡邉|美代子      1988/08/01  女性
# 691           19     VS01025  692         和田|功      2015/03/31  男性
#
#                     slug      status_then
# 0    /pdbj/detail/207680              教職員
# 1    /pdbj/detail/207588               学生
# 2    /pdbj/detail/208156               学生
# 3    /pdbj/detail/208155               学生
# 4    /pdbj/detail/208185       学生（中学校2年生）
# 5    /pdbj/detail/207223               主婦
# 6    /pdbj/detail/273357             専業主婦
# 7    /pdbj/detail/206965
# 8    /pdbj/detail/208302
# 9    /pdbj/detail/208198              公務員
# 10   /pdbj/detail/207250               学生
# 11   /pdbj/detail/207747               主婦
# 12   /pdbj/detail/208165       学生（中学校1年生）
# 13   /pdbj/detail/207639              会社員
# 14   /pdbj/detail/207825               学生
# 15   /pdbj/detail/207073               軍人
# 16   /pdbj/detail/208388        教職員（臨時教師）
# 17   /pdbj/detail/243778
# 18   /pdbj/detail/208330      学生（国民学校1年生）
# 19   /pdbj/detail/207391               学生
# 20   /pdbj/detail/208095               学生
# 21   /pdbj/detail/207130        看護婦（看護学生）
# 22   /pdbj/detail/206998               学生
# 23   /pdbj/detail/207844              公務員
# 24   /pdbj/detail/206940               学生
# 25   /pdbj/detail/208294
# 26   /pdbj/detail/206947      軍人（陸軍少年航空兵）
# 27   /pdbj/detail/207408       学生（中学校2年生）
# 28   /pdbj/detail/207685               軍人
# 29   /pdbj/detail/207684          教職員（校長）
# ..                   ...              ...
# 662  /pdbj/detail/208389      学生（国民学校1年生）
# 663  /pdbj/detail/207008
# 664  /pdbj/detail/207075               軍人
# 665  /pdbj/detail/207225               学生
# 666  /pdbj/detail/207859               学生
# 667  /pdbj/detail/208108
# 668  /pdbj/detail/207297               学生
# 669  /pdbj/detail/208269               学生
# 670  /pdbj/detail/244054    学生（段原国民学校1年生）
# 671  /pdbj/detail/207802               学生
# 672  /pdbj/detail/207119               軍人
# 673  /pdbj/detail/273189              会社員
# 674  /pdbj/detail/208090              会社員
# 675  /pdbj/detail/208091               学生
# 676  /pdbj/detail/207403              公務員
# 677  /pdbj/detail/207893   学生（県立広島第一中学1年）
# 678  /pdbj/detail/207114               学生
# 679  /pdbj/detail/207055               学生
# 680  /pdbj/detail/206976
# 681  /pdbj/detail/208232
# 682  /pdbj/detail/207831  学生（県立広島第二中学校2年）
# 683  /pdbj/detail/208075               主婦
# 684  /pdbj/detail/207300               学生
# 685  /pdbj/detail/265005            中学１年生
# 686  /pdbj/detail/208332
# 687  /pdbj/detail/244047               車掌
# 688  /pdbj/detail/207756      学生（国民学校6年生）
# 689  /pdbj/detail/208074              公務員
# 690  /pdbj/detail/207007               学生
# 691  /pdbj/detail/208384               軍人
#
# [692 rows x 8 columns]

# %% [markdown]
# # Scrape details for all survivors

# %%
slugs = df_basic.slug
rows = []

for slug in slugs:
    url = main_url + slug
    response = requests.get(url)
    doc = BeautifulSoup(response.text)
    
    row = {}
    row['code'] = doc.find('td').text.strip()
    row['name_kana'] = doc.find_all('td')[1].text.split('（')[1].replace('\u3000','|').replace('）','')
    row['exposure_loc'] = doc.find_all('td')[3].text
    row['exposure_dist'] = doc.find_all('td')[4].text
    row['age_exposure_detail'] = doc.find_all('td')[5].text.replace('歳','').strip()
    row['age_production'] = doc.find_all('td')[6].text.replace('歳','').strip()
    row['details'] = doc.find_all('td')[7].text
    row['status_then_detail'] = doc.find_all('td')[8].text
    row['work_location'] = doc.find_all('td')[9].text
    rows.append(row)
rows
# Out:
# [{'code': 'VS00366',
#   'name_kana': 'アオヤマ|ヤスコ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '21',
#   'age_production': '69',
#   'details': '当日の朝、女学校（現吉田高校）職員室内から閃光を見、音を聞いた。南方にはきのこ雲。一日中生徒と一緒に勤労奉仕。夕方、芸備線吉田口駅へ出ると広島から逃れてきた人たちで溢れていたので、介護を始めた。翌朝から市内の被災者の看護（本川小、勧銀、逓信病院等）。',
#   'status_then_detail': '教職員',
#   'work_location': '吉田高等女学校'},
#  {'code': 'VS00678',
#   'name_kana': 'アキタ|サチエ',
#   'exposure_loc': '三篠町',
#   'exposure_dist': '2.5km',
#   'age_exposure_detail': '14',
#   'age_production': '69',
#   'details': '作業中明るい光が走った。焼夷弾の直撃を受けたと思い、机の下に隠れたが気づくと下敷きになっていた。瓦礫の外に出ると友人たちの顔は墨で真っ黒だった古市の工場に逃げ、その時配給されたむすびは今でも覚えている。自宅に戻ったが全焼。翌日、地御前小学校に向かい、両親と弟に再会した。',
#   'status_then_detail': '学生',
#   'work_location': '安田高等女学校'},
#  {'code': 'VS00929',
#   'name_kana': 'アキタ|ヒトシ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '15',
#   'age_production': '77',
#   'details': '学徒動員先の呉の海軍工廠で作業中、建物の外が何か光ったような感じがあった。しばらくして兄を探すため、実家の父親と一緒に広島市内へ入り入市被爆。市内は建物などはほとんど焼けて、何もないような状態だった。結局お兄さんは行方不明のままだそうです。',
#   'status_then_detail': '学生',
#   'work_location': ''},
#  {'code': 'VS00901-13',
#   'name_kana': 'アキヤマ|シゲオ',
#   'exposure_loc': '千田町',
#   'exposure_dist': '2.0km',
#   'age_exposure_detail': '21',
#   'age_production': '81',
#   'details': '受講中に校舎内で被爆',
#   'status_then_detail': '学生',
#   'work_location': '広島高等工業学校'},
#  {'code': 'VS00937',
#   'name_kana': 'アサノ|ヨシオ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '13',
#   'age_production': '76',
#   'details': '母親の里へ向かうため、江田島の桟橋の船の中に居た時、マグネシウムを焚いたような閃光が走り、その後パラシュート型の雲が上空へ昇っていった。翌日、入市被爆。幼馴染の悲惨な姿やたくさんの死体をみたショックは今でも忘れられないと言います。',
#   'status_then_detail': '学生（中学校2年生）',
#   'work_location': '県立広島第二中学校'},
#  {'code': 'VS00466',
#   'name_kana': 'アサヒ|カツコ',
#   'exposure_loc': '牛田町,自宅',
#   'exposure_dist': '2.3km',
#   'age_exposure_detail': '30',
#   'age_production': '80',
#   'details': '当時、妊娠8か月の身重だった。家の風呂場で洗濯中、空襲解除のサイレンが鳴ったが、爆音が聞こえていた。突然、ガラスや壁が壊れる音がした。額と足に火傷を負った母と、無傷だった娘（6歳）を連れ、牛田山を越え、矢口の小学校へ避難した。',
#   'status_then_detail': '主婦',
#   'work_location': ''},
#  {'code': 'VS01085',
#   'name_kana': 'アズマ|ミヨノ',
#   'exposure_loc': '牛田町',
#   'exposure_dist': '2.5km',
#   'age_exposure_detail': '24',
#   'age_production': '97',
#   'details': '神田橋のたもとでニワトリに餌をやっている時に被爆。生後３か月の娘の無事を確認し、気がつくと自分は半身やけどの重傷。「お母さん」と泣いていた若い兵隊の姿が忘れられない。庄原の実家に戻り家族の助けを借りながら一命を取り留める。薬がないためキュウリの絞り汁などを患部に塗っていた。',
#   'status_then_detail': '専業主婦',
#   'work_location': ''},
#  {'code': 'VS00072',
#   'name_kana': 'アベ|シズコ',
#   'exposure_loc': '鶴見町,鶴見橋付近',
#   'exposure_dist': '1.8km',
#   'age_exposure_detail': '18',
#   'age_production': '60',
#   'details': '当時18才。爆心地から1.8キロの鶴見橋付近で建物疎開の作業中被爆した。屋根の上で熱風を浴び、気が付いたら身体中やけどをして地面に放り出されていた。戦後結婚し、3人の子供に恵まれた。現在、自分の体験を語り継ごうと語り部活動をしている。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS00968',
#   'name_kana': 'アベ|ハツコ',
#   'exposure_loc': '白島九軒町',
#   'exposure_dist': '1.7km',
#   'age_exposure_detail': '24',
#   'age_production': '90',
#   'details': '安部初子さん。被爆当時２４歳。爆心地からおよそ1.7ｋｍの白島九軒町の自宅で被爆しました。福岡県の門司から広島に移り住んだ翌年に被爆。原爆に生後間もない我が子を奪われてしまいました。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS00862',
#   'name_kana': 'アマノ|ミツグ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '22',
#   'age_production': '82',
#   'details': '県の職員として賀茂郡黒瀬町の事務所でキノコ雲を目撃。９日、トラックで広島駅から入市。県庁を探すが市内は一面の焼け野原であった。その後も県庁の跡を探すが結局、見つからなかった。兄弟も広島と長崎で被爆し死亡した。',
#   'status_then_detail': '公務員',
#   'work_location': ''},
#  {'code': 'VS00510',
#   'name_kana': 'アマノ|ミネコ',
#   'exposure_loc': '大手町,大手町国民学校',
#   'exposure_dist': '0.9km',
#   'age_exposure_detail': '13',
#   'age_production': '64',
#   'details': '広島市立第一高等女学校の一年生だった。建物疎開作業をさぼり友人と爆心地に近い大手町国民学校で遊んでいて被爆。爆風で丸裸になっていた。原爆症で髪が抜け落ち、うんだ皮膚はウジがわき、加古町に住んでいた家族は全員亡くなった。又、学徒動員先の材木町で一、二年生は全員死亡した。',
#   'status_then_detail': '学生',
#   'work_location': '広島市立第一高等校女学校'},
#  {'code': 'VS00808',
#   'name_kana': 'アマノ|ヨシコ',
#   'exposure_loc': '白島西中町,自宅',
#   'exposure_dist': '1.6km',
#   'age_exposure_detail': '23',
#   'age_production': '80',
#   'details': '洗濯物を干しに裏庭に出ようとして、片足を踏み下ろした。物置の屋根に青白い光が反射して、顔を火傷した。家に逃げると、家が崩れ落ち下敷きになった。昼頃、夫に助け出され、子供二人を連れて避難した。長寿園は負傷者でいっぱいだった。黒い雨が降った。29日に娘の一人は亡くなった。',
#   'status_then_detail': '主婦',
#   'work_location': ''},
#  {'code': 'VS00882',
#   'name_kana': 'アライ|シュンイチロウ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '13',
#   'age_production': '75',
#   'details': '学徒動員先の加茂郡から、広島市内の母校へ連絡文書を届けるため、８月６日の朝広島へ出発した。途中瀬野駅で列車は止まり、そこから自宅のある方向へと歩くが、その途中で被災した広島市内の光景を目にした。家族は負傷していたが無事だった。原爆で死亡してしまった同級生が数人おり、その家族と会うのが辛かった。',
#   'status_then_detail': '学生（中学校1年生）',
#   'work_location': '広島高等師範学校附属中学校'},
#  {'code': 'VS00805',
#   'name_kana': 'アライ|ノボル',
#   'exposure_loc': '南観音町,三菱重工内',
#   'exposure_dist': '3.2km',
#   'age_exposure_detail': '16',
#   'age_production': '73',
#   'details': '段原の叔母宅から、観音の三菱重工の工場へ出勤。工場へ着いた時、まぶしく光って爆音が聞こえた。工場の防空壕へ入れず、叔母のいる段原へ向かった。負傷者の波に押し戻され、結局己斐の山中で野宿。一晩中市内は燃え続け、一睡もできなかった。翌日、実家の砂谷村まで歩いて帰宅。家族と再会。',
#   'status_then_detail': '会社員',
#   'work_location': '三菱重工業'},
#  {'code': 'VS00209',
#   'name_kana': 'アリサキ|ショウジ',
#   'exposure_loc': '舟入町,建物疎開作業中',
#   'exposure_dist': '2km',
#   'age_exposure_detail': '15',
#   'age_production': '59',
#   'details': '当時、広島二中（現、観音高校）の3年生で、建物疎開作業中に舟入川口町で被爆。桃色の光を見た瞬間、爆風によりガラスなどが壊れた。火事が発生し、すり傷や打ち身などの被害にあった。8学級のうち約40人と先生1人が被爆。ＪＴ（日本たばこ）広島支社Ｓ．24年6月入社（18才）。',
#   'status_then_detail': '学生',
#   'work_location': '県立広島第二中学校'},
#  {'code': 'VS00222',
#   'name_kana': 'アワムラ|イツゾウ',
#   'exposure_loc': '基町,中国軍管区司令部',
#   'exposure_dist': '0.5km',
#   'age_exposure_detail': '30',
#   'age_production': '75',
#   'details': '中国軍管区司令部副官部で庶務係をしていた。本部内で被爆。その後の軍関係の状況に詳しい。現在、師友会会長。（中国軍管区司令ＯＢ会）',
#   'status_then_detail': '軍人',
#   'work_location': '中国軍管区司令部'},
#  {'code': 'VS01029',
#   'name_kana': 'アンノ|ユリコ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '19',
#   'age_production': '88',
#   'details': '仁保国民学校の臨時教師として、湯来町のお寺に学校の子どもたちと集団疎開をしていた。8月6日、広島に爆弾が落とされたことを知らされ、翌日、子どもたちの家族の安否を確認するため、市内に入った。悲惨な光景を眺めながら、黙々と歩いた。',
#   'status_then_detail': '教職員（臨時教師）',
#   'work_location': '仁保国民学校 （にほ）'},
#  {'code': 'VS01036',
#   'name_kana': 'イ|ヂョングン',
#   'exposure_loc': '荒神町',
#   'exposure_dist': '1.8km',
#   'age_exposure_detail': '16',
#   'age_production': '85',
#   'details': '李さんが被爆したのは、平良村の自宅から職場へ向かう途中、的場町で路面電車を降り、荒神橋を渡り終えたところでした。李さんは、顔と首に大やけどを負いましたが、避難する途中、助けを求める人に何もできなかったことを今でも後悔しています。現在李さんは、被爆体験証言者として活動しています。',
#   'status_then_detail': '',
#   'work_location': '広島鉄道局広島第二機関区'},
#  {'code': 'VS00996',
#   'name_kana': 'イイダ|サトル',
#   'exposure_loc': '皆実町',
#   'exposure_dist': '2.5km',
#   'age_exposure_detail': '7',
#   'age_production': '73',
#   'details': '８月６日の朝、分散授業でお寺に１５人程度の友人と先生を待っていた。目の前に青白い光りが見え、皆がキャーと叫んだ瞬間、爆風でお寺が倒れ気を失った。気が付くと屋根と柱の間にいた。そこから這い出し、自宅へ戻ると隣の家が倒れて壊れていた。',
#   'status_then_detail': '学生（国民学校1年生）',
#   'work_location': '皆実国民学校'},
#  {'code': 'VS00733',
#   'name_kana': 'イイムラ|タカシ',
#   'exposure_loc': '自宅, 西観音町',
#   'exposure_dist': '1.7km',
#   'age_exposure_detail': '16',
#   'age_production': '71',
#   'details': '学徒動員が休みで、自宅で物理の勉強をしていた。トイレに行ったとき目を刺すような光と共にトイレごと吹き飛ばされ、倒れた家から無我夢中で飛び出した。火が迫ったので母と兄嫁とともに南方面に逃げ、途中黒い雨を浴びた。行方不明になった姪を心配し家に戻ったが、既に炎に包まれ近寄ることもできなかった。半狂乱の兄嫁を無理やり引っ張って避難した。',
#   'status_then_detail': '学生',
#   'work_location': '県立広島第二中学校'},
#  {'code': 'VS00901-05',
#   'name_kana': 'イキ|ヒロム',
#   'exposure_loc': '千田町',
#   'exposure_dist': '2.0km',
#   'age_exposure_detail': '21',
#   'age_production': '81',
#   'details': '受講中に校舎内で被爆',
#   'status_then_detail': '学生',
#   'work_location': '広島高等工業学校'},
#  {'code': 'VS00303',
#   'name_kana': '久保|トミ子',
#   'exposure_loc': '千田町,日赤病院屋内',
#   'exposure_dist': '1.5km',
#   'age_exposure_detail': '17',
#   'age_production': '64',
#   'details': '日赤の看護学校2年生だったが、小児病棟に勤務していた。その日は夜勤あけ。日赤病院内で被爆。あっと思ったら火の中でグルグル回っていた。意識を取り戻したのち、肋骨にひびが入ったままケガ人の治療や看病をつづけた。',
#   'status_then_detail': '看護婦（看護学生）',
#   'work_location': '広島赤十字病院付属看護学校'},
#  {'code': 'VS00119',
#   'name_kana': 'イケダ|セイコ',
#   'exposure_loc': '鶴見町,建物疎開作業場',
#   'exposure_dist': '1.5km',
#   'age_exposure_detail': '12',
#   'age_production': '55',
#   'details': '当時12才。爆心地から1．5キロの鶴見橋付近で被爆した。池田さんは原爆で顔に大やけどを負っている。これから青春を送ろうとする少女にとってそれは、大きなショックだった。やけどの皮膚の移植手術を戦後13回も受けた。現在社交ダンスの先生をしている。戦後、人前に出るのを避けてきた池田さんにとってダンスは積極的に生きるきっかけになった。',
#   'status_then_detail': '学生',
#   'work_location': ''},
#  {'code': 'VS00302',
#   'name_kana': 'イザワ|スミコ',
#   'exposure_loc': '的場町,荒神橋',
#   'exposure_dist': '1.7km',
#   'age_exposure_detail': '28',
#   'age_production': '74',
#   'details': '歩いて保育園に出勤する途中、荒神橋の上で被爆。ピカっと光った瞬間しゃがみ両足に火傷を負っただけで助かる。被爆後、比治山国民学校に設けられた臨時の戦災孤児収容所に勤務する。そこで、体中にウジをわかせた乳飲み子や衰弱し髪が抜け次々に死んでいく幼児を見る。',
#   'status_then_detail': '公務員',
#   'work_location': '広島市役所'},
#  {'code': 'VS00042',
#   'name_kana': 'イシカワ|フミエ',
#   'exposure_loc': '祇園町,自宅',
#   'exposure_dist': '4.1km',
#   'age_exposure_detail': '16',
#   'age_production': '57',
#   'details': '当時16才。爆心地から4．1キロの自宅の庭で農作業中に被爆した。翌日、土橋方面に学徒動員に出ていた弟を捜しに出た。戦後結婚し、2人の娘さんを育てた。',
#   'status_then_detail': '学生',
#   'work_location': ''},
#  {'code': 'VS00959',
#   'name_kana': 'イシザキ|サチコ',
#   'exposure_loc': '南観音町',
#   'exposure_dist': '3.5km',
#   'age_exposure_detail': '13',
#   'age_production': '77',
#   'details': '母の体調が悪く、学徒動員を休み自宅に。急に部屋が明るくなり、その後爆風に襲われる。家のガラスは割れ天井も垂れ下がっていた。ガラスが背中や足に刺さったが、恐ろしさのあまり痛みは感じなかった。生き残ってしまった罪悪感や原因不明の病気に苦しむ。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS00050-01',
#   'name_kana': 'イシダ|アキラ',
#   'exposure_loc': '八丁堀付近,電車内',
#   'exposure_dist': '0.75km',
#   'age_exposure_detail': '17',
#   'age_production': '57',
#   'details': '当時17才。陸軍の少年航空兵だった石田さんは、あの日は休暇で兄と一緒に武運長久を祈りに宮島へ行く途中だった。兄は9月に原爆症で亡くなった。',
#   'status_then_detail': '軍人（陸軍少年航空兵）',
#   'work_location': ''},
#  {'code': 'VS00770',
#   'name_kana': 'イシダ|アキラ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '13',
#   'age_production': '69',
#   'details': '自宅にいると爆音・爆風とともに縁側のガラスが割れ頭をかすった。可部街道を市内から被爆した人が避難してきた。キノコ雲がグルグル回っていた。横川で被爆した父親が火傷した手を前に出した状態で帰ってきた。翌日、舟入の叔母を探しに市内に行き入市被爆。死体の山に衝撃を受けた。',
#   'status_then_detail': '学生（中学校2年生）',
#   'work_location': '広島市立中学校'},
#  {'code': 'VS00138',
#   'name_kana': 'イシダ|タミオ',
#   'exposure_loc': '出汐町,被服廠',
#   'exposure_dist': '2.7km',
#   'age_exposure_detail': '15',
#   'age_production': '58',
#   'details': '当時15才。爆心地から2．7キロの出汐町で被爆した。戦後高校で国語を教える一方、被爆教師の会での活動を通して被爆体験を語り継いできた。旧被服廠の倉庫の一部は今も残り、運送会社が使っている。被爆直後、救護所にあてられ多くの人がここに収容された。石田さんも自ら傷を負いながら救護活動にあたった。',
#   'status_then_detail': '軍人',
#   'work_location': ''},
#  {'code': 'VS00081',
#   'name_kana': 'イシダ|マサミ',
#   'exposure_loc': '東雲町,比治山国民学校内',
#   'exposure_dist': '2.8km',
#   'age_exposure_detail': '45',
#   'age_production': '87',
#   'details': '当時45才。当時の比治山国民学校、現在の比治山小学校の校長として、8月6日校内で被爆した。学校が救護所に指定されていたので、それからは不眠不休で負傷者の救護活動に当たった。当時三篠の自宅にいた長男の行方は今もってわからない。今は、小学校を退職して東広島市で農業に従事している。',
#   'status_then_detail': '教職員（校長）',
#   'work_location': '比治山国民学校'},
#  {'code': 'VS00964',
#   'name_kana': 'イズミ|カンジ',
#   'exposure_loc': '己斐町',
#   'exposure_dist': '2.5km',
#   'age_exposure_detail': '5',
#   'age_production': '70',
#   'details': '泉寛治さん。被爆当時５歳。爆心地からおよそ2.5ｋｍの己斐町の橋の下で被爆しました。近所の友人３人で、川に魚を捕りに出かけ被爆。家族が心配になりそれぞれ急いで帰宅しましたが、それが２人の友人との最期の別れになってしまいました。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS00623',
#   'name_kana': 'イセ|チエコ',
#   'exposure_loc': '入市,亀山村',
#   'exposure_dist': '',
#   'age_exposure_detail': '32',
#   'age_production': '84',
#   'details': '当日は、亀山村に疎開していた。義勇隊として召集になり、疎開していなかった夫を捜すため、15日から毎日市内の猿楽町へ帰るが、結局夫は行方不明のままだった。市内は焼け野原で何もなく、猿楽町へ立った時、宇品の海が見えた。',
#   'status_then_detail': '主婦',
#   'work_location': ''},
#  {'code': 'VS00214',
#   'name_kana': 'イタノ|ロクロウ',
#   'exposure_loc': '吉島本町,工場事務所内',
#   'exposure_dist': '2.5km',
#   'age_exposure_detail': '33',
#   'age_production': '78',
#   'details': '工場長、工場の事務所で被爆。工場は疎開していたため、従業員20～30人で荷物の疎開作業をしていた。建物は半分ぐらいがこわれ、倒れた柱で死んだり、表にいた者にはやけどした人もいた。知人を探すため、大手町界わいを歩く。',
#   'status_then_detail': '会社員',
#   'work_location': '中国塗料'},
#  {'code': 'VS00260',
#   'name_kana': 'イタムラ|サチコ',
#   'exposure_loc': '加古町,自宅内',
#   'exposure_dist': '1km',
#   'age_exposure_detail': '15',
#   'age_production': '61',
#   'details': '学徒動員で日本製鋼所へ通っていたが、当日は休みのため、家の2階にいた。爆風のため家は崩れ、本人は気絶する。両親の懸命の救出作業で助け出される。その後、原爆の後遺症に悩まされている。',
#   'status_then_detail': '学生',
#   'work_location': '広島市立第一高等女学校'},
#  {'code': 'VS00693',
#   'name_kana': 'イチハラ|レイコ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '10',
#   'age_production': '65',
#   'details': '10歳の時、疎開先の海田町の親戚の家で8月6日を迎えた。遠くの空に雲がわきあがってくるのを見た。10日広瀬町で商売を営んでいる祖父母の消息を訪ねて両親と入市。悲惨な様子を見せまいと道を選んで歩いてくれたが、色と臭いの記憶は鮮明に覚えている。',
#   'status_then_detail': '学生',
#   'work_location': '奥海田国民学校'},
#  {'code': 'VS00217',
#   'name_kana': 'イデモト|ユキコ',
#   'exposure_loc': '宇品町,陸軍共済病院内',
#   'exposure_dist': '3.2km',
#   'age_exposure_detail': '14',
#   'age_production': '59',
#   'details': '当時、陸軍共済病院の看護婦生徒。外科病棟の廊下で被爆。8月30日まで救護や死体の処理、病院の後片付けを行う。9月以降高熱、下痢に見舞われ、自宅で養生。',
#   'status_then_detail': '看護婦',
#   'work_location': '広島陸軍共済病院'},
#  {'code': 'VS00381',
#   'name_kana': 'イトウ|カオル',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '31',
#   'age_production': '79',
#   'details': '府中町の東洋工場に勤めていた伊藤さんは、仕事を始めようとした時に突然の閃光を目にした。続々と運ばれてくる被災者の介護をしたあと、夕方、西観音町の自宅に戻った。',
#   'status_then_detail': '会社員',
#   'work_location': '東洋工業'},
#  {'code': 'VS00901-03',
#   'name_kana': 'イトウ|コウジ',
#   'exposure_loc': '千田町',
#   'exposure_dist': '2.0km',
#   'age_exposure_detail': '21',
#   'age_production': '81',
#   'details': '受講中に校舎内で被爆',
#   'status_then_detail': '学生',
#   'work_location': '広島高等工業学校'},
#  {'code': 'VS00124',
#   'name_kana': 'イトウ|サカエ',
#   'exposure_loc': '鶴見町,建物疎開作業場',
#   'exposure_dist': '1.5km',
#   'age_exposure_detail': '34',
#   'age_production': '77',
#   'details': '当時34才。爆心地から1.5キロの鶴見町で被爆した。鶴見町で建物疎開の作業を始めようとした瞬間、後から強烈な閃光を浴び、背中に大やけどを負った。戦後、広島県被団協の結成時から理事を務め、現在は日本被団協・代表委員3人のうちの一人である。平和運動の草分け的存在で、国連軍縮総会でも被爆者を代表して核廃絶を訴えた。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS00151',
#   'name_kana': 'イトウ|ジロウ',
#   'exposure_loc': '基町,軍の建物内',
#   'exposure_dist': '0.6km',
#   'age_exposure_detail': '24',
#   'age_production': '68',
#   'details': '歩兵第11連隊。建物の2階で被爆。部隊は全滅状態となる。仲間の叫び声が今も頭から消えない。',
#   'status_then_detail': '軍人',
#   'work_location': '歩兵第11連隊'},
#  {'code': 'VS00970',
#   'name_kana': 'イトウ|ヨシユキ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '19',
#   'age_production': '84',
#   'details': 'いつ召集されてもおかしくない状態だったため四国へ墓参りに行き、７日に広島へ戻り入市被爆。宇品から川沿いに歩いて市内へ入り、うめき声であふれる惨状を目にする。知り合いの病院を訪ね、ケガ人の治療の手伝いに追われる。独特のニオイが今も忘れられないという。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS01058',
#   'name_kana': 'イトガ|シノブ',
#   'exposure_loc': '横川町，自宅',
#   'exposure_dist': '1.5km',
#   'age_exposure_detail': '4',
#   'age_production': '75',
#   'details': '爆心地からおよそ１.５キロ離れた 横川町で被爆。当時わずか4歳と幼かった糸賀さんだが、被爆して真っ黒に焼けただれた人の姿や、焼け跡の強烈な臭いが忘れられない。戦後の食糧難や、差別を受けた経験から、戦争は終わった後ものちのちまで人を苦しめると語る。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS00532',
#   'name_kana': 'イノウエ|クニソウ',
#   'exposure_loc': '観音町,三菱重工',
#   'exposure_dist': '3km',
#   'age_exposure_detail': '15',
#   'age_production': '66',
#   'details': 'ピカッと光り机の下にもぐり込んだ。アメリカが爆弾を落としたと思った。己斐の山付近と観音高校の二階建て木造校舎は燃えていた。それから天満町方面に行く途中多くの怪我人を見た。土手に来た時、夕立に会った後にそれが黒い雨だと知った。級友と太田川を渡り牛田の浄水場まで着いた時傷ついた兵隊が歩いていた。',
#   'status_then_detail': '学生',
#   'work_location': '広島県立広島工業学校'},
#  {'code': 'VS00348',
#   'name_kana': 'イノウエ|ヨシトキ',
#   'exposure_loc': '皆実町,学校の武道場',
#   'exposure_dist': '2km',
#   'age_exposure_detail': '15',
#   'age_production': '62',
#   'details': '当時、広島師範学校予科の1年生であり、比治山の学校の寮に住んでいた。8月6日の朝、学校の武道場に横になっている時被爆するが、ガラスによる怪我のみであった。原爆ドームそばの自宅にいた両親と弟は遺体すら見つけだすことができなかった。',
#   'status_then_detail': '学生',
#   'work_location': '広島師範学校'},
#  {'code': 'VS01000',
#   'name_kana': 'イノクチ|タケシ',
#   'exposure_loc': '天満町',
#   'exposure_dist': '1.5km',
#   'age_exposure_detail': '14',
#   'age_production': '80',
#   'details': '学徒動員の軍需工場で点呼中、光と熱、爆風がおこり、工場の中で何かが破裂したようだった。建物の下敷きになり気絶した。目が覚めると辺りが燃え始めていたので建物の隙間をくぐって川へ飛び込んだ。その後西広島へ。途中、まさに地獄の様子だった。',
#   'status_then_detail': '学生（山陽中学生2年生）',
#   'work_location': '東洋製缶(天満町、学徒動員）'},
#  {'code': 'VS00290',
#   'name_kana': 'イマイ|トシロウ',
#   'exposure_loc': '松原町,広島駅前',
#   'exposure_dist': '2km',
#   'age_exposure_detail': '34',
#   'age_production': '80',
#   'details': '広島第二総軍司令部で軍事輸送を担当していた。8月6日、宮島の下宿から電車に乗りちょうど広島駅に着いた時に被爆。すぐに駅裏の東練兵場に逃げ込み、1週間後東京の鉄道司令部に帰任。',
#   'status_then_detail': '',
#   'work_location': '広島地区鉄道司令部'},
#  {'code': 'VS00775',
#   'name_kana': 'イマガワ|トシハル',
#   'exposure_loc': '白島北町',
#   'exposure_dist': '2km',
#   'age_exposure_detail': '21',
#   'age_production': '77',
#   'details': '兵舎で被爆。強い光と「シュシュ」という音を聞いた直後、後頭部と頬にガラスの破片が刺さり出血。牛田の水源地へ避難後に失神。その後戸坂の救護所へ治療のため徒歩移動。救護所は血まみれの子供を抱える女性や死んだ母親を探す乳児、念仏を唱える老婆などまさに生き地獄だった。',
#   'status_then_detail': '軍人',
#   'work_location': '広島工兵第五連隊'},
#  {'code': 'VS00401',
#   'name_kana': 'イワタ|カズコ',
#   'exposure_loc': '翠町,自宅',
#   'exposure_dist': '2.5km',
#   'age_exposure_detail': '29',
#   'age_production': '77',
#   'details': '3歳の長男を連れて里帰りしていた翠町の自宅で被爆。勤めに出ていた父親を捜して妹と二人で市内を歩きまわる。焼けただれた電車のそばで父親の死体を見つけ、その場で焼いてお骨にした。',
#   'status_then_detail': '主婦',
#   'work_location': ''},
#  {'code': 'VS00809',
#   'name_kana': 'イワタ|セイゾウ',
#   'exposure_loc': '山根町,自宅',
#   'exposure_dist': '3km',
#   'age_exposure_detail': '15',
#   'age_production': '72',
#   'details': '泳ぎに行く予定だったが、座敷で戦闘帽を縫っていた。青白い閃光の後、爆音が轟いて天井が落ちてきた。防空壕へ避難してまもなく黒い雨が降った。広島駅の向こうは火の海で、特殊な爆弾だと思った。皮膚をぶら下げた人々が逃げ回っていた。負傷者の体にウジがわき、毎日のように死んでいった。',
#   'status_then_detail': '学生',
#   'work_location': '日本製鋼所'},
#  {'code': 'VS00597',
#   'name_kana': 'イワタ|モリオ',
#   'exposure_loc': '舟入川口町',
#   'exposure_dist': '2.5km',
#   'age_exposure_detail': '11',
#   'age_production': '63',
#   'details': '岩田さんの通う舟入小学校は東広島に疎開していたが、岩田さんは右足を骨折したため自宅に戻っていた。8月6日、弟と自宅で留守番をしていたときに原爆が落ちた。骨折していたがなんとか避難した。勤労奉仕に出ていた母親は亡くなった。',
#   'status_then_detail': '学生',
#   'work_location': '舟入国民学校'},
#  {'code': 'VS00273',
#   'name_kana': 'イワモト|セツコ',
#   'exposure_loc': '南竹屋町,進徳高等女学校内',
#   'exposure_dist': '1.4km',
#   'age_exposure_detail': '13',
#   'age_production': '59',
#   'details': '進徳高等女学校の屋内で朝礼前に被爆。気がついた時は、右足と手にヤケドを負っていた。すぐに、救護所となっていた陸軍被服支廠に逃げ10日間はそこで過ごした。',
#   'status_then_detail': '学生',
#   'work_location': '進徳高等女学校'},
#  {'code': 'VS00340',
#   'name_kana': 'ウエオカ|マサシ',
#   'exposure_loc': '薬研堀,下宿',
#   'exposure_dist': '1km',
#   'age_exposure_detail': '24',
#   'age_production': '70',
#   'details': '6日勤務明けの朝食を食べようとした瞬間、閃光が走る。下宿の下敷きになる。死体検案書を取りに市内を走り回る。7日深夜まで東署付近で救護にあたる。8日には既に派出所を仮設営する。そこで、勧業銀行収容の被爆者が次々に死んでいくのを目撃する。',
#   'status_then_detail': '公務員',
#   'work_location': '下流川派出所'},
#  {'code': 'VS01014',
#   'name_kana': 'ウエキ|スミコ',
#   'exposure_loc': '楠木町',
#   'exposure_dist': '1.6km',
#   'age_exposure_detail': '17',
#   'age_production': '85',
#   'details': '朝、風邪をひいて自宅で休んでいましたが、みんなが働いているのに申し訳なく思い、工場へ向いました。工場で作業着に着替えている時に真黄色い光線を背後に感じた瞬間、工場の下敷きになりました。しばらくして、大田潤子さんに助け出してもらいました。',
#   'status_then_detail': '学生（女学校5年生）',
#   'work_location': '鋳物工場（楠木町、学徒動員）'},
#  {'code': 'VS00304',
#   'name_kana': 'ウエスギ|アヤコ',
#   'exposure_loc': '舟入川口町,自宅',
#   'exposure_dist': '2km',
#   'age_exposure_detail': '45',
#   'age_production': '92',
#   'details': '主人を玄関で見送ったのち、ふと振り返るとオレンジ色の空が見えた。そのとたんに爆風で飛ばされ、家の下敷きになる。もどってきた主人に助けられる。その後は、全身大火傷の主人の看病がつづいた。',
#   'status_then_detail': '主婦',
#   'work_location': ''},
#  {'code': 'VS00190',
#   'name_kana': 'ウエゾノ|シスイ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '29',
#   'age_production': '73',
#   'details': '郡部から帰ってきたが、ただの焼野原でどうすることもできず、坊守の里方である島根県の西蔵寺に寄留し、10月から浄圓寺仮寺務所を設けた。',
#   'status_then_detail': '僧侶',
#   'work_location': '浄圓寺'},
#  {'code': 'VS01070',
#   'name_kana': 'ウエゾノ|スミコ',
#   'exposure_loc': '金輪島,暁六一四〇部隊',
#   'exposure_dist': '6.0km',
#   'age_exposure_detail': '19',
#   'age_production': '92',
#   'details': '被爆当時は女子挺身隊の一員として、金輪島の暁部隊で給仕や特攻艇の部品の作成などに携わっていた。被爆直後から金輪島と似島で被災者の看病にあたった。皮がずるりと剥ける様子や、体からわいたウジ虫を箸でとる作業、ずらりと並んだ死体、その死体を焼く匂いは、今でも忘れられない。被爆後は甲状腺の異常からくる手足の震えや、目の病気に悩まされた。',
#   'status_then_detail': '女子挺身隊',
#   'work_location': '暁六一四〇部隊'},
#  {'code': 'VS00021',
#   'name_kana': 'ウエダ|シズト',
#   'exposure_loc': '横川町,横川駅前路上',
#   'exposure_dist': '1.5km',
#   'age_exposure_detail': '28',
#   'age_production': '69',
#   'details': '当時28才。爆心地から1．5キロ、横川駅で被爆した。東洋工業に勤務。8月6日の朝は田舎に食糧を買い出しに行くため、駅で汽車を待っていた。広島駅で待ち合わせしていた奥さんも被爆した。',
#   'status_then_detail': '会社員',
#   'work_location': '東洋工業'},
#  {'code': 'VS00234',
#   'name_kana': 'ウエダ|ノリコ',
#   'exposure_loc': '南観音町,学徒動員作業場',
#   'exposure_dist': '2km',
#   'age_exposure_detail': '13',
#   'age_production': '58',
#   'details': '県立第一高等女学校2年生で、学徒動員中に被爆。1年生にいた妹を土橋で失う。いまでも、日記が残る。',
#   'status_then_detail': '学生',
#   'work_location': '県立第一高等女学校'},
#  {'code': 'VS00144',
#   'name_kana': 'ウエダ|マサノリ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '17',
#   'age_production': '60',
#   'details': '金輪島の暁部隊へ学徒動員で通っていた。警戒警報解除とともに金輪島に渡り、閃光を見る。6日の3時か4時頃入市。燃えくすぶる火と人の叫び声の中、連日、被災者の名簿作りと遺品や死体の処理、収容所へのはがき配りなどの活動をする。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS00455',
#   'name_kana': 'ウエノ|テルコ',
#   'exposure_loc': '千田町,広島赤十字病院',
#   'exposure_dist': '1.5km',
#   'age_exposure_detail': '15',
#   'age_production': '65',
#   'details': '当日は日赤病院の宿舎にいた。2階の渡り廊下で被爆。建物の下敷きになった方の救出作業を行った。被爆した人々が病院に着いては力尽きて倒れていった。徹夜で看護活動に従事。本人も頭にしらみが湧くなどして、一週間休暇をとるが、すぐ仕事に復帰した。',
#   'status_then_detail': '看護婦（看護学生）',
#   'work_location': '広島赤十字病院付属看護学校'},
#  {'code': 'VS00436',
#   'name_kana': 'ウエノ|ハルエ',
#   'exposure_loc': '基町,広島逓信局内',
#   'exposure_dist': '0.7km',
#   'age_exposure_detail': '21',
#   'age_production': '70',
#   'details': '局内で被爆。局の建物は無事で、それ以外見渡す限り何も見えなかった。自分はガラス片によるケガのみだった。隣の逓信病院に一人で行き、手当てを受けた。常磐橋を渡ろうとしたが、熱くて渡れず、そこにはたくさんの死体が重なっていた。',
#   'status_then_detail': '公務員',
#   'work_location': '広島逓信局'},
#  {'code': 'VS00979',
#   'name_kana': 'ウエノ|モトム',
#   'exposure_loc': '南観音町',
#   'exposure_dist': '4.1km',
#   'age_exposure_detail': '16',
#   'age_production': '81',
#   'details': '被爆当時１６歳。爆心地からおよそ4.1ｋｍの南観音町の工場で被爆しました。広島市内の造船所で働いていた上野さんは、青白い光を感じた瞬間爆風で吹き飛ばされていました。何が起こったのが分からず、悪夢を見ているようでした。',
#   'status_then_detail': '',
#   'work_location': '三菱重工業の工場（南観音町）'},
#  {'code': 'VS00942',
#   'name_kana': 'ウエヤマ|カズコ',
#   'exposure_loc': '三篠本町',
#   'exposure_dist': '3km',
#   'age_exposure_detail': '11',
#   'age_production': '75',
#   'details': '妹の子守りをしていた自宅で被爆。ピカっと光ったと思ったら、外を歩いていた牛が爆風で浮いた。逃げる途中で黒い雨にあう。トラックに山のように人が積まれて運ばれる様子や河原で死体を焼くにおいはまるで地獄のようだったそうです。',
#   'status_then_detail': '学生（国民学校6年生）',
#   'work_location': '大芝国民学校'},
#  {'code': 'VS00662',
#   'name_kana': 'ウキタ|トシロウ',
#   'exposure_loc': '光町',
#   'exposure_dist': '1.5km',
#   'age_exposure_detail': '13',
#   'age_production': '68',
#   'details': '空襲警報が解除され、集合しようとしていた時、飛行機から三つの物が落とされた。その直後板で叩きつけられたような衝動が走り、目と耳を押さえうずくまった。友人の顔の皮膚がずり落ちていた。天高くまっすぐに黒い雲が伸びているのを見た。街には入れず、呉に向かい、そこで兄と再会。',
#   'status_then_detail': '',
#   'work_location': '県立広島第二中学校'},
#  {'code': 'VS00761',
#   'name_kana': 'ウサガワ|ヨシタカ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '14',
#   'age_production': '71',
#   'details': '原爆投下時は宮島口で作業をしていたが、大きな音とキノコ雲を見た。黒焦げの死体が海岸に流れ着いていた。助勤命令が出たため広島市内に向かい入市被爆。4日間死体を焼き続けたショックは大きい。その後画家となり、被爆が題材の絵画が1点平和記念資料館にある。',
#   'status_then_detail': '公務員',
#   'work_location': '岩国保線区宮島線路班'},
#  {'code': 'VS01067',
#   'name_kana': 'ウシオ|トミエ',
#   'exposure_loc': '台屋町',
#   'exposure_dist': '1.5km',
#   'age_exposure_detail': '14',
#   'age_production': '85',
#   'details': '爆心地からおよそ１.５キロ離れた台屋町の自宅で被爆。広島逓信講習所の生徒だった潮さんは、たまたま休みで自宅にいた。朝食を終え、箸を置いた瞬間、爆風で吹き飛ばされ、気を失った。妹の声で目が覚め、妊娠８ヶ月の姉と母との4人で避難した。戦争がなかったらいい、戦争をする事を考えてほしくないと語る。',
#   'status_then_detail': '学生',
#   'work_location': '広島逓信講習所'},
#  {'code': 'VS00306',
#   'name_kana': 'ウネ|トシエ',
#   'exposure_loc': '霞町,託児所調理室内',
#   'exposure_dist': '2.7km',
#   'age_exposure_detail': '26',
#   'age_production': '73',
#   'details': '霞町の陸軍広島兵器補給廠に勤務する婦人のための託児所に勤務。その日は調理室からでるときに被爆。乳児室の子はハンモックにまかれて泣いていた。比治山の防空濠で水を求めてきた人に水をあげられなかったことを悔やみ、献水活動をつづけている。',
#   'status_then_detail': '軍関係',
#   'work_location': '広島陸軍兵器補給廠'},
#  {'code': 'VS00092',
#   'name_kana': 'ウネ|ヨシノブ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '23',
#   'age_production': '65',
#   'details': '当時23才。呉市で父親の営むやすり工場の工場長をしていた。8月6日の夕方、警防団の仲間2人と共に救援の食糧を広島駅の裏にあった東連兵場に運んだ。現在、呉市の被爆者の会の会長として語り部活動にあたっている。',
#   'status_then_detail': '会社員（工場長）',
#   'work_location': ''},
#  {'code': 'VS00025',
#   'name_kana': 'ウメダ|ヨシフミ',
#   'exposure_loc': '千田町,広島文理大構内',
#   'exposure_dist': '1.7km',
#   'age_exposure_detail': '31',
#   'age_production': '70',
#   'details': '当時31才。爆心地から1．7キロの広島文理科大学の校舎内で被爆した。歯科医だったが作業部隊として召集され、大学を宿舎にして建物疎開にあたっていた。',
#   'status_then_detail': '歯科医',
#   'work_location': ''},
#  {'code': 'VS00954',
#   'name_kana': 'エガワ|マサイチ',
#   'exposure_loc': '荒神町',
#   'exposure_dist': '2.3km',
#   'age_exposure_detail': '16',
#   'age_production': '81',
#   'details': '勤務先である鉄道局へ向かう途中、荒神町の橋付近で歩いているときに被爆。突然ピカッと光ったので、目をつぶり、耳と鼻をふさいで伏せたが、顔と首に火傷を負う。鉄道局の防空壕で昼まで過ごし、機関車の油を火傷した部分に塗ってもらって廿日市の自宅へ。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS00670',
#   'name_kana': 'エガワ|マサル',
#   'exposure_loc': '比治山',
#   'exposure_dist': '1.6km',
#   'age_exposure_detail': '12',
#   'age_production': '66',
#   'details': '学校で遊んでいる時だった。熱い光が校庭を覆い、爆音と共に校舎の下敷きになった。這い出し辺りを見渡すと、沢山の兵隊が倒れ死んでいた。自宅に戻ると家は燃え、家族はいなかった。一人、人の流れについて逃げた。怪我が酷く大洲の病院に入院した。2週間後姉が訪ねて来てくれた。',
#   'status_then_detail': '学生（国民学校6年生）',
#   'work_location': ''},
#  {'code': 'VS00539',
#   'name_kana': 'エグサ|ユウジ',
#   'exposure_loc': '金輪島,島内学生控室',
#   'exposure_dist': '6km',
#   'age_exposure_detail': '17',
#   'age_production': '68',
#   'details': '学徒動員で金輪島にいた。倉庫で友達とお茶を飲んでいた時、左のほっぺに熱線が走った。気が付いたら軍服で長机の下にしゃがんでいた。周囲のすべての音はなくなっていた。外に飛び出して直後のキノコ雲を見た。いろんな色で廻りながら舞上がっていた。橋の方から体にガラスが突きささった女学生を見た。',
#   'status_then_detail': '学生（本科1年生）',
#   'work_location': '広島師範学校'},
#  {'code': 'VS00793',
#   'name_kana': 'エダマツ|キミコ',
#   'exposure_loc': '千田町',
#   'exposure_dist': '1.5km',
#   'age_exposure_detail': '19',
#   'age_production': '75',
#   'details': '職場で被爆。外が光った後、窓ガラスが割れ真っ暗になった。見えるようになると周囲は血だらけだった。自分も顔をガラスで切り前歯を2本折っていた事に後で気付いた。避難する途中で泣いていた5歳位の男の子を県病院まで連れていったが別れてしまい、後に新聞投稿などで捜したが見つからなかった。',
#   'status_then_detail': '公務員',
#   'work_location': ''},
#  {'code': 'VS00011',
#   'name_kana': '土井二三枝',
#   'exposure_loc': '宝町,下宿室内',
#   'exposure_dist': '1km',
#   'age_exposure_detail': '24',
#   'age_production': '65',
#   'details': '当時24才。爆心地から1キロの下宿の室内で被爆した。当時煙石さんは市の職員で夜勤明けの後、家に帰り一休みしている時のことだった。戦後結婚し、現在は娘さん夫婦とお米屋さんを営んでいる。',
#   'status_then_detail': '公務員',
#   'work_location': '広島市役所'},
#  {'code': 'VS00884',
#   'name_kana': 'エンヤ|セツコ',
#   'exposure_loc': '段原町',
#   'exposure_dist': '1.6km',
#   'age_exposure_detail': '5',
#   'age_production': '66',
#   'details': '段原町にある自宅で被爆にあった。ピカッと光った瞬間、次に気付いたときは瓦礫の下敷きになっていた。お母さんが手を差し伸べてくれ助けられた。その日は比治山へ避難し、そこへ行く間にさまざまな悲惨な光景を目にした。7年後妹が突然光熱をだし、原因不明で死んでしまった。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS00505',
#   'name_kana': 'オ|ビョンスウ',
#   'exposure_loc': '矢賀町,自宅',
#   'exposure_dist': '4.1km',
#   'age_exposure_detail': '14',
#   'age_production': '65',
#   'details': '当日朝、家族全員で食事した直後ピカッと光った。何が何だかわからなかった。トタン屋根は吹っ飛び家財道具は散乱、家の中へ入れる状況ではなかった。まもなく周囲はくらくなった。府中川へ近所の人達と避難、一週間位そこで暮らした。',
#   'status_then_detail': '学生（国民学校6年生）',
#   'work_location': '矢賀国民学校'},
#  {'code': 'VS00192',
#   'name_kana': 'オ|ポンス',
#   'exposure_loc': '広瀬北町,建物疎開作業中',
#   'exposure_dist': '1km',
#   'age_exposure_detail': '37',
#   'age_production': '81',
#   'details': '建物の取り壊し作業中に被爆。朝鮮国籍。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS01039',
#   'name_kana': 'オオサキ|ハルオ',
#   'exposure_loc': '南観音町',
#   'exposure_dist': '4.2km',
#   'age_exposure_detail': '16',
#   'age_production': '86',
#   'details': '大咲さんは当時、南観音町の三菱重工業広島機械製作所に動員されていました。８月６日、ちょうど工場で作業に取りかろうとした時に原爆に遭いました。原子爆弾は悪魔の兵器。絶対に無くさなければならない、と語ります。',
#   'status_then_detail': '学生（崇徳中学校3年生）',
#   'work_location': '崇徳中学校'},
#  {'code': 'VS01015',
#   'name_kana': 'オオタ|ジュンコ',
#   'exposure_loc': '楠木町',
#   'exposure_dist': '1.6km',
#   'age_exposure_detail': '14',
#   'age_production': '82',
#   'details': '鋳物工場の窓から見ていると、飛行機から丸い物が落ちてきてピカッと光りました。アッと思った瞬間に建物の下敷きになり気を失いました。ほかの人の泣き声で気が付き、外に出ると、辺りは真っ暗でした。みんな髪は逆立ち、体から血が出ていてとても怖かった。',
#   'status_then_detail': '学生（女学校3年生）',
#   'work_location': '鋳物工場（楠木町、学徒動員）'},
#  {'code': 'VS00396',
#   'name_kana': 'オオタニ|カツヒコ',
#   'exposure_loc': '水主町,軍需工場内',
#   'exposure_dist': '0.9km',
#   'age_exposure_detail': '26',
#   'age_production': '74',
#   'details': '当時大谷さんは、水主町にあった軍需工場で兵器の部品を作っていた。8月5日の夜は宿直。6日の朝、再び勤務についた時被爆した。腕に怪我を負い、出血多量で貧血状態となった。',
#   'status_then_detail': '会社員',
#   'work_location': '巣守金属工業'},
#  {'code': 'VS00736',
#   'name_kana': 'オオタニ|クニタカ',
#   'exposure_loc': '自宅, 平野町',
#   'exposure_dist': '2km',
#   'age_exposure_detail': '16',
#   'age_production': '71',
#   'details': 'ピカッと光り、ドーンと音がする。外に出ると辺りはどの家も潰れ、火の手が上がっていた。比治山橋方面へ逃げる。翌日、死の街と化したヒロシマを歩く。あの時のヒロシマの惨状を一人でも多くの人に伝え、一瞬のうちに消え去った人々の命の意味を考えて欲しいと願う。',
#   'status_then_detail': '学生',
#   'work_location': '航空士官学校'},
#  {'code': 'VS00153',
#   'name_kana': 'オオツカ|ムネモト',
#   'exposure_loc': '大手町,電車内',
#   'exposure_dist': '0.4km',
#   'age_exposure_detail': '23',
#   'age_production': '66',
#   'details': '船舶砲兵部隊の小隊長。宇品に向かう電車内で被爆。500メートル以内で奇跡的に助かった一人。',
#   'status_then_detail': '軍人',
#   'work_location': '船舶砲兵部隊'},
#  {'code': 'VS00776',
#   'name_kana': 'オオト|キヌエ',
#   'exposure_loc': '千田町',
#   'exposure_dist': '1.7km',
#   'age_exposure_detail': '19',
#   'age_production': '75',
#   'details': '職場で被爆。稲光のあと窓ガラスが割れ真黄色の煙が入ってきた。ガラスで胸を怪我し、右腕に火傷を負った。東側だった机が西側に移動していた。段原の自宅へ戻って怪我を治療。3日経って背中に火傷を負った妹が帰宅。かゆいと言うので幕を剥ぐとうじが湧いていた。',
#   'status_then_detail': '公務員',
#   'work_location': '広島貯金支局'},
#  {'code': 'VS00909',
#   'name_kana': 'オオノ|イツミ',
#   'exposure_loc': '出汐町',
#   'exposure_dist': '2.5km',
#   'age_exposure_detail': '14',
#   'age_production': '76',
#   'details': '幼いころから遊び場として慣れ親しんでいた、比治山の山頂に続々と集まってくる全身やけどを負った被爆者たち。その中には大野さんの名前を呼ぶ幼馴染らしき少女。しかしその顔は少女が誰なのかわからぬほど腫れ上がっていました。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS00657',
#   'name_kana': 'オオバ|タカコ',
#   'exposure_loc': '上天満町',
#   'exposure_dist': '1.2km',
#   'age_exposure_detail': '15',
#   'age_production': '70',
#   'details': '作業をするため機械の電源を入れた瞬間に青い光がした。直後体が浮き、記憶を失った。気が付くと真っ暗の中下敷きになっていた。助けてと叫び続け、助けられ外に出ると、回りは何も無く火の手が上がっていた。実家の打越に逃げ翌日母と再会。父が死んだと聞く。祖父・祖母相次いで死亡。',
#   'status_then_detail': '学生',
#   'work_location': '安芸高等女学校'},
#  {'code': 'VS00643',
#   'name_kana': 'オオバ|マサオ',
#   'exposure_loc': '入市,狩留家',
#   'exposure_dist': '',
#   'age_exposure_detail': '19',
#   'age_production': '71',
#   'details': '学徒動員で名古屋の大同製鋼所にいたが、足を怪我し甲立町に疎開していた。広島の病院に通院しており、向かう途中の狩留家辺りで被爆。先に進めず、汽車で引き返した。8日入市。',
#   'status_then_detail': '学生',
#   'work_location': '明治大学'},
#  {'code': 'VS00479',
#   'name_kana': 'オオバヤシ|ユキエ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '26',
#   'age_production': '76',
#   'details': '安佐町久地村の畑で草取りをしていた。突然、東の山に大きな入道雲がわき上り、黒い雨が降ってきた。夫が怪我をしたという知らせを受け、9日、夫を捜しに、古市まで車で、徒歩で白島へ向かった。夫と南観音の実家に避難した。行方不明の妹を探しに、市内の収容所（学校）を何か所も歩き回った。',
#   'status_then_detail': '主婦',
#   'work_location': ''},
#  {'code': 'VS00684',
#   'name_kana': 'オオバヤシ|ヨシノリ',
#   'exposure_loc': '己斐町',
#   'exposure_dist': '2.8km',
#   'age_exposure_detail': '16',
#   'age_production': '71',
#   'details': '工場で作業している時だった。すごい音がして外を覗いた瞬間爆風が襲ってきた一瞬のうちに工場はペチャンコ。幸いに同僚たちも皆無傷だった。福島町の工場に救援に向かったが火の手がすごくたどり着くことが出来なかった。己斐の山から悲惨な街の様子を見ていた。翌日救援に向かった。',
#   'status_then_detail': '',
#   'work_location': '旧中学'},
#  {'code': 'VS00885',
#   'name_kana': 'オオマエ|タツオ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '16',
#   'age_production': '78',
#   'details': '国鉄に勤務しており、８月５日の朝から６日の朝まで海田市駅にいた。６日の朝、勤務交代のため駅の中で引継ぎをしているとき、突然の爆音を耳にした。何が起きたか分からないまま線路を通り自宅へと帰った。その途中で被爆し負傷した人々をたくさん目にした。その後、爆心地に近い下柳町で被爆に遭い行方不明になった姪を探して歩いたが、結局発見できなかった。',
#   'status_then_detail': '公務員',
#   'work_location': '広島鉄道局'},
#  {'code': 'VS00330',
#   'name_kana': 'オオマエ|マサミ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '32',
#   'age_production': '79',
#   'details': '当時32歳だった大前さんは、宮島駅駅長だった。6日太陽が炸裂したかと思われる様な真っ赤な陽の玉を見た。乗客を防空壕に誘導している最中、爆風で人が吹き飛ばされるのを見た。7日の午後、試験運転のため、市内に入って被爆した。',
#   'status_then_detail': '会社員',
#   'work_location': '広島電鉄'},
#  {'code': 'VS00901-08',
#   'name_kana': 'オカ|タモツ',
#   'exposure_loc': '千田町',
#   'exposure_dist': '2.0km',
#   'age_exposure_detail': '21',
#   'age_production': '81',
#   'details': '受講中に校舎内で被爆',
#   'status_then_detail': '学生',
#   'work_location': '広島高等工業学校'},
#  {'code': 'VS00054',
#   'name_kana': 'オカ|ヨシエ',
#   'exposure_loc': '基町,軍管区司令部地下',
#   'exposure_dist': '0.5km',
#   'age_exposure_detail': '14',
#   'age_production': '56',
#   'details': '当時14才。学徒動員で、基町の中国軍管区司令部の地下室で空襲警報の発令や解除の連絡業務をしていた。8月5日の夜は警報の連絡で大変忙しかったそうだ。そして8月6日の朝、交換台に座っていた時、地下室に紫いろの閃光が走り、2～3分間気を失った。地下室から外にでてみると広島市内は大火災となっており、早速交換台に駆けつけ、広島に新型爆弾が落ちたことを最初に九州と福山の軍関係に連絡した。',
#   'status_then_detail': '学生',
#   'work_location': ''},
#  {'code': 'VS00308',
#   'name_kana': 'オカザキ|ヒデヒコ',
#   'exposure_loc': '東雲,比治山小学校前',
#   'exposure_dist': '3km',
#   'age_exposure_detail': '17',
#   'age_production': '65',
#   'details': '当時、市立第一工業学校へ通っていた岡崎さんは、登校の途中に比治山小学校の前で被爆。岡崎さんは、小網町に居た弟を原爆で失う。高田郡の田舎に居た両親と妹は無事だった。市民の手で原爆を記録しようと昭和49年、被爆の様子を描く。',
#   'status_then_detail': '学生',
#   'work_location': '市立第一工業学校'},
#  {'code': 'VS00955',
#   'name_kana': 'オカダ|アキノリ',
#   'exposure_loc': '霞町',
#   'exposure_dist': '2.7km',
#   'age_exposure_detail': '17',
#   'age_production': '81',
#   'details': '学徒動員先の霞町の兵器廠で被爆。突然ピカッと光り、気がついた時には飛ばされていた。建物は潰れなかった。兵器廠の防空壕が比治山にあったのでそこに避難。昼過ぎには自宅へ帰るため広島駅へ向かったが、的場町は火事がひどく、己斐→横川を回って帰った。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS01027',
#   'name_kana': 'オカダ|イツエ',
#   'exposure_loc': '御幸橋の上',
#   'exposure_dist': '2.2km',
#   'age_exposure_detail': '15',
#   'age_production': '84',
#   'details': '広島電鉄家政女学校の学生だった。半日勉強、半日電車乗務員の生活だった。8月6日、御幸橋の上で、宇品行きの電車に乗っているときに被爆した。車内は皆右往左往するばかり。顔の皮がぶら下がり、怪我をした人の列が続いていた。',
#   'status_then_detail': '学生',
#   'work_location': '広島電鉄家政女学校'},
#  {'code': 'VS00747',
#   'name_kana': 'オカダ|エミコ',
#   'exposure_loc': '自宅, 尾長町',
#   'exposure_dist': '2.8km',
#   'age_exposure_detail': '8',
#   'age_production': '64',
#   'details': '空を飛ぶB29に向かって、無邪気に手を振っていた。ドーンとゆう音とともに地面に叩きつけられる。自宅の柱は、くの字に曲った。家族で中山へ逃げる。峠の竹やぶから、広島が燃え尽きていくのを眺める。原爆で姉を亡くす。現在、核兵器廃絶を願い、様々な平和活動に参加している。',
#   'status_then_detail': '学生（尾長国民学校3年）',
#   'work_location': '尾長国民学校'},
#  {'code': 'VS00886',
#   'name_kana': 'オカダ|ヒサエ',
#   'exposure_loc': '楠木町',
#   'exposure_dist': '1.6km',
#   'age_exposure_detail': '16',
#   'age_production': '77',
#   'details': '８月６日は仕事が休みで、近所の友達と立ち話しをしていた。その後一緒に病院へ行くため、縁側で準備をしているときに原爆が投下された。ものすごい爆風で家の中に飛ばされたが、打撲程度で大したケガは無かった。一緒にいた友達は大火傷を負い、悲惨な姿になっていた。その後避難先の安小学校で数日過ごし、自宅へ戻って父親と再会した。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS00344',
#   'name_kana': 'オカダ|ヤソキチ',
#   'exposure_loc': '中広町,自宅',
#   'exposure_dist': '1.5km',
#   'age_exposure_detail': '15',
#   'age_production': '62',
#   'details': '6日は元安橋での建物疎開を休み、通学準備をしていた。一緒に行く友人を待って、玄関の板の間で寝転んでいた時、被爆。家の下敷きとなる。母親と共に山手町へ逃げる。逃げる途中、生きながら焼かれていく人々を目撃する。後年ケロイドが元で結婚を断られる。',
#   'status_then_detail': '学生',
#   'work_location': '市立第二工業学校'},
#  {'code': 'VS00887',
#   'name_kana': 'オカダ|ヨシノリ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '17',
#   'age_production': '78',
#   'details': '陸軍特攻空母に乗船するため坂町におり、そこで原爆の被害に遭った。自宅のある楠木町に帰るとき、悲惨な光景を目にした。自宅は潰れており、母と兄弟は竹やぶに避難し無事だった。その後、勤労奉仕に出ていた父親を探して歩いたが、数日後結局死体で見つかった。',
#   'status_then_detail': '軍属',
#   'work_location': ''},
#  {'code': 'VS00154',
#   'name_kana': 'オカダ|ロクロウ',
#   'exposure_loc': '宇品町,宇品港',
#   'exposure_dist': '4.0km',
#   'age_exposure_detail': '23',
#   'age_production': '67',
#   'details': '船舶兵として南方北方を転戦後、広島で被爆。昭和59年に初めて被爆者手帳をもらう。',
#   'status_then_detail': '軍人',
#   'work_location': '暁第2953部隊'},
#  {'code': 'VS00635',
#   'name_kana': 'オカノ|フサエ',
#   'exposure_loc': '入市,五日市町',
#   'exposure_dist': '',
#   'age_exposure_detail': '38',
#   'age_production': '90',
#   'details': '吉見園に疎開。9日に娘に報告のため、師団司令部に夫と行った。歩く道に死骸はほとんどなく片付いていた。家の焼け跡を覗いた時、家を建てた大工（棟梁）の奥さんが粉々になっていた。',
#   'status_then_detail': '',
#   'work_location': '岡重商店'},
#  {'code': 'VS00216',
#   'name_kana': 'オカノシタ|カナメ',
#   'exposure_loc': '鉄砲町,知人宅',
#   'exposure_dist': '0.8km',
#   'age_exposure_detail': '28',
#   'age_production': '73',
#   'details': '鉄砲町の知人宅で新聞を読んでいて被爆。家の下敷きになるが、自力で脱出し、京橋、駅前を経て、日本製鋼所の附属病院のそばまでくるが、患者で一杯のため、海田にある妻の実家まで帰る。8月20日ごろから脱毛、発熱、皮下出血し、3カ月療養。',
#   'status_then_detail': '会社員',
#   'work_location': '日本製鋼所'},
#  {'code': 'VS00888',
#   'name_kana': 'オカムラ|エツヤ',
#   'exposure_loc': '南観音町',
#   'exposure_dist': '3.0km',
#   'age_exposure_detail': '16',
#   'age_production': '77',
#   'details': '学徒動員で三菱造船の工場で働いており、その勤務中に被爆にあった。建物は鉄骨だったので壊れることはなく、かすり傷を負った程度だった。市内の悲惨な光景を目にしながら自宅へと戻った。自宅は残っており家族も健在だった。夕方、負傷した父の友人が自宅に現れ看病したが、数日後死亡した。',
#   'status_then_detail': '学生（旧制中学4年生）',
#   'work_location': ''},
#  {'code': 'VS00927',
#   'name_kana': 'オカムラ|ジュンコ',
#   'exposure_loc': '宇品町',
#   'exposure_dist': '3km',
#   'age_exposure_detail': '16',
#   'age_production': '80',
#   'details': '学校の講堂で校長先生の話が終わって椅子に座ろうとした時に被爆。とっさに机の下に隠れた。屋根が崩れて木片やガラスが降ってきた。夕方自宅へ帰る途中、電車の中でそのまま亡くなっている人や防火用水に頭を突っ込んでいる人など悲惨な状況を目撃しているそうです。',
#   'status_then_detail': '学生',
#   'work_location': '広島女子専門学校'},
#  {'code': 'VS00981',
#   'name_kana': 'オカモト|ツヨシ',
#   'exposure_loc': '三篠町',
#   'exposure_dist': '3.0km',
#   'age_exposure_detail': '9',
#   'age_production': '75',
#   'details': '被爆当時９歳。爆心地からおよそ3kmの三篠町の通学していたお宮で被爆しました。小学校４年生の時、通っていたお宮で、石臼を挽くような爆音を響かすB29を目撃。みんなに知らせようとした時、何かが炸裂し、意識を失ったといいます。',
#   'status_then_detail': '学生（国民学校4年生）',
#   'work_location': ''},
#  {'code': 'VS00995',
#   'name_kana': 'オカモト|トオル',
#   'exposure_loc': '南観音町',
#   'exposure_dist': '3.1km',
#   'age_exposure_detail': '8',
#   'age_production': '74',
#   'details': '８月６日、夏休みだったので寮で一人で朝食をとっていた。ピカッと光った瞬間、真っ暗になった。何が起こったのかと、割れた窓ガラスから見ると外も暗かった。８月６日の夜から２、３日\u3000庚午橋で過ごした。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS00864',
#   'name_kana': 'オカモト|トシユキ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '18',
#   'age_production': '78',
#   'details': '呉海兵団の炊事係で宇和島で終戦を迎えた。１８日に広島駅より宇品のあかつき部隊にいたおじを訪ねる。一面焼け野原の広島市を歩き遺骨の山を見て呆然とした。９月になって広島に来た時は人の背中がハエで真っ黒であった。その次に来た時は、ハエはいなかった。',
#   'status_then_detail': '軍属',
#   'work_location': '呉海兵団'},
#  {'code': 'VS00029',
#   'name_kana': 'オガサワラ|ハルコ',
#   'exposure_loc': '舟入中町,自宅庭',
#   'exposure_dist': '1.2km',
#   'age_exposure_detail': '13',
#   'age_production': '54',
#   'details': '当時13才。爆心地から1．2キロの自宅で梅を干している最中に被爆した。4才の妹は家の下敷きになったが、母と二人で救出した。戦後、結婚したご主人も被爆者で現在は自宅で療養生活を送っている。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS01087',
#   'name_kana': 'オガタ|スミコ',
#   'exposure_loc': '十日市町',
#   'exposure_dist': '0.7km',
#   'age_exposure_detail': '13',
#   'age_production': '86',
#   'details': '広島女学院高等学校２年生だった当時、毎日学徒動員で雑魚場町に行っていたが、その日は体調が悪く自宅にいたところ被爆。叔母が壊れた建物から助け出してくれた。弟たちと一緒に山手川の河川敷に避難。２週間後、原爆症を発症。意識が戻った時には叔母は亡くなっていた。学徒動員に出ていた多くの学友も亡くなった。',
#   'status_then_detail': '中学2年生',
#   'work_location': '広島女学院高等女学校'},
#  {'code': 'VS00332',
#   'name_kana': 'オガワ|カツスミ',
#   'exposure_loc': '八丁堀,電車内',
#   'exposure_dist': '0.5km',
#   'age_exposure_detail': '17',
#   'age_production': '64',
#   'details': '被爆の朝、呉を6時に出発し8時に広島入り。八丁堀付近走行中の電車内で被爆。金色の光が視界一杯に広がったかと思うと気を失う。気がついた時は電車の外におり、あわてて防火用水に飛び込む。負傷者を乗せたトラックで呉まで戻るが、その後下痢などに悩まされる。',
#   'status_then_detail': '軍人',
#   'work_location': '呉海兵団'},
#  {'code': 'VS00734',
#   'name_kana': 'オガワ|ミチコ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '12',
#   'age_production': '67',
#   'details': '呉の自宅で掃除をしていると、手元に閃光を感じる。広島方向の空を見上げると、大きなキノコ雲があがっていた。8月8日、五日市に疎開していた妹が心配になり広島市内に入る。広島は、焼け野原で、はるか遠くまで見渡すことが出来た。あのヒロシマの様子は、目に焼きつき忘れることはない。',
#   'status_then_detail': '学生',
#   'work_location': '五日市国民学校'},
#  {'code': 'VS00210',
#   'name_kana': 'オキモト|シゲオ',
#   'exposure_loc': '南観音町,三菱重工内',
#   'exposure_dist': '4.6km',
#   'age_exposure_detail': '15',
#   'age_production': '60',
#   'details': '学徒動員（タービン作り）作業中に建物の中で被爆。白っぽい一瞬の光が目をおおった。爆風のため体が倒されたが怪我はなかった。約5人が被爆し、担当教師1人も被爆した。観音町で黒い雨を浴びた。その後、救援活動を行った。ＪＴ（日本たばこ）広島支社Ｓ．23年6月入社（19才）。',
#   'status_then_detail': '学生',
#   'work_location': '広島市立中学校'},
#  {'code': 'VS00652',
#   'name_kana': 'オクダ|サカエ',
#   'exposure_loc': '河原町',
#   'exposure_dist': '1km',
#   'age_exposure_detail': '8',
#   'age_production': '63',
#   'details': '疎開先から戻り自宅に戻った時、光が覆い空が真っ暗になった。家の下敷きになり記憶がなくなったが無意識に外に這い出していた。辺りは家が崩れ、火が燃え悲惨な状況の中、草津小学校まで逃げた。翌朝、廿日市に向かい父と姉に再会。祖母と上の兄は即死、母と兄は行方不明のままだった。',
#   'status_then_detail': '学生（国民学校3年生）',
#   'work_location': ''},
#  {'code': 'VS01012',
#   'name_kana': 'オグラ|ケイコ',
#   'exposure_loc': '牛田町',
#   'exposure_dist': '2.4km',
#   'age_exposure_detail': '8',
#   'age_production': '75',
#   'details': '６日の朝、父親から不吉な予感がするから今日は学校を休めと言われ、自宅に居ました。前の道路に出た瞬間、目もくらむような閃光に襲われました。近くの高台からは、似島が見えました。被爆の惨状を伝えることが、生かされている意味を感じる時と語ります。',
#   'status_then_detail': '学生（国民学校2年生）',
#   'work_location': ''},
#  {'code': 'VS00988',
#   'name_kana': 'オグラ|トシツグ',
#   'exposure_loc': '吉島羽衣町',
#   'exposure_dist': '1.7km',
#   'age_exposure_detail': '14',
#   'age_production': '80',
#   'details': '８月６日朝学校へ向う途中ピカッと光り爆風で飛ばされた。立ち上がり学校へ行くと怪我をしている同級生たちが沢山いた。市内が燃えていたので草津の球場まで逃げ泥だらけの体を洗い流した。自宅へ向ったがあまりの熱さで帰れなかった。川には死体が沢山流れていた。',
#   'status_then_detail': '学生（国民学校高等科）',
#   'work_location': ''},
#  {'code': 'VS00482',
#   'name_kana': 'オグラ|ミヨコ',
#   'exposure_loc': '宇品神田通り,隣家',
#   'exposure_dist': '3.3km',
#   'age_exposure_detail': '22',
#   'age_production': '72',
#   'details': '主人を送り出した後、隣家へ米の配給に出かけた。その隣家の土間で被爆。自宅は壁が落ち、屋根は破れガラスも壊れた。食料をかき集め近所の方の救護を隣家でした。その後、八木に住んでいる知人のところに避難した。',
#   'status_then_detail': '主婦',
#   'work_location': ''},
#  {'code': 'VS00485',
#   'name_kana': 'オグラ|ヨウイチ',
#   'exposure_loc': '金輪島',
#   'exposure_dist': '4.1km',
#   'age_exposure_detail': '26',
#   'age_production': '76',
#   'details': '勤務場所の金輪島に到着。突然、激しい閃光を受けた。状況把握のため外に出ようとした瞬間、爆風に襲われ吹き飛ばされた。床に倒れ、屋根の構造物が落下して軽傷を負った。船舶司令部の命令で、広島市内に入り、救助活動に当った。',
#   'status_then_detail': '軍人',
#   'work_location': '暁第6140部隊'},
#  {'code': 'VS00572',
#   'name_kana': 'オダ|ケイソウ',
#   'exposure_loc': '宝町',
#   'exposure_dist': '1.3km',
#   'age_exposure_detail': '15',
#   'age_production': '67',
#   'details': '小田さんは当時、山陽商業学校の3年生だったが、学徒動員のため軍需工場で作業をしていた。8月6日は作業が休みだったので自宅で両親と朝食をとった後、近所の友人の家に遊びに行きそこで被爆した。',
#   'status_then_detail': '学生',
#   'work_location': '山陽商業学校'},
#  {'code': 'VS01078',
#   'name_kana': 'オダ|サダエ',
#   'exposure_loc': '入市被爆',
#   'exposure_dist': '',
#   'age_exposure_detail': '20',
#   'age_production': '93',
#   'details': '広島鉄道局で車掌を務めていた小田さんは8月6日の朝、三次の寮でピカッと光を感じた。駆けつけた三次駅には男か女かもわからない負傷者たちが貨車で運び込まれていた。翌日入った広島市は何もない空っぽの街だった。広島・三次間の列車は負傷者たちの臭いが立ちこめ、制服に染み付いた臭いを宿泊所で洗った。',
#   'status_then_detail': '公務員（車掌）',
#   'work_location': '広島鉄道局車掌区'},
#  {'code': 'VS00335',
#   'name_kana': 'オダ|ヤスヒコ',
#   'exposure_loc': '白島町,西部第114部隊',
#   'exposure_dist': '2km',
#   'age_exposure_detail': '22',
#   'age_production': '69',
#   'details': '週番日誌をつけている時ピカッと火の玉が炸裂。あわてて中廊下に出た時。爆風が押し寄せた。気を失い、気がつくと木の間にはさまっていた。隊の救護活動を手伝った後、宇品へ逃げる。穴の中に一人置き去りにされた赤ん坊の姿が忘れられない。',
#   'status_then_detail': '軍人',
#   'work_location': '西部第114部隊'},
#  {'code': 'VS00817',
#   'name_kana': 'オダニ|ミワコ',
#   'exposure_loc': '祇園町,国民学校',
#   'exposure_dist': '4.1km',
#   'age_exposure_detail': '8',
#   'age_production': '65',
#   'details': '校庭の掃除中に空襲警報が鳴って、帰宅する。姉妹3人で遊んでいると、目の前を閃光が走った。轟音がして、障子やふすまが倒れた。防空壕へ避難。夕方、長女が血だらけで帰宅。父と次女は戻らず。9日、全身火傷を負った次女を、母が連れ帰る。翌朝次女は亡くなる。父は未だ行方不明のまま。',
#   'status_then_detail': '学生（国民学校2年生）',
#   'work_location': '山本国民学校'},
#  {'code': 'VS00309',
#   'name_kana': 'オヌカ|マサミ',
#   'exposure_loc': '宇品,暁部隊訓練中',
#   'exposure_dist': '4km',
#   'age_exposure_detail': '24',
#   'age_production': '70',
#   'details': '暁部隊の写真班に所属。朝の訓練を受けている時突然黄色い光が目の前に広がり、腹にこたえる轟音が伝わった。軍の指示で、被災者の様子を多数撮影する。',
#   'status_then_detail': '軍人',
#   'work_location': '暁部隊'},
#  {'code': 'VS00471',
#   'name_kana': 'オノエ|カズオ',
#   'exposure_loc': '千田町,県車体整備組合',
#   'exposure_dist': '2km',
#   'age_exposure_detail': '38',
#   'age_production': '88',
#   'details': '定例の朝礼が始まり、作業予定の指示を受けていた。倉庫に入ろうとした瞬間、被爆した。自宅に戻り、火傷に効くと言われた、石灰を油で練ったものを毎日母が取り替えてくれた。40日間寝たきりだった。',
#   'status_then_detail': '会社員',
#   'work_location': '広島県車体整備組合'},
#  {'code': 'VS00789',
#   'name_kana': 'オノオカ|ヨシタカ',
#   'exposure_loc': '比治山町',
#   'exposure_dist': '2km',
#   'age_exposure_detail': '13',
#   'age_production': '70',
#   'details': '建物疎開のため校庭で朝礼中に被爆。ビカッと光ったあと校舎まで飛ばされた。自分も含め周囲の人は火傷で顔が風船のように腫れ上がった。川や防火水槽で冷やしながら避難。福屋が火災でゴーと音を立てていたのを覚えている。現在もABCCで指定患者として検査を受けている。',
#   'status_then_detail': '学生（商業学校2年生）',
#   'work_location': '県立商業学校'},
#  {'code': 'VS00019',
#   'name_kana': 'オノギ|アキラ',
#   'exposure_loc': '天満町,自宅室内',
#   'exposure_dist': '1.2km',
#   'age_exposure_detail': '16',
#   'age_production': '56',
#   'details': '当時16才。爆心地から1.2キロの自宅で被爆した。建物が土蔵の陰になり、猛烈な爆風を避けることができた。家は間もなく焼けたが、一家5人、奇跡的に助かった。',
#   'status_then_detail': '学生（中学校2年生）',
#   'work_location': ''},
#  {'code': 'VS00279',
#   'name_kana': 'オモダ|タカコ',
#   'exposure_loc': '千田町,日赤病院屋内',
#   'exposure_dist': '1.6km',
#   'age_exposure_detail': '20',
#   'age_production': '66',
#   'details': '広島赤十字病院の看護学院の教務室で被爆。くずれた建物の下敷きになり、肋骨を折って頭部にケガをした。しかし、傷ついた体で、看護生の救出や、病院での看護活動を続けた。',
#   'status_then_detail': '看護婦',
#   'work_location': '広島赤十字病院'},
#  {'code': 'VS00985',
#   'name_kana': 'オリカワ|タケシ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '16',
#   'age_production': '82',
#   'details': '８月６日の午後、西条駅で怪我をして広島から逃げてきた被爆者を運んだ。広島が大変なことになっていると聞き、地元の人たちと助けに広島へ向った。数えきれないほどの死体があった。全く知らない生きた人と出会うと話をする前に抱き合って涙を流した。',
#   'status_then_detail': '学生（西条農学校3年生）',
#   'work_location': ''},
#  {'code': 'VS00237',
#   'name_kana': 'オリメン|シゲコ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '37',
#   'age_production': '82',
#   'details': '小網町に、学徒動員されていた二男の滋くんを探しに市内に入る。朝、持たせた大豆入りの弁当箱が、黒焦げで遺体の下に残っていた。弁当箱は資料館に保管されている。〈まっ黒なおべんとう〉として出版された。',
#   'status_then_detail': '主婦',
#   'work_location': ''},
#  {'code': 'VS00004',
#   'name_kana': 'カイカワ|ユリコ',
#   'exposure_loc': '八丁堀,貯金局福屋7階',
#   'exposure_dist': '0.8km',
#   'age_exposure_detail': '15',
#   'age_production': '56',
#   'details': '当時15才。爆心地から0.8キロの福屋7階の貯金局に学徒動員として勤めていた。原爆のため、4人の兄弟を亡くした。',
#   'status_then_detail': '学生',
#   'work_location': '広島貯金局（福屋7階、学徒動員）'},
#  {'code': 'VS00658',
#   'name_kana': 'カガワ|クニアキ',
#   'exposure_loc': '田中町',
#   'exposure_dist': '1.2km',
#   'age_exposure_detail': '8',
#   'age_production': '63',
#   'details': '窓から不思議な青白い光が入ってきたと同時に家が崩れ下敷きになっていた。外に這い出してみると真っ暗で、小学校が崩れ、赤々と燃えていたのを覚えている。怪我が酷かったため、兄弟と分かれ比治山・宇品・金輪島へと逃げた。大竹の小学校で母と再会。家族の状況を知った。',
#   'status_then_detail': '学生',
#   'work_location': '竹屋国民学校'},
#  {'code': 'VS00126',
#   'name_kana': 'カガワ|サトコ',
#   'exposure_loc': '大須賀町,第二総軍司令部',
#   'exposure_dist': '1.7km',
#   'age_exposure_detail': '18',
#   'age_production': '61',
#   'details': '当時18才。爆心地から1．7キロにある大須賀町の第二総軍司令部で被爆した。広島駅裏にある東照宮、昔はここから広大な連兵場と賀川さんの勤める第二総軍司令部を見渡すことができた。8月6日賀川さんは薄い肌着しか着ていなかったため全身に大やけどを負った。あちらこちで火の手が上がる広島市内を逃げ惑った。あの苦しい日々のことを自分の子供や孫たちに伝えようと最近手記を書き始めた。',
#   'status_then_detail': '軍人',
#   'work_location': '第二総軍司令部'},
#  {'code': 'VS00432',
#   'name_kana': 'カガワ|フミコ',
#   'exposure_loc': '鶴見町,勤労奉仕',
#   'exposure_dist': '1.5km',
#   'age_exposure_detail': '20',
#   'age_production': '69',
#   'details': '矢賀の自宅から町内の50人余りの人と勤労奉仕に出掛けていた。朝礼を受けているとき、飛行機が飛び、突然爆風を受け、熱湯を浴びた様な感じがして気絶した。気がつくと背中や腕に火傷を負っていた。火傷からは次々にウジがわき、日に十回も包帯を替えるようであった。',
#   'status_then_detail': '主婦',
#   'work_location': ''},
#  {'code': 'VS00940',
#   'name_kana': 'カギモト|イズミ',
#   'exposure_loc': '青崎町',
#   'exposure_dist': '4km',
#   'age_exposure_detail': '12',
#   'age_production': '76',
#   'details': '朝礼前の小学校校庭で被爆。ピカっと光り、爆風で学校の窓ガラスは割れ、窓枠もなくなっていた。学校には多くのけが人が運び込まれ、皮膚が垂れ下がり誰だか分らないような負傷者に水を運んであげたりしていた。衝撃的な光景は心に深く刻まれ、忘れられないそうです。',
#   'status_then_detail': '学生',
#   'work_location': '青崎国民学校高等科'},
#  {'code': 'VS00443',
#   'name_kana': 'カク|キフン',
#   'exposure_loc': '白島北町,作業場へ行く途中',
#   'exposure_dist': '2km',
#   'age_exposure_detail': '21',
#   'age_production': '70',
#   'details': '6日の朝、白島で100人以上の兵隊たちと穴掘り作業に行くためシャベルをもって行進していたとき被爆した。小学校に収容され、肉親の名前を呼ぶ声や、遺体を焼く臭いを今でも鮮明に覚えている。現在、韓国の被爆者援護活動の中心となっている。',
#   'status_then_detail': '軍人',
#   'work_location': '中国軍管区歩兵第一補充隊（中国第104部隊）'},
#  {'code': 'VS00106',
#   'name_kana': 'カク|ポクスン',
#   'exposure_loc': '大手町,自宅',
#   'exposure_dist': '0.9km',
#   'age_exposure_detail': '16',
#   'age_production': '59',
#   'details': '当時16才。爆心地から0．9キロの大手町5丁目で被爆した。昭和3年日本で生まれ、前の年に韓国から渡って来た両親と広島で暮らしていた。現在は4人の子を持つ母親である。これまで人前では決して原爆を語らなかった。そんな彼女をかえたのは、平和公園の外にある（当時）韓国人原爆犠牲者慰霊碑との出会いであった。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS00689',
#   'name_kana': 'カサオカ|サダエ',
#   'exposure_loc': '江波町',
#   'exposure_dist': '3.8km',
#   'age_exposure_detail': '13',
#   'age_production': '67',
#   'details': 'いつもは学徒動員で作業に出ている時間だったが、この日は休み家の片付けをしていた。家に入った瞬間に東側から強烈な光が入り、ガラスの破片が飛び、自分の方に向かってきた。祖母と防空壕に避難した。火傷や怪我を負った多くの人たちが続々と街から逃れてきていた。見るのも無残な光景だった。',
#   'status_then_detail': '学生（女学校1年生）',
#   'work_location': ''},
#  {'code': 'VS00889',
#   'name_kana': 'カシハラ|ミツヤ',
#   'exposure_loc': '大手町',
#   'exposure_dist': '1.0km',
#   'age_exposure_detail': '17',
#   'age_production': '79',
#   'details': '広島市農業会に勤務しており、８月６日当日は職場に着いてすぐ被災に遭った。建物の下敷きになり、その瞬間に気絶していた。自力で脱出し、市内へ出た。激しい火災、被爆した人々を見ながら、途中で出会った同僚と共に病院へと向かい、翌日横川駅で家族に再会した。',
#   'status_then_detail': '公務員',
#   'work_location': '広島市農業会'},
#  {'code': 'VS00724',
#   'name_kana': 'カシワ|カズユキ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '13',
#   'age_production': '68',
#   'details': '疎開中の郊外から広島の方面がピカッと光るのを見る。郊外には、怪我をし呆然とした様子で多くの被災者達が逃げてきた。8月15日市内に入り、変わり果てた広島の様子に驚く。原爆で父を亡くす。現在、被爆体験証言者として活動中。',
# ...
#   'exposure_loc': '大手町,自宅',
#   'exposure_dist': '0.8km',
#   'age_exposure_detail': '18',
#   'age_production': '60',
#   'details': '当時18才。山下さんは大手町の元公会堂の近くにあった3階建ての自宅で被爆した。被爆後、吉島にあった飛行機に5日間避難した。体に36カ所も傷を受け、髪も抜けた。山下さんの頭髪は広島の原爆資料館に展示されている。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS00595',
#   'name_kana': 'ヤマダ|スミコ',
#   'exposure_loc': '三滝町',
#   'exposure_dist': '2.3km',
#   'age_exposure_detail': '2',
#   'age_production': '54',
#   'details': '旧姓吉村さん。山田さんは当時、両親・兄弟3人・いとこ2人と一緒に三滝町へ疎開していた。幼いときに被爆したので、詳しいことは覚えていない。その後の生活の苦労・生き方についての話。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS00212',
#   'name_kana': 'ヤマダ|トシオ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '34',
#   'age_production': '79',
#   'details': '当時、海田女学校教師。学徒動員で生徒を誘導しているとき、向洋の東洋工業前で原爆投下を知る。その後、流川町等市内に入り救護活動を行い、多くの人の死に直面した。自分の生徒の中にも原爆孤児がいた。',
#   'status_then_detail': '教職員',
#   'work_location': '海田女学校'},
#  {'code': 'VS00782',
#   'name_kana': 'ヤマダ|モトシ',
#   'exposure_loc': '国泰寺町',
#   'exposure_dist': '1km',
#   'age_exposure_detail': '17',
#   'age_production': '73',
#   'details': '旧庁舎へ建物疎開中に被爆。その瞬間はあまりにも突然で一瞬の出来事だったので記憶が無く、光や音・爆風などを感じなかった。庁舎の影にいたため運良く大きな怪我は無かったが、周囲は地獄のようだった。9月になってから高熱が10日間続いた。',
#   'status_then_detail': '学生',
#   'work_location': ''},
#  {'code': 'VS01065',
#   'name_kana': 'ヤマナカ|エミコ',
#   'exposure_loc': '水主町',
#   'exposure_dist': '1.4km',
#   'age_exposure_detail': '11',
#   'age_production': '82',
#   'details': '爆心地から約１.４キロ離れた 水主町で被爆。 その瞬間は、頭の上に太陽が落ちてきたのかと思うほどだった。倒れた建物の下敷きになったが、親切な男性に助けられ、懸命に逃げ帰った。様々な病気で苦しみ、差別も経験した山中さんは、こうして語ることが私の使命、全世界の指導者に広島に来てほしいと語る。',
#   'status_then_detail': '学生（小学6年生）',
#   'work_location': '倉橋町立須川国民学校'},
#  {'code': 'VS00715',
#   'name_kana': 'ヤマナカ|シゲコ',
#   'exposure_loc': '自宅, 東平塚町',
#   'exposure_dist': '1.6km',
#   'age_exposure_detail': '16',
#   'age_production': '71',
#   'details': '自宅で、家族を見送った直後被爆。閃光が走り、まるで谷底に落ちていくような気がし、気が付くと家の下敷きとなっていた。その後、中山峠へ逃げる。原爆で妹を亡くすが、遺体はみつからなかった。小学校に30年間勤務し、子供達に被爆体験を伝えてきた。',
#   'status_then_detail': '学生（女学校3年）',
#   'work_location': ''},
#  {'code': 'VS00700',
#   'name_kana': 'ヤマネ|カツジ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '14',
#   'age_production': '68',
#   'details': '造成作業をするため廿日市にいた。朝礼をしていた時、突然青白く光った。その後大きな爆発音がした。キノコ雲が上がっていくのが見えた。広島の上空は真っ暗で東西へ広がっていく炎が見えた。全員で国道を歩き街に向かう。己斐で解散し自宅に戻ったが焼けていた。父と従兄弟の家で再会。',
#   'status_then_detail': '',
#   'work_location': '広島市立造船工業学校'},
#  {'code': 'VS00908',
#   'name_kana': 'ヤマネ|ヒデコ',
#   'exposure_loc': '幟町',
#   'exposure_dist': '1.1km',
#   'age_exposure_detail': '13',
#   'age_production': '75',
#   'details': '爆風で倒壊した自宅から母親の手によって救助。その後二人して逃げまどいます。途中破裂した水道管から水を飲んだとたん、黄色い塊を嘔吐。それが「毒」だったのかもしれないと回想されます。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS00032',
#   'name_kana': 'ヤマネ|リキオ',
#   'exposure_loc': '皆実町,御幸橋付近',
#   'exposure_dist': '2.3km',
#   'age_exposure_detail': '37',
#   'age_production': '77',
#   'details': '当時37才。広島市役所の職員だった。爆心地から2．3キロの御幸橋付近で隣組の人たちを集めて配給物資の打ち合せ中に被爆した。現在、広島平和文化センターの語り部として被爆の体験を伝えている。（収録時）',
#   'status_then_detail': '公務員',
#   'work_location': '広島市役所'},
#  {'code': 'VS01033',
#   'name_kana': 'ヤマモト|サダオ',
#   'exposure_loc': '東練兵場',
#   'exposure_dist': '2.5km',
#   'age_exposure_detail': '14',
#   'age_production': '83',
#   'details': '東練兵場で芋畑の草取りをしていた。B-29が急に旋回して逃げて行くのを見た瞬間、ものすごい爆音と熱風で吹き飛ばされた。広島駅の方向に巨大な炎が猛烈な勢いで湧き上がっていた。音楽を通して平和活動に貢献し続けたいと語る。',
#   'status_then_detail': '学生',
#   'work_location': '広島県立広島第二中学校'},
#  {'code': 'VS00327',
#   'name_kana': 'ヤマモト|シゲル',
#   'exposure_loc': '横川,横川駅',
#   'exposure_dist': '1.6km',
#   'age_exposure_detail': '16',
#   'age_production': '63',
#   'details': '学徒動員にかりだされ、廿日市の木工工場に通っていた。その日は横川駅のホームで汽車を待っていた時に被爆。ホームの下にふっとばされる。山の方に逃げる途中黒い雨が降る。「重油をまかれた」という声。橋の下に隠れた。',
#   'status_then_detail': '学生',
#   'work_location': '県立廿日市工業学校'},
#  {'code': 'VS00182',
#   'name_kana': 'ヤマモト|シズコ',
#   'exposure_loc': '牛田町,神田橋',
#   'exposure_dist': '1.8km',
#   'age_exposure_detail': '19',
#   'age_production': '63',
#   'details': '当時、内務省広島土木出張所に勤務。（7月31日まで原爆ドーム内に事務所があった。）父、兄も原爆ドーム内で勤務。父はドーム内で被爆死。兄も、ドームに向かう途中に被爆し、その後、死亡。',
#   'status_then_detail': '公務員',
#   'work_location': '内務省広島土木出張所'},
#  {'code': 'VS00034',
#   'name_kana': 'ヤマモト|タダヨ',
#   'exposure_loc': '三滝町,自宅',
#   'exposure_dist': '2.5km',
#   'age_exposure_detail': '24',
#   'age_production': '65',
#   'details': '当時24才。爆心地から2．5キロの自宅の台所で被爆した。外に干していたふとんが雨に濡れて黒くなったのを覚えている。三篠国民学校5年生だった妹さんは3カ月後、校舎の焼け跡で白骨となって見つかった。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS00975',
#   'name_kana': 'ヤマモト|チエコ',
#   'exposure_loc': '幟町',
#   'exposure_dist': '1.1km',
#   'age_exposure_detail': '25',
#   'age_production': '89',
#   'details': '山本千恵子さん。被爆当時25歳。爆心地からおよそ1.1ｋｍの幟町の自宅で被爆しました。自宅で洗濯物を干していたときに閃光を目撃。当時、妊娠４ヵ月であった山本さんは取るものも取らず裸足で避難しました。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS00967',
#   'name_kana': 'ヤマモト|ノリコ',
#   'exposure_loc': '寺町',
#   'exposure_dist': '1.0km',
#   'age_exposure_detail': '4',
#   'age_production': '70',
#   'details': '母親と兄妹たちと一緒に暮らしていた母方の実家のお寺（分寺）で被爆。崩れた建物の下敷きになったが、母親に助けられる。幼い妹は、数回返事をしたものの、下敷きになったまま息絶えた。頭には傷を、顔や腕にも火傷を負った。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS00815',
#   'name_kana': 'ヤマモト|ヒロヤ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '13',
#   'age_production': '71',
#   'details': '外で体操中、市内の方が光って、鋸の歯の様な白い光が宮島へ向かって走り、大きな音がした。市内から続々と焼け爛れた人が運ばれてきた。翌日入市すると、ひどい臭いで死体が散らばっていた。寄宿舎で、同室の村田君の臨終を目の当たりにした。9日の昼、戸河内まで帰りついた。',
#   'status_then_detail': '学生',
#   'work_location': '崇徳中学校'},
#  {'code': 'VS01030',
#   'name_kana': 'ヤマモト|レイコ',
#   'exposure_loc': '祇園町長束',
#   'exposure_dist': '4.1km',
#   'age_exposure_detail': '7',
#   'age_production': '76',
#   'details': '太陽の光をきらきらと反射して飛ぶＢ－２９に見とれていると、突然強い光を感じた。先生の指示で家に帰ると、爆風のため家具が散乱していた。しばらくすると、市内からひどい火傷や怪我をした人たちが逃げてきた。',
#   'status_then_detail': '学生（国民学校1年生）',
#   'work_location': '長束国民学校 （ながつか）'},
#  {'code': 'VS00139',
#   'name_kana': 'ヤン|チェーシク',
#   'exposure_loc': '大洲町,路上',
#   'exposure_dist': '3.7km',
#   'age_exposure_detail': '15',
#   'age_production': '58',
#   'details': '当時28才。爆心地から3.7キロの大洲町路上で被爆した。若い頃からクラシックファンだった梁さんは戦後、闇市で蓄音機とレコードを見つけ、「音楽」で心の傷をいやし、暮らしをたてることにした。昭和21年には原爆詩人、峠三吉らが好んで通った音楽喫茶「ムシカ」を開店。被爆後、がれきの町と化した広島で店内に流れるクラシック音楽は多くの人々の心をとらえ、和ませたという。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS00224',
#   'name_kana': 'ユカワ|マサオ',
#   'exposure_loc': '幟町,特設警備隊駐屯地',
#   'exposure_dist': '1.3km',
#   'age_exposure_detail': '33',
#   'age_production': '77',
#   'details': '特設警備隊付衛生兵で被爆。原爆投下後、特設警備隊兵士の「衛生兵助けてくれ」という絶叫を聞く。',
#   'status_then_detail': '軍人',
#   'work_location': '世羅部隊'},
#  {'code': 'VS00469',
#   'name_kana': 'ヨコタ|マサル',
#   'exposure_loc': '南千田町,自宅',
#   'exposure_dist': '2.5km',
#   'age_exposure_detail': '19',
#   'age_production': '69',
#   'details': '当日は学校が休みだったので、部屋にいた。Ｂ29の爆音で家を飛び出し、元安川の土手に駆け上がった。突然、閃光を浴び右半身に火傷を負ったことに気づいた。身体があまりに熱いので貯水槽の水をかけると、頭から出血、貯水槽が真っ赤になった。',
#   'status_then_detail': '学生',
#   'work_location': '広島工業専門学校'},
#  {'code': 'VS00487',
#   'name_kana': 'ヨコヤマ|ケイコ',
#   'exposure_loc': '己斐本町,己斐駅',
#   'exposure_dist': '1.4km',
#   'age_exposure_detail': '14',
#   'age_production': '64',
#   'details': '己斐駅から電車に駆け乗り草津駅に向かう途中、破裂する音と同時にガラスが粉々になった。電車を下り、五日市の親戚の家に避難した。次の日、無惨な光景を目にしながら、家へ帰り、母と再会した。2、3日後、父が日赤病院にいる知らせを受けたが、父の遺体はもうそこにはなかった。',
#   'status_then_detail': '学生',
#   'work_location': '広島実践高等女学校'},
#  {'code': 'VS00916',
#   'name_kana': 'ヨコヤマ|ミエコ',
#   'exposure_loc': '宇品町',
#   'exposure_dist': '4.0km',
#   'age_exposure_detail': '15',
#   'age_production': '77',
#   'details': '陸軍糧秣支廠で被爆。ガラス片で怪我を負いますが、治療先の県立病院ではすでに大量の被爆者が訪れ、その様子はまさに地獄。やっとの思いで自宅にたどり着くも、家は焼け落ち、野宿の日々が続きました。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS00585',
#   'name_kana': 'ヨシオカ|ユキオ',
#   'exposure_loc': '鶴見町',
#   'exposure_dist': '1.5km',
#   'age_exposure_detail': '16',
#   'age_production': '68',
#   'details': '𠮷岡さんは当時、学徒動員のため大洲の製鋼所に通っていたが、8月6日、作業が休みだったので父親と一緒に鶴見町に出掛けていたときに原爆が落ちた。すぐに家に戻りそこから意識を失い10日間生死の間をさまよった。',
#   'status_then_detail': '学生',
#   'work_location': '広島県松本商業学校'},
#  {'code': 'VS00901-04',
#   'name_kana': 'ヨシダ|ゼンイチ',
#   'exposure_loc': '千田町',
#   'exposure_dist': '2.0km',
#   'age_exposure_detail': '21',
#   'age_production': '81',
#   'details': '受講中に校舎内で被爆',
#   'status_then_detail': '学生',
#   'work_location': '広島高等工業学校'},
#  {'code': 'VS01042',
#   'name_kana': 'ヨシダ|チカエ|',
#   'exposure_loc': '金屋町',
#   'exposure_dist': '1.6km',
#   'age_exposure_detail': '6',
#   'age_production': '76',
#   'details': 'あの日、国民学校１年生だった吉田さんは分散授業の教室になっていた専立寺にいました。爆風で、倒れた本堂の下敷きになりましたが、奇跡的に助け出され、家族とともに東練兵場へ逃げました。身体に残る、爆風でガラス片がつきささった跡が、今も痛みます。',
#   'status_then_detail': '学生（段原国民学校1年生）',
#   'work_location': '段原国民学校'},
#  {'code': 'VS00826',
#   'name_kana': 'ヨシノ|カツユキ',
#   'exposure_loc': '草津,市内電車内',
#   'exposure_dist': '4.1km',
#   'age_exposure_detail': '14',
#   'age_production': '72',
#   'details': '宮島線の電車に乗って、動員先の廿日市の工場へ向かう途中、草津町で被爆。電車を降りて市内方向を見ると、不気味なきのこ雲が立ち昇っていた。家族が心配になり家に向かう途中で黒い雨に遭う。街は火の海で結局自宅まではたどり着けず、9日になってようやく焼け跡を訪れた。両親の遺骨を発見し、その翌日長女と再会できた。次女と妹の遺骨は帰らぬままである。',
#   'status_then_detail': '学生',
#   'work_location': ''},
#  {'code': 'VS00284',
#   'name_kana': 'ヨシノ|トヨコ',
#   'exposure_loc': '広島駅付近,電車内',
#   'exposure_dist': '2.5km',
#   'age_exposure_detail': '21',
#   'age_production': '67',
#   'details': '陸軍被服支廠に勤務していた。8月6日の朝、電車で広島駅に向かっていた時、車内で被爆。右足に火傷を負ったが、被服支廠に行き、被爆者の救護活動にあたった。',
#   'status_then_detail': '軍人',
#   'work_location': '広島陸軍被服支廠'},
#  {'code': 'VS01084',
#   'name_kana': 'ヨシムラ ミチコ|',
#   'exposure_loc': '山口町',
#   'exposure_dist': '1.2km',
#   'age_exposure_detail': '22',
#   'age_production': '95',
#   'details': '山口町の会社に出社し、事務所の隣の蔵に帳簿を取りに入った時に被爆。蔵から出ると事務所は壊れ、落ちた電線から火が出ていた。井戸の中から助けを呼ぶ声がしたが何もできず、火が迫る中、現鉄道病院のあたりへ避難した。白島の家は焼け落ち、避難先で家族と再会。市外に借りた事務所で、同僚と仕事を再開した。',
#   'status_then_detail': '会社員',
#   'work_location': '食糧公団'},
#  {'code': 'VS00897',
#   'name_kana': 'ヨシムラ|セツコ',
#   'exposure_loc': '江波町',
#   'exposure_dist': '2.7km',
#   'age_exposure_detail': '17',
#   'age_production': '79',
#   'details': '勤務先の三菱造船所へ行く途中、江波の射撃場付近でＢ２９を発見。それから約２０分後造船所に付いた瞬間にドーンという大きな音がして机の下に潜り、助かった。勤労奉仕に出ていた父を探して歩いたが見つからず、母も大火傷を負い２３日に亡くなってしまった。両親がいなくなり差別をうけ辛い思いをした。',
#   'status_then_detail': '会社員',
#   'work_location': '三菱造船所'},
#  {'code': 'VS00898',
#   'name_kana': 'ヨネクラ|シゲジ',
#   'exposure_loc': '比治山橋東詰',
#   'exposure_dist': '1.7km',
#   'age_exposure_detail': '12',
#   'age_production': '74',
#   'details': '８月６日の朝、建物疎開のため比治山橋のたもとに集合しているところで被爆に遭った。爆風で吹き飛ばされはしたが、爆心地に背中を向けていたため背中と後頭部への火傷を負った。その後、解散になり市内の悲惨な光景を目にしながら自宅へと帰った。自宅は壊れていたので被爆後は祖母の家で過ごしたが、後遺症で髪の毛が抜けバカにされた事もあった。',
#   'status_then_detail': '学生',
#   'work_location': ''},
#  {'code': 'VS00760',
#   'name_kana': 'ヨリカネ|ヤオゾウ',
#   'exposure_loc': '松原町',
#   'exposure_dist': '1.5km',
#   'age_exposure_detail': '14',
#   'age_production': '70',
#   'details': '国鉄職員として勤務中に被爆。フラッシュのような光とともに建物が崩れる物凄い音。駅のホームの屋根が全部剥がれて、本人は駅だけが空襲を受けたと思った。負傷した人々が駅へ向かってくる風景は忘れられない。投下3時間後には突然空が暗くなり大粒の黒い雨が降った。',
#   'status_then_detail': '公務員',
#   'work_location': '広島鉄道局広島駅'},
#  {'code': 'VS00713',
#   'name_kana': 'ヨリタ|キョウ',
#   'exposure_loc': '広島県第一中学校舎内',
#   'exposure_dist': '1km',
#   'age_exposure_detail': '13',
#   'age_production': '68',
#   'details': '学校で自習中に被爆。潰れた校舎から這い出ると、辺りは真暗で太陽が日食したように見えた。同級生の9割は、原爆により一ヶ月内に命をおとした。残りの一割も、その後の放射能障害で亡くなる人があとを立たなかった。戦後、医師となり、多くの被爆者の診察をし放射能の恐ろしさを見てきた。（寄田さんのホームページ\u3000http://ww2.enjoy.ne.jp/~yorita/）',
#   'status_then_detail': '学生（県立広島第一中学1年）',
#   'work_location': '県立広島第一中学校'},
#  {'code': 'VS00275',
#   'name_kana': 'リ|シルグン',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '16',
#   'age_production': '62',
#   'details': '兵庫県から山口県へ列車で向かっていた時に、原爆が投下される。途中で列車が止まり、7日の朝歩いて広島市内に入る。その後、山口県の実家に帰り、高熱と体中にできた赤い斑点に悩まされた。',
#   'status_then_detail': '学生',
#   'work_location': '山口県立厚狭中学校'},
#  {'code': 'VS00197',
#   'name_kana': 'ルーメル, クラウス',
#   'exposure_loc': '祇園町長束,修道院内',
#   'exposure_dist': '4.5km',
#   'age_exposure_detail': '28',
#   'age_production': '72',
#   'details': 'キリスト教の修道院で被爆。現在、上智学院の理事長。ドイツ人。',
#   'status_then_detail': '学生',
#   'work_location': '長束修練院'},
#  {'code': 'VS00090',
#   'name_kana': 'ワカツキ|ノブコ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '18',
#   'age_production': '60',
#   'details': '当時18才。広島湾の金輪島にあった暁部隊に女子挺身隊として動員されていた。当時2階の炊飯場にいて頭部にかすり傷を受けた。「防空壕に避難」という大声を聞き、駆けこんだ。防空壕に避難していたが、昼すぎになると市内から大勢の被爆者が避難してきたため、島に残った兵隊や女子挺身隊員は終日救援活動に当たった。',
#   'status_then_detail': '',
#   'work_location': '暁部隊（女子挺身隊）'},
#  {'code': 'VS00917',
#   'name_kana': 'ワキ|イサオ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '17',
#   'age_production': '79',
#   'details': '最近になるまで、被爆の惨状を目にした記憶すら無くなっていたと話される脇さん。しかし高齢になった今、市街から列をなして歩いてくる被爆者、大八車を引いて友を探して奔走したことなど次々とその記憶が蘇ってきます。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS00741',
#   'name_kana': 'ワキジ|ニソウ',
#   'exposure_loc': '東練兵場',
#   'exposure_dist': '2km',
#   'age_exposure_detail': '13',
#   'age_production': '68',
#   'details': '学徒動員のため、東練兵場にて芋畑の草取り作業中、被爆。飛行機から落とされたパラシュートを見あげると、空がピカッと光り、爆風に飛ばされ気を失う。当時、原爆によって多くの人達が亡くなっていった。あれから半世紀、自分の死をいつも意識し過してきた。',
#   'status_then_detail': '学生（県立広島第二中学校2年）',
#   'work_location': '県立広島第二中学校'},
#  {'code': 'VS00868',
#   'name_kana': 'ワキナカ|エツコ',
#   'exposure_loc': '広瀬北町',
#   'exposure_dist': '1km',
#   'age_exposure_detail': '22',
#   'age_production': '82',
#   'details': '３歳の娘を行水させていた時に被爆した。倒れた家屋の下敷きになってケガをしたが娘と妹と３人で祇園の親戚に避難した。翌日、自宅に帰り義父を探した。義父は、横川の事務所で白骨になっていた。その後、自宅あとで３所帯の人たちと共同生活を３ヶ月くらい送った。',
#   'status_then_detail': '主婦',
#   'work_location': ''},
#  {'code': 'VS00588',
#   'name_kana': 'ワタサキ|ナオコ',
#   'exposure_loc': '大須賀町',
#   'exposure_dist': '1.8km',
#   'age_exposure_detail': '10',
#   'age_production': '62',
#   'details': '綿崎さんは当時、白島国民学校5年生。8月6日は玄関先で鉛筆を削っている時に被爆。家の下敷きになったが助けを求める母の声で気が付き、近所の人の力もあって何とか助け出された。',
#   'status_then_detail': '学生',
#   'work_location': '白島国民学校'},
#  {'code': 'VS01069',
#   'name_kana': 'ワタナベ|カツヒコ',
#   'exposure_loc': '比治山本町,比治山橋東詰め',
#   'exposure_dist': '1.8km',
#   'age_exposure_detail': '12',
#   'age_production': '84',
#   'details': '建物疎開に動員されていたところ、爆風で飛ばされ気絶した。気が付くと一緒に集合していた学生は誰もいなくなっていた。自宅に戻った後ひどい火傷の影響で12日間生死をさまよった。戦後、就職試験や勤務先で差別を受け、辛い思いをした。今でも火傷の跡は治らず、貧血や内臓の病気など体調不良が続く。',
#   'status_then_detail': '中学１年生',
#   'work_location': '広陵中学校'},
#  {'code': 'VS00998',
#   'name_kana': 'ワタナベ|シュンイチ',
#   'exposure_loc': '大須賀町',
#   'exposure_dist': '1.7km',
#   'age_exposure_detail': '6',
#   'age_production': '72',
#   'details': '当時６歳。灯火管制で夜は暗く、町にはほとんど出たことがない。京橋川のほとりで被爆。避難時に足のかかとに怪我。その後数ヶ月にわたり、ひどい皮膚病に。７～１５歳まで発育不良。',
#   'status_then_detail': '',
#   'work_location': ''},
#  {'code': 'VS01040',
#   'name_kana': 'ワタナベ|シンイチ',
#   'exposure_loc': '山口町',
#   'exposure_dist': '1.2km',
#   'age_exposure_detail': '17',
#   'age_production': '87',
#   'details': '渡邉さんは当時、広島鉄道局の車掌として働いていました。原爆が投下されたときは夜勤明けで宿舎におり、爆風で倒れた柱の下敷きになりました。収容された病院では、悲惨な負傷者の姿を目撃。その後、被爆の後遺症で髪の毛が抜け、差別に苦しみました。',
#   'status_then_detail': '車掌',
#   'work_location': '広島鉄道局広島車掌区'},
#  {'code': 'VS00785',
#   'name_kana': 'ワタナベ|タエコ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '12',
#   'age_production': '68',
#   'details': '山県郡壬生で学童疎開中に、光とドーンという音ときのこ雲を目撃。それから毎晩広島方面の空は真っ赤だった。終戦後すぐに母親と下の妹が迎えにきたので一緒に市内の叔母の家へ向かい入市被爆。父・兄・上の妹は市内で被爆死。横川付近の焼け野原と瓦礫の山にびっくりした。',
#   'status_then_detail': '学生（国民学校6年生）',
#   'work_location': ''},
#  {'code': 'VS00866',
#   'name_kana': 'ワタナベ|タツオ',
#   'exposure_loc': '広島駅，５番線',
#   'exposure_dist': '1.7km',
#   'age_exposure_detail': '17',
#   'age_production': '77',
#   'details': '６日の朝、乗務する貨物列車が変更になり８時２０分発の糸崎行き客車内で被爆した。東練兵場に避難し昼ごろ職場に戻ったところ自宅に帰れという指示であった。母は自宅で無事であったが次女が行方不明となり市内を数日間捜索した。結局、次女は発見できなかった。',
#   'status_then_detail': '公務員',
#   'work_location': '広島鉄道局'},
#  {'code': 'VS00137',
#   'name_kana': 'ワタナベ|ミヨコ',
#   'exposure_loc': '南千田町,自宅',
#   'exposure_dist': '2.5km',
#   'age_exposure_detail': '15',
#   'age_production': '57',
#   'details': '当時15才。爆心地から2．5キロ離れた南千田町の自宅で被爆した。渡辺さんが通っていた市立第一高等女学校の1、2年生は爆心地付近に建物疎開作業に出ていて殆どが即死した。3年生の渡辺さんは家にいて軽いけがですんだが、原爆で父と兄を失った。現在、修学旅行生相手に語り部活動をしながら被爆の実状を伝える詩を書いている。',
#   'status_then_detail': '学生',
#   'work_location': '市立第一高等女学校'},
#  {'code': 'VS01025',
#   'name_kana': 'ワダ|イサオ',
#   'exposure_loc': '入市',
#   'exposure_dist': '',
#   'age_exposure_detail': '19',
#   'age_production': '88',
#   'details': '江田島の幸の浦で特攻訓練を受けていた。８月６日、兵舎で休憩しているときにピカッと光り、轟音が響いた。昼過ぎ、救護作業の出動命令で広島市内に入り、負傷者の救護に当たった。翌日、川に浮いている死体を収容し、積み重ねて油をかけて燃やした。',
#   'status_then_detail': '軍人',
#   'work_location': '陸軍船舶練習部（江田島）'}]

# %%
df_details = pd.DataFrame(rows)
df_details.to_csv('data/survivors_bio_details.csv', index=False)

# %%
df = df_details.merge(df_basic, on='code')
df.to_csv('data/survivors_bio.csv', index=False)

# %%
df.sort_values('name')
# Out:
#     age_exposure_detail age_production        code  \
# 679                  28             72     VS00197
# 380                  22             67     VS00247
# 581                  33             73     VS00028
# 594                  14             73     VS00844
# 595                  38             84     VS00267
# 593                  19             68     VS00446
# 584                  13             63     VS00472
# 582                  21             81  VS00901-06
# 580                  21             81  VS00901-12
# 583                  28             86     VS00840
# 62                   11             75     VS00942
# 51                   24             70     VS00340
# 53                   45             92     VS00304
# 58                   17             60     VS00144
# 56                   28             69     VS00021
# 54                   29             73     VS00190
# 60                   21             70     VS00436
# 61                   16             81     VS00979
# 59                   15             65     VS00455
# 290                  29             78     VS00434
# 294                  15             66     VS00525
# 292                  41             84     VS00113
# 291                  18             83     VS00973
# 293                  24             84     VS00851
# 427                  19             70     VS00528
# 421                                        VS00473
# 429                  13             68     VS00748
# 426                  30             80     VS00491
# 422                   8             65     VS00839
# 424                  15             62     VS00319
# ..                  ...            ...         ...
# 407                  15             72     VS00812
# 142                  17             80     VS00926
# 19                   16             71     VS00733
# 18                    7             73     VS00996
# 131                  20             69     VS00432
# 129                   8             63     VS00658
# 242                  16             70     VS00674
# 343                  18             77     VS00845
# 330                  21             73     VS00641
# 339                  18             65     VS00331
# 340                  19             61     VS00052
# 341                  16             79     VS00928
# 338                  25             72     VS00336
# 342                  16             62     VS00297
# 337                  14             55     VS00020
# 335                  31             88     VS00816
# 336                  16             67     VS00509
# 332                  19             60     VS10001
# 331                  19             60     VS00001
# 334                   8             76     VS01019
# 333                  42             84  VS00100-03
# 412                  14             70     VS00765
# 413                  17             67     VS00483
# 454                  16             72     VS00756
# 226                  32             91     VS00849
# 224                  12             73     VS00899
# 223                  19             77     VS00834
# 222                  22             85     VS00904
# 225                  21             92     VS01061
# 668                  16             68     VS00585
#
#                                                details exposure_dist  \
# 679                     キリスト教の修道院で被爆。現在、上智学院の理事長。ドイツ人。         4.5km
# 380  長男が被爆死。大火傷をおった母と縮景園へ逃げる。戦後、アメリカ人の夫と再婚し、現在、アメリカ...           1km
# 581  当時33才。爆心地から1．9キロの千田町の電車の中で被爆した。消防士だった三上さんは8月6日...         1.9km
# 594  日本製鋼の工場に学徒動員として派遣されて働く毎日だったが、その日は偶然休みで家にいた。姉は被...         3.0km
# 595  広島駅で軍備輸送にあたっていた。駅の庶務室で机に向かった時、鋭い閃光と大音響を聞いた。すぐに...           2km
# 593  当時、内務省の土木出張所の職員として産業奨励館（現在の原爆ドーム）に勤務していた。6日の朝は...           2km
# 584  学徒動員で鶴見町にて建物の後片付けをしていた。誰かが「Ｂ29が飛んでいる」の声と同じに目の前...         1.5km
# 582                                         受講中に校舎内で被爆         2.0km
# 580                                         受講中に校舎内で被爆         2.0km
# 583  結婚後、陸軍に入隊して、島根から広島へ出てきた。工兵隊第五連隊に所属していた。毎日、軍服を縫...         1.5km
# 62   妹の子守りをしていた自宅で被爆。ピカっと光ったと思ったら、外を歩いていた牛が爆風で浮いた。逃...           3km
# 51   6日勤務明けの朝食を食べようとした瞬間、閃光が走る。下宿の下敷きになる。死体検案書を取りに市...           1km
# 53   主人を玄関で見送ったのち、ふと振り返るとオレンジ色の空が見えた。そのとたんに爆風で飛ばされ、...           2km
# 58   金輪島の暁部隊へ学徒動員で通っていた。警戒警報解除とともに金輪島に渡り、閃光を見る。6日の3...
# 56   当時28才。爆心地から1．5キロ、横川駅で被爆した。東洋工業に勤務。8月6日の朝は田舎に食糧...         1.5km
# 54   郡部から帰ってきたが、ただの焼野原でどうすることもできず、坊守の里方である島根県の西蔵寺に寄...
# 60   局内で被爆。局の建物は無事で、それ以外見渡す限り何も見えなかった。自分はガラス片によるケガの...         0.7km
# 61   被爆当時１６歳。爆心地からおよそ4.1ｋｍの南観音町の工場で被爆しました。広島市内の造船所で...         4.1km
# 59   当日は日赤病院の宿舎にいた。2階の渡り廊下で被爆。建物の下敷きになった方の救出作業を行った。...         1.5km
# 290  当時、妊娠8カ月であった。夫は出勤していた。8時15分、激しい爆音とともに家がゆれ、時計や窓...         3.5km
# 294  広島二中校舎の玄関の中でバリバリッと音がし真暗くなった。天井がフワッと落ちる感じがした。伏せ...         1.5km
# 292  当時41才。爆心地から1．3キロの白島町の路上で被爆した。被爆当日、自転車に乗って県庁へ出勤...         1.3km
# 291  下石テルミさん。被爆当時18歳。爆心地からおよそ1.5kmの千田町の日赤病院で被爆しました。...         1.5km
# 293  鶴見橋のたもとに、夫、義父母と暮らしていた。田舎の加計に帰っていて、６日の朝、市内に戻る予定...
# 427  自宅に爆弾が落ちたと思った一瞬真暗くなりやがて明るくなってきた。階段の下に素早く潜り助かった...         2.3km
# 421  誠さんは店で準備していて、半身火傷を負い、きよのさんは、自宅で子供に母乳を与えていて天井の下...         1.4km
# 429  動員学徒として雑魚場町の建物疎開作業中、被爆。細かい火の粉が雨のように降ってきた。とっさに耳...           1km
# 426  8時頃、トラックが廿日市あたりで故障した。パラシュートが落ち、閃光と同時に右頬に強烈な熱さを...         3.5km
# 422  自宅の近くにあった小学校の分校に向かう途中で、友達と一緒に被爆。友達や上級生は大火傷を負って...         1.4km
# 424  広島商業4年生で船越の日本製鋼所に学徒動員で行っており、8月6日は夜勤明けで自宅に6時に帰り...           4km
# ..                                                 ...           ...
# 407  郵便局に出社して、飛行機の音がするので外に出た。Ｂ29から何かが落ちてくるのを見て、建物に戻...         1.3km
# 142  貨物列車に車掌として乗務、原爆が落ちた時は竹原あたりにいた。救援のために夕方に広島市内へ。建...
# 19   学徒動員が休みで、自宅で物理の勉強をしていた。トイレに行ったとき目を刺すような光と共にトイレ...         1.7km
# 18   ８月６日の朝、分散授業でお寺に１５人程度の友人と先生を待っていた。目の前に青白い光りが見え、...         2.5km
# 131  矢賀の自宅から町内の50人余りの人と勤労奉仕に出掛けていた。朝礼を受けているとき、飛行機が飛...         1.5km
# 129  窓から不思議な青白い光が入ってきたと同時に家が崩れ下敷きになっていた。外に這い出してみると真...         1.2km
# 242  出勤中に北へ向かうB29をみた。その後、全身を熱い光線に突かれたような感じがした。自宅に向か...           2km
# 343  当時は国鉄の車掌をしており、勤務で下関にいた。６日朝、広島に戻る汽車の中で広島に爆弾が落ちた...
# 330  軍隊で島根県大田におり免れる。15日に市内へ入る。目に写るものは瓦ばっかりで、広島駅から宇品...
# 339  当時、高橋さんは千田町の貯金局で働いていた。閃光を浴び一瞬目が見えなくなり、気が付くと周りは...         1.5km
# 340  当時19才。高橋さんは爆心地から500メートル以内で被爆した数少ない生存者の一人である。当時...         0.3km
# 341  原爆投下時は、東広島市八本松の自宅にいた。突然すごい音がして一瞬顔が熱くなるのを感じた。１７...
# 338  当時、牛田にある養成所で動員学徒の研修を行っていた。空襲警報が解除になり、生徒と共に養成所に...         2.5km
# 342  材木町に自宅があったが、その日は祖母の見舞のため岡山県笠岡市に居た。翌日、姉を探しに自宅に帰...
# 337  当時14才。爆心地から1．4キロの中学校で朝礼で整列した時、被爆した。その日から1年半に及ぶ...         1.4km
# 335  5日の晩から、当番で消防署に泊まっていた。事務所で仕事をしていると、外が突然明るくなった。大...         4.1km
# 336  安古市駅から安国民学校に着いて汗を拭いた直後の事近所の軍需工場へ爆弾が落ちたと思った。青空な...
# 332  当時19才。爆心地から0．3キロの芸備銀行の内部で被爆した。背中に150カ所の裂傷を負いなが...         0.3km
# 331  当時19才。爆心地から0．3キロの芸備銀行の内部で被爆した。背中に150カ所の裂傷を負いなが...         0.3km
# 334  町内の大きな防火用水のそばで友達と遊んでいました。防火用水の縁にしゃがんだと同時に青白い光が...         2.5km
# 333                      当時、広島市の近郊で農業を営んでいた主婦たちの証言である。          14km
# 412  自宅から外出した直後に被爆。さえぎる物が無かったため、炸裂した光が全身を覆った。まるで煮え湯...           2km
# 413  当日は、赤十字病院の学生寮にいた。木造の寮の下敷きになるが、運良く救助された。院内で被爆者の...         1.5km
# 454  体調不良で療養中、病院に向かうところで被爆。黄色の光が絹針のように全身を覆った後、身体が宙に...           1km
# 226  水主町で被爆。道路わきの溝に体がはまり上へ瓦礫が落ちてきた。何とか外へ出るがしばらく目が見え...         0.9km
# 224  ８月６日、疎開先の吉田町で広島の原爆を知り、残っている家族の庫とが心配で眠れなかった。８月１...
# 223  いつもなら出勤していた時間だったが、その日はまだ自宅にいた。友達が迎えに来てくれていて、出勤...         0.6km
# 222  爆風で倒壊した事務所の屋根に足を挟まれながらも命からがら脱出。しかし足の負傷のため動けず、4...         1.3km
# 225  爆心地からおよそ１キロ離れた 西白島町の広島陸軍幼年学校で被爆。校舎の下敷きになり、体中にガ...           1km
# 668  𠮷岡さんは当時、学徒動員のため大洲の製鋼所に通っていたが、8月6日、作業が休みだったので父親...         1.5km
#
#        exposure_loc       name_kana status_then_detail   work_location  \
# 679      祇園町長束,修道院内      ルーメル, クラウス                 学生           長束修練院
# 380         上流川町,自宅  チエコ|フレイブル|マツウラ
# 581       千田町,広電本社前         ミカミ|ヨサク           公務員（消防士）       西消防署宇品出張所
# 594          仁保町、自宅          ミホ|トシオ                 学生            市立商業
# 595       松原町,広島駅構内          ミホ|ヨシト                公務員           広島鉄道局
# 593         松原町,広島駅         ミハラ|キミエ                公務員    内務省中国四国土木出張所
# 584          鶴見町,町内         ミシマ|ミチエ                 学生        広島女子商業学校
# 582             千田町          ミキ|タクヤ                 学生        広島高等工業学校
# 580             千田町       ミウラ|トミタロウ                 学生        広島高等工業学校
# 583             牛田町       ミザワ|ジュウイチ                 軍人       陸軍工兵隊第五連隊
# 62             三篠本町        ウエヤマ|カズコ        学生（国民学校6年生）          大芝国民学校
# 51           薬研堀,下宿        ウエオカ|マサシ                公務員          下流川派出所
# 53         舟入川口町,自宅        ウエスギ|アヤコ                 主婦
# 58               入市        ウエダ|マサノリ
# 56       横川町,横川駅前路上         ウエダ|シズト                会社員            東洋工業
# 54               入市        ウエゾノ|シスイ                 僧侶             浄圓寺
# 60        基町,広島逓信局内         ウエノ|ハルエ                公務員           広島逓信局
# 61             南観音町         ウエノ|モトム                     三菱重工業の工場（南観音町）
# 59      千田町,広島赤十字病院         ウエノ|テルコ          看護婦（看護学生）   広島赤十字病院付属看護学校
# 290          宇品町,自宅         シモイ|ツユコ                 主婦
# 294  西観音町,広島第二中学校玄関        シモハラ|タカシ                 学生       県立広島第二中学校
# 292          白島町,路上         シモエ|ブスケ                公務員            広島県庁
# 291          千田町1丁目        シモイシ|テルミ                         広島赤十字病院内薬局
# 293              入市        シモタケ|チヨコ                軍関係           陸軍兵器廠
# 427          牛田町,自宅        ナカシタ|マリコ                 軍人         陸軍船舶司令部
# 421           段原大畑町  ナカイ|マコト,中井|きよの
# 429    建物疎開現場, 雑魚場町        ナカゾノ|ヨシコ      学生（国民学校高等科1年）     市立第三国民学校高等科
# 426           古江,町内       ナカシオ|マサヨシ                 軍人       中部第八八七六部隊
# 422             中広町        ナカオ|カズヒロ                 学生            国民学校
# 424           仁保,自宅         ナカオ|マツオ                 学生            広島商業
# ..              ...             ...                ...             ...
# 407        舟入本町,郵便局         トユキ|カズコ                公務員         舟入本町郵便局
# 142              入市      カゼトウ|ショウソウ                公務員           広島鉄道局
# 19         自宅, 西観音町        イイムラ|タカシ                 学生       県立広島第二中学校
# 18              皆実町         イイダ|サトル        学生（国民学校1年生）          皆実国民学校
# 131        鶴見町,勤労奉仕         カガワ|フミコ                 主婦
# 129             田中町        カガワ|クニアキ                 学生          竹屋国民学校
# 242           吉島羽衣町         コマダ|タモツ                 学生    県立広島第一中学校夜間部
# 343              入市       タカヤス|マサアキ                公務員           広島鉄道局
# 330       入市,島根県太田市         タカキ|セイジ                 軍人
# 339         千田町,貯金局        タカハシ|タケコ                公務員          広島貯金支局
# 340          袋町,会社内        タカハシ|タダシ
# 341              入市        タカハシ|チヅコ                 学生         賀茂高等女学校
# 338        牛田,牛田養成所        タカハシ|キミエ                公務員           広島鉄道局
# 342              入市        タカハシ|マサコ                 学生        広島女子商業学校
# 337        中広町,市中校庭       タカハシ|アキヒロ                 学生         広島市立中学校
# 335        江波町,消防署内         タカタ|シゲル           公務員（消防士）       西消防署江波出張所
# 336              入市         タカタ|シズコ                教職員           安国民学校
# 332      紙屋町,芸備銀行屋内        タカクラ|アキコ                会社員            芸備銀行
# 331      紙屋町,芸備銀行屋内        タカクラ|アキコ                会社員            芸備銀行
# 334             出汐町        タカシナ|ケンジ        学生（国民学校1年生）
# 333       川内村,自宅前の畑     タカサキ|ハル||||                 主婦
# 412             山手町        トリコシ|フジオ                 学生
# 413     千田町,広島赤十字病院         トリノ|カズコ                看護婦         広島赤十字病院
# 454          （旧）田中町        ナルトコ|テルコ                 学生
# 226             水主町        クロクチ|リソウ                自営業
# 224              入市        クロカワ|トモエ                 学生          広島ろう学校
# 223          河原町,自宅        クロカワ|トミコ                会社員        住友銀行広島支店
# 222             山口町        クロカワ|シズエ
# 225   西白島町,広島陸軍幼年学校        クロガ|ヨシノリ                 軍人
# 668             鶴見町        ヨシオカ|ユキオ                 学生       広島県松本商業学校
#
#     age_exposure   id         name production_date    sex  \
# 679           28  680    クラウス・ルーメル      1989/08/01     男性
# 380           22  381   チエコ・Ｆ・マツウラ      1990/08/01     女性
# 581           33  582        三上|與作      1986/08/01     男性
# 594           14  595        三保|俊雄      2005/03/31     男性
# 595           38  596        三保|芳登      1991/08/01     男性
# 593           19  594        三原|君江      1994/08/01     女性
# 584           13  585       三島|美智恵      1995/08/01     女性
# 582           21  583        三木|琢弥      2005/09/08     男性
# 580           21  581       三浦|富太郎      2005/09/08     男性
# 583           28  584        三澤|重市      2004/03/31     男性
# 62            11   63        上山|和子      2009/03/31     女性
# 51            24   52         上岡|雅      1992/08/01     男性
# 53            45   54        上杉|綾子      1992/08/01     女性
# 58            17   59        上田|正紀      1988/08/01     男性
# 56            28   57        上田|静人      1986/08/01     男性
# 54            29   55        上薗|志水      1989/08/01     男性
# 60            21   61       上野|ハルエ      1994/08/01     女性
# 61            16   62         上野|求      2011/03/31     男性
# 59            15   60        上野|照子      1995/08/01     女性
# 290           29  291        下井|露子      1994/08/01     女性
# 294           15  295        下原|隆資      1996/09/30     男性
# 292           41  293        下江|武介      1988/08/01     男性
# 291           18  292       下石|テルミ      2011/03/31     女性
# 293           24  294       下竹|千代子      2005/03/31     女性
# 427           19  428        中下|毬子      1996/09/30     女性
# 421               422  中井|誠,中井|きよの      1995/08/01  男性,女性
# 429           13  430        中園|芳子      2001/03/31     女性
# 426           30  427        中塩|正義      1995/08/01     男性
# 422            8  423        中尾|一弘      2004/03/31     男性
# 424           15  425        中尾|松夫      1992/08/01     男性
# ..           ...  ...          ...             ...    ...
# 407           15  408        頓行|和子      2003/03/31     女性
# 142           17  143        風藤|昭三      2009/03/31     男性
# 19            16   20         飯村|卓      2001/03/31     男性
# 18             7   19         飯田|暁      2012/03/31     男性
# 131           20  132       香川|フミコ      1994/08/01     女性
# 129            8  130        香川|邦昭      2000/03/31     男性
# 242           16  243         駒田|保      2000/03/31     男性
# 343           18  344        高安|正明      2005/03/31     男性
# 330           21  331        高木|成司      1999/03/31     男性
# 339           18  340       高橋|タケ子      1992/08/01     女性
# 340           19  341         高橋|匡      1987/08/01     男性
# 341           16  342       高橋|千鶴子      2009/03/31     女性
# 338           25  339        高橋|君江      1992/08/01     女性
# 342           16  343        高橋|昌子      1991/08/01     女性
# 337           14  338        高橋|昭博      1986/08/01     男性
# 335           31  336         高田|茂      2003/03/31     男性
# 336           16  337        高田|静子      1996/09/30     女性
# 332           19  333        高蔵|信子      1986/08/01     女性
# 331           19  332        高蔵|信子      1986/08/01     女性
# 334            8  335        髙品|健二      2014/02/28     男性
# 333           42  334        髙崎|ハル      1987/08/01     女性
# 412           14  413       鳥越|不二夫      2002/03/29     男性
# 413           17  414        鳥野|和子      1995/08/01     女性
# 454           16  455        鳴床|輝子      2002/03/29     女性
# 226           32  227        黒口|利三      2005/03/31     男性
# 224           12  225       黒川|トモエ      2007/03/31     女性
# 223           19  224        黒川|富子      2004/03/31     女性
# 222           22  223        黒川|静枝      2008/03/31     女性
# 225           21  226        黒賀|良則      2017/02/28     男性
# 668           16  669        𠮷岡|幸雄      1998/02/28     男性
#
#                     slug    status_then
# 679  /pdbj/detail/207055             学生
# 380  /pdbj/detail/207095
# 581  /pdbj/detail/206934       公務員（消防士）
# 594  /pdbj/detail/208266             学生
# 595  /pdbj/detail/207110            公務員
# 593  /pdbj/detail/207213            公務員
# 584  /pdbj/detail/207227             学生
# 582  /pdbj/detail/208096             学生
# 580  /pdbj/detail/208099             学生
# 583  /pdbj/detail/207444             軍人
# 62   /pdbj/detail/208163    学生（国民学校6年生）
# 51   /pdbj/detail/207630            公務員
# 53   /pdbj/detail/207631             主婦
# 58   /pdbj/detail/207633
# 56   /pdbj/detail/206930            会社員
# 54   /pdbj/detail/207048             僧侶
# 60   /pdbj/detail/207634            公務員
# 61   /pdbj/detail/208313
# 59   /pdbj/detail/207635      看護婦（看護学生）
# 290  /pdbj/detail/207863             主婦
# 294  /pdbj/detail/207257             学生
# 292  /pdbj/detail/207862            公務員
# 291  /pdbj/detail/208307
# 293  /pdbj/detail/208065            軍関係
# 427  /pdbj/detail/207720             軍人
# 421  /pdbj/detail/207718
# 429  /pdbj/detail/207717  学生（国民学校高等科1年）
# 426  /pdbj/detail/207719             軍人
# 422  /pdbj/detail/207443             学生
# 424  /pdbj/detail/207731             学生
# ..                   ...            ...
# 407  /pdbj/detail/207767            公務員
# 142  /pdbj/detail/208113            公務員
# 19   /pdbj/detail/207391             学生
# 18   /pdbj/detail/208330    学生（国民学校1年生）
# 131  /pdbj/detail/207206             主婦
# 129  /pdbj/detail/207346             学生
# 242  /pdbj/detail/207355             学生
# 343  /pdbj/detail/208260            公務員
# 330  /pdbj/detail/207336             軍人
# 339  /pdbj/detail/207147            公務員
# 340  /pdbj/detail/206954
# 341  /pdbj/detail/208114             学生
# 338  /pdbj/detail/207149            公務員
# 342  /pdbj/detail/207127             学生
# 337  /pdbj/detail/206929             学生
# 335  /pdbj/detail/207431       公務員（消防士）
# 336  /pdbj/detail/207249            教職員
# 332  /pdbj/detail/274231            会社員
# 331  /pdbj/detail/206918            会社員
# 334  /pdbj/detail/208354    学生（国民学校1年生）
# 333  /pdbj/detail/206988             主婦
# 412  /pdbj/detail/207739             学生
# 413  /pdbj/detail/207235            看護婦
# 454  /pdbj/detail/207814             学生
# 226  /pdbj/detail/208063            自営業
# 224  /pdbj/detail/208092             学生
# 223  /pdbj/detail/207880            会社員
# 222  /pdbj/detail/208262
# 225  /pdbj/detail/254999             軍人
# 668  /pdbj/detail/207297             学生
#
# [692 rows x 16 columns]

# %% [markdown]
# ---------------------------------------------------------------------------------------

# %% [markdown]
# # Scrape survivor bios from Global Network
#
# https://www.global-peace.go.jp/picture/pic_kekka.php?PageNo=1&dt=190805140418

# %% [markdown]
# ## Scrape just the basic info for one page
#
# There are 32 pages total, 20 results each, 638 bios

# %%
page= 1 
url = f'https://www.global-peace.go.jp/picture/pic_kekka.php?PageNo={page}&dt=190805140418'
response = requests.get(url)
doc = BeautifulSoup(response.content, from_encoding='utf-8')

main_url = 'https://www.global-peace.go.jp/picture/'

# OR:
# url = f'https://www.global-peace.go.jp/picture/pic_kekka.php?PageNo=1&dt=190805140418'
# response = requests.get(url)
# response.encoding = 'utf-8'
# doc = BeautifulSoup(response.text)

# %%
# Get info for one survivor

survivors = doc.find('table', width="800").find_all('tr')[1:]
survivor = survivors[0]

number = int(survivor.find_all('td')[0].text)
name = survivor.find_all('td')[1].text.replace('\u3000','|').strip()
slug = survivor.find_all('td')[1].a['href']
sex = survivor.find_all('td')[2].text.strip()
age_exposure = survivor.find_all('td')[3].text.replace('歳','').strip()
exposure_pref = survivor.find_all('td')[4].text.strip()
exposure_dist = survivor.find_all('td')[5].text.strip()

# %%
# Get info for all survivors on page 1

rows = []
for survivor in survivors:
    row = {}
    row['name'] = survivor.find_all('td')[1].text.replace('\u3000','|').strip()
    row['id'] = int(survivor.find_all('td')[0].text)
    row['slug'] = survivor.find_all('td')[1].a['href']
    row['sex'] = survivor.find_all('td')[2].text.strip()
    row['age_exposure'] = survivor.find_all('td')[3].text.replace('歳','').strip()
    row['exposure_pref'] = survivor.find_all('td')[4].text.strip()
    row['exposure_dist'] = survivor.find_all('td')[5].text.strip()
    rows.append(row)
rows
# Out:
# [{'name': 'アイリーン|トモエ|平野',
#   'id': 1,
#   'slug': 'pic_syousai.php?gbID=1280&dt=190805144842',
#   'sex': '女性',
#   'age_exposure': '6',
#   'exposure_pref': '広島',
#   'exposure_dist': '6.0km'},
#  {'name': '青木|茂',
#   'id': 2,
#   'slug': 'pic_syousai.php?gbID=140&dt=190805144842',
#   'sex': '男性',
#   'age_exposure': '20',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.2km'},
#  {'name': '青木|美枝',
#   'id': 3,
#   'slug': 'pic_syousai.php?gbID=141&dt=190805144842',
#   'sex': '女性',
#   'age_exposure': '23',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.8km'},
#  {'name': '赤名|正市',
#   'id': 4,
#   'slug': 'pic_syousai.php?gbID=1130&dt=190805144842',
#   'sex': '男性',
#   'age_exposure': '21',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '秋月|辰一郎',
#   'id': 5,
#   'slug': 'pic_syousai.php?gbID=87&dt=190805144842',
#   'sex': '男性',
#   'age_exposure': '29',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.8km'},
#  {'name': '秋本|三郎',
#   'id': 6,
#   'slug': 'pic_syousai.php?gbID=847&dt=190805144842',
#   'sex': '男性',
#   'age_exposure': '14',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.2km'},
#  {'name': '安里|盛繁',
#   'id': 7,
#   'slug': 'pic_syousai.php?gbID=9&dt=190805144842',
#   'sex': '男性',
#   'age_exposure': '16',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.5km'},
#  {'name': '朝比奈|隆',
#   'id': 8,
#   'slug': 'pic_syousai.php?gbID=1206&dt=190805144842',
#   'sex': '男性',
#   'age_exposure': '13',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '阿部|磨智惠',
#   'id': 9,
#   'slug': 'pic_syousai.php?gbID=1067&dt=190805144842',
#   'sex': '女性',
#   'age_exposure': '19',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '天野|文子',
#   'id': 10,
#   'slug': 'pic_syousai.php?gbID=142&dt=190805144842',
#   'sex': '女性',
#   'age_exposure': '14',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '網谷|エイ',
#   'id': 11,
#   'slug': 'pic_syousai.php?gbID=146&dt=190805144842',
#   'sex': '女性',
#   'age_exposure': '14',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.2km'},
#  {'name': '荒井|彊',
#   'id': 12,
#   'slug': 'pic_syousai.php?gbID=150&dt=190805144842',
#   'sex': '男性',
#   'age_exposure': '19',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.2km'},
#  {'name': '新井|政子',
#   'id': 13,
#   'slug': 'pic_syousai.php?gbID=151&dt=190805144842',
#   'sex': '女性',
#   'age_exposure': '23',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.8km'},
#  {'name': '荒川|秀男',
#   'id': 14,
#   'slug': 'pic_syousai.php?gbID=91&dt=190805144842',
#   'sex': '男性',
#   'age_exposure': '40',
#   'exposure_pref': '長崎',
#   'exposure_dist': '0.5km'},
#  {'name': '新垣|和子',
#   'id': 15,
#   'slug': 'pic_syousai.php?gbID=885&dt=190805144842',
#   'sex': '女性',
#   'age_exposure': '16',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.5km'},
#  {'name': '荒木|禮子',
#   'id': 16,
#   'slug': 'pic_syousai.php?gbID=155&dt=190805144842',
#   'sex': '女性',
#   'age_exposure': '14',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.7km'},
#  {'name': '荒田|千代子',
#   'id': 17,
#   'slug': 'pic_syousai.php?gbID=156&dt=190805144842',
#   'sex': '女性',
#   'age_exposure': '17',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.8km'},
#  {'name': '有田|卓司',
#   'id': 18,
#   'slug': 'pic_syousai.php?gbID=1056&dt=190805144842',
#   'sex': '男性',
#   'age_exposure': '10',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.5km'},
#  {'name': '安|月嬋',
#   'id': 19,
#   'slug': 'pic_syousai.php?gbID=157&dt=190805144842',
#   'sex': '女性',
#   'age_exposure': '15',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.6km'},
#  {'name': '李|一守',
#   'id': 20,
#   'slug': 'pic_syousai.php?gbID=756&dt=190805144842',
#   'sex': '女性',
#   'age_exposure': '15',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.5km'}]

# %% [markdown]
# ## Scrape all pages for basic info (Global Peace table)

# %%
pages = list(range(1,33))
rows = []

for page in pages:
    url = f'https://www.global-peace.go.jp/picture/pic_kekka.php?PageNo={page}&dt=190805140418'
    response = requests.get(url)
    doc = BeautifulSoup(response.content, from_encoding='utf-8')
    survivors = doc.find('table', width="800").find_all('tr')[1:]

    for survivor in survivors:
        row = {}
        row['name'] = survivor.find_all('td')[1].text.replace('\u3000','|').strip()
        row['id'] = int(survivor.find_all('td')[0].text)
        row['slug'] = survivor.find_all('td')[1].a['href']
        row['sex'] = survivor.find_all('td')[2].text.strip()
        row['age_exposure'] = survivor.find_all('td')[3].text.replace('歳','').strip()
        row['exposure_pref'] = survivor.find_all('td')[4].text.strip()
        row['exposure_dist'] = survivor.find_all('td')[5].text.strip()
        rows.append(row)
rows
# Out:
# [{'name': 'アイリーン|トモエ|平野',
#   'id': 1,
#   'slug': 'pic_syousai.php?gbID=1280&dt=190805151358',
#   'sex': '女性',
#   'age_exposure': '6',
#   'exposure_pref': '広島',
#   'exposure_dist': '6.0km'},
#  {'name': '青木|茂',
#   'id': 2,
#   'slug': 'pic_syousai.php?gbID=140&dt=190805151358',
#   'sex': '男性',
#   'age_exposure': '20',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.2km'},
#  {'name': '青木|美枝',
#   'id': 3,
#   'slug': 'pic_syousai.php?gbID=141&dt=190805151358',
#   'sex': '女性',
#   'age_exposure': '23',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.8km'},
#  {'name': '赤名|正市',
#   'id': 4,
#   'slug': 'pic_syousai.php?gbID=1130&dt=190805151358',
#   'sex': '男性',
#   'age_exposure': '21',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '秋月|辰一郎',
#   'id': 5,
#   'slug': 'pic_syousai.php?gbID=87&dt=190805151358',
#   'sex': '男性',
#   'age_exposure': '29',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.8km'},
#  {'name': '秋本|三郎',
#   'id': 6,
#   'slug': 'pic_syousai.php?gbID=847&dt=190805151358',
#   'sex': '男性',
#   'age_exposure': '14',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.2km'},
#  {'name': '安里|盛繁',
#   'id': 7,
#   'slug': 'pic_syousai.php?gbID=9&dt=190805151358',
#   'sex': '男性',
#   'age_exposure': '16',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.5km'},
#  {'name': '朝比奈|隆',
#   'id': 8,
#   'slug': 'pic_syousai.php?gbID=1206&dt=190805151358',
#   'sex': '男性',
#   'age_exposure': '13',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '阿部|磨智惠',
#   'id': 9,
#   'slug': 'pic_syousai.php?gbID=1067&dt=190805151358',
#   'sex': '女性',
#   'age_exposure': '19',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '天野|文子',
#   'id': 10,
#   'slug': 'pic_syousai.php?gbID=142&dt=190805151358',
#   'sex': '女性',
#   'age_exposure': '14',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '網谷|エイ',
#   'id': 11,
#   'slug': 'pic_syousai.php?gbID=146&dt=190805151358',
#   'sex': '女性',
#   'age_exposure': '14',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.2km'},
#  {'name': '荒井|彊',
#   'id': 12,
#   'slug': 'pic_syousai.php?gbID=150&dt=190805151358',
#   'sex': '男性',
#   'age_exposure': '19',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.2km'},
#  {'name': '新井|政子',
#   'id': 13,
#   'slug': 'pic_syousai.php?gbID=151&dt=190805151358',
#   'sex': '女性',
#   'age_exposure': '23',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.8km'},
#  {'name': '荒川|秀男',
#   'id': 14,
#   'slug': 'pic_syousai.php?gbID=91&dt=190805151358',
#   'sex': '男性',
#   'age_exposure': '40',
#   'exposure_pref': '長崎',
#   'exposure_dist': '0.5km'},
#  {'name': '新垣|和子',
#   'id': 15,
#   'slug': 'pic_syousai.php?gbID=885&dt=190805151358',
#   'sex': '女性',
#   'age_exposure': '16',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.5km'},
#  {'name': '荒木|禮子',
#   'id': 16,
#   'slug': 'pic_syousai.php?gbID=155&dt=190805151358',
#   'sex': '女性',
#   'age_exposure': '14',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.7km'},
#  {'name': '荒田|千代子',
#   'id': 17,
#   'slug': 'pic_syousai.php?gbID=156&dt=190805151358',
#   'sex': '女性',
#   'age_exposure': '17',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.8km'},
#  {'name': '有田|卓司',
#   'id': 18,
#   'slug': 'pic_syousai.php?gbID=1056&dt=190805151358',
#   'sex': '男性',
#   'age_exposure': '10',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.5km'},
#  {'name': '安|月嬋',
#   'id': 19,
#   'slug': 'pic_syousai.php?gbID=157&dt=190805151358',
#   'sex': '女性',
#   'age_exposure': '15',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.6km'},
#  {'name': '李|一守',
#   'id': 20,
#   'slug': 'pic_syousai.php?gbID=756&dt=190805151358',
#   'sex': '女性',
#   'age_exposure': '15',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.5km'},
#  {'name': '李|圭永',
#   'id': 21,
#   'slug': 'pic_syousai.php?gbID=1213&dt=190805151359',
#   'sex': '男性',
#   'age_exposure': '4',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.7km'},
#  {'name': '李|相必',
#   'id': 22,
#   'slug': 'pic_syousai.php?gbID=919&dt=190805151359',
#   'sex': '女性',
#   'age_exposure': '7',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.8km'},
#  {'name': '李|相烈',
#   'id': 23,
#   'slug': 'pic_syousai.php?gbID=1070&dt=190805151359',
#   'sex': '男性',
#   'age_exposure': '10',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.8km'},
#  {'name': '飯島|信一',
#   'id': 24,
#   'slug': 'pic_syousai.php?gbID=158&dt=190805151359',
#   'sex': '男性',
#   'age_exposure': '23',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '飯田|マリ子',
#   'id': 25,
#   'slug': 'pic_syousai.php?gbID=159&dt=190805151359',
#   'sex': '女性',
#   'age_exposure': '13',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.3km'},
#  {'name': '伊江|和夫',
#   'id': 26,
#   'slug': 'pic_syousai.php?gbID=10&dt=190805151359',
#   'sex': '男性',
#   'age_exposure': '17',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.5km'},
#  {'name': '生島|渉',
#   'id': 27,
#   'slug': 'pic_syousai.php?gbID=160&dt=190805151359',
#   'sex': '男性',
#   'age_exposure': '13',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '生田|カツ子',
#   'id': 28,
#   'slug': 'pic_syousai.php?gbID=161&dt=190805151359',
#   'sex': '女性',
#   'age_exposure': '16',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.0km'},
#  {'name': '池田|武臣',
#   'id': 29,
#   'slug': 'pic_syousai.php?gbID=1201&dt=190805151359',
#   'sex': '男性',
#   'age_exposure': '19',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.8km'},
#  {'name': '池田|雅道',
#   'id': 30,
#   'slug': 'pic_syousai.php?gbID=900&dt=190805151359',
#   'sex': '男性',
#   'age_exposure': '8',
#   'exposure_pref': '長崎',
#   'exposure_dist': '4.0km'},
#  {'name': '池田|松義',
#   'id': 31,
#   'slug': 'pic_syousai.php?gbID=817&dt=190805151359',
#   'sex': '男性',
#   'age_exposure': '7',
#   'exposure_pref': '長崎',
#   'exposure_dist': '0.7km'},
#  {'name': '池田|道明',
#   'id': 32,
#   'slug': 'pic_syousai.php?gbID=765&dt=190805151359',
#   'sex': '男性',
#   'age_exposure': '6',
#   'exposure_pref': '長崎',
#   'exposure_dist': '0.7km'},
#  {'name': '池田|實',
#   'id': 33,
#   'slug': 'pic_syousai.php?gbID=11&dt=190805151359',
#   'sex': '男性',
#   'age_exposure': '18',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '石井|忠顕',
#   'id': 34,
#   'slug': 'pic_syousai.php?gbID=165&dt=190805151359',
#   'sex': '男性',
#   'age_exposure': '18',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '石川|元二',
#   'id': 35,
#   'slug': 'pic_syousai.php?gbID=883&dt=190805151359',
#   'sex': '男性',
#   'age_exposure': '21',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '石川|渉',
#   'id': 36,
#   'slug': 'pic_syousai.php?gbID=166&dt=190805151359',
#   'sex': '男性',
#   'age_exposure': '22',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.0km'},
#  {'name': '泉|勇',
#   'id': 37,
#   'slug': 'pic_syousai.php?gbID=908&dt=190805151359',
#   'sex': '男性',
#   'age_exposure': '12',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.0km'},
#  {'name': '伊谷|周一',
#   'id': 38,
#   'slug': 'pic_syousai.php?gbID=170&dt=190805151359',
#   'sex': '男性',
#   'age_exposure': '16',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.0km'},
#  {'name': '市川|倭文枝',
#   'id': 39,
#   'slug': 'pic_syousai.php?gbID=1143&dt=190805151359',
#   'sex': '女性',
#   'age_exposure': '14',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.0km'},
#  {'name': '市原|憲二郎',
#   'id': 40,
#   'slug': 'pic_syousai.php?gbID=171&dt=190805151359',
#   'sex': '男性',
#   'age_exposure': '9',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.8km'},
#  {'name': '市原|大資',
#   'id': 41,
#   'slug': 'pic_syousai.php?gbID=172&dt=190805151400',
#   'sex': '男性',
#   'age_exposure': '21',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.0km'},
#  {'name': '市場|元喜',
#   'id': 42,
#   'slug': 'pic_syousai.php?gbID=772&dt=190805151400',
#   'sex': '男性',
#   'age_exposure': '14',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.8km'},
#  {'name': '伊藤|晶',
#   'id': 43,
#   'slug': 'pic_syousai.php?gbID=173&dt=190805151400',
#   'sex': '男性',
#   'age_exposure': '18',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.0km'},
#  {'name': '伊藤|武治',
#   'id': 44,
#   'slug': 'pic_syousai.php?gbID=891&dt=190805151400',
#   'sex': '男性',
#   'age_exposure': '4',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.8km'},
#  {'name': '伊藤|宣夫',
#   'id': 45,
#   'slug': 'pic_syousai.php?gbID=174&dt=190805151400',
#   'sex': '男性',
#   'age_exposure': '17',
#   'exposure_pref': '広島',
#   'exposure_dist': '4.2km'},
#  {'name': '伊藤|雅浩',
#   'id': 46,
#   'slug': 'pic_syousai.php?gbID=175&dt=190805151400',
#   'sex': '男性',
#   'age_exposure': '10',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '伊藤|美代子',
#   'id': 47,
#   'slug': 'pic_syousai.php?gbID=1125&dt=190805151400',
#   'sex': '女性',
#   'age_exposure': '16',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '糸澤|定雄',
#   'id': 48,
#   'slug': 'pic_syousai.php?gbID=1199&dt=190805151400',
#   'sex': '男性',
#   'age_exposure': '18',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '井上 惣左衛門',
#   'id': 49,
#   'slug': 'pic_syousai.php?gbID=1292&dt=190805151400',
#   'sex': '男性',
#   'age_exposure': '20',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '井上|力',
#   'id': 50,
#   'slug': 'pic_syousai.php?gbID=780&dt=190805151400',
#   'sex': '男性',
#   'age_exposure': '17',
#   'exposure_pref': '長崎',
#   'exposure_dist': '4.0km'},
#  {'name': '井上|稔',
#   'id': 51,
#   'slug': 'pic_syousai.php?gbID=176&dt=190805151400',
#   'sex': '男性',
#   'age_exposure': '17',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.5km'},
#  {'name': '井原|東洋一',
#   'id': 52,
#   'slug': 'pic_syousai.php?gbID=826&dt=190805151400',
#   'sex': '男性',
#   'age_exposure': '9',
#   'exposure_pref': '長崎',
#   'exposure_dist': '6.5km'},
#  {'name': '今泉|一枝',
#   'id': 53,
#   'slug': 'pic_syousai.php?gbID=177&dt=190805151400',
#   'sex': '女性',
#   'age_exposure': '20',
#   'exposure_pref': '広島',
#   'exposure_dist': '0.8km'},
#  {'name': '今道|忍',
#   'id': 54,
#   'slug': 'pic_syousai.php?gbID=813&dt=190805151400',
#   'sex': '男性',
#   'age_exposure': '8',
#   'exposure_pref': '長崎',
#   'exposure_dist': '4.5km'},
#  {'name': '居森|清子',
#   'id': 55,
#   'slug': 'pic_syousai.php?gbID=181&dt=190805151400',
#   'sex': '女性',
#   'age_exposure': '11',
#   'exposure_pref': '広島',
#   'exposure_dist': '0.3km'},
#  {'name': '井守|能成',
#   'id': 56,
#   'slug': 'pic_syousai.php?gbID=182&dt=190805151400',
#   'sex': '男性',
#   'age_exposure': '14',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.0km'},
#  {'name': '岩永|芙美子',
#   'id': 57,
#   'slug': 'pic_syousai.php?gbID=859&dt=190805151400',
#   'sex': '女性',
#   'age_exposure': '1',
#   'exposure_pref': '長崎',
#   'exposure_dist': '4.0km'},
#  {'name': '岩野|貴久子',
#   'id': 58,
#   'slug': 'pic_syousai.php?gbID=12&dt=190805151400',
#   'sex': '女性',
#   'age_exposure': '10',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.0km'},
#  {'name': '岩野|久雄',
#   'id': 59,
#   'slug': 'pic_syousai.php?gbID=13&dt=190805151400',
#   'sex': '男性',
#   'age_exposure': '9',
#   'exposure_pref': '長崎',
#   'exposure_dist': '4.4km'},
#  {'name': '岩橋|ヤエ子',
#   'id': 60,
#   'slug': 'pic_syousai.php?gbID=1040&dt=190805151400',
#   'sex': '女性',
#   'age_exposure': '19',
#   'exposure_pref': '長崎',
#   'exposure_dist': '0.9km'},
#  {'name': '岩元|イホエ',
#   'id': 61,
#   'slug': 'pic_syousai.php?gbID=832&dt=190805151403',
#   'sex': '女性',
#   'age_exposure': '18',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.8km'},
#  {'name': '岩元|順子',
#   'id': 62,
#   'slug': 'pic_syousai.php?gbID=867&dt=190805151403',
#   'sex': '女性',
#   'age_exposure': '5',
#   'exposure_pref': '長崎',
#   'exposure_dist': '5.5km'},
#  {'name': '岩本|千枝子',
#   'id': 63,
#   'slug': 'pic_syousai.php?gbID=863&dt=190805151403',
#   'sex': '女性',
#   'age_exposure': '6',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.4km'},
#  {'name': '岩本|フク子',
#   'id': 64,
#   'slug': 'pic_syousai.php?gbID=860&dt=190805151403',
#   'sex': '女性',
#   'age_exposure': '14',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.6km'},
#  {'name': '印藤|福一',
#   'id': 65,
#   'slug': 'pic_syousai.php?gbID=186&dt=190805151403',
#   'sex': '男性',
#   'age_exposure': '17',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.5km'},
#  {'name': '上島|富太',
#   'id': 66,
#   'slug': 'pic_syousai.php?gbID=825&dt=190805151403',
#   'sex': '男性',
#   'age_exposure': '16',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '上杉|卓助',
#   'id': 67,
#   'slug': 'pic_syousai.php?gbID=187&dt=190805151403',
#   'sex': '男性',
#   'age_exposure': '22',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '上田|亨',
#   'id': 68,
#   'slug': 'pic_syousai.php?gbID=848&dt=190805151403',
#   'sex': '男性',
#   'age_exposure': '13',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.5km'},
#  {'name': '植野|克彦',
#   'id': 69,
#   'slug': 'pic_syousai.php?gbID=1128&dt=190805151403',
#   'sex': '男性',
#   'age_exposure': '12',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.5km'},
#  {'name': '上野|良子',
#   'id': 70,
#   'slug': 'pic_syousai.php?gbID=880&dt=190805151403',
#   'sex': '女性',
#   'age_exposure': '16',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.6km'},
#  {'name': '植村|茂夫',
#   'id': 71,
#   'slug': 'pic_syousai.php?gbID=1227&dt=190805151403',
#   'sex': '男性',
#   'age_exposure': '14',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '上村|末彦',
#   'id': 72,
#   'slug': 'pic_syousai.php?gbID=191&dt=190805151403',
#   'sex': '男性',
#   'age_exposure': '19',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.3km'},
#  {'name': '宇木|赫',
#   'id': 73,
#   'slug': 'pic_syousai.php?gbID=773&dt=190805151403',
#   'sex': '男性',
#   'age_exposure': '10',
#   'exposure_pref': '長崎',
#   'exposure_dist': '6.0km'},
#  {'name': '内田|栄一',
#   'id': 74,
#   'slug': 'pic_syousai.php?gbID=192&dt=190805151403',
#   'sex': '男性',
#   'age_exposure': '20',
#   'exposure_pref': '広島',
#   'exposure_dist': '0.8km'},
#  {'name': '内野|節雄',
#   'id': 75,
#   'slug': 'pic_syousai.php?gbID=892&dt=190805151403',
#   'sex': '男性',
#   'age_exposure': '1',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.8km'},
#  {'name': '内山|守',
#   'id': 76,
#   'slug': 'pic_syousai.php?gbID=196&dt=190805151403',
#   'sex': '男性',
#   'age_exposure': '11',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.5km'},
#  {'name': '宇根|利枝',
#   'id': 77,
#   'slug': 'pic_syousai.php?gbID=197&dt=190805151403',
#   'sex': '女性',
#   'age_exposure': '26',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.7km'},
#  {'name': '梅岡|昭生',
#   'id': 78,
#   'slug': 'pic_syousai.php?gbID=198&dt=190805151403',
#   'sex': '男性',
#   'age_exposure': '15',
#   'exposure_pref': '広島',
#   'exposure_dist': '3.0km'},
#  {'name': '梅路|セツ子',
#   'id': 79,
#   'slug': 'pic_syousai.php?gbID=1057&dt=190805151403',
#   'sex': '女性',
#   'age_exposure': '17',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.3km'},
#  {'name': '浦|由蔵',
#   'id': 80,
#   'slug': 'pic_syousai.php?gbID=199&dt=190805151403',
#   'sex': '男性',
#   'age_exposure': '22',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.0km'},
#  {'name': '浦上|冨久美',
#   'id': 81,
#   'slug': 'pic_syousai.php?gbID=856&dt=190805151404',
#   'sex': '女性',
#   'age_exposure': '14',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.6km'},
#  {'name': '浦田|正人',
#   'id': 82,
#   'slug': 'pic_syousai.php?gbID=201&dt=190805151404',
#   'sex': '男性',
#   'age_exposure': '9',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.5km'},
#  {'name': '浦田|昌則',
#   'id': 83,
#   'slug': 'pic_syousai.php?gbID=202&dt=190805151404',
#   'sex': '男性',
#   'age_exposure': '13',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.0km'},
#  {'name': '浦田|弘',
#   'id': 84,
#   'slug': 'pic_syousai.php?gbID=200&dt=190805151404',
#   'sex': '男性',
#   'age_exposure': '18',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.0km'},
#  {'name': '江頭|千代子',
#   'id': 85,
#   'slug': 'pic_syousai.php?gbID=107&dt=190805151404',
#   'sex': '女性',
#   'age_exposure': '35',
#   'exposure_pref': '長崎',
#   'exposure_dist': '0.5km'},
#  {'name': '遠藤|健一',
#   'id': 86,
#   'slug': 'pic_syousai.php?gbID=203&dt=190805151404',
#   'sex': '男性',
#   'age_exposure': '25',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.0km'},
#  {'name': '遠藤|留雄',
#   'id': 87,
#   'slug': 'pic_syousai.php?gbID=207&dt=190805151404',
#   'sex': '男性',
#   'age_exposure': '14',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.6km'},
#  {'name': '遠藤|昌弘',
#   'id': 88,
#   'slug': 'pic_syousai.php?gbID=208&dt=190805151404',
#   'sex': '男性',
#   'age_exposure': '19',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.5km'},
#  {'name': '呉 錫權',
#   'id': 89,
#   'slug': 'pic_syousai.php?gbID=758&dt=190805151404',
#   'sex': '男性',
#   'age_exposure': '11',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '大石|晴三',
#   'id': 90,
#   'slug': 'pic_syousai.php?gbID=212&dt=190805151404',
#   'sex': '女性',
#   'age_exposure': '22',
#   'exposure_pref': '広島',
#   'exposure_dist': '3.0km'},
#  {'name': '大岩|孝平',
#   'id': 91,
#   'slug': 'pic_syousai.php?gbID=216&dt=190805151404',
#   'sex': '男性',
#   'age_exposure': '13',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.2km'},
#  {'name': '大越|シミエ',
#   'id': 92,
#   'slug': 'pic_syousai.php?gbID=217&dt=190805151404',
#   'sex': '女性',
#   'age_exposure': '23',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.5km'},
#  {'name': '大坂|剛三',
#   'id': 93,
#   'slug': 'pic_syousai.php?gbID=218&dt=190805151404',
#   'sex': '男性',
#   'age_exposure': '19',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.0km'},
#  {'name': '大下|美津',
#   'id': 94,
#   'slug': 'pic_syousai.php?gbID=219&dt=190805151404',
#   'sex': '女性',
#   'age_exposure': '21',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '大瀬|貞男',
#   'id': 95,
#   'slug': 'pic_syousai.php?gbID=220&dt=190805151404',
#   'sex': '男性',
#   'age_exposure': '18',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '大塚|一敏',
#   'id': 96,
#   'slug': 'pic_syousai.php?gbID=827&dt=190805151404',
#   'sex': '男性',
#   'age_exposure': '9',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.8km'},
#  {'name': '大荷|康夫',
#   'id': 97,
#   'slug': 'pic_syousai.php?gbID=221&dt=190805151404',
#   'sex': '男性',
#   'age_exposure': '19',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '大野|禮子',
#   'id': 98,
#   'slug': 'pic_syousai.php?gbID=1225&dt=190805151404',
#   'sex': '女性',
#   'age_exposure': '10',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.2km'},
#  {'name': '大藤|俊栄',
#   'id': 99,
#   'slug': 'pic_syousai.php?gbID=222&dt=190805151404',
#   'sex': '女性',
#   'age_exposure': '23',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '大村|一夫',
#   'id': 100,
#   'slug': 'pic_syousai.php?gbID=1287&dt=190805151404',
#   'sex': '男性',
#   'age_exposure': '4',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.6km'},
#  {'name': '大本|竜敬',
#   'id': 101,
#   'slug': 'pic_syousai.php?gbID=223&dt=190805151405',
#   'sex': '男性',
#   'age_exposure': '15',
#   'exposure_pref': '広島',
#   'exposure_dist': '4.5km'},
#  {'name': '岡|信子',
#   'id': 102,
#   'slug': 'pic_syousai.php?gbID=793&dt=190805151405',
#   'sex': '女性',
#   'age_exposure': '16',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.8km'},
#  {'name': '岡田|健子',
#   'id': 103,
#   'slug': 'pic_syousai.php?gbID=224&dt=190805151405',
#   'sex': '女性',
#   'age_exposure': '13',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '岡田|實',
#   'id': 104,
#   'slug': 'pic_syousai.php?gbID=876&dt=190805151405',
#   'sex': '男性',
#   'age_exposure': '20',
#   'exposure_pref': '広島',
#   'exposure_dist': '4.1km'},
#  {'name': '岡邊|冨子',
#   'id': 105,
#   'slug': 'pic_syousai.php?gbID=225&dt=190805151405',
#   'sex': '女性',
#   'age_exposure': '23',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.0km'},
#  {'name': '岡邊|好子',
#   'id': 106,
#   'slug': 'pic_syousai.php?gbID=229&dt=190805151405',
#   'sex': '女性',
#   'age_exposure': '15',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.7km'},
#  {'name': '岡村|昌三郎',
#   'id': 107,
#   'slug': 'pic_syousai.php?gbID=233&dt=190805151405',
#   'sex': '男性',
#   'age_exposure': '20',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.5km'},
#  {'name': '岡元|貞則',
#   'id': 108,
#   'slug': 'pic_syousai.php?gbID=14&dt=190805151405',
#   'sex': '男性',
#   'age_exposure': '18',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.0km'},
#  {'name': '小笠原|貞雄',
#   'id': 109,
#   'slug': 'pic_syousai.php?gbID=1126&dt=190805151405',
#   'sex': '男性',
#   'age_exposure': '18',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '小方|悟',
#   'id': 110,
#   'slug': 'pic_syousai.php?gbID=1218&dt=190805151405',
#   'sex': '男性',
#   'age_exposure': '14',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.5km'},
#  {'name': '小川|友弘',
#   'id': 111,
#   'slug': 'pic_syousai.php?gbID=234&dt=190805151405',
#   'sex': '男性',
#   'age_exposure': '7',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.5km'},
#  {'name': '沖本|光子',
#   'id': 112,
#   'slug': 'pic_syousai.php?gbID=235&dt=190805151405',
#   'sex': '女性',
#   'age_exposure': '14',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.8km'},
#  {'name': '奥城|和海',
#   'id': 113,
#   'slug': 'pic_syousai.php?gbID=236&dt=190805151405',
#   'sex': '男性',
#   'age_exposure': '8',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.4km'},
#  {'name': '奥谷|美枝子',
#   'id': 114,
#   'slug': 'pic_syousai.php?gbID=240&dt=190805151405',
#   'sex': '女性',
#   'age_exposure': '18',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '奥田|静男',
#   'id': 115,
#   'slug': 'pic_syousai.php?gbID=830&dt=190805151405',
#   'sex': '男性',
#   'age_exposure': '17',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.2km'},
#  {'name': '奥田 豊治',
#   'id': 116,
#   'slug': 'pic_syousai.php?gbID=1293&dt=190805151405',
#   'sex': '男性',
#   'age_exposure': '15',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '奥田|萩子',
#   'id': 117,
#   'slug': 'pic_syousai.php?gbID=1304&dt=190805151405',
#   'sex': '女性',
#   'age_exposure': '17',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.3km'},
#  {'name': '奥村|英二',
#   'id': 118,
#   'slug': 'pic_syousai.php?gbID=15&dt=190805151405',
#   'sex': '男性',
#   'age_exposure': '6',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '桶田|岩男',
#   'id': 119,
#   'slug': 'pic_syousai.php?gbID=1203&dt=190805151405',
#   'sex': '男性',
#   'age_exposure': '16',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '小崎|登明',
#   'id': 120,
#   'slug': 'pic_syousai.php?gbID=111&dt=190805151405',
#   'sex': '男性',
#   'age_exposure': '17',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.3km'},
#  {'name': '尾崎|正義',
#   'id': 121,
#   'slug': 'pic_syousai.php?gbID=820&dt=190805151406',
#   'sex': '男性',
#   'age_exposure': '13',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '小田中|幸子',
#   'id': 122,
#   'slug': 'pic_syousai.php?gbID=244&dt=190805151406',
#   'sex': '女性',
#   'age_exposure': '8',
#   'exposure_pref': '長崎',
#   'exposure_dist': '4.5km'},
#  {'name': '越智|晴子',
#   'id': 123,
#   'slug': 'pic_syousai.php?gbID=245&dt=190805151406',
#   'sex': '女性',
#   'age_exposure': '22',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.7km'},
#  {'name': '落合|末治郎',
#   'id': 124,
#   'slug': 'pic_syousai.php?gbID=249&dt=190805151406',
#   'sex': '男性',
#   'age_exposure': '21',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.0km'},
#  {'name': '鬼塚|邦彦',
#   'id': 125,
#   'slug': 'pic_syousai.php?gbID=16&dt=190805151406',
#   'sex': '男性',
#   'age_exposure': '20',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.3km'},
#  {'name': '尾糠|政美',
#   'id': 126,
#   'slug': 'pic_syousai.php?gbID=250&dt=190805151406',
#   'sex': '男性',
#   'age_exposure': '24',
#   'exposure_pref': '広島',
#   'exposure_dist': '4.0km'},
#  {'name': '小野|美穂',
#   'id': 127,
#   'slug': 'pic_syousai.php?gbID=251&dt=190805151406',
#   'sex': '女性',
#   'age_exposure': '24',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '小野﨑|浅治',
#   'id': 128,
#   'slug': 'pic_syousai.php?gbID=1200&dt=190805151406',
#   'sex': '男性',
#   'age_exposure': '21',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '小山|春雄',
#   'id': 129,
#   'slug': 'pic_syousai.php?gbID=252&dt=190805151406',
#   'sex': '男性',
#   'age_exposure': '21',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.0km'},
#  {'name': '折田|サチ',
#   'id': 130,
#   'slug': 'pic_syousai.php?gbID=833&dt=190805151406',
#   'sex': '女性',
#   'age_exposure': '19',
#   'exposure_pref': '長崎',
#   'exposure_dist': '0.7km'},
#  {'name': '折免|シゲコ',
#   'id': 131,
#   'slug': 'pic_syousai.php?gbID=253&dt=190805151406',
#   'sex': '女性',
#   'age_exposure': '37',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '恩田|明彦',
#   'id': 132,
#   'slug': 'pic_syousai.php?gbID=748&dt=190805151406',
#   'sex': '男性',
#   'age_exposure': '2',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.2km'},
#  {'name': 'O.E.',
#   'id': 133,
#   'slug': 'pic_syousai.php?gbID=1134&dt=190805151406',
#   'sex': '男性',
#   'age_exposure': '14',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.6km'},
#  {'name': '香川|清',
#   'id': 134,
#   'slug': 'pic_syousai.php?gbID=254&dt=190805151406',
#   'sex': '男性',
#   'age_exposure': '19',
#   'exposure_pref': '広島',
#   'exposure_dist': '4.0km'},
#  {'name': '郭|守亨',
#   'id': 135,
#   'slug': 'pic_syousai.php?gbID=258&dt=190805151406',
#   'sex': '男性',
#   'age_exposure': '6',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.7km'},
#  {'name': '樫村|從子',
#   'id': 136,
#   'slug': 'pic_syousai.php?gbID=259&dt=190805151406',
#   'sex': '女性',
#   'age_exposure': '21',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.1km'},
#  {'name': '加瀬|和夫',
#   'id': 137,
#   'slug': 'pic_syousai.php?gbID=263&dt=190805151406',
#   'sex': '男性',
#   'age_exposure': '12',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.3km'},
#  {'name': '片岡|修',
#   'id': 138,
#   'slug': 'pic_syousai.php?gbID=267&dt=190805151406',
#   'sex': '男性',
#   'age_exposure': '13',
#   'exposure_pref': '広島',
#   'exposure_dist': '0.8km'},
#  {'name': '片岡|ツヨ',
#   'id': 139,
#   'slug': 'pic_syousai.php?gbID=115&dt=190805151406',
#   'sex': '女性',
#   'age_exposure': '24',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.3km'},
#  {'name': '加田|弘子',
#   'id': 140,
#   'slug': 'pic_syousai.php?gbID=745&dt=190805151406',
#   'sex': '女性',
#   'age_exposure': '9',
#   'exposure_pref': '広島',
#   'exposure_dist': '4.0km'},
#  {'name': '加藤|和已',
#   'id': 141,
#   'slug': 'pic_syousai.php?gbID=268&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '15',
#   'exposure_pref': '広島',
#   'exposure_dist': '4.0km'},
#  {'name': '加藤|昇',
#   'id': 142,
#   'slug': 'pic_syousai.php?gbID=269&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '17',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '加藤|正矩',
#   'id': 143,
#   'slug': 'pic_syousai.php?gbID=805&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '16',
#   'exposure_pref': '広島',
#   'exposure_dist': '5.0km'},
#  {'name': '金子 廣子',
#   'id': 144,
#   'slug': 'pic_syousai.php?gbID=1284&dt=190805151407',
#   'sex': '女性',
#   'age_exposure': '5',
#   'exposure_pref': '広島',
#   'exposure_dist': '3.0km'},
#  {'name': '金近|衛',
#   'id': 145,
#   'slug': 'pic_syousai.php?gbID=1132&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '2',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.2km'},
#  {'name': '兼松|茂',
#   'id': 146,
#   'slug': 'pic_syousai.php?gbID=761&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '17',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.1km'},
#  {'name': '鎌形|金作',
#   'id': 147,
#   'slug': 'pic_syousai.php?gbID=1205&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '19',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '上川 仁',
#   'id': 148,
#   'slug': 'pic_syousai.php?gbID=17&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '10',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.2km'},
#  {'name': '禿樹|暲',
#   'id': 149,
#   'slug': 'pic_syousai.php?gbID=270&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '11',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.0km'},
#  {'name': '亀井|好一',
#   'id': 150,
#   'slug': 'pic_syousai.php?gbID=1136&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '8',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '亀沢|深雪',
#   'id': 151,
#   'slug': 'pic_syousai.php?gbID=274&dt=190805151407',
#   'sex': '女性',
#   'age_exposure': '17',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.3km'},
#  {'name': '嘉屋重|順子',
#   'id': 152,
#   'slug': 'pic_syousai.php?gbID=801&dt=190805151407',
#   'sex': '女性',
#   'age_exposure': '6',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.5km'},
#  {'name': '假野|幸光',
#   'id': 153,
#   'slug': 'pic_syousai.php?gbID=878&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '19',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.2km'},
#  {'name': '河井|亮',
#   'id': 154,
#   'slug': 'pic_syousai.php?gbID=1053&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '12',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.0km'},
#  {'name': '河内|正昭',
#   'id': 155,
#   'slug': 'pic_syousai.php?gbID=903&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '15',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.5km'},
#  {'name': '川上|千津子',
#   'id': 156,
#   'slug': 'pic_syousai.php?gbID=278&dt=190805151407',
#   'sex': '女性',
#   'age_exposure': '12',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '川口|与作',
#   'id': 157,
#   'slug': 'pic_syousai.php?gbID=18&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '15',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.0km'},
#  {'name': '川谷|邦夫',
#   'id': 158,
#   'slug': 'pic_syousai.php?gbID=768&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '14',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.4km'},
#  {'name': '川並|順吾',
#   'id': 159,
#   'slug': 'pic_syousai.php?gbID=282&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '11',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.0km'},
#  {'name': '川原|進',
#   'id': 160,
#   'slug': 'pic_syousai.php?gbID=888&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '0',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '川畑|芳也',
#   'id': 161,
#   'slug': 'pic_syousai.php?gbID=283&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '24',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.3km'},
#  {'name': '河村|信子',
#   'id': 162,
#   'slug': 'pic_syousai.php?gbID=869&dt=190805151407',
#   'sex': '女性',
#   'age_exposure': '15',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.4km'},
#  {'name': '川本|司郎',
#   'id': 163,
#   'slug': 'pic_syousai.php?gbID=284&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '8',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.3km'},
#  {'name': '川本|都',
#   'id': 164,
#   'slug': 'pic_syousai.php?gbID=288&dt=190805151407',
#   'sex': '女性',
#   'age_exposure': '17',
#   'exposure_pref': '広島',
#   'exposure_dist': '3.0km'},
#  {'name': '川本|嘉幸',
#   'id': 165,
#   'slug': 'pic_syousai.php?gbID=1131&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '16',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '瓦田|一生',
#   'id': 166,
#   'slug': 'pic_syousai.php?gbID=871&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '22',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.3km'},
#  {'name': '姜|弘九',
#   'id': 167,
#   'slug': 'pic_syousai.php?gbID=1104&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '14',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.5km'},
#  {'name': '康|弘子',
#   'id': 168,
#   'slug': 'pic_syousai.php?gbID=1307&dt=190805151407',
#   'sex': '女性',
#   'age_exposure': '2',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.8km'},
#  {'name': '姜|文煕',
#   'id': 169,
#   'slug': 'pic_syousai.php?gbID=292&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '26',
#   'exposure_pref': '広島',
#   'exposure_dist': '4.6km'},
#  {'name': '神戸|美和子',
#   'id': 170,
#   'slug': 'pic_syousai.php?gbID=296&dt=190805151407',
#   'sex': '女性',
#   'age_exposure': '7',
#   'exposure_pref': '広島',
#   'exposure_dist': '3.8km'},
#  {'name': '木内|恭子',
#   'id': 171,
#   'slug': 'pic_syousai.php?gbID=1197&dt=190805151407',
#   'sex': '女性',
#   'age_exposure': '9',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.6km'},
#  {'name': '菊野|和子',
#   'id': 172,
#   'slug': 'pic_syousai.php?gbID=770&dt=190805151407',
#   'sex': '女性',
#   'age_exposure': '18',
#   'exposure_pref': '長崎',
#   'exposure_dist': '0.7km'},
#  {'name': '木口|久',
#   'id': 173,
#   'slug': 'pic_syousai.php?gbID=853&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '5',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.5km'},
#  {'name': '木皿|善雄',
#   'id': 174,
#   'slug': 'pic_syousai.php?gbID=297&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '18',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.0km'},
#  {'name': '喜夛|康巳',
#   'id': 175,
#   'slug': 'pic_syousai.php?gbID=1060&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '15',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '鍛永|利夫',
#   'id': 176,
#   'slug': 'pic_syousai.php?gbID=298&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '18',
#   'exposure_pref': '広島',
#   'exposure_dist': '4.7km'},
#  {'name': '北村|三子夫',
#   'id': 177,
#   'slug': 'pic_syousai.php?gbID=299&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '21',
#   'exposure_pref': '広島',
#   'exposure_dist': '4.0km'},
#  {'name': '木戸|季市',
#   'id': 178,
#   'slug': 'pic_syousai.php?gbID=916&dt=190805151407',
#   'sex': '男性',
#   'age_exposure': '5',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.9km'},
#  {'name': '城戸|真子',
#   'id': 179,
#   'slug': 'pic_syousai.php?gbID=868&dt=190805151407',
#   'sex': '女性',
#   'age_exposure': '16',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '金|日祚',
#   'id': 180,
#   'slug': 'pic_syousai.php?gbID=303&dt=190805151407',
#   'sex': '女性',
#   'age_exposure': '16',
#   'exposure_pref': '広島',
#   'exposure_dist': '3.0km'},
#  {'name': '金|光子',
#   'id': 181,
#   'slug': 'pic_syousai.php?gbID=1174&dt=190805151408',
#   'sex': '女性',
#   'age_exposure': '2',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.2km'},
#  {'name': '金|敬道',
#   'id': 182,
#   'slug': 'pic_syousai.php?gbID=1306&dt=190805151408',
#   'sex': '男性',
#   'age_exposure': '4',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.1km'},
#  {'name': '金|三洙',
#   'id': 183,
#   'slug': 'pic_syousai.php?gbID=1219&dt=190805151408',
#   'sex': '男性',
#   'age_exposure': '23',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.0km'},
#  {'name': '金|島植',
#   'id': 184,
#   'slug': 'pic_syousai.php?gbID=304&dt=190805151408',
#   'sex': '男性',
#   'age_exposure': '9',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.2km'},
#  {'name': '木村|徳子',
#   'id': 185,
#   'slug': 'pic_syousai.php?gbID=305&dt=190805151408',
#   'sex': '女性',
#   'age_exposure': '10',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.6km'},
#  {'name': '木村|緋紗子',
#   'id': 186,
#   'slug': 'pic_syousai.php?gbID=306&dt=190805151408',
#   'sex': '女性',
#   'age_exposure': '8',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.6km'},
#  {'name': '木村|勝',
#   'id': 187,
#   'slug': 'pic_syousai.php?gbID=1065&dt=190805151408',
#   'sex': '男性',
#   'age_exposure': '15',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.3km'},
#  {'name': '木村|光盛',
#   'id': 188,
#   'slug': 'pic_syousai.php?gbID=1004&dt=190805151408',
#   'sex': '男性',
#   'age_exposure': '10',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.3km'},
#  {'name': '清野|定廣',
#   'id': 189,
#   'slug': 'pic_syousai.php?gbID=1042&dt=190805151408',
#   'sex': '男性',
#   'age_exposure': '8',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '銀林|美恵子',
#   'id': 190,
#   'slug': 'pic_syousai.php?gbID=310&dt=190805151408',
#   'sex': '女性',
#   'age_exposure': '17',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.6km'},
#  {'name': '久慈|敏子',
#   'id': 191,
#   'slug': 'pic_syousai.php?gbID=314&dt=190805151408',
#   'sex': '女性',
#   'age_exposure': '17',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.7km'},
#  {'name': '工藤 朱實',
#   'id': 192,
#   'slug': 'pic_syousai.php?gbID=1285&dt=190805151408',
#   'sex': '女性',
#   'age_exposure': '5',
#   'exposure_pref': '広島',
#   'exposure_dist': '5.0km'},
#  {'name': '久原|一弘',
#   'id': 193,
#   'slug': 'pic_syousai.php?gbID=315&dt=190805151408',
#   'sex': '男性',
#   'age_exposure': '17',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.5km'},
#  {'name': '久保|清子',
#   'id': 194,
#   'slug': 'pic_syousai.php?gbID=881&dt=190805151408',
#   'sex': '女性',
#   'age_exposure': '6',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.5km'},
#  {'name': '久保|寿子',
#   'id': 195,
#   'slug': 'pic_syousai.php?gbID=316&dt=190805151408',
#   'sex': '女性',
#   'age_exposure': '13',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.1km'},
#  {'name': '久保|ミツエ',
#   'id': 196,
#   'slug': 'pic_syousai.php?gbID=320&dt=190805151408',
#   'sex': '女性',
#   'age_exposure': '16',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.4km'},
#  {'name': '久保|ヨシミ',
#   'id': 197,
#   'slug': 'pic_syousai.php?gbID=321&dt=190805151408',
#   'sex': '女性',
#   'age_exposure': '12',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.9km'},
#  {'name': '久保山|栄典',
#   'id': 198,
#   'slug': 'pic_syousai.php?gbID=322&dt=190805151408',
#   'sex': '男性',
#   'age_exposure': '8',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.0km'},
#  {'name': '熊谷|直朗',
#   'id': 199,
#   'slug': 'pic_syousai.php?gbID=326&dt=190805151408',
#   'sex': '男性',
#   'age_exposure': '7',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.2km'},
#  {'name': '熊谷|龍生',
#   'id': 200,
#   'slug': 'pic_syousai.php?gbID=19&dt=190805151408',
#   'sex': '男性',
#   'age_exposure': '17',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '熊本|キクエ',
#   'id': 201,
#   'slug': 'pic_syousai.php?gbID=834&dt=190805151409',
#   'sex': '女性',
#   'age_exposure': '18',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.8km'},
#  {'name': 'クラウス|ルーメル',
#   'id': 202,
#   'slug': 'pic_syousai.php?gbID=330&dt=190805151409',
#   'sex': '男性',
#   'age_exposure': '28',
#   'exposure_pref': '広島',
#   'exposure_dist': '4.5km'},
#  {'name': '倉本|純一',
#   'id': 203,
#   'slug': 'pic_syousai.php?gbID=334&dt=190805151409',
#   'sex': '男性',
#   'age_exposure': '12',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.8km'},
#  {'name': '栗﨑|郁子',
#   'id': 204,
#   'slug': 'pic_syousai.php?gbID=338&dt=190805151409',
#   'sex': '女性',
#   'age_exposure': '18',
#   'exposure_pref': '広島',
#   'exposure_dist': '0.7km'},
#  {'name': '栗永|秀子',
#   'id': 205,
#   'slug': 'pic_syousai.php?gbID=769&dt=190805151409',
#   'sex': '女性',
#   'age_exposure': '19',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.0km'},
#  {'name': '厨川|克巳',
#   'id': 206,
#   'slug': 'pic_syousai.php?gbID=339&dt=190805151409',
#   'sex': '男性',
#   'age_exposure': '21',
#   'exposure_pref': '広島',
#   'exposure_dist': '3.5km'},
#  {'name': '黒木|俊一',
#   'id': 207,
#   'slug': 'pic_syousai.php?gbID=340&dt=190805151409',
#   'sex': '男性',
#   'age_exposure': '16',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '黒田|初代',
#   'id': 208,
#   'slug': 'pic_syousai.php?gbID=873&dt=190805151409',
#   'sex': '女性',
#   'age_exposure': '19',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.0km'},
#  {'name': '郡家|徳郎',
#   'id': 209,
#   'slug': 'pic_syousai.php?gbID=839&dt=190805151409',
#   'sex': '男性',
#   'age_exposure': '16',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.5km'},
#  {'name': '郡司|英子',
#   'id': 210,
#   'slug': 'pic_syousai.php?gbID=341&dt=190805151409',
#   'sex': '女性',
#   'age_exposure': '18',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '小池|高夫',
#   'id': 211,
#   'slug': 'pic_syousai.php?gbID=345&dt=190805151409',
#   'sex': '男性',
#   'age_exposure': '20',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.0km'},
#  {'name': '小稲|吉春',
#   'id': 212,
#   'slug': 'pic_syousai.php?gbID=349&dt=190805151409',
#   'sex': '男性',
#   'age_exposure': '17',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '河内|朗',
#   'id': 213,
#   'slug': 'pic_syousai.php?gbID=353&dt=190805151409',
#   'sex': '男性',
#   'age_exposure': '16',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '河野|昭二',
#   'id': 214,
#   'slug': 'pic_syousai.php?gbID=20&dt=190805151409',
#   'sex': '男性',
#   'age_exposure': '17',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.1km'},
#  {'name': '河野|正則',
#   'id': 215,
#   'slug': 'pic_syousai.php?gbID=354&dt=190805151409',
#   'sex': '男性',
#   'age_exposure': '15',
#   'exposure_pref': '広島',
#   'exposure_dist': '4.0km'},
#  {'name': '古賀|喜代三',
#   'id': 216,
#   'slug': 'pic_syousai.php?gbID=902&dt=190805151409',
#   'sex': '男性',
#   'age_exposure': '19',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '小坂|義雄',
#   'id': 217,
#   'slug': 'pic_syousai.php?gbID=1133&dt=190805151409',
#   'sex': '男性',
#   'age_exposure': '15',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.0km'},
#  {'name': '小谷|孝子',
#   'id': 218,
#   'slug': 'pic_syousai.php?gbID=355&dt=190805151409',
#   'sex': '女性',
#   'age_exposure': '6',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.5km'},
#  {'name': '小髙|美代子',
#   'id': 219,
#   'slug': 'pic_syousai.php?gbID=1059&dt=190805151409',
#   'sex': '女性',
#   'age_exposure': '20',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.9km'},
#  {'name': '小寺|博',
#   'id': 220,
#   'slug': 'pic_syousai.php?gbID=356&dt=190805151409',
#   'sex': '男性',
#   'age_exposure': '21',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.3km'},
#  {'name': '小寺|開蔵',
#   'id': 221,
#   'slug': 'pic_syousai.php?gbID=872&dt=190805151410',
#   'sex': '男性',
#   'age_exposure': '14',
#   'exposure_pref': '長崎',
#   'exposure_dist': '4.5km'},
#  {'name': '小西|伸一',
#   'id': 222,
#   'slug': 'pic_syousai.php?gbID=861&dt=190805151410',
#   'sex': '男性',
#   'age_exposure': '6',
#   'exposure_pref': '長崎',
#   'exposure_dist': '4.0km'},
#  {'name': '木幡|吉輝',
#   'id': 223,
#   'slug': 'pic_syousai.php?gbID=361&dt=190805151410',
#   'sex': '男性',
#   'age_exposure': '16',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '木場|耕平',
#   'id': 224,
#   'slug': 'pic_syousai.php?gbID=360&dt=190805151410',
#   'sex': '男性',
#   'age_exposure': '12',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '小林|康司',
#   'id': 225,
#   'slug': 'pic_syousai.php?gbID=362&dt=190805151410',
#   'sex': '男性',
#   'age_exposure': '9',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.8km'},
#  {'name': '小柳|恵美子',
#   'id': 226,
#   'slug': 'pic_syousai.php?gbID=363&dt=190805151410',
#   'sex': '女性',
#   'age_exposure': '14',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.8km'},
#  {'name': '孔 杜煥',
#   'id': 227,
#   'slug': 'pic_syousai.php?gbID=1251&dt=190805151410',
#   'sex': '男性',
#   'age_exposure': '8',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '孔 元甲',
#   'id': 228,
#   'slug': 'pic_syousai.php?gbID=1250&dt=190805151410',
#   'sex': '男性',
#   'age_exposure': '8',
#   'exposure_pref': '広島',
#   'exposure_dist': '3.4km'},
#  {'name': '近藤|節子',
#   'id': 229,
#   'slug': 'pic_syousai.php?gbID=21&dt=190805151410',
#   'sex': '女性',
#   'age_exposure': '22',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '近藤|敏子',
#   'id': 230,
#   'slug': 'pic_syousai.php?gbID=367&dt=190805151410',
#   'sex': '女性',
#   'age_exposure': '20',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.2km'},
#  {'name': '佐伯|敏子',
#   'id': 231,
#   'slug': 'pic_syousai.php?gbID=380&dt=190805151410',
#   'sex': '女性',
#   'age_exposure': '26',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '斎藤|寿美子',
#   'id': 232,
#   'slug': 'pic_syousai.php?gbID=368&dt=190805151410',
#   'sex': '女性',
#   'age_exposure': '13',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.5km'},
#  {'name': '斎藤|民子',
#   'id': 233,
#   'slug': 'pic_syousai.php?gbID=912&dt=190805151410',
#   'sex': '女性',
#   'age_exposure': '9',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.8km'},
#  {'name': '齋藤|忠治',
#   'id': 234,
#   'slug': 'pic_syousai.php?gbID=372&dt=190805151410',
#   'sex': '男性',
#   'age_exposure': '19',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.0km'},
#  {'name': '齋藤|政一',
#   'id': 235,
#   'slug': 'pic_syousai.php?gbID=376&dt=190805151410',
#   'sex': '男性',
#   'age_exposure': '21',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.0km'},
#  {'name': '佐伯|博行',
#   'id': 236,
#   'slug': 'pic_syousai.php?gbID=1196&dt=190805151410',
#   'sex': '男性',
#   'age_exposure': '1',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.3km'},
#  {'name': '酒井|武',
#   'id': 237,
#   'slug': 'pic_syousai.php?gbID=889&dt=190805151410',
#   'sex': '男性',
#   'age_exposure': '17',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.1km'},
#  {'name': '坂井|立昇',
#   'id': 238,
#   'slug': 'pic_syousai.php?gbID=837&dt=190805151410',
#   'sex': '男性',
#   'age_exposure': '22',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.0km'},
#  {'name': '坂巻|毅治',
#   'id': 239,
#   'slug': 'pic_syousai.php?gbID=810&dt=190805151410',
#   'sex': '男性',
#   'age_exposure': '12',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.0km'},
#  {'name': '坂元|浪男',
#   'id': 240,
#   'slug': 'pic_syousai.php?gbID=22&dt=190805151410',
#   'sex': '男性',
#   'age_exposure': '15',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.0km'},
#  {'name': '佐々木|京一',
#   'id': 241,
#   'slug': 'pic_syousai.php?gbID=384&dt=190805151411',
#   'sex': '男性',
#   'age_exposure': '28',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '佐々木|繁夫',
#   'id': 242,
#   'slug': 'pic_syousai.php?gbID=388&dt=190805151411',
#   'sex': '男性',
#   'age_exposure': '30',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '佐々木|光幸',
#   'id': 243,
#   'slug': 'pic_syousai.php?gbID=23&dt=190805151411',
#   'sex': '男性',
#   'age_exposure': '13',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.7km'},
#  {'name': '笹森|恵子',
#   'id': 244,
#   'slug': 'pic_syousai.php?gbID=389&dt=190805151411',
#   'sex': '女性',
#   'age_exposure': '13',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.5km'},
#  {'name': '貞清|百合子',
#   'id': 245,
#   'slug': 'pic_syousai.php?gbID=1055&dt=190805151411',
#   'sex': '女性',
#   'age_exposure': '6',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.5km'},
#  {'name': '佐藤 慧子',
#   'id': 246,
#   'slug': 'pic_syousai.php?gbID=1308&dt=190805151411',
#   'sex': '女性',
#   'age_exposure': '7',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '佐藤|里枝',
#   'id': 247,
#   'slug': 'pic_syousai.php?gbID=391&dt=190805151411',
#   'sex': '女性',
#   'age_exposure': '4',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.8km'},
#  {'name': '佐藤|寅雄',
#   'id': 248,
#   'slug': 'pic_syousai.php?gbID=395&dt=190805151411',
#   'sex': '男性',
#   'age_exposure': '20',
#   'exposure_pref': '長崎',
#   'exposure_dist': '0.7km'},
#  {'name': '佐藤|良生',
#   'id': 249,
#   'slug': 'pic_syousai.php?gbID=399&dt=190805151411',
#   'sex': '男性',
#   'age_exposure': '14',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.0km'},
#  {'name': '眞田|保',
#   'id': 250,
#   'slug': 'pic_syousai.php?gbID=1202&dt=190805151411',
#   'sex': '男性',
#   'age_exposure': '7',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.5km'},
#  {'name': '佐野|博敏',
#   'id': 251,
#   'slug': 'pic_syousai.php?gbID=400&dt=190805151411',
#   'sex': '男性',
#   'age_exposure': '17',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '更科|洵爾',
#   'id': 252,
#   'slug': 'pic_syousai.php?gbID=1192&dt=190805151411',
#   'sex': '男性',
#   'age_exposure': '16',
#   'exposure_pref': '広島',
#   'exposure_dist': '3.5km'},
#  {'name': '澤口|與四蔵',
#   'id': 253,
#   'slug': 'pic_syousai.php?gbID=725&dt=190805151411',
#   'sex': '男性',
#   'age_exposure': '21',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '澤野|實',
#   'id': 254,
#   'slug': 'pic_syousai.php?gbID=739&dt=190805151411',
#   'sex': '男性',
#   'age_exposure': '18',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': 'サーロー|節子',
#   'id': 255,
#   'slug': 'pic_syousai.php?gbID=754&dt=190805151411',
#   'sex': '女性',
#   'age_exposure': '13',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.8km'},
#  {'name': '柴田|フミノ',
#   'id': 256,
#   'slug': 'pic_syousai.php?gbID=405&dt=190805151411',
#   'sex': '女性',
#   'age_exposure': '20',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '柴田|政一',
#   'id': 257,
#   'slug': 'pic_syousai.php?gbID=738&dt=190805151411',
#   'sex': '男性',
#   'age_exposure': '16',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '島袋|仁栄',
#   'id': 258,
#   'slug': 'pic_syousai.php?gbID=24&dt=190805151411',
#   'sex': '男性',
#   'age_exposure': '23',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.0km'},
#  {'name': '清水|信雄',
#   'id': 259,
#   'slug': 'pic_syousai.php?gbID=406&dt=190805151411',
#   'sex': '男性',
#   'age_exposure': '2',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.0km'},
#  {'name': '下|正一',
#   'id': 260,
#   'slug': 'pic_syousai.php?gbID=407&dt=190805151411',
#   'sex': '男性',
#   'age_exposure': '17',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '下斗米|洋子',
#   'id': 261,
#   'slug': 'pic_syousai.php?gbID=408&dt=190805151412',
#   'sex': '女性',
#   'age_exposure': '17',
#   'exposure_pref': '広島',
#   'exposure_dist': '3.6km'},
#  {'name': '下春|不二男',
#   'id': 262,
#   'slug': 'pic_syousai.php?gbID=917&dt=190805151412',
#   'sex': '男性',
#   'age_exposure': '11',
#   'exposure_pref': '長崎',
#   'exposure_dist': '5.6km'},
#  {'name': '下平|作江',
#   'id': 263,
#   'slug': 'pic_syousai.php?gbID=67&dt=190805151412',
#   'sex': '女性',
#   'age_exposure': '10',
#   'exposure_pref': '長崎',
#   'exposure_dist': '0.8km'},
#  {'name': '白石|俊一',
#   'id': 264,
#   'slug': 'pic_syousai.php?gbID=1151&dt=190805151412',
#   'sex': '男性',
#   'age_exposure': '17',
#   'exposure_pref': '両市',
#   'exposure_dist': ''},
#  {'name': '白石|多美子',
#   'id': 265,
#   'slug': 'pic_syousai.php?gbID=401&dt=190805151412',
#   'sex': '女性',
#   'age_exposure': '6',
#   'exposure_pref': '広島',
#   'exposure_dist': '4.0km'},
#  {'name': '白川|ミツエ',
#   'id': 266,
#   'slug': 'pic_syousai.php?gbID=785&dt=190805151412',
#   'sex': '女性',
#   'age_exposure': '15',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '白木|幸雄',
#   'id': 267,
#   'slug': 'pic_syousai.php?gbID=413&dt=190805151412',
#   'sex': '男性',
#   'age_exposure': '15',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.5km'},
#  {'name': '白澤|いづみ',
#   'id': 268,
#   'slug': 'pic_syousai.php?gbID=734&dt=190805151412',
#   'sex': '女性',
#   'age_exposure': '21',
#   'exposure_pref': '広島',
#   'exposure_dist': '4.0km'},
#  {'name': '白取|豊一',
#   'id': 269,
#   'slug': 'pic_syousai.php?gbID=417&dt=190805151412',
#   'sex': '男性',
#   'age_exposure': '17',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '新宮|義盛',
#   'id': 270,
#   'slug': 'pic_syousai.php?gbID=421&dt=190805151412',
#   'sex': '男性',
#   'age_exposure': '17',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.2km'},
#  {'name': '施|秀子',
#   'id': 271,
#   'slug': 'pic_syousai.php?gbID=752&dt=190805151412',
#   'sex': '女性',
# ...
#   'sex': '女性',
#   'age_exposure': '13',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.4km'},
#  {'name': '三田 健二郎',
#   'id': 550,
#   'slug': 'pic_syousai.php?gbID=1288&dt=190805151428',
#   'sex': '男性',
#   'age_exposure': '8',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.3km'},
#  {'name': '三田|良一',
#   'id': 551,
#   'slug': 'pic_syousai.php?gbID=823&dt=190805151428',
#   'sex': '男性',
#   'age_exposure': '15',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.2km'},
#  {'name': '三田村|静子',
#   'id': 552,
#   'slug': 'pic_syousai.php?gbID=1145&dt=190805151428',
#   'sex': '女性',
#   'age_exposure': '3',
#   'exposure_pref': '長崎',
#   'exposure_dist': '4.0km'},
#  {'name': '道上|昭雄',
#   'id': 553,
#   'slug': 'pic_syousai.php?gbID=664&dt=190805151428',
#   'sex': '男性',
#   'age_exposure': '16',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.0km'},
#  {'name': '道下|孝人',
#   'id': 554,
#   'slug': 'pic_syousai.php?gbID=844&dt=190805151428',
#   'sex': '男性',
#   'age_exposure': '6',
#   'exposure_pref': '長崎',
#   'exposure_dist': '4.7km'},
#  {'name': '三戸森|蔦子',
#   'id': 555,
#   'slug': 'pic_syousai.php?gbID=1066&dt=190805151428',
#   'sex': '女性',
#   'age_exposure': '1',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.5km'},
#  {'name': '南|七郎',
#   'id': 556,
#   'slug': 'pic_syousai.php?gbID=668&dt=190805151428',
#   'sex': '男性',
#   'age_exposure': '21',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.4km'},
#  {'name': '三根|繁',
#   'id': 557,
#   'slug': 'pic_syousai.php?gbID=906&dt=190805151428',
#   'sex': '男性',
#   'age_exposure': '8',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.4km'},
#  {'name': '三根|須美子',
#   'id': 558,
#   'slug': 'pic_syousai.php?gbID=64&dt=190805151428',
#   'sex': '女性',
#   'age_exposure': '12',
#   'exposure_pref': '長崎',
#   'exposure_dist': '7.5km'},
#  {'name': '峰|徹',
#   'id': 559,
#   'slug': 'pic_syousai.php?gbID=774&dt=190805151428',
#   'sex': '男性',
#   'age_exposure': '9',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.5km'},
#  {'name': '三宅|榮子',
#   'id': 560,
#   'slug': 'pic_syousai.php?gbID=672&dt=190805151428',
#   'sex': '女性',
#   'age_exposure': '18',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.0km'},
#  {'name': '三宅|信雄',
#   'id': 561,
#   'slug': 'pic_syousai.php?gbID=673&dt=190805151429',
#   'sex': '男性',
#   'age_exposure': '16',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.8km'},
#  {'name': '宮崎|昭郎',
#   'id': 562,
#   'slug': 'pic_syousai.php?gbID=855&dt=190805151429',
#   'sex': '男性',
#   'age_exposure': '13',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.1km'},
#  {'name': '宮永|龍馬',
#   'id': 563,
#   'slug': 'pic_syousai.php?gbID=674&dt=190805151429',
#   'sex': '男性',
#   'age_exposure': '15',
#   'exposure_pref': '広島',
#   'exposure_dist': '3.8km'},
#  {'name': '宮本|須美子',
#   'id': 564,
#   'slug': 'pic_syousai.php?gbID=1221&dt=190805151429',
#   'sex': '女性',
#   'age_exposure': '7',
#   'exposure_pref': '長崎',
#   'exposure_dist': '6.0km'},
#  {'name': '六倉|武',
#   'id': 565,
#   'slug': 'pic_syousai.php?gbID=762&dt=190805151429',
#   'sex': '男性',
#   'age_exposure': '17',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '武藤|嘉光',
#   'id': 566,
#   'slug': 'pic_syousai.php?gbID=789&dt=190805151429',
#   'sex': '男性',
#   'age_exposure': '12',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.2km'},
#  {'name': '村岡|洋',
#   'id': 567,
#   'slug': 'pic_syousai.php?gbID=904&dt=190805151429',
#   'sex': '男性',
#   'age_exposure': '15',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '村上|繁太郎',
#   'id': 568,
#   'slug': 'pic_syousai.php?gbID=678&dt=190805151429',
#   'sex': '男性',
#   'age_exposure': '19',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '村山|季美枝',
#   'id': 569,
#   'slug': 'pic_syousai.php?gbID=1204&dt=190805151429',
#   'sex': '女性',
#   'age_exposure': '5',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.3km'},
#  {'name': '茂木|貞夫',
#   'id': 570,
#   'slug': 'pic_syousai.php?gbID=682&dt=190805151429',
#   'sex': '男性',
#   'age_exposure': '11',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.2km'},
#  {'name': '本村|チヨ子',
#   'id': 571,
#   'slug': 'pic_syousai.php?gbID=815&dt=190805151429',
#   'sex': '女性',
#   'age_exposure': '6',
#   'exposure_pref': '長崎',
#   'exposure_dist': '4.0km'},
#  {'name': '森|喜代子',
#   'id': 572,
#   'slug': 'pic_syousai.php?gbID=829&dt=190805151429',
#   'sex': '女性',
#   'age_exposure': '14',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.3km'},
#  {'name': '森|重子',
#   'id': 573,
#   'slug': 'pic_syousai.php?gbID=845&dt=190805151429',
#   'sex': '女性',
#   'age_exposure': '9',
#   'exposure_pref': '長崎',
#   'exposure_dist': '4.1km'},
#  {'name': '森|武徳',
#   'id': 574,
#   'slug': 'pic_syousai.php?gbID=1146&dt=190805151429',
#   'sex': '男性',
#   'age_exposure': '15',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.6km'},
#  {'name': '森|忠義',
#   'id': 575,
#   'slug': 'pic_syousai.php?gbID=686&dt=190805151429',
#   'sex': '男性',
#   'age_exposure': '17',
#   'exposure_pref': '広島',
#   'exposure_dist': '4.7km'},
#  {'name': '森|敏夫',
#   'id': 576,
#   'slug': 'pic_syousai.php?gbID=687&dt=190805151429',
#   'sex': '男性',
#   'age_exposure': '20',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.5km'},
#  {'name': '森内|久美枝',
#   'id': 577,
#   'slug': 'pic_syousai.php?gbID=865&dt=190805151429',
#   'sex': '女性',
#   'age_exposure': '11',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '森内|繁廣',
#   'id': 578,
#   'slug': 'pic_syousai.php?gbID=781&dt=190805151429',
#   'sex': '男性',
#   'age_exposure': '13',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.2km'},
#  {'name': '森尾|佐賀',
#   'id': 579,
#   'slug': 'pic_syousai.php?gbID=688&dt=190805151429',
#   'sex': '女性',
#   'age_exposure': '21',
#   'exposure_pref': '広島',
#   'exposure_dist': '3.5km'},
#  {'name': '森口|貢',
#   'id': 580,
#   'slug': 'pic_syousai.php?gbID=898&dt=190805151429',
#   'sex': '男性',
#   'age_exposure': '8',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '森田|隆',
#   'id': 581,
#   'slug': 'pic_syousai.php?gbID=753&dt=190805151430',
#   'sex': '男性',
#   'age_exposure': '21',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.5km'},
#  {'name': '森田|宏',
#   'id': 582,
#   'slug': 'pic_syousai.php?gbID=886&dt=190805151430',
#   'sex': '男性',
#   'age_exposure': '10',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.6km'},
#  {'name': '森滝|市郎',
#   'id': 583,
#   'slug': 'pic_syousai.php?gbID=692&dt=190805151430',
#   'sex': '男性',
#   'age_exposure': '44',
#   'exposure_pref': '広島',
#   'exposure_dist': '4.1km'},
#  {'name': '森永|正人',
#   'id': 584,
#   'slug': 'pic_syousai.php?gbID=819&dt=190805151430',
#   'sex': '男性',
#   'age_exposure': '17',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.2km'},
#  {'name': '諸岡|定雄',
#   'id': 585,
#   'slug': 'pic_syousai.php?gbID=791&dt=190805151430',
#   'sex': '男性',
#   'age_exposure': '18',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '八木|道子',
#   'id': 586,
#   'slug': 'pic_syousai.php?gbID=818&dt=190805151430',
#   'sex': '女性',
#   'age_exposure': '6',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.3km'},
#  {'name': '矢倉|正',
#   'id': 587,
#   'slug': 'pic_syousai.php?gbID=693&dt=190805151430',
#   'sex': '男性',
#   'age_exposure': '19',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.2km'},
#  {'name': '山|重幸',
#   'id': 588,
#   'slug': 'pic_syousai.php?gbID=694&dt=190805151430',
#   'sex': '男性',
#   'age_exposure': '15',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '山家|好子',
#   'id': 589,
#   'slug': 'pic_syousai.php?gbID=1054&dt=190805151430',
#   'sex': '女性',
#   'age_exposure': '11',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.0km'},
#  {'name': '山川|富佐子',
#   'id': 590,
#   'slug': 'pic_syousai.php?gbID=1147&dt=190805151430',
#   'sex': '女性',
#   'age_exposure': '3',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.4km'},
#  {'name': '山口|仙二',
#   'id': 591,
#   'slug': 'pic_syousai.php?gbID=79&dt=190805151430',
#   'sex': '男性',
#   'age_exposure': '14',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.3km'},
#  {'name': '山口|疆',
#   'id': 592,
#   'slug': 'pic_syousai.php?gbID=119&dt=190805151430',
#   'sex': '男性',
#   'age_exposure': '29',
#   'exposure_pref': '両市',
#   'exposure_dist': '広島: 3.0km   長崎: 3.0km'},
#  {'name': '山口|鉄夫',
#   'id': 593,
#   'slug': 'pic_syousai.php?gbID=854&dt=190805151430',
#   'sex': '男性',
#   'age_exposure': '15',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '山口|保雄',
#   'id': 594,
#   'slug': 'pic_syousai.php?gbID=877&dt=190805151430',
#   'sex': '男性',
#   'age_exposure': '20',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '山口|洋一郎',
#   'id': 595,
#   'slug': 'pic_syousai.php?gbID=788&dt=190805151430',
#   'sex': '男性',
#   'age_exposure': '14',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.5km'},
#  {'name': '山口|淑子',
#   'id': 596,
#   'slug': 'pic_syousai.php?gbID=695&dt=190805151430',
#   'sex': '女性',
#   'age_exposure': '13',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.3km'},
#  {'name': '山崎|馨',
#   'id': 597,
#   'slug': 'pic_syousai.php?gbID=866&dt=190805151430',
#   'sex': '男性',
#   'age_exposure': '19',
#   'exposure_pref': '長崎',
#   'exposure_dist': '4.0km'},
#  {'name': '山崎|芳城',
#   'id': 598,
#   'slug': 'pic_syousai.php?gbID=696&dt=190805151430',
#   'sex': '男性',
#   'age_exposure': '26',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.5km'},
#  {'name': '山下|弘子',
#   'id': 599,
#   'slug': 'pic_syousai.php?gbID=771&dt=190805151430',
#   'sex': '女性',
#   'age_exposure': '17',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.3km'},
#  {'name': '山下|幸雄',
#   'id': 600,
#   'slug': 'pic_syousai.php?gbID=899&dt=190805151430',
#   'sex': '男性',
#   'age_exposure': '17',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.2km'},
#  {'name': '山科|和子',
#   'id': 601,
#   'slug': 'pic_syousai.php?gbID=697&dt=190805151431',
#   'sex': '女性',
#   'age_exposure': '23',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.5km'},
#  {'name': '山科|トシコ',
#   'id': 602,
#   'slug': 'pic_syousai.php?gbID=807&dt=190805151431',
#   'sex': '女性',
#   'age_exposure': '13',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.0km'},
#  {'name': '山田|市太郎',
#   'id': 603,
#   'slug': 'pic_syousai.php?gbID=123&dt=190805151431',
#   'sex': '男性',
#   'age_exposure': '39',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '山田|一美',
#   'id': 604,
#   'slug': 'pic_syousai.php?gbID=890&dt=190805151431',
#   'sex': '男性',
#   'age_exposure': '12',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.3km'},
#  {'name': '山田|玲子',
#   'id': 605,
#   'slug': 'pic_syousai.php?gbID=701&dt=190805151431',
#   'sex': '女性',
#   'age_exposure': '11',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.5km'},
#  {'name': '大和|忠雄',
#   'id': 606,
#   'slug': 'pic_syousai.php?gbID=741&dt=190805151431',
#   'sex': '男性',
#   'age_exposure': '5',
#   'exposure_pref': '広島',
#   'exposure_dist': '3.5km'},
#  {'name': '山畑|善孝',
#   'id': 607,
#   'slug': 'pic_syousai.php?gbID=1144&dt=190805151431',
#   'sex': '男性',
#   'age_exposure': '9',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.5km'},
#  {'name': '山本|信男',
#   'id': 608,
#   'slug': 'pic_syousai.php?gbID=705&dt=190805151431',
#   'sex': '男性',
#   'age_exposure': '23',
#   'exposure_pref': '広島',
#   'exposure_dist': '0.5km'},
#  {'name': '山本|登',
#   'id': 609,
#   'slug': 'pic_syousai.php?gbID=1038&dt=190805151431',
#   'sex': '男性',
#   'age_exposure': '11',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.0km'},
#  {'name': '山本|政子',
#   'id': 610,
#   'slug': 'pic_syousai.php?gbID=896&dt=190805151431',
#   'sex': '女性',
#   'age_exposure': '22',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.0km'},
#  {'name': '山本|真理子',
#   'id': 611,
#   'slug': 'pic_syousai.php?gbID=709&dt=190805151431',
#   'sex': '女性',
#   'age_exposure': '18',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.8km'},
#  {'name': '尹|壽基',
#   'id': 612,
#   'slug': 'pic_syousai.php?gbID=713&dt=190805151431',
#   'sex': '男性',
#   'age_exposure': '15',
#   'exposure_pref': '広島',
#   'exposure_dist': '2.0km'},
#  {'name': '横谷|アサエ',
#   'id': 613,
#   'slug': 'pic_syousai.php?gbID=714&dt=190805151431',
#   'sex': '女性',
#   'age_exposure': '18',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.5km'},
#  {'name': '横山|弘',
#   'id': 614,
#   'slug': 'pic_syousai.php?gbID=715&dt=190805151431',
#   'sex': '男性',
#   'age_exposure': '12',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.3km'},
#  {'name': '吉岡|泰志',
#   'id': 615,
#   'slug': 'pic_syousai.php?gbID=864&dt=190805151431',
#   'sex': '男性',
#   'age_exposure': '11',
#   'exposure_pref': '長崎',
#   'exposure_dist': '4.5km'},
#  {'name': '吉兼|実',
#   'id': 616,
#   'slug': 'pic_syousai.php?gbID=716&dt=190805151431',
#   'sex': '男性',
#   'age_exposure': '18',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '吉崎|幸恵',
#   'id': 617,
#   'slug': 'pic_syousai.php?gbID=717&dt=190805151431',
#   'sex': '女性',
#   'age_exposure': '5',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.5km'},
#  {'name': '吉田|勇',
#   'id': 618,
#   'slug': 'pic_syousai.php?gbID=784&dt=190805151431',
#   'sex': '男性',
#   'age_exposure': '12',
#   'exposure_pref': '長崎',
#   'exposure_dist': '4.2km'},
#  {'name': '吉田|一人',
#   'id': 619,
#   'slug': 'pic_syousai.php?gbID=718&dt=190805151431',
#   'sex': '男性',
#   'age_exposure': '13',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.5km'},
#  {'name': '吉田|勝二',
#   'id': 620,
#   'slug': 'pic_syousai.php?gbID=83&dt=190805151431',
#   'sex': '男性',
#   'age_exposure': '13',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.1km'},
#  {'name': '吉田|進',
#   'id': 621,
#   'slug': 'pic_syousai.php?gbID=835&dt=190805151432',
#   'sex': '男性',
#   'age_exposure': '13',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.0km'},
#  {'name': '吉田|恒雄',
#   'id': 622,
#   'slug': 'pic_syousai.php?gbID=792&dt=190805151432',
#   'sex': '男性',
#   'age_exposure': '15',
#   'exposure_pref': '長崎',
#   'exposure_dist': '3.5km'},
#  {'name': '吉冨|安美',
#   'id': 623,
#   'slug': 'pic_syousai.php?gbID=65&dt=190805151432',
#   'sex': '男性',
#   'age_exposure': '16',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.3km'},
#  {'name': '吉永|正子',
#   'id': 624,
#   'slug': 'pic_syousai.php?gbID=719&dt=190805151432',
#   'sex': '女性',
#   'age_exposure': '14',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.2km'},
#  {'name': '吉村|和弘',
#   'id': 625,
#   'slug': 'pic_syousai.php?gbID=720&dt=190805151432',
#   'sex': '男性',
#   'age_exposure': '4',
#   'exposure_pref': '長崎',
#   'exposure_dist': '5.0km'},
#  {'name': '吉本|桂三',
#   'id': 626,
#   'slug': 'pic_syousai.php?gbID=721&dt=190805151432',
#   'sex': '男性',
#   'age_exposure': '9',
#   'exposure_pref': '広島',
#   'exposure_dist': '3.0km'},
#  {'name': '四田|シズヨ',
#   'id': 627,
#   'slug': 'pic_syousai.php?gbID=131&dt=190805151432',
#   'sex': '女性',
#   'age_exposure': '26',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.0km'},
#  {'name': '与那嶺|浩',
#   'id': 628,
#   'slug': 'pic_syousai.php?gbID=66&dt=190805151432',
#   'sex': '男性',
#   'age_exposure': '17',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '米田|チヨノ',
#   'id': 629,
#   'slug': 'pic_syousai.php?gbID=722&dt=190805151432',
#   'sex': '女性',
#   'age_exposure': '18',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.0km'},
#  {'name': '米村|博臣',
#   'id': 630,
#   'slug': 'pic_syousai.php?gbID=795&dt=190805151432',
#   'sex': '男性',
#   'age_exposure': '20',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': 'ランメル|好村|幸',
#   'id': 631,
#   'slug': 'pic_syousai.php?gbID=723&dt=190805151432',
#   'sex': '女性',
#   'age_exposure': '8',
#   'exposure_pref': '広島',
#   'exposure_dist': '3.5km'},
#  {'name': '龍|智江子',
#   'id': 632,
#   'slug': 'pic_syousai.php?gbID=135&dt=190805151432',
#   'sex': '女性',
#   'age_exposure': '15',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.0km'},
#  {'name': '柳|秉文',
#   'id': 633,
#   'slug': 'pic_syousai.php?gbID=1214&dt=190805151432',
#   'sex': '男性',
#   'age_exposure': '0',
#   'exposure_pref': '広島',
#   'exposure_dist': '1.3km'},
#  {'name': '龍野|昭子',
#   'id': 634,
#   'slug': 'pic_syousai.php?gbID=724&dt=190805151432',
#   'sex': '女性',
#   'age_exposure': '1',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.8km'},
#  {'name': 'ローレンス 文雄 三輪',
#   'id': 635,
#   'slug': 'pic_syousai.php?gbID=1279&dt=190805151432',
#   'sex': '男性',
#   'age_exposure': '14',
#   'exposure_pref': '広島',
#   'exposure_dist': ''},
#  {'name': '渡邊|すが子',
#   'id': 636,
#   'slug': 'pic_syousai.php?gbID=842&dt=190805151432',
#   'sex': '女性',
#   'age_exposure': '11',
#   'exposure_pref': '長崎',
#   'exposure_dist': ''},
#  {'name': '渡辺|千恵子',
#   'id': 637,
#   'slug': 'pic_syousai.php?gbID=103&dt=190805151432',
#   'sex': '女性',
#   'age_exposure': '16',
#   'exposure_pref': '長崎',
#   'exposure_dist': '2.5km'},
#  {'name': '渡邉|司',
#   'id': 638,
#   'slug': 'pic_syousai.php?gbID=990&dt=190805151432',
#   'sex': '男性',
#   'age_exposure': '13',
#   'exposure_pref': '長崎',
#   'exposure_dist': '1.5km'}]

# %%
df_basic = pd.DataFrame(rows)
df_basic
# Out:
#     age_exposure exposure_dist exposure_pref   id          name sex  \
# 0              6         6.0km            広島    1  アイリーン|トモエ|平野  女性
# 1             20         2.2km            長崎    2          青木|茂  男性
# 2             23         1.8km            広島    3         青木|美枝  女性
# 3             21                          広島    4         赤名|正市  男性
# 4             29         1.8km            長崎    5        秋月|辰一郎  男性
# 5             14         3.2km            長崎    6         秋本|三郎  男性
# 6             16         3.5km            長崎    7         安里|盛繁  男性
# 7             13                          広島    8         朝比奈|隆  男性
# 8             19                          広島    9        阿部|磨智惠  女性
# 9             14                          広島   10         天野|文子  女性
# 10            14         2.2km            長崎   11         網谷|エイ  女性
# 11            19         2.2km            広島   12          荒井|彊  男性
# 12            23         1.8km            広島   13         新井|政子  女性
# 13            40         0.5km            長崎   14         荒川|秀男  男性
# 14            16         1.5km            広島   15         新垣|和子  女性
# 15            14         1.7km            広島   16         荒木|禮子  女性
# 16            17         1.8km            広島   17        荒田|千代子  女性
# 17            10         1.5km            広島   18         有田|卓司  男性
# 18            15         1.6km            広島   19          安|月嬋  女性
# 19            15         2.5km            広島   20          李|一守  女性
# 20             4         1.7km            広島   21          李|圭永  男性
# 21             7         1.8km            長崎   22          李|相必  女性
# 22            10         1.8km            長崎   23          李|相烈  男性
# 23            23                          広島   24         飯島|信一  男性
# 24            13         2.3km            長崎   25        飯田|マリ子  女性
# 25            17         3.5km            長崎   26         伊江|和夫  男性
# 26            13                          長崎   27          生島|渉  男性
# 27            16         2.0km            広島   28        生田|カツ子  女性
# 28            19         1.8km            広島   29         池田|武臣  男性
# 29             8         4.0km            長崎   30         池田|雅道  男性
# ..           ...           ...           ...  ...           ...  ..
# 608           11         2.0km            長崎  609          山本|登  男性
# 609           22         2.0km            長崎  610         山本|政子  女性
# 610           18         1.8km            広島  611        山本|真理子  女性
# 611           15         2.0km            広島  612          尹|壽基  男性
# 612           18         3.5km            長崎  613        横谷|アサエ  女性
# 613           12         1.3km            広島  614          横山|弘  男性
# 614           11         4.5km            長崎  615         吉岡|泰志  男性
# 615           18                          広島  616          吉兼|実  男性
# 616            5         3.5km            長崎  617         吉崎|幸恵  女性
# 617           12         4.2km            長崎  618          吉田|勇  男性
# 618           13         3.5km            長崎  619         吉田|一人  男性
# 619           13         1.1km            長崎  620         吉田|勝二  男性
# 620           13         3.0km            長崎  621          吉田|進  男性
# 621           15         3.5km            長崎  622         吉田|恒雄  男性
# 622           16         2.3km            長崎  623         吉冨|安美  男性
# 623           14         1.2km            長崎  624         吉永|正子  女性
# 624            4         5.0km            長崎  625         吉村|和弘  男性
# 625            9         3.0km            広島  626         吉本|桂三  男性
# 626           26         1.0km            長崎  627        四田|シズヨ  女性
# 627           17                          長崎  628         与那嶺|浩  男性
# 628           18         1.0km            長崎  629        米田|チヨノ  女性
# 629           20                          長崎  630         米村|博臣  男性
# 630            8         3.5km            広島  631     ランメル|好村|幸  女性
# 631           15         1.0km            長崎  632         龍|智江子  女性
# 632            0         1.3km            広島  633          柳|秉文  男性
# 633            1         1.8km            長崎  634         龍野|昭子  女性
# 634           14                          広島  635   ローレンス 文雄 三輪  男性
# 635           11                          長崎  636        渡邊|すが子  女性
# 636           16         2.5km            長崎  637        渡辺|千恵子  女性
# 637           13         1.5km            長崎  638          渡邉|司  男性
#
#                                           slug
# 0    pic_syousai.php?gbID=1280&dt=190805151358
# 1     pic_syousai.php?gbID=140&dt=190805151358
# 2     pic_syousai.php?gbID=141&dt=190805151358
# 3    pic_syousai.php?gbID=1130&dt=190805151358
# 4      pic_syousai.php?gbID=87&dt=190805151358
# 5     pic_syousai.php?gbID=847&dt=190805151358
# 6       pic_syousai.php?gbID=9&dt=190805151358
# 7    pic_syousai.php?gbID=1206&dt=190805151358
# 8    pic_syousai.php?gbID=1067&dt=190805151358
# 9     pic_syousai.php?gbID=142&dt=190805151358
# 10    pic_syousai.php?gbID=146&dt=190805151358
# 11    pic_syousai.php?gbID=150&dt=190805151358
# 12    pic_syousai.php?gbID=151&dt=190805151358
# 13     pic_syousai.php?gbID=91&dt=190805151358
# 14    pic_syousai.php?gbID=885&dt=190805151358
# 15    pic_syousai.php?gbID=155&dt=190805151358
# 16    pic_syousai.php?gbID=156&dt=190805151358
# 17   pic_syousai.php?gbID=1056&dt=190805151358
# 18    pic_syousai.php?gbID=157&dt=190805151358
# 19    pic_syousai.php?gbID=756&dt=190805151358
# 20   pic_syousai.php?gbID=1213&dt=190805151359
# 21    pic_syousai.php?gbID=919&dt=190805151359
# 22   pic_syousai.php?gbID=1070&dt=190805151359
# 23    pic_syousai.php?gbID=158&dt=190805151359
# 24    pic_syousai.php?gbID=159&dt=190805151359
# 25     pic_syousai.php?gbID=10&dt=190805151359
# 26    pic_syousai.php?gbID=160&dt=190805151359
# 27    pic_syousai.php?gbID=161&dt=190805151359
# 28   pic_syousai.php?gbID=1201&dt=190805151359
# 29    pic_syousai.php?gbID=900&dt=190805151359
# ..                                         ...
# 608  pic_syousai.php?gbID=1038&dt=190805151431
# 609   pic_syousai.php?gbID=896&dt=190805151431
# 610   pic_syousai.php?gbID=709&dt=190805151431
# 611   pic_syousai.php?gbID=713&dt=190805151431
# 612   pic_syousai.php?gbID=714&dt=190805151431
# 613   pic_syousai.php?gbID=715&dt=190805151431
# 614   pic_syousai.php?gbID=864&dt=190805151431
# 615   pic_syousai.php?gbID=716&dt=190805151431
# 616   pic_syousai.php?gbID=717&dt=190805151431
# 617   pic_syousai.php?gbID=784&dt=190805151431
# 618   pic_syousai.php?gbID=718&dt=190805151431
# 619    pic_syousai.php?gbID=83&dt=190805151431
# 620   pic_syousai.php?gbID=835&dt=190805151432
# 621   pic_syousai.php?gbID=792&dt=190805151432
# 622    pic_syousai.php?gbID=65&dt=190805151432
# 623   pic_syousai.php?gbID=719&dt=190805151432
# 624   pic_syousai.php?gbID=720&dt=190805151432
# 625   pic_syousai.php?gbID=721&dt=190805151432
# 626   pic_syousai.php?gbID=131&dt=190805151432
# 627    pic_syousai.php?gbID=66&dt=190805151432
# 628   pic_syousai.php?gbID=722&dt=190805151432
# 629   pic_syousai.php?gbID=795&dt=190805151432
# 630   pic_syousai.php?gbID=723&dt=190805151432
# 631   pic_syousai.php?gbID=135&dt=190805151432
# 632  pic_syousai.php?gbID=1214&dt=190805151432
# 633   pic_syousai.php?gbID=724&dt=190805151432
# 634  pic_syousai.php?gbID=1279&dt=190805151432
# 635   pic_syousai.php?gbID=842&dt=190805151432
# 636   pic_syousai.php?gbID=103&dt=190805151432
# 637   pic_syousai.php?gbID=990&dt=190805151432
#
# [638 rows x 7 columns]

# %%
df_basic.to_csv('data/survivors_globalpeace_bio_basic.csv', index=False)

# %% [markdown]
# # Scrape more data for each survivor

# %%
# Scrape details for one survivor
df_basic.slug[0]
url = main_url + survivor['slug']
response = requests.get(url)
response.encoding = 'utf-8'
doc = BeautifulSoup(response.text)

table = doc.find('table', bordercolor="#99CCFF")

name_kana = table.find_all('td')[0].text.split('（')[1].replace('\u3000','|').replace('）','')
age_production = table.find_all('td')[6].text.strip()
exposure_loc = table.find_all('td')[12].text.strip()
status_then = table.find_all('td')[14].text.strip()
status_then_detail = table.find_all('td')[16].text.strip().replace('\u3000','|')
record_location = table.find_all('td')[18].text.strip()

rows = []
row = {}
row['name_kana'] = table.find_all('td')[0].text.split('（')[1].replace('\u3000','|').replace('）','')
row['age_production'] = table.find_all('td')[6].text.strip()
row['exposure_loc'] = table.find_all('td')[12].text.strip()
row['status_then'] = table.find_all('td')[14].text.strip()
row['status_then_detail'] = table.find_all('td')[16].text.strip().replace('\u3000','|')
row['record_location'] = table.find_all('td')[18].text.strip()

rows.append(row)
rows
# Out:
# [{'name_kana': 'あいりーん|ともえ|ひらの',
#   'age_production': '2018年11月5日',
#   'exposure_loc': '広島市仁保町堀越［現：広島市南区（堀越）］',
#   'status_then': '児童',
#   'status_then_detail': '青崎国民学校|一年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館'}]

# %%
# Scrape details for ALL survivors in Global Peace databse

slugs = df_basic.slug
rows = []
errors = []

for slug in slugs:
    row = {}
    
    url = main_url + slug
    response = requests.get(url)
    response.encoding = 'utf-8'
    doc = BeautifulSoup(response.text)
    table = doc.find('table', bordercolor="#99CCFF")
    
    try:
        row['name_kana'] = table.find_all('td')[0].text.split('（')[1].replace('\u3000','|').replace('）','')
        row['age_production'] = table.find_all('td')[6].text.strip()
        row['exposure_loc'] = table.find_all('td')[12].text.strip()
        row['status_then'] = table.find_all('td')[14].text.strip()
        row['status_then_detail'] = table.find_all('td')[16].text.strip().replace('\u3000','|')
        row['record_location'] = table.find_all('td')[18].text.strip()
        row['slug'] = slug
    except:
        errors.append(slug)
    rows.append(row)
rows
# Out:
# [{'name_kana': 'あいりーん|ともえ|ひらの',
#   'age_production': '2018年11月5日',
#   'exposure_loc': '広島市仁保町堀越［現：広島市南区（堀越）］',
#   'status_then': '児童',
#   'status_then_detail': '青崎国民学校|一年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1280&dt=190805151358'},
#  {'name_kana': 'あおき|しげる',
#   'age_production': '2012年10月13日',
#   'exposure_loc': '長崎市東北郷[現在の長崎市]',
#   'status_then': '一般就業者',
#   'status_then_detail': '三菱重工㈱長崎兵器製作所',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=140&dt=190805151358'},
#  {'name_kana': 'あおき|みえ',
#   'age_production': '2006年9月30日',
#   'exposure_loc': '広島市平野町[現：広島市中区平野町]',
#   'status_then': '',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=141&dt=190805151358'},
#  {'name_kana': 'あかな|しょういち',
#   'age_production': '2016年10月3日',
#   'exposure_loc': '',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '中国軍管区歩兵第２補充隊（中国第106部隊）|兵長',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1130&dt=190805151358'},
#  {'name_kana': 'あきづき|たついちろう',
#   'age_production': '1990年9月1日',
#   'exposure_loc': '浦上第一病院(長崎市本原町二丁目[現：長崎市小峰町])',
#   'status_then': '医療従事者',
#   'status_then_detail': '浦上第一病院',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=87&dt=190805151358'},
#  {'name_kana': 'あきもと|さぶろう',
#   'age_production': '2013年2月13日',
#   'exposure_loc': '長崎市築町[現：長崎市築町]',
#   'status_then': '一般就業者',
#   'status_then_detail': '長崎電気通信工事局',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=847&dt=190805151358'},
#  {'name_kana': 'あさと|せいはん',
#   'age_production': '2012年1月28日',
#   'exposure_loc': '三菱重工業㈱長崎造船所(長崎市)',
#   'status_then': '生徒・学生',
#   'status_then_detail': '三菱長崎工業青年学校',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=9&dt=190805151358'},
#  {'name_kana': 'あさひな|たかし',
#   'age_production': '2017年10月18日',
#   'exposure_loc': '',
#   'status_then': '生徒・学生',
#   'status_then_detail': '広島市立中学校',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1206&dt=190805151358'},
#  {'name_kana': 'あべ|まちえ',
#   'age_production': '2015年10月7日',
#   'exposure_loc': '',
#   'status_then': '医療従事者',
#   'status_then_detail': '日立造船(株) 因島病院',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1067&dt=190805151358'},
#  {'name_kana': 'あまの|ふみこ',
#   'age_production': '2011年10月18日',
#   'exposure_loc': '',
#   'status_then': '生徒・学生',
#   'status_then_detail': '広島県海田高等女学校|３年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=142&dt=190805151358'},
#  {'name_kana': 'あみや|えい',
#   'age_production': '2004年',
#   'exposure_loc': '長崎市(稲佐町)[現：長崎市]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '常清高等実践女学校|３年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=146&dt=190805151358'},
#  {'name_kana': 'あらい|きょう',
#   'age_production': '2013年10月10日',
#   'exposure_loc': '広島市皆実町二丁目[現：広島市南区]',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '大本営陸軍部船舶司令部教育船舶兵団船舶通信隊補充隊（暁第16710部隊）',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=150&dt=190805151358'},
#  {'name_kana': 'あらい|まさこ',
#   'age_production': '2006年9月29日',
#   'exposure_loc': '広島市舟入川口町[現：広島市中区舟入川口町]',
#   'status_then': '主婦',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=151&dt=190805151358'},
#  {'name_kana': 'あらかわ|ひでお',
#   'age_production': '1990年7月1日',
#   'exposure_loc': '城山国民学校(長崎市城山町一丁目[現:長崎市城山町])',
#   'status_then': '教師',
#   'status_then_detail': '城山国民学校',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=91&dt=190805151358'},
#  {'name_kana': 'あらがき|かずこ',
#   'age_production': '2013年2月19日',
#   'exposure_loc': '広島赤十字病院（広島市千田町一丁目[現：広島市中区千田町一丁目]）',
#   'status_then': '生徒・学生',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=885&dt=190805151358'},
#  {'name_kana': 'あらき|れいこ',
#   'age_production': '2012年10月27日',
#   'exposure_loc': '広島市松原町',
#   'status_then': '生徒・学生',
#   'status_then_detail': '広島市立第一高等女学校|２年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=155&dt=190805151358'},
#  {'name_kana': 'あらた|ちよこ',
#   'age_production': '2003年12月11日',
#   'exposure_loc': '広島市（千田）[現：広島市中区]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '日本赤十字社広島支部病院救護看護婦養成所|2年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=156&dt=190805151358'},
#  {'name_kana': 'ありた|たくじ',
#   'age_production': '2015年9月18日',
#   'exposure_loc': '広島市稲荷町[現：広島市南区稲荷町]',
#   'status_then': '児童',
#   'status_then_detail': '段原国民学校|５年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1056&dt=190805151358'},
#  {'name_kana': 'あん|おるそん',
#   'age_production': '2013年11月26日',
#   'exposure_loc': '広島市吉島町[現：広島市中区]',
#   'status_then': '一般就業者',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=157&dt=190805151358'},
#  {'name_kana': 'い|いるす',
#   'age_production': '2014年11月25日',
#   'exposure_loc': '広島市西蟹屋町［現：広島市南区］',
#   'status_then': '一般就業者',
#   'status_then_detail': '東洋工業（株）',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=756&dt=190805151358'},
#  {'name_kana': 'い|ぎゅよん',
#   'age_production': '2017年9月6日',
#   'exposure_loc': '広島市西観音町二丁目[現：広島市西区]',
#   'status_then': '乳幼児',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1213&dt=190805151359'},
#  {'name_kana': 'い|さんぴる',
#   'age_production': '2014年11月27日',
#   'exposure_loc': '長崎市東北郷[現：長崎市]',
#   'status_then': '乳幼児',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=919&dt=190805151359'},
#  {'name_kana': 'い|さんよる',
#   'age_production': '2015年11月10日',
#   'exposure_loc': '長崎市東北郷[現：長崎市住吉町]',
#   'status_then': '児童',
#   'status_then_detail': '西浦上国民学校 5年生',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1070&dt=190805151359'},
#  {'name_kana': 'いいじま|しんいち',
#   'age_production': '2012年10月11日',
#   'exposure_loc': '',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=158&dt=190805151359'},
#  {'name_kana': 'いいだ|まりこ',
#   'age_production': '2006年10月4日',
#   'exposure_loc': '長崎市立山町[現：長崎市]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '長崎県立長崎高等女学校',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=159&dt=190805151359'},
#  {'name_kana': 'いえ|かずお',
#   'age_production': '2012年1月26日',
#   'exposure_loc': '三菱重工業㈱長崎造船所 飽の浦工場(長崎市（飽ノ浦町）[現：長崎市])',
#   'status_then': '一般就業者',
#   'status_then_detail': '三菱重工業㈱長崎造船所',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=10&dt=190805151359'},
#  {'name_kana': 'いくしま|わたる',
#   'age_production': '2006年10月2日',
#   'exposure_loc': '',
#   'status_then': '生徒・学生',
#   'status_then_detail': '長崎県立長崎工業学校|航空科|1年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=160&dt=190805151359'},
#  {'name_kana': 'いくた|かつこ',
#   'age_production': '2004年',
#   'exposure_loc': '広島市（千田）[現：広島市中区]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '日本赤十字社広島支部病院救護看護婦養成所|1年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=161&dt=190805151359'},
#  {'name_kana': 'いけだ|たけおみ',
#   'age_production': '2017年9月27日',
#   'exposure_loc': '広島市皆実町一丁目［現：広島市南区皆実町一丁目］',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '大本営陸軍部船舶司令部教育船舶兵団船舶通信隊補充隊（暁第16710部隊）',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1201&dt=190805151359'},
#  {'name_kana': 'いけだ|まさみち',
#   'age_production': '2015年2月2日',
#   'exposure_loc': '長崎市稲田町[現：長崎市稲田町]',
#   'status_then': '児童',
#   'status_then_detail': '仁田国民学校',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=900&dt=190805151359'},
#  {'name_kana': 'いけだ|まつよし',
#   'age_production': '2010年2月14日',
#   'exposure_loc': '長崎市城山町一丁目[現：長崎市城栄町]',
#   'status_then': '児童',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=817&dt=190805151359'},
#  {'name_kana': 'いけだ|みちあき',
#   'age_production': '2006年7月8日',
#   'exposure_loc': '長崎医科大学附属病院（長崎市坂本町[現：長崎市坂本一丁目]）',
#   'status_then': '児童',
#   'status_then_detail': '山里国民学校',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=765&dt=190805151359'},
#  {'name_kana': 'いけだ|みのる',
#   'age_production': '2011年12月13日',
#   'exposure_loc': '',
#   'status_then': '生徒・学生',
#   'status_then_detail': '長崎造船専門学校',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=11&dt=190805151359'},
#  {'name_kana': 'いしい|ただあき',
#   'age_production': '2013年10月8日',
#   'exposure_loc': '',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '大本営陸軍部船舶司令部船舶練習部第10教育隊',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=165&dt=190805151359'},
#  {'name_kana': 'いしかわ|げんに',
#   'age_production': '2013年2月20日',
#   'exposure_loc': '',
#   'status_then': '一般就業者',
#   'status_then_detail': '川南工業(株)香焼島造船所',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=883&dt=190805151359'},
#  {'name_kana': 'いしかわ|わたる',
#   'age_production': '2005年10月12日',
#   'exposure_loc': '船舶通信隊補充隊(暁第16710部隊)(広島市皆実町一丁目[現：広島市南区])',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '大本営陸軍部船舶司令部教育船舶兵団船舶通信隊補充隊（暁第16710部隊）',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=166&dt=190805151359'},
#  {'name_kana': 'いずみ|いさむ',
#   'age_production': '2015年1月14日',
#   'exposure_loc': '長崎市桜馬場町[現：長崎市]',
#   'status_then': '児童',
#   'status_then_detail': '勝山国民学校 6年生',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=908&dt=190805151359'},
#  {'name_kana': 'いだに|しゅういち',
#   'age_production': '2009年11月5日',
#   'exposure_loc': '広島市堀川町[現：広島市中区]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '鳥取第一中学校',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=170&dt=190805151359'},
#  {'name_kana': 'いちかわ|しづえ',
#   'age_production': '2016年10月12日',
#   'exposure_loc': '長崎市片淵町三丁目[現：長崎市(片淵)]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '長崎県立長崎高等女学校3年生',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1143&dt=190805151359'},
#  {'name_kana': 'いちはら|けんじろう',
#   'age_production': '2012年10月13日',
#   'exposure_loc': '長崎市滑石郷[現：長崎市]',
#   'status_then': '児童',
#   'status_then_detail': '西浦上国民学校|3年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=171&dt=190805151359'},
#  {'name_kana': 'いちはら|だいすけ',
#   'age_production': '2005年11月16日',
#   'exposure_loc': '広島市松原町[現：広島市南区松原町]',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '中国憲兵隊|広島憲兵分隊',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=172&dt=190805151400'},
#  {'name_kana': 'いちば|もとき',
#   'age_production': '2006年11月19日',
#   'exposure_loc': '官立長崎師範学校（長崎市家野郷[現：長崎市文教町]）',
#   'status_then': '生徒・学生',
#   'status_then_detail': '長崎師範学校 予科 1年生',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=772&dt=190805151400'},
#  {'name_kana': 'いとう|あきら',
#   'age_production': '2005年11月14日',
#   'exposure_loc': '広島市（千田）[現：広島市中区]-電車',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '大本営陸軍部船舶司令部教育船舶兵団船舶通信隊補充隊（暁第16710部隊）',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=173&dt=190805151400'},
#  {'name_kana': 'いとう|たけはる',
#   'age_production': '2014年3月5日',
#   'exposure_loc': '長崎市館内町[現：長崎市館内町]',
#   'status_then': '乳幼児',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=891&dt=190805151400'},
#  {'name_kana': 'いとう|のぶお',
#   'age_production': '2013年10月12日',
#   'exposure_loc': '広島市宇品町[現：広島市南区]',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '大本営陸軍部船舶司令部教育船舶兵団船舶通信隊補充隊（暁第16710部隊）',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=174&dt=190805151400'},
#  {'name_kana': 'いとう|まさひろ',
#   'age_production': '2011年9月28日',
#   'exposure_loc': '',
#   'status_then': '児童',
#   'status_then_detail': '田結村国民学校|5年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=175&dt=190805151400'},
#  {'name_kana': 'いとう|みよこ',
#   'age_production': '2016年9月15日',
#   'exposure_loc': '',
#   'status_then': '生徒・学生',
#   'status_then_detail': '山口師範学校|予科|2年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1125&dt=190805151400'},
#  {'name_kana': 'いとざわ|さだお',
#   'age_production': '2017年9月25日',
#   'exposure_loc': '',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '大本営陸軍部船舶司令部船舶練習部第10教育隊',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1199&dt=190805151400'},
#  {'name_kana': 'いのうえ|そうざえもん',
#   'age_production': '2018年12月6日',
#   'exposure_loc': '',
#   'status_then': '生徒・学生',
#   'status_then_detail': '第五高等学校|２年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1292&dt=190805151400'},
#  {'name_kana': 'いのうえ|つとむ',
#   'age_production': '2007年1月20日',
#   'exposure_loc': '長崎市大浦出雲町[現：長崎市上田町]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '海星中学校 4年生',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=780&dt=190805151400'},
#  {'name_kana': 'いのうえ|みのる',
#   'age_production': '2003年10月28日',
#   'exposure_loc': '広島市東蟹屋町[現：広島市南区]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '広島高等師範学校',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=176&dt=190805151400'},
#  {'name_kana': 'いはら|とよかず',
#   'age_production': '2010年10月21日',
#   'exposure_loc': '西彼杵郡矢上村田中名薩摩城[現：長崎市田中町]',
#   'status_then': '児童',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=826&dt=190805151400'},
#  {'name_kana': 'いまいずみ|かずえ',
#   'age_production': '2005年12月5日',
#   'exposure_loc': '広島市小網町[現：広島市中区]',
#   'status_then': '一般就業者',
#   'status_then_detail': '三菱重工㈱第20製作所',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=177&dt=190805151400'},
#  {'name_kana': 'いまみち|しのぶ',
#   'age_production': '2009年12月9日',
#   'exposure_loc': '長崎市西泊町[現：長崎市西泊町]',
#   'status_then': '児童',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=813&dt=190805151400'},
#  {'name_kana': 'いもり|きよこ',
#   'age_production': '2006年9月28日',
#   'exposure_loc': '広島市鍛冶屋町[現：広島市中区]',
#   'status_then': '児童',
#   'status_then_detail': '本川国民学校',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=181&dt=190805151400'},
#  {'name_kana': 'いもり|よしなり',
#   'age_production': '2005年11月18日',
#   'exposure_loc': '三菱重工業㈱広島機械製作所(広島市南観音町[現：広島市西区観音新町四丁目])',
#   'status_then': '生徒・学生',
#   'status_then_detail': '広島県立広島工業学校|機械科|2年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=182&dt=190805151400'},
#  {'name_kana': 'いわなが|ふみこ',
#   'age_production': '2013年3月7日',
#   'exposure_loc': '長崎市東立神町[現：長崎市東立神町]',
#   'status_then': '乳幼児',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=859&dt=190805151400'},
#  {'name_kana': 'いわの|きくこ',
#   'age_production': '2011年11月24日',
#   'exposure_loc': '長崎市東上町[現：長崎市上町]',
#   'status_then': '児童',
#   'status_then_detail': '磨屋国民学校5年生',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=12&dt=190805151400'},
#  {'name_kana': 'いわの|ひさお',
#   'age_production': '2011年11月24日',
#   'exposure_loc': '長崎市西泊町[現：長崎市西泊町]',
#   'status_then': '児童',
#   'status_then_detail': '立神国民学校4年生',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=13&dt=190805151400'},
#  {'name_kana': 'いわはし|やえこ',
#   'age_production': '2015年9月25日',
#   'exposure_loc': '長崎市城山町二丁目[現：長崎市立岩町]',
#   'status_then': '',
#   'status_then_detail': '家事手伝い',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1040&dt=190805151400'},
#  {'name_kana': 'いわもと|いほえ',
#   'age_production': '2010年11月24日',
#   'exposure_loc': '三菱重工業㈱長崎兵器製作所 住吉寮(長崎市東北郷[現：長崎市住吉町])',
#   'status_then': '一般就業者',
#   'status_then_detail': '奄美大島女子挺身隊 三菱重工業株式会社長崎兵器製作所 住吉トンネル工場（赤迫トンネル工場）',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=832&dt=190805151403'},
#  {'name_kana': 'いわもと|じゅんこ',
#   'age_production': '2013年2月7日',
#   'exposure_loc': '長崎市上郷[現：長崎市上戸町]',
#   'status_then': '児童',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=867&dt=190805151403'},
#  {'name_kana': 'いわもと|ちえこ',
#   'age_production': '2013年3月8日',
#   'exposure_loc': '長崎市（銭座町）[現：長崎市]',
#   'status_then': '児童',
#   'status_then_detail': '銭座国民学校 1年生',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=863&dt=190805151403'},
#  {'name_kana': 'いわもと|ふくこ',
#   'age_production': '2012年9月26日',
#   'exposure_loc': '長崎市上西山町[現：長崎市上西山町]',
#   'status_then': '一般就業者',
#   'status_then_detail': '三菱製鋼(株)長崎製鋼所 旋盤工場 補助員',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=860&dt=190805151403'},
#  {'name_kana': 'いんとう|ふくいち',
#   'age_production': '2003年10月7日',
#   'exposure_loc': '広島市仁保町向洋[現：広島市南区(向洋町)]',
#   'status_then': '公務員',
#   'status_then_detail': '運輸省広島鉄道局|広島鉄道教習所|広島技能者養成所',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=186&dt=190805151403'},
#  {'name_kana': 'うえしま|とみた',
#   'age_production': '2010年11月16日',
#   'exposure_loc': '',
#   'status_then': '生徒・学生',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=825&dt=190805151403'},
#  {'name_kana': 'うえすぎ|たくすけ',
#   'age_production': '2003年10月8日',
#   'exposure_loc': '',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '航空総軍大阪陸軍航空補給廠宇品出張所（師第34209部隊）',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=187&dt=190805151403'},
#  {'name_kana': 'うえだ|とおる',
#   'age_production': '2013年2月',
#   'exposure_loc': '長崎市上筑後町[現：長崎市玉園町]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '長崎県立長崎中学校 2年生',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=848&dt=190805151403'},
#  {'name_kana': 'うえの|かつひこ',
#   'age_production': '2016年9月27日',
#   'exposure_loc': '広島市東千田町[現：広島市中区]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '広島高等師範学校付属中学校|1年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1128&dt=190805151403'},
#  {'name_kana': 'うえの|よしこ',
#   'age_production': '2013年1月30日',
#   'exposure_loc': '広島赤十字病院（広島市千田町一丁目[現：広島市中区千田町一丁目]）',
#   'status_then': '医療従事者',
#   'status_then_detail': '広島赤十字病院 看護学校',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=880&dt=190805151403'},
#  {'name_kana': 'うえむら|しげお',
#   'age_production': '2017年10月20日',
#   'exposure_loc': '三菱重工業(株)長崎造船所 幸町工場(長崎市幸町[現：長崎市幸町])',
#   'status_then': '生徒・学生',
#   'status_then_detail': '三菱青年学校(三菱重工業(株)長崎造船所 製缶工場)',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1227&dt=190805151403'},
#  {'name_kana': 'うえむら|すえひこ',
#   'age_production': '2003年11月5日',
#   'exposure_loc': '船舶通信隊補充隊(暁第16710部隊)(広島市皆実町一丁目[現：広島市南区])',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '大本営陸軍部船舶司令部教育船舶兵団船舶通信隊補充隊（暁第16710部隊）',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=191&dt=190805151403'},
#  {'name_kana': 'うき|あきら',
#   'age_production': '2006年11月19日',
#   'exposure_loc': '西彼杵郡時津村浜田郷[現：西彼杵郡時津町浜田郷]',
#   'status_then': '児童',
#   'status_then_detail': '時津国民学校',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=773&dt=190805151403'},
#  {'name_kana': 'うちだ|えいいち',
#   'age_production': '2004年',
#   'exposure_loc': '広島第1陸軍病院(広島市基町[現：広島市中区基町])',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '第2総軍15方面軍広島第1陸軍病院',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=192&dt=190805151403'},
#  {'name_kana': 'うちの|せつお',
#   'age_production': '2014年3月3日',
#   'exposure_loc': '長崎市御船蔵町[現：長崎市御船蔵町]',
#   'status_then': '乳幼児',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=892&dt=190805151403'},
#  {'name_kana': 'うちやま|まもる',
#   'age_production': '2012年10月11日',
#   'exposure_loc': '広島市（皆実町）[現：広島市南区]',
#   'status_then': '児童',
#   'status_then_detail': '皆実国民学校|6年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=196&dt=190805151403'},
#  {'name_kana': 'うね|としえ',
#   'age_production': '1992年8月',
#   'exposure_loc': '広島陸軍兵器補給廠(広島市霞町[現：広島市南区霞一丁目])',
#   'status_then': '教師',
#   'status_then_detail': '陸軍兵器行政本部広島陸軍兵器補給廠',
#   'record_location': '広島平和記念資料館',
#   'slug': 'pic_syousai.php?gbID=197&dt=190805151403'},
#  {'name_kana': 'うめおか|あきお',
#   'age_production': '2004年',
#   'exposure_loc': '広島市江波町[現：広島市中区]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '修道中学校|4年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=198&dt=190805151403'},
#  {'name_kana': 'うめじ|せつこ',
#   'age_production': '2015年9月18日',
#   'exposure_loc': '広島市鶴見町[現：広島市中区鶴見町]',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '広島陸軍糧秣支廠',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1057&dt=190805151403'},
#  {'name_kana': 'うら|よしぞう',
#   'age_production': '2006年9月29日',
#   'exposure_loc': '広島市皆実町一丁目[現：広島市南区皆実町一丁目]',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=199&dt=190805151403'},
#  {'name_kana': 'うらかみ|ふくみ',
#   'age_production': '2012年9月25日',
#   'exposure_loc': '長崎市西小島町[現：長崎市（西小島）]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '九州簿記学校 1年生',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=856&dt=190805151404'},
#  {'name_kana': 'うらた|まさと',
#   'age_production': '2006年10月5日',
#   'exposure_loc': '長崎市(伊良林町)[現：長崎市]',
#   'status_then': '児童',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=201&dt=190805151404'},
#  {'name_kana': 'うらた|まさのり',
#   'age_production': '2009年11月6日',
#   'exposure_loc': '比治山',
#   'status_then': '生徒・学生',
#   'status_then_detail': '松本工業学校',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=202&dt=190805151404'},
#  {'name_kana': 'うらだ|ひろし',
#   'age_production': '2004年',
#   'exposure_loc': '広島市(皆実町)[現：広島市南区]',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '大本営陸軍部船舶司令部教育船舶兵団船舶通信隊補充隊（暁第16710部隊）',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=200&dt=190805151404'},
#  {'name_kana': 'えがしら|ちよこ',
#   'age_production': '1990年11月1日',
#   'exposure_loc': '三菱重工業㈱長崎兵器製作所 大橋工場(長崎市大橋町[現：長崎市文教町])',
#   'status_then': '教師',
#   'status_then_detail': '城山国民学校',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=107&dt=190805151404'},
#  {'name_kana': 'えんどう|けんいち',
#   'age_production': '2004年9月',
#   'exposure_loc': '広島第2陸軍病院(広島市基町[現：広島市中区基町])',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '大本営陸軍部船舶司令部教育船舶兵団船舶通信隊補充隊（暁第16710部隊）',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=203&dt=190805151404'},
#  {'name_kana': 'えんどう|とめお',
#   'age_production': '2005年12月1日',
#   'exposure_loc': '広島市（横川町）[現：広島市西区]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '山陽中学校',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=207&dt=190805151404'},
#  {'name_kana': 'えんどう|まさひろ',
#   'age_production': '2005年10月17日',
#   'exposure_loc': '広島第2陸軍病院 三滝分院(広島市三滝町[現在の広島市西区])',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=208&dt=190805151404'},
#  {'name_kana': 'お|そっこん',
#   'age_production': '2014年11月26日',
#   'exposure_loc': '',
#   'status_then': '児童',
#   'status_then_detail': '伴国民学校６年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=758&dt=190805151404'},
#  {'name_kana': 'おおいし|はれみ',
#   'age_production': '2009年11月24日',
#   'exposure_loc': '広島市尾長町[現：広島市東区]',
#   'status_then': '主婦',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=212&dt=190805151404'},
#  {'name_kana': 'おおいわ|こうへい',
#   'age_production': '2011年9月29日',
#   'exposure_loc': '広島市段原中町[現：広島市南区]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '中学校|1年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=216&dt=190805151404'},
#  {'name_kana': 'おおこし|しみえ',
#   'age_production': '2004年',
#   'exposure_loc': '長崎市水ノ浦町[現：長崎市]',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '海軍艦政本部|福岡海軍監督官事務所|長崎出張所',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=217&dt=190805151404'},
#  {'name_kana': 'おおさか|ごうぞう',
#   'age_production': '2013年10月17日',
#   'exposure_loc': '広島市皆実町一丁目[現：広島市南区]',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '大本営陸軍部船舶司令部教育船舶兵団船舶通信隊補充隊（暁第16710部隊）',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=218&dt=190805151404'},
#  {'name_kana': 'おおした|みつ',
#   'age_production': '2010年11月30日',
#   'exposure_loc': '',
#   'status_then': '医療従事者',
#   'status_then_detail': '海軍総隊佐世保鎮守府大村海軍病院',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=219&dt=190805151404'},
#  {'name_kana': 'おおせ|さだお',
#   'age_production': '2010年10月27日',
#   'exposure_loc': '',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '大本営陸軍部船舶司令部船舶衛生隊本部（暁第6177部隊）',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=220&dt=190805151404'},
#  {'name_kana': 'おおつか|かずとし',
#   'age_production': '2011年1月19日',
#   'exposure_loc': '新興善国民学校(長崎市興善町[現：長崎市興善町])',
#   'status_then': '児童',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=827&dt=190805151404'},
#  {'name_kana': 'おおに|やすお',
#   'age_production': '2005年11月15日',
#   'exposure_loc': '',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '大本営陸軍部船舶司令部船舶練習部第10教育隊海上挺進第42戦隊（暁第19857部隊）',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=221&dt=190805151404'},
#  {'name_kana': 'おおの|れいこ',
#   'age_production': '2017年10月19日',
#   'exposure_loc': '長崎市(飽ノ浦町)[現：長崎市]',
#   'status_then': '児童',
#   'status_then_detail': '飽浦国民学校 5年生',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1225&dt=190805151404'},
#  {'name_kana': 'おおふじ|としえ',
#   'age_production': '2005年11月20日',
#   'exposure_loc': '',
#   'status_then': '主婦',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=222&dt=190805151404'},
#  {'name_kana': 'おおむら|かずお',
#   'age_production': '2018年9月29日',
#   'exposure_loc': '白島中町［現：広島市中区］',
#   'status_then': '乳幼児',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1287&dt=190805151404'},
#  {'name_kana': 'おおもと|りゅうけい',
#   'age_production': '2006年10月2日',
#   'exposure_loc': '広島市(観音)[現：広島市西区]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=223&dt=190805151405'},
#  {'name_kana': 'おか|のぶこ',
#   'age_production': '2009年2月27日',
#   'exposure_loc': '長崎市東北郷[現：長崎市住吉町]',
#   'status_then': '医療従事者',
#   'status_then_detail': '大阪赤十字病院',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=793&dt=190805151405'},
#  {'name_kana': 'おかだ|たけこ',
#   'age_production': '2013年10月9日',
#   'exposure_loc': '',
#   'status_then': '生徒・学生',
#   'status_then_detail': '広島実践高等女学校',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=224&dt=190805151405'},
#  {'name_kana': 'おかだ|みのる',
#   'age_production': '2013年1月17日',
#   'exposure_loc': '広島市宇品町[現：広島市南区]',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '大本営陸軍部船舶司令部船舶練習部 輸送隊',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=876&dt=190805151405'},
#  {'name_kana': 'おかべ|とみこ',
#   'age_production': '2004年',
#   'exposure_loc': '広島市(三篠)[現在の広島市西区]',
#   'status_then': '',
#   'status_then_detail': '挺身隊',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=225&dt=190805151405'},
#  {'name_kana': 'おかべ|よしこ',
#   'age_production': '2005年12月2日',
#   'exposure_loc': '広島市松原町',
#   'status_then': '生徒・学生',
#   'status_then_detail': '広島女学院高等女学校',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=229&dt=190805151405'},
#  {'name_kana': 'おかむら|しょうざぶろう',
#   'age_production': '2005年12月5日',
#   'exposure_loc': '広島市西天満町[現：広島市西区]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '京都帝国大学',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=233&dt=190805151405'},
#  {'name_kana': 'おかもと|さだのり',
#   'age_production': '2011年11月15日',
#   'exposure_loc': '三菱重工業㈱長崎兵器製作所 大橋工場(長崎市大橋町[現：長崎市文教町])',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '海軍総隊佐世保鎮守府佐世保海兵団',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=14&dt=190805151405'},
#  {'name_kana': 'おがさわら|さだお',
#   'age_production': '2016年9月15日',
#   'exposure_loc': '',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '広島陸軍被服支廠',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1126&dt=190805151405'},
#  {'name_kana': 'おがた|さとる',
#   'age_production': '2017年11月28日',
#   'exposure_loc': '長崎市今籠町[現：長崎市鍛冶屋町]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '海星中学校 2年生',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1218&dt=190805151405'},
#  {'name_kana': 'おがわ|ともひろ',
#   'age_production': '2010年10月26日',
#   'exposure_loc': '広島市牛田町[現：広島市東区]',
#   'status_then': '児童',
#   'status_then_detail': '広島高等師範学校附属国民学校',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=234&dt=190805151405'},
#  {'name_kana': 'おきもと|みつこ',
#   'age_production': '2011年10月20日',
#   'exposure_loc': '誉航空軽合金(広島市楠木町三丁目[現：広島市西区楠木町三丁目])',
#   'status_then': '生徒・学生',
#   'status_then_detail': '安田高等女学校',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=235&dt=190805151405'},
#  {'name_kana': 'おくじょう|かずみ',
#   'age_production': '2003年12月10日',
#   'exposure_loc': '長崎市中川町[現：長崎市(中川)]',
#   'status_then': '児童',
#   'status_then_detail': '国民学校|3年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=236&dt=190805151405'},
#  {'name_kana': 'おくたに|みえこ',
#   'age_production': '2004年',
#   'exposure_loc': '',
#   'status_then': '医療従事者',
#   'status_then_detail': '海軍総隊舞鶴鎮守府舞鶴海軍病院鳥取赤十字病院',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=240&dt=190805151405'},
#  {'name_kana': 'おくだ|しずお',
#   'age_production': '2010年11月23日',
#   'exposure_loc': '三菱重工業(株)長崎造船所 飽の浦工場(長崎市（飽ノ浦町）[現：長崎市])',
#   'status_then': '一般就業者',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=830&dt=190805151405'},
#  {'name_kana': 'おくだ|とよじ',
#   'age_production': '2018年12月7日',
#   'exposure_loc': '',
#   'status_then': '生徒・学生',
#   'status_then_detail': '山口県立豊浦中学校|４年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1293&dt=190805151405'},
#  {'name_kana': 'おくだ|はぎこ',
#   'age_production': '2018年12月8日',
#   'exposure_loc': '長崎市（飽の浦町）［長崎市］',
#   'status_then': '',
#   'status_then_detail': '女子挺身隊',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1304&dt=190805151405'},
#  {'name_kana': 'おくむら|えいじ',
#   'age_production': '2011年11月15日',
#   'exposure_loc': '',
#   'status_then': '乳幼児',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=15&dt=190805151405'},
#  {'name_kana': 'おけた|いわお',
#   'age_production': '2017年9月29日',
#   'exposure_loc': '',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '賀茂海軍衛生学校',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1203&dt=190805151405'},
#  {'name_kana': 'おざき|とうめい',
#   'age_production': '1998年10月26日',
#   'exposure_loc': '三菱重工業(株)長崎兵器製作所 住吉トンネル工場(赤迫トンネル工場)(長崎市[現:長崎市])',
#   'status_then': '一般就業者',
#   'status_then_detail': '聖母の騎士修道院',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=111&dt=190805151405'},
#  {'name_kana': 'おざき|まさよし',
#   'age_production': '2010年7月16日',
#   'exposure_loc': '',
#   'status_then': '生徒・学生',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=820&dt=190805151406'},
#  {'name_kana': 'おだなか|さちこ',
#   'age_production': '2011年11月17日',
#   'exposure_loc': '長崎市愛宕町[現：長崎市]',
#   'status_then': '児童',
#   'status_then_detail': '国民学校|2年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=244&dt=190805151406'},
#  {'name_kana': 'おち|はるこ',
#   'age_production': '2006年9月5日',
#   'exposure_loc': '広島市千田町一丁目(現：広島市中区千田町一丁目)',
#   'status_then': '主婦',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=245&dt=190805151406'},
#  {'name_kana': 'おちあい|すえじろう',
#   'age_production': '2013年10月17日',
#   'exposure_loc': '広島市皆実町一丁目[現：広島市南区]',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '大本営陸軍部船舶司令部教育船舶兵団船舶通信隊補充隊（暁第16710部隊）',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=249&dt=190805151406'},
#  {'name_kana': 'おにづか|くにひこ',
#   'age_production': '2011年11月19日',
#   'exposure_loc': '長崎市大黒町[現：長崎市大黒町]',
#   'status_then': '一般就業者',
#   'status_then_detail': '運輸省福岡管区気象台 長崎測候所',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=16&dt=190805151406'},
#  {'name_kana': 'おぬか|まさみ',
#   'age_production': '1992年8月',
#   'exposure_loc': '広島市宇品町[現：広島市南区]',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '大本営陸軍部船舶司令部',
#   'record_location': '広島平和記念資料館',
#   'slug': 'pic_syousai.php?gbID=250&dt=190805151406'},
#  {'name_kana': 'おの|みほ',
#   'age_production': '2012年10月26日',
#   'exposure_loc': '',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '海軍総隊佐世保鎮守府第21海軍航空廠|総務部',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=251&dt=190805151406'},
#  {'name_kana': 'おのざき|あさじ',
#   'age_production': '2017年9月26日',
#   'exposure_loc': '',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1200&dt=190805151406'},
#  {'name_kana': 'おやま|はるお',
#   'age_production': '2005年10月19日',
#   'exposure_loc': '南観音町総合グランド(広島市南観音町[現：広島市西区])',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '大本営陸軍部船舶司令部船舶砲兵団船舶砲兵第1連隊（暁第2953部隊）',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=252&dt=190805151406'},
#  {'name_kana': 'おりた|さち',
#   'age_production': '2010年11月25日',
#   'exposure_loc': '三菱重工業(株)長崎兵器製作所 大橋工場(長崎市大橋町[現：長崎市文教町])',
#   'status_then': '',
#   'status_then_detail': '奄美大島女子挺身隊 三菱重工業(株)長崎兵器製作所 大橋工場',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=833&dt=190805151406'},
#  {'name_kana': 'おりめん|しげこ',
#   'age_production': '1990年8月',
#   'exposure_loc': '',
#   'status_then': '主婦',
#   'status_then_detail': '',
#   'record_location': '広島平和記念資料館',
#   'slug': 'pic_syousai.php?gbID=253&dt=190805151406'},
#  {'name_kana': 'おんだ|あきひこ',
#   'age_production': '2014年12月9日',
#   'exposure_loc': '',
#   'status_then': '乳幼児',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=748&dt=190805151406'},
#  {'name_kana': 'おー．いー．',
#   'age_production': '2016年10月18日',
#   'exposure_loc': '広島市大須賀町',
#   'status_then': '公務員',
#   'status_then_detail': '運輸省|広島鉄道局|広島通信区',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1134&dt=190805151406'},
#  {'name_kana': 'かがわ|きよし',
#   'age_production': '2004年',
#   'exposure_loc': '広島市仁保町柞木[現：広島市南区]',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '大本営陸軍部船舶司令部船舶砲兵団司令部（暁第6180部隊）',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=254&dt=190805151406'},
#  {'name_kana': 'かく|すひょん',
#   'age_production': '2011年8月7日',
#   'exposure_loc': '広島市牛田町[現：広島市東区]',
#   'status_then': '児童',
#   'status_then_detail': '牛田国民学校|1年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=258&dt=190805151406'},
#  {'name_kana': 'かしむら|よりこ',
#   'age_production': '2006年9月28日',
#   'exposure_loc': '広島市牛田町[現：広島市東区]',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '教育総監部広島陸軍幼年学校',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=259&dt=190805151406'},
#  {'name_kana': 'かせ|かずお',
#   'age_production': '2005年11月16日',
#   'exposure_loc': '皆実国民学校(広島市皆実町二丁目[現：広島市南区皆実町一丁目])',
#   'status_then': '児童',
#   'status_then_detail': '皆実国民学校|6年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=263&dt=190805151406'},
#  {'name_kana': 'かたおか|おさむ',
#   'age_production': '1988年8月1日',
#   'exposure_loc': '広島市中町[現：広島市中区]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '広島県立広島第一中学校|1年生',
#   'record_location': '広島平和記念資料館',
#   'slug': 'pic_syousai.php?gbID=267&dt=190805151406'},
#  {'name_kana': 'かたおか|つよ',
#   'age_production': '1990年10月1日',
#   'exposure_loc': '三菱重工業(株)長崎兵器製作所 (長崎市[現:長崎市])',
#   'status_then': '一般就業者',
#   'status_then_detail': '三菱重工業㈱長崎兵器製作所',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=115&dt=190805151406'},
#  {'name_kana': 'かだ|ひろこ',
#   'age_production': '2014年11月12日',
#   'exposure_loc': '安佐郡祇園町',
#   'status_then': '児童',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=745&dt=190805151406'},
#  {'name_kana': 'かとう|かずみ',
#   'age_production': '2012年10月14日',
#   'exposure_loc': '広島市江波町[現：広島市中区]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '広島市立造船工業学校',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=268&dt=190805151407'},
#  {'name_kana': 'かとう|のぼる',
#   'age_production': '2004年',
#   'exposure_loc': '',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '大本営陸軍部船舶司令部船舶練習部第10教育隊',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=269&dt=190805151407'},
#  {'name_kana': 'かとう|まさのり',
#   'age_production': '2009年12月4日',
#   'exposure_loc': '広島湾',
#   'status_then': '生徒・学生',
#   'status_then_detail': '広島師範学校',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=805&dt=190805151407'},
#  {'name_kana': 'かねこ|ひろこ',
#   'age_production': '2018年9月27日',
#   'exposure_loc': '宇品町［現：広島市南区］',
#   'status_then': '乳幼児',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1284&dt=190805151407'},
#  {'name_kana': 'かねちか|まもる',
#   'age_production': '2016年10月12日',
#   'exposure_loc': '広島市天満町[現：広島市西区]',
#   'status_then': '乳幼児',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1132&dt=190805151407'},
#  {'name_kana': 'かねまつ|しげる',
#   'age_production': '2006年6月18日',
#   'exposure_loc': '長崎市本紙屋町[現：長崎市八幡町]',
#   'status_then': '一般就業者',
#   'status_then_detail': '長崎新聞社',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=761&dt=190805151407'},
#  {'name_kana': 'かまがた|きんさく',
#   'age_production': '2017年10月17日',
#   'exposure_loc': '',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '第2総軍第15方面軍第59軍第230師団歩兵第321連隊（総武第27695部隊）',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1205&dt=190805151407'},
#  {'name_kana': 'かみかわ|ひとし',
#   'age_production': '2011年11月24日',
#   'exposure_loc': '長崎市稲佐町三丁目[現：長崎市稲佐町]',
#   'status_then': '児童',
#   'status_then_detail': '稲佐国民学校',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=17&dt=190805151407'},
#  {'name_kana': 'かむろぎ|すすむ',
#   'age_production': '2005年11月17日',
#   'exposure_loc': '広瀬国民学校(広島市広瀬北町[現：広島市中区広瀬北町])',
#   'status_then': '児童',
#   'status_then_detail': '広瀬国民学校|5年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=270&dt=190805151407'},
#  {'name_kana': 'かめい|よしかず',
#   'age_production': '2016年10月19日',
#   'exposure_loc': '広島市打越町［現：広島市西区］',
#   'status_then': '児童',
#   'status_then_detail': '三篠国民学校|３年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1136&dt=190805151407'},
#  {'name_kana': 'かめざわ|みゆき',
#   'age_production': '2004年',
#   'exposure_loc': '広島市舟入仲町[現：広島市中区舟入中町]',
#   'status_then': '',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=274&dt=190805151407'},
#  {'name_kana': 'かやしげ|じゅんこ',
#   'age_production': '2009年12月1日',
#   'exposure_loc': '広島市（横川町）[現：広島市西区]',
#   'status_then': '児童',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=801&dt=190805151407'},
#  {'name_kana': 'かりの|ゆきみつ',
#   'age_production': '2013年1月31日',
#   'exposure_loc': '広島女子商業学校（広島市南段原町[現：広島市南区段原南一丁目]）',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '陸軍 船舶指令部 無線通信教育隊',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=878&dt=190805151407'},
#  {'name_kana': 'かわい|りょう',
#   'age_production': '2015年9月16日',
#   'exposure_loc': '広島市皆実町一丁目[現：広島市南区皆実町一丁目]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '広島市立第一工業学校|機械科|１年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1053&dt=190805151407'},
#  {'name_kana': 'かわうち|まさあき',
#   'age_production': '2015年1月16日',
#   'exposure_loc': '三菱電機(株)長崎製作所 本工場（長崎市平戸小屋町[現：長崎市丸尾町]）',
#   'status_then': '一般就業者',
#   'status_then_detail': '三菱電機(株)長崎製作所 本工場',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=903&dt=190805151407'},
#  {'name_kana': 'かわかみ|ちづこ',
#   'age_production': '2005年10月12日',
#   'exposure_loc': '',
#   'status_then': '生徒・学生',
#   'status_then_detail': '口田国民学校|高等科2年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=278&dt=190805151407'},
#  {'name_kana': 'かわぐち|よさく',
#   'age_production': '2011年11月18日',
#   'exposure_loc': '長崎市昭和町[現：長崎市昭和町]',
#   'status_then': '一般就業者',
#   'status_then_detail': '九州配電㈱',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=18&dt=190805151407'},
#  {'name_kana': 'かわたに|くにお',
#   'age_production': '2006年7月29日',
#   'exposure_loc': '三菱重工業(株)長崎兵器製作所 茂里町工場(長崎市茂里町[現：長崎市茂里町])',
#   'status_then': '生徒・学生',
#   'status_then_detail': '長崎市立長崎商業学校',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=768&dt=190805151407'},
#  {'name_kana': 'かわなみ|じゅんご',
#   'age_production': '2003年11月4日',
#   'exposure_loc': '長崎市(稲佐町)[現：長崎市]',
#   'status_then': '児童',
#   'status_then_detail': '朝日国民学校|5年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=282&dt=190805151407'},
#  {'name_kana': 'かわはら|すすむ',
#   'age_production': '2014年2月25日',
#   'exposure_loc': '',
#   'status_then': '乳幼児',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=888&dt=190805151407'},
#  {'name_kana': 'かわばた|よしや',
#   'age_production': '2003年10月29日',
#   'exposure_loc': '船舶通信隊補充隊(暁第16710部隊)(広島市皆実町一丁目[現：広島市南区])',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '大本営陸軍部船舶司令部教育船舶兵団船舶通信隊補充隊（暁第16710部隊）',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=283&dt=190805151407'},
#  {'name_kana': 'かわむら|のぶこ',
#   'age_production': '2013年2月8日',
#   'exposure_loc': '三菱重工業(株)長崎兵器製作所 住吉トンネル工場（赤迫トンネル工場）（長崎市[現：長崎市]）',
#   'status_then': '生徒・学生',
#   'status_then_detail': '瓊浦高等女学校 4年生',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=869&dt=190805151407'},
#  {'name_kana': 'かわもと|しろう',
#   'age_production': '2004年',
#   'exposure_loc': '広島市西蟹屋町[現：広島市南区]',
#   'status_then': '児童',
#   'status_then_detail': '荒神町国民学校|3年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=284&dt=190805151407'},
#  {'name_kana': 'かわもと|みやこ',
#   'age_production': '2010年10月26日',
#   'exposure_loc': '広島市己斐町[現：広島市西区]',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '広島陸軍被服支廠',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=288&dt=190805151407'},
#  {'name_kana': 'かわもと|よしゆき',
#   'age_production': '2016年10月4日',
#   'exposure_loc': '',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '賀茂海軍衛生学校|第3期普通科|衛生術練習生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1131&dt=190805151407'},
#  {'name_kana': 'かわらだ|かずお',
#   'age_production': '2013年2月7日',
#   'exposure_loc': '長崎市尾上町[現：長崎市尾上町]',
#   'status_then': '一般就業者',
#   'status_then_detail': '運輸省門司鉄道局|長崎車掌区',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=871&dt=190805151407'},
#  {'name_kana': 'かん|ほんぐ',
#   'age_production': '2015年11月12日',
#   'exposure_loc': '広島鉄道局\u3000広島第2機関区（広島市東蟹屋町[現：広島市南区]）',
#   'status_then': '公務員',
#   'status_then_detail': '広島鉄道局|広島第2機関区',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1104&dt=190805151407'},
#  {'name_kana': 'かん|ほんじゃ',
#   'age_production': '2018年9月4日',
#   'exposure_loc': '長崎市東北郷［現：長崎市］',
#   'status_then': '乳幼児',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1307&dt=190805151407'},
#  {'name_kana': 'かん|むんひ',
#   'age_production': '1988年8月1日',
#   'exposure_loc': '三菱重工業㈱広島造船所(広島市江波町[現：広島市中区江波沖町])',
#   'status_then': '一般就業者',
#   'status_then_detail': '三菱重工業㈱広島造船所',
#   'record_location': '広島平和記念資料館',
#   'slug': 'pic_syousai.php?gbID=292&dt=190805151407'},
#  {'name_kana': 'かんべ|みわこ',
#   'age_production': '2011年10月5日',
#   'exposure_loc': '広島市東雲町[現：広島市南区]',
#   'status_then': '児童',
#   'status_then_detail': '比治山国民学校|2年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=296&dt=190805151407'},
#  {'name_kana': 'きうち|ゆきこ',
#   'age_production': '2017年7月19日',
#   'exposure_loc': '広島市吉島町［現：広島市中区吉島町］',
#   'status_then': '児童',
#   'status_then_detail': '中島国民学校|４年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1197&dt=190805151407'},
#  {'name_kana': 'きくの|かずこ',
#   'age_production': '2006年10月28日',
#   'exposure_loc': '長崎医科大学附属医院（長崎市坂本町[現：長崎市坂本一丁目]）',
#   'status_then': '医療従事者',
#   'status_then_detail': '長崎医科大学附属医院|皮膚科学教室',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=770&dt=190805151407'},
#  {'name_kana': 'きぐち|ひさし',
#   'age_production': '2013年1月10日',
#   'exposure_loc': '長崎市平戸小屋町[現：長崎市大鳥町]',
#   'status_then': '児童',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=853&dt=190805151407'},
#  {'name_kana': 'きさら|よしお',
#   'age_production': '2013年10月11日',
#   'exposure_loc': '広島市千田町[現：広島市中区]',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '大本営陸軍部船舶司令部潜水輸送教育隊（暁第2940部隊）',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=297&dt=190805151407'},
#  {'name_kana': 'きた|こうじ',
#   'age_production': '2015年9月30日',
#   'exposure_loc': '',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '大本営陸軍部船舶司令部船舶練習部第10教育隊海上挺進第42戦隊(暁第19857部隊)',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1060&dt=190805151407'},
#  {'name_kana': 'きたえ|としお',
#   'age_production': '2005年11月16日',
#   'exposure_loc': '宇品凱旋館 船舶司令部(暁第2940部隊)(広島市宇品町[現：広島市南区宇品海岸三丁目])',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '大本営陸軍部船舶司令部教育船舶兵団船舶通信隊補充隊（暁第16710部隊）',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=298&dt=190805151407'},
#  {'name_kana': 'きたむら|みねお',
#   'age_production': '2004年',
#   'exposure_loc': '広島市仁保町柞木[現：広島市南区]',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '大本営陸軍部船舶司令部教育船舶兵団船舶通信隊補充隊（暁第16710部隊）',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=299&dt=190805151407'},
#  {'name_kana': 'きど|すえいち',
#   'age_production': '2014年11月12日',
#   'exposure_loc': '長崎市旭町一丁目[現：長崎市光町]',
#   'status_then': '乳幼児',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=916&dt=190805151407'},
#  {'name_kana': 'きど|まさこ',
#   'age_production': '2013年2月8日',
#   'exposure_loc': '',
#   'status_then': '生徒・学生',
#   'status_then_detail': '広島県立広島第二高等女学校 4年生',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=868&dt=190805151407'},
#  {'name_kana': 'きむ|いるちょ',
#   'age_production': '2013年11月25日',
#   'exposure_loc': '広島市江波町[現：広島市中区]',
#   'status_then': '主婦',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=303&dt=190805151407'},
#  {'name_kana': 'きむ|かんじゃ',
#   'age_production': '2016年11月10日',
#   'exposure_loc': '長崎市稲佐町二丁目[現：長崎市]',
#   'status_then': '乳幼児',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1174&dt=190805151408'},
#  {'name_kana': 'きむ|きょんど',
#   'age_production': '2018年9月4日',
#   'exposure_loc': '長崎市御船町［現：長崎市］',
#   'status_then': '乳幼児',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1306&dt=190805151408'},
#  {'name_kana': 'きむ|さんす',
#   'age_production': '2017年9月5日',
#   'exposure_loc': '長崎市西郷[現：長崎市]',
#   'status_then': '一般就業者',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1219&dt=190805151408'},
#  {'name_kana': 'きむ|どしく',
#   'age_production': '2013年11月26日',
#   'exposure_loc': '広島市南観音町[現：広島市西区]',
#   'status_then': '児童',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=304&dt=190805151408'},
#  {'name_kana': 'きむら|とくこ',
#   'age_production': '2011年10月3日',
#   'exposure_loc': '長崎市新地町[現：長崎市新地町]',
#   'status_then': '児童',
#   'status_then_detail': '佐古国民学校|4年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=305&dt=190805151408'},
# ...
#  {'name_kana': 'もりうち|くみえ',
#   'age_production': '2013年2月7日',
#   'exposure_loc': '',
#   'status_then': '児童',
#   'status_then_detail': '銭座国民学校',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=865&dt=190805151429'},
#  {'name_kana': 'もりうち|しげひろ',
#   'age_production': '2007年1月20日',
#   'exposure_loc': '長崎市大黒町[現：長崎市大黒町]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '長崎県立長崎中学校',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=781&dt=190805151429'},
#  {'name_kana': 'もりお|さが',
#   'age_production': '2005年10月16日',
#   'exposure_loc': '広島市仁保町大河[現：広島市南区（大河）]',
#   'status_then': '主婦',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=688&dt=190805151429'},
#  {'name_kana': 'もりぐち|みつぎ',
#   'age_production': '2015年2月3日',
#   'exposure_loc': '',
#   'status_then': '児童',
#   'status_then_detail': '飽の浦国民学校 3年生',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=898&dt=190805151429'},
#  {'name_kana': 'もりた|たかし',
#   'age_production': '2014年11月6日',
#   'exposure_loc': '広島市横川町一丁目［現：広島市西区］',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '中国憲兵隊司令部|憲兵兵長',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=753&dt=190805151430'},
#  {'name_kana': 'もりた|ひろし',
#   'age_production': '2013年12月27日',
#   'exposure_loc': '長崎市片淵町三丁目[現：長崎市片淵五丁目]',
#   'status_then': '児童',
#   'status_then_detail': '上長崎国民学校 5年生',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=886&dt=190805151430'},
#  {'name_kana': 'もりたき|いちろう',
#   'age_production': '1987年8月1日',
#   'exposure_loc': '三菱重工業㈱広島造船所(広島市江波町[現：広島市中区江波沖町])',
#   'status_then': '教師',
#   'status_then_detail': '',
#   'record_location': '広島平和記念資料館',
#   'slug': 'pic_syousai.php?gbID=692&dt=190805151430'},
#  {'name_kana': 'もりなが|まさと',
#   'age_production': '2010年3月8日',
#   'exposure_loc': '三菱重工業(株)長崎兵器製作所 茂里町工場（長崎市茂里町[現：長崎市茂里町]）',
#   'status_then': '生徒・学生',
#   'status_then_detail': '長崎工業経営専門学校',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=819&dt=190805151430'},
#  {'name_kana': 'もろおか|さだお',
#   'age_production': '2000年7月22日',
#   'exposure_loc': '',
#   'status_then': '公務員',
#   'status_then_detail': '運輸省門司鉄道局 早岐機関区',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=791&dt=190805151430'},
#  {'name_kana': 'やぎ|みちこ',
#   'age_production': '2010年2月27日',
#   'exposure_loc': '長崎市鳴滝町[現：長崎市（鳴滝）]',
#   'status_then': '児童',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=818&dt=190805151430'},
#  {'name_kana': 'やくら|しょう',
#   'age_production': '2004年',
#   'exposure_loc': '崇徳中学校 独立鉄道第2大隊(線第13352部隊)(広島市楠木町四丁目[現：広島市西区楠木町四丁目])',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '大本営陸軍部内地鉄道司令部広島地区鉄道司令部独立鉄道第2大隊（線第13352部隊）',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=693&dt=190805151430'},
#  {'name_kana': 'やま|しげゆき',
#   'age_production': '2006年10月1日',
#   'exposure_loc': '',
#   'status_then': '生徒・学生',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=694&dt=190805151430'},
#  {'name_kana': 'やまいえ|よしこ',
#   'age_production': '2015年9月17日',
#   'exposure_loc': '己斐駅（広島市己斐町[現：広島市西区己斐本町一丁目]）',
#   'status_then': '児童',
#   'status_then_detail': '国民学校|５年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1054&dt=190805151430'},
#  {'name_kana': 'やまかわ|ふさこ',
#   'age_production': '2017年2月9日',
#   'exposure_loc': '長崎市本原町一丁目[現：長崎市]',
#   'status_then': '乳幼児',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1147&dt=190805151430'},
#  {'name_kana': 'やまぐち|せんじ',
#   'age_production': '1991年3月1日',
#   'exposure_loc': '三菱重工業(株)長崎兵器製作所 大橋工場(長崎市大橋町[現:長崎市文教町])',
#   'status_then': '生徒・学生',
#   'status_then_detail': '長崎県立長崎工業学校',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=79&dt=190805151430'},
#  {'name_kana': 'やまぐち|つとむ',
#   'age_production': '2004年7月1日',
#   'exposure_loc': '広島:広島市江波町[現:広島市中区]長崎:長崎市水の浦町[現:長崎市飽の浦町]',
#   'status_then': '一般就業者',
#   'status_then_detail': '三菱重工業㈱長崎造船所|造機設計部',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=119&dt=190805151430'},
#  {'name_kana': 'やまぐち|てつお',
#   'age_production': '2012年9月24日',
#   'exposure_loc': '',
#   'status_then': '生徒・学生',
#   'status_then_detail': '長崎県立水産学校 1年生',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=854&dt=190805151430'},
#  {'name_kana': 'やまぐち|やすお',
#   'age_production': '2013年1月18日',
#   'exposure_loc': '',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '海軍総隊佐世保鎮守府川棚海軍工廠 水雷部',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=877&dt=190805151430'},
#  {'name_kana': 'やまぐち|よういちろう',
#   'age_production': '2008年12月19日',
#   'exposure_loc': '長崎県立長崎中学校（長崎市鳴滝町[現：長崎市鳴滝一丁目]）',
#   'status_then': '生徒・学生',
#   'status_then_detail': '長崎県立長崎中学校',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=788&dt=190805151430'},
#  {'name_kana': 'やまぐち|よしこ',
#   'age_production': '2012年10月29日',
#   'exposure_loc': '広島市上柳町[現：広島市中区]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '広島女学院高等女学校|1年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=695&dt=190805151430'},
#  {'name_kana': 'やまさき|かおる',
#   'age_production': '2013年2月7日',
#   'exposure_loc': '三菱重工業(株)長崎造船所（長崎市[現：長崎市]）',
#   'status_then': '生徒・学生',
#   'status_then_detail': '九州経済専門学校',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=866&dt=190805151430'},
#  {'name_kana': 'やまさき|よしき',
#   'age_production': '2009年11月23日',
#   'exposure_loc': '長崎市(飽ノ浦町)[現：長崎市]',
#   'status_then': '一般就業者',
#   'status_then_detail': '三菱重工業㈱長崎造船所|飽の浦工場',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=696&dt=190805151430'},
#  {'name_kana': 'やました|ひろこ',
#   'age_production': '2006年10月28日',
#   'exposure_loc': '長崎市東古川町[現：長崎市古川町]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '瓊浦高等女学校',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=771&dt=190805151430'},
#  {'name_kana': 'やました|ゆきお',
#   'age_production': '2015年2月3日',
#   'exposure_loc': '三菱重工業(株)長崎兵器製作所 茂里町工場（長崎市茂里町[現：長崎市茂里町]）',
#   'status_then': '生徒・学生',
#   'status_then_detail': '三菱長崎工業青年学校 3年生',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=899&dt=190805151430'},
#  {'name_kana': 'やましな|かずこ',
#   'age_production': '2010年10月27日',
#   'exposure_loc': '浜屋百貨店(長崎市東浜町[現：長崎市浜町])',
#   'status_then': '一般就業者',
#   'status_then_detail': '東亜交通公社',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=697&dt=190805151431'},
#  {'name_kana': 'やましな|としこ',
#   'age_production': '2009年12月5日',
#   'exposure_loc': '広島市舟入町[現：広島市中区]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=807&dt=190805151431'},
#  {'name_kana': 'やまだ|いちたろう',
#   'age_production': '1994年5月1日',
#   'exposure_loc': '',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=123&dt=190805151431'},
#  {'name_kana': 'やまだ|かずみ',
#   'age_production': '2014年2月26日',
#   'exposure_loc': '長崎市昭和町[現：長崎市昭和町]',
#   'status_then': '児童',
#   'status_then_detail': '西浦上国民学校 6年生',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=890&dt=190805151431'},
#  {'name_kana': 'やまだ|れいこ',
#   'age_production': '2006年10月5日',
#   'exposure_loc': '広島市己斐町[現：広島市西区己斐上二丁目]',
#   'status_then': '児童',
#   'status_then_detail': '己斐国民学校|5年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=701&dt=190805151431'},
#  {'name_kana': 'やまと|ただお',
#   'age_production': '2014年10月27日',
#   'exposure_loc': '広島市庚午北町七丁目［現：広島市西区］',
#   'status_then': '乳幼児',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=741&dt=190805151431'},
#  {'name_kana': 'やまはた|よしたか',
#   'age_production': '2016年11月7日',
#   'exposure_loc': '長崎市竹ノ久保町[現：長崎市竹の久保町]',
#   'status_then': '児童',
#   'status_then_detail': '稲佐国民学校3年生',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1144&dt=190805151431'},
#  {'name_kana': 'やまもと|のぶお',
#   'age_production': '2004年',
#   'exposure_loc': '光道国民学校 広島憲兵分隊(広島市猫屋町[現：広島市中区猫屋町])',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '中国憲兵隊|広島憲兵分隊',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=705&dt=190805151431'},
#  {'name_kana': 'やまもと|のぼる',
#   'age_production': '2015年10月5日',
#   'exposure_loc': '長崎市稲佐町二丁目[現：長崎市稲佐町]',
#   'status_then': '児童',
#   'status_then_detail': '稲佐国民学校 6年生',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1038&dt=190805151431'},
#  {'name_kana': 'やまもと|まさこ',
#   'age_production': '2014年11月27日',
#   'exposure_loc': '長崎市稲佐町二丁目[現：長崎市]',
#   'status_then': '主婦',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=896&dt=190805151431'},
#  {'name_kana': 'やまもと|まりこ',
#   'age_production': '2005年12月1日',
#   'exposure_loc': '広島市打越町[現：広島市西区]',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '中国軍管区司令部',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=709&dt=190805151431'},
#  {'name_kana': 'ゆん|すぎ',
#   'age_production': '2013年11月25日',
#   'exposure_loc': '広島市横川町[現：広島市西区]',
#   'status_then': '公務員',
#   'status_then_detail': '運輸省広島鉄道局|横川駅',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=713&dt=190805151431'},
#  {'name_kana': 'よこたに|あさえ',
#   'age_production': '2012年10月24日',
#   'exposure_loc': '長崎市万屋町[現：長崎市]',
#   'status_then': '公務員',
#   'status_then_detail': '内閣逓信院熊本逓信局|本博多郵便局',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=714&dt=190805151431'},
#  {'name_kana': 'よこやま|ひろし',
#   'age_production': '2012年10月24日',
#   'exposure_loc': '広島市（横川町）[現：広島市西区]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '三篠国民学校|高等科|1年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=715&dt=190805151431'},
#  {'name_kana': 'よしおか|やすし',
#   'age_production': '2013年3月9日',
#   'exposure_loc': '長崎市愛宕町[現：長崎市（愛宕）]',
#   'status_then': '児童',
#   'status_then_detail': '小島国民学校 6年生',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=864&dt=190805151431'},
#  {'name_kana': 'よしかね|みのる',
#   'age_production': '2012年10月14日',
#   'exposure_loc': '',
#   'status_then': '生徒・学生',
#   'status_then_detail': '広島高等師範学校|1年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=716&dt=190805151431'},
#  {'name_kana': 'よしざき|さちえ',
#   'age_production': '2003年10月28日',
#   'exposure_loc': '長崎市(伊良林町)[現：長崎市]',
#   'status_then': '乳幼児',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=717&dt=190805151431'},
#  {'name_kana': 'よしだ|いさむ',
#   'age_production': '2007年2月10日',
#   'exposure_loc': '長崎市中新町[現：長崎市中新町]',
#   'status_then': '児童',
#   'status_then_detail': '仁田国民学校',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=784&dt=190805151431'},
#  {'name_kana': 'よしだ|かずと',
#   'age_production': '2011年10月3日',
#   'exposure_loc': '長崎市中川町[現：長崎市(中川)]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '長崎県立長崎中学校|2年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=718&dt=190805151431'},
#  {'name_kana': 'よしだ|かつじ',
#   'age_production': '1992年8月1日',
#   'exposure_loc': '長崎市大橋町[現:長崎市]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '長崎県立長崎工業学校',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=83&dt=190805151431'},
#  {'name_kana': 'よしだ|すすむ',
#   'age_production': '2011年2月28日',
#   'exposure_loc': '長崎市今魚町[現：長崎市魚の町]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '勝山国民学校',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=835&dt=190805151432'},
#  {'name_kana': 'よしだ|つねお',
#   'age_production': '2009年3月2日',
#   'exposure_loc': '長崎市新地町[現：長崎市新地町]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '長崎県立長崎中学校',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=792&dt=190805151432'},
#  {'name_kana': 'よしどみ|やすみ',
#   'age_production': '2011年11月28日',
#   'exposure_loc': '三菱重工業㈱長崎兵器製作所 住吉トンネル工場(赤迫トンネル工場)(長崎市[現：長崎市])',
#   'status_then': '生徒・学生',
#   'status_then_detail': '佐賀県立伊万里商業学校4年生',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=65&dt=190805151432'},
#  {'name_kana': 'よしなが|まさこ',
#   'age_production': '2003年10月29日',
#   'exposure_loc': '三菱重工業㈱長崎兵器製作所 大橋工場(長崎市大橋町[現：長崎市文教町])',
#   'status_then': '生徒・学生',
#   'status_then_detail': '長崎県立長崎高等女学校|3年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=719&dt=190805151432'},
#  {'name_kana': 'よしむら|かずひろ',
#   'age_production': '2012年10月12日',
#   'exposure_loc': '長崎市小菅町[現：長崎市]',
#   'status_then': '乳幼児',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=720&dt=190805151432'},
#  {'name_kana': 'よしもと|けいそう',
#   'age_production': '2003年12月10日',
#   'exposure_loc': '広島市江波町[現：広島市中区]',
#   'status_then': '児童',
#   'status_then_detail': '国民学校|4年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=721&dt=190805151432'},
#  {'name_kana': 'よつだ|しずよ',
#   'age_production': '2001年8月5日',
#   'exposure_loc': '長崎市大橋町[現：長崎市油木町]',
#   'status_then': '主婦',
#   'status_then_detail': '',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=131&dt=190805151432'},
#  {'name_kana': 'よなみね|ひろし',
#   'age_production': '2012年1月27日',
#   'exposure_loc': '',
#   'status_then': '生徒・学生',
#   'status_then_detail': '長崎造船専門学校',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=66&dt=190805151432'},
#  {'name_kana': 'よねだ|ちよの',
#   'age_production': '2006年10月9日',
#   'exposure_loc': '長崎市[現：長崎市]',
#   'status_then': '一般就業者',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=722&dt=190805151432'},
#  {'name_kana': 'よねむら|ひろおみ',
#   'age_production': '2009年3月14日',
#   'exposure_loc': '',
#   'status_then': '軍人・軍属',
#   'status_then_detail': '軍人（大阪海兵団軍医見習尉官）',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=795&dt=190805151432'},
#  {'name_kana': 'らんめる|こうむら|さち',
#   'age_production': '2011年9月25日',
#   'exposure_loc': '広島市古田町[現：広島市西区]',
#   'status_then': '児童',
#   'status_then_detail': '古田国民学校|3年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=723&dt=190805151432'},
#  {'name_kana': 'りゅう|ちえこ',
#   'age_production': '2001年8月5日',
#   'exposure_loc': '長崎市山里町[現:長崎市]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '鶴鳴高等女学校',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=135&dt=190805151432'},
#  {'name_kana': 'りゅう|びょんむん',
#   'age_production': '2017年9月7日',
#   'exposure_loc': '広島市横川町一丁目[現：広島市西区]',
#   'status_then': '乳幼児',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1214&dt=190805151432'},
#  {'name_kana': 'りゅうの|あきこ',
#   'age_production': '2003年11月4日',
#   'exposure_loc': '長崎市御船蔵町[現：長崎市]',
#   'status_then': '乳幼児',
#   'status_then_detail': '',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=724&dt=190805151432'},
#  {'name_kana': 'ろーれんす ふみお みわ',
#   'age_production': '2018年11月5日',
#   'exposure_loc': '',
#   'status_then': '生徒・学生',
#   'status_then_detail': '広島高等師範学校附属中学校|二年生',
#   'record_location': '国立広島原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=1279&dt=190805151432'},
#  {'name_kana': 'わたなべ|すがこ',
#   'age_production': '2013年3月9日',
#   'exposure_loc': '',
#   'status_then': '児童',
#   'status_then_detail': '三重国民学校 6年生',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=842&dt=190805151432'},
#  {'name_kana': 'わたなべ|ちえこ',
#   'age_production': '1990年7月1日',
#   'exposure_loc': '三菱電機(株)長崎製作所\u3000本工場(長崎市平戸小屋町[現：長崎市丸尾町])',
#   'status_then': '生徒・学生',
#   'status_then_detail': '鶴鳴高等女学校',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=103&dt=190805151432'},
#  {'name_kana': 'わたなべ|つかさ',
#   'age_production': '1995年5月12日',
#   'exposure_loc': '長崎市（銭座町）[現：長崎市]',
#   'status_then': '生徒・学生',
#   'status_then_detail': '長崎県立瓊浦中学校 2年',
#   'record_location': '国立長崎原爆死没者追悼平和祈念館',
#   'slug': 'pic_syousai.php?gbID=990&dt=190805151432'}]

# %%
df_details = pd.DataFrame(rows)
df_details.to_csv('data/survivors_globalpeace_bio_details.csv', index=False)

# %%
df_globalpeace = df_details.merge(df_basic, on='slug')
df_globalpeace.to_csv('data/survivors_globalpeace_bio.csv', index=False)

# %% [markdown]
# # Turn names into romaji
#
# https://github.com/soimort/python-romkan

# %%
# !pip install romkan
import romkan

# %%
name_romaji = []
for name in df.name_kana:
    name = romkan.to_roma(name)
    name_romaji.append(name)
name_romaji

df['name_romaji'] = name_romaji
df[['name_kana', 'name_romaji']].tail(3)
# Out:
#     name_kana      name_romaji
# 689  ワタナベ|タツオ  watanabe|tatsuo
# 690  ワタナベ|ミヨコ  watanabe|miyoko
# 691    ワダ|イサオ        wada|isao

# %%
name_romaji = []
for name in df_globalpeace.name_kana:
    name = romkan.to_roma(name)
    name_romaji.append(name)
name_romaji

df_globalpeace['name_romaji'] = name_romaji
df_globalpeace[['name_kana', 'name_romaji']].tail(3)
# Out:
#     name_kana       name_romaji
# 635  わたなべ|すがこ   watanabe|sugako
# 636  わたなべ|ちえこ   watanabe|chieko
# 637  わたなべ|つかさ  watanabe|tsukasa

# %%
df.shape
# Out:
# (692, 17)

# %%
df_globalpeace.shape
# Out:
# (638, 14)

# %% [markdown]
# # Merge Hiroshima Peace Museum and Global Peace datasets into one dataframe

# %%
df_survivors = df.merge(df_globalpeace, how='outer', on='name_romaji', suffixes=('_hiroshima', '_globalpeace'))
df_survivors.shape
# Out:
# (1312, 30)

# %%
df_survivors.to_csv('data/survivors_bio_complete.csv', index=False)

# %%
df_survivors = pd.read_csv('data/survivors_bio_complete.csv')

# %% [markdown]
# # Clean the dataframe by filling in values for common columns (age, etc)

# %%
df_survivors.columns
# Out:
# Index(['age_exposure_detail', 'age_production_hiroshima', 'code', 'details',
#        'exposure_dist_hiroshima', 'exposure_loc_hiroshima',
#        'name_kana_hiroshima', 'status_then_detail_hiroshima', 'work_location',
#        'age_exposure_hiroshima', 'id_hiroshima', 'name_hiroshima',
#        'production_date', 'sex_hiroshima', 'slug_hiroshima',
#        'status_then_hiroshima', 'name_romaji', 'age_production_globalpeace',
#        'exposure_loc_globalpeace', 'name_kana_globalpeace', 'record_location',
#        'slug_globalpeace', 'status_then_globalpeace',
#        'status_then_detail_globalpeace', 'age_exposure_globalpeace',
#        'exposure_dist_globalpeace', 'exposure_pref', 'id_globalpeace',
#        'name_globalpeace', 'sex_globalpeace'],
#       dtype='object')

# %%
df_survivors[['age_exposure_hiroshima','age_exposure_globalpeace']]
# Out:
#      age_exposure_hiroshima age_exposure_globalpeace
# 0                        21                      NaN
# 1                        14                      NaN
# 2                        15                      NaN
# 3                        21                      NaN
# 4                        13                      NaN
# 5                        30                      NaN
# 6                        24                      NaN
# 7                        18                      NaN
# 8                        24                      NaN
# 9                        22                      NaN
# 10                       13                      NaN
# 11                       23                      NaN
# 12                       13                      NaN
# 13                       16                      NaN
# 14                       15                      NaN
# 15                       30                      NaN
# 16                       19                      NaN
# 17                       16                      NaN
# 18                        7                      NaN
# 19                       16                      NaN
# 20                       21                      NaN
# 21                       17                      NaN
# 22                       12                      NaN
# 23                       28                      NaN
# 24                       16                      NaN
# 25                       13                      NaN
# 26                       17                      NaN
# 27                       13                      NaN
# 28                       15                      NaN
# 29                       45                      NaN
# 30                        5                      NaN
# 31                       32                      NaN
# 32                       33                      NaN
# 33                       15                      NaN
# 34                       10                      NaN
# 35                       14                      NaN
# 36                       31                      NaN
# 37                       21                      NaN
# 38                       34                      NaN
# 39                       24                      NaN
# 40                       19                      NaN
# 41                        4                      NaN
# 42                       15                      NaN
# 43                       15                      NaN
# 44                       14                      NaN
# 45                       34                      NaN
# 46                       21                      NaN
# 47                       29                      NaN
# 48                       15                      NaN
# 49                       11                      NaN
# 50                       13                      NaN
# 51                       24                      NaN
# 52                       17                      NaN
# 53                       45                      NaN
# 54                       29                      NaN
# 55                       19                      NaN
# 56                       28                      NaN
# 57                       13                      NaN
# 58                       17                      NaN
# 59                       15                      NaN
# 60                       21                      NaN
# 61                       16                      NaN
# 62                       11                      NaN
# 63                       13                      NaN
# 64                       14                      NaN
# 65                       14                      NaN
# 66                       26                       26
# 67                       23                      NaN
# 68                       31                      NaN
# 69                       16                      NaN
# 70                       12                      NaN
# 71                       17                      NaN
# 72                       19                      NaN
# 73                       24                      NaN
# 74                        5                      NaN
# 75                       14                      NaN
# 76                       37                      NaN
# 77                       16                      NaN
# 78                       14                      NaN
# 79                       26                      NaN
# 80                       16                      NaN
# 81                       23                      NaN
# 82                       19                      NaN
# 83                       14                      NaN
# 84                       15                      NaN
# 85                       19                      NaN
# 86                       26                      NaN
# 87                       16                      NaN
# 88                       16                      NaN
# 89                       32                      NaN
# 90                       21                      NaN
# 91                       14                      NaN
# 92                       17                      NaN
# 93                       17                      NaN
# 94                       15                      NaN
# 95                        8                      NaN
# 96                       16                      NaN
# 97                       15                      NaN
# 98                       17                      NaN
# 99                       23                      NaN
# 100                      38                      NaN
# 101                      28                      NaN
# 102                      16                      NaN
# 103                      16                      NaN
# 104                       9                      NaN
# 105                       8                      NaN
# 106                      18                      NaN
# 107                      13                      NaN
# 108                      13                      NaN
# 109                      17                      NaN
# 110                      12                      NaN
# 111                      15                      NaN
# 112                       8                      NaN
# 113                       8                      NaN
# 114                      14                      NaN
# 115                      22                      NaN
# 116                      26                      NaN
# 117                      15                      NaN
# 118                      20                      NaN
# 119                      22                      NaN
# 120                       8                      NaN
# 121                      24                       24
# 122                      38                      NaN
# 123                      13                      NaN
# 124                      16                      NaN
# 125                      20                      NaN
# 126                      16                      NaN
# 127                      37                       37
# 128                      15                      NaN
# 129                       8                      NaN
# 130                      18                      NaN
# 131                      20                      NaN
# 132                      12                      NaN
# 133                      21                      NaN
# 134                      16                      NaN
# 135                      13                      NaN
# 136                      17                      NaN
# 137                      13                      NaN
# 138                      13                      NaN
# 139                      14                      NaN
# 140                      12                      NaN
# 141                      16                      NaN
# 142                      17                      NaN
# 143                      13                      NaN
# 144                      12                      NaN
# 145                      22                      NaN
# 146                      12                      NaN
# 147                       5                      NaN
# 148                      17                      NaN
# 149                      16                      NaN
# 150                      27                      NaN
# 151                      14                      NaN
# 152                      17                      NaN
# 153                      18                      NaN
# 154                      16                      NaN
# 155                      19                      NaN
# 156                      19                      NaN
# 157                      40                      NaN
# 158                      13                      NaN
# 159                      28                      NaN
# 160                      15                      NaN
# 161                      16                      NaN
# 162                      17                       17
# 163                      18                      NaN
# 164                      32                      NaN
# 165                      14                      NaN
# 166                      22                      NaN
# 167                      15                      NaN
# 168                      16                      NaN
# 169                      32                      NaN
# 170                      14                      NaN
# 171                      32                      NaN
# 172                      15                      NaN
# 173                      15                      NaN
# 174                      18                      NaN
# 175                      21                      NaN
# 176                      11                      NaN
# 177                      19                      NaN
# 178                      27                      NaN
# 179                      23                      NaN
# 180                      13                      NaN
# 181                       6                      NaN
# 182                      26                       26
# 183                      23                      NaN
# 184                      23                      NaN
# 185                      21                      NaN
# 186                      34                      NaN
# 187                      16                      NaN
# 188                      10                      NaN
# 189                      21                      NaN
# 190                      22                      NaN
# 191                      20                      NaN
# 192                       5                      NaN
# 193                      13                      NaN
# 194                      13                      NaN
# 195                      16                      NaN
# 196                       8                      NaN
# 197                       8                      NaN
# 198                      12                      NaN
# 199                      14                      NaN
# 200                      18                      NaN
# 201                      18                      NaN
# 202                      15                      NaN
# 203                      15                      NaN
# 204                      14                      NaN
# 205                      21                      NaN
# 206                      16                      NaN
# 207                      16                      NaN
# 208                       3                      NaN
# 209                      19                      NaN
# 210                       9                      NaN
# 211                      27                      NaN
# 212                       8                      NaN
# 213                      15                      NaN
# 214                      19                      NaN
# 215                      13                      NaN
# 216                      19                      NaN
# 217                      14                      NaN
# 218                      19                      NaN
# 219                      17                      NaN
# 220                      32                      NaN
# 221                      19                      NaN
# 222                      22                      NaN
# 223                      19                      NaN
# 224                      12                      NaN
# 225                      21                      NaN
# 226                      32                      NaN
# 227                      17                      NaN
# 228                      41                      NaN
# 229                       8                      NaN
# 230                      16                      NaN
# 231                      13                      NaN
# 232                      18                      NaN
# 233                      14                      NaN
# 234                      15                      NaN
# 235                      29                      NaN
# 236                      14                      NaN
# 237                      16                      NaN
# 238                      14                      NaN
# 239                      12                      NaN
# 240                      17                      NaN
# 241                      14                      NaN
# 242                      16                      NaN
# 243                       9                      NaN
# 244                      14                      NaN
# 245                       4                      NaN
# 246                      26                      NaN
# 247                      26                      NaN
# 248                      13                      NaN
# 249                      24                      NaN
# 250                      15                      NaN
# 251                      21                      NaN
# 252                      22                      NaN
# 253                      19                      NaN
# 254                      15                      NaN
# 255                      14                      NaN
# 256                      37                      NaN
# 257                      17                      NaN
# 258                      14                      NaN
# 259                      34                      NaN
# 260                      14                      NaN
# 261                      15                      NaN
# 262                      26                      NaN
# 263                      36                      NaN
# 264                      20                      NaN
# 265                      17                      NaN
# 266                      16                      NaN
# 267                      14                      NaN
# 268                      36                      NaN
# 269                      13                      NaN
# 270                       3                      NaN
# 271                      26                      NaN
# 272                      15                      NaN
# 273                       6                      NaN
# 274                      18                      NaN
# 275                      19                      NaN
# 276                      21                      NaN
# 277                      16                      NaN
# 278                      17                      NaN
# 279                      23                      NaN
# 280                      22                      NaN
# 281                      15                      NaN
# 282                      13                      NaN
# 283                      18                      NaN
# 284                      39                      NaN
# 285                      42                      NaN
# 286                      20                      NaN
# 287                      38                      NaN
# 288                      22                      NaN
# 289                      18                      NaN
# 290                      29                      NaN
# 291                      18                      NaN
# 292                      41                      NaN
# 293                      24                      NaN
# 294                      15                      NaN
# 295                      24                      NaN
# 296                       6                        6
# 297                      21                      NaN
# 298                      18                      NaN
# 299                      28                      NaN
# 300                      14                      NaN
# 301                      19                      NaN
# 302                      26                      NaN
# 303                      12                      NaN
# 304                      13                      NaN
# 305                      18                       18
# 306                      12                      NaN
# 307                      14                      NaN
# 308                      11                      NaN
# 309                      14                      NaN
# 310                      14                      NaN
# 311                      17                      NaN
# 312                      21                      NaN
# 313                       5                      NaN
# 314                      17                      NaN
# 315                      25                      NaN
# 316                      14                      NaN
# 317                      14                      NaN
# 318                      24                      NaN
# 319                      19                      NaN
# 320                      17                      NaN
# 321                      38                      NaN
# 322                      14                      NaN
# 323                      13                      NaN
# 324                      10                      NaN
# 325                      11                      NaN
# 326                      20                      NaN
# 327                      29                       29
# 328                      36                      NaN
# 329                      15                      NaN
# 330                      21                      NaN
# 331                      19                      NaN
# 332                      19                      NaN
# 333                      42                      NaN
# 334                       8                      NaN
# 335                      31                      NaN
# 336                      16                      NaN
# 337                      14                      NaN
# 338                      25                      NaN
# 339                      18                      NaN
# 340                      19                      NaN
# 341                      16                      NaN
# 342                      16                      NaN
# 343                      18                      NaN
# 344                      18                      NaN
# 345                      17                      NaN
# 346                      15                      NaN
# 347                      22                      NaN
# 348                      17                      NaN
# 349                      10                      NaN
# 350                      17                      NaN
# 351                      14                      NaN
# 352                      17                      NaN
# 353                      13                      NaN
# 354                      12                      NaN
# 355                      17                      NaN
# 356                      12                      NaN
# 357                      19                      NaN
# 358                      19                      NaN
# 359                      31                      NaN
# 360                      18                      NaN
# 361                       9                      NaN
# 362                      12                      NaN
# 363                       6                      NaN
# 364                      16                      NaN
# 365                      12                      NaN
# 366                      30                      NaN
# 367                      22                      NaN
# 368                      27                      NaN
# 369                      30                      NaN
# 370                      16                      NaN
# 371                       6                      NaN
# 372                      13                      NaN
# 373                      37                      NaN
# 374                      22                      NaN
# 375                      18                      NaN
# 376                      15                      NaN
# 377                      16                      NaN
# 378                      23                      NaN
# 379                      25                      NaN
# 380                      22                      NaN
# 381                      17                      NaN
# 382                      20                      NaN
# 383                      31                      NaN
# 384                      14                      NaN
# 385                      18                      NaN
# 386                      15                      NaN
# 387                      20                       20
# 388                      15                      NaN
# 389                       9                      NaN
# 390                       9                      NaN
# 391                      36                       36
# 392                      13                      NaN
# 393                      18                      NaN
# 394                      37                      NaN
# 395                                              NaN
# 396                      15                      NaN
# 397                      10                      NaN
# 398                      22                      NaN
# 399                      19                      NaN
# 400                      24                      NaN
# 401                      25                      NaN
# 402                      23                      NaN
# 403                      25                      NaN
# 404                      15                      NaN
# 405                      17                      NaN
# 406                       4                      NaN
# 407                      15                      NaN
# 408                      15                      NaN
# 409                      23                      NaN
# 410                       9                      NaN
# 411                      36                      NaN
# 412                      14                      NaN
# 413                      17                      NaN
# 414                      25                      NaN
# 415                      14                      NaN
# 416                      21                      NaN
# 417                      21                      NaN
# 418                      16                      NaN
# 419                      14                      NaN
# 420                      17                      NaN
# 421                                              NaN
# 422                       8                      NaN
# 423                      14                      NaN
# 424                      15                      NaN
# 425                       6                        6
# 426                      30                      NaN
# 427                      19                      NaN
# 428                      18                      NaN
# 429                      13                      NaN
# 430                      22                      NaN
# 431                      22                      NaN
# 432                      22                      NaN
# 433                      15                      NaN
# 434                      18                      NaN
# 435                      16                      NaN
# 436                      11                      NaN
# 437                      16                      NaN
# 438                      11                      NaN
# 439                      27                      NaN
# 440                      14                      NaN
# 441                      27                      NaN
# 442                      14                      NaN
# 443                      19                      NaN
# 444                      14                      NaN
# 445                      14                      NaN
# 446                      15                      NaN
# 447                      20                      NaN
# 448                      22                      NaN
# 449                      16                      NaN
# 450                      18                      NaN
# 451                      14                      NaN
# 452                      10                      NaN
# 453                      16                      NaN
# 454                      16                      NaN
# 455                      14                      NaN
# 456                      20                      NaN
# 457                       6                      NaN
# 458                      13                      NaN
# 459                      16                      NaN
# 460                      31                      NaN
# 461                      11                      NaN
# 462                      17                      NaN
# 463                      12                      NaN
# 464                      12                      NaN
# 465                      17                      NaN
# 466                       9                      NaN
# 467                      15                      NaN
# 468                      16                      NaN
# 469                      22                       22
# 470                      22                      NaN
# 471                      15                      NaN
# 472                      24                      NaN
# 473                      18                      NaN
# 474                      14                      NaN
# 475                      15                      NaN
# 476                      13                      NaN
# 477                      16                      NaN
# 478                      23                      NaN
# 479                      33                      NaN
# 480                      13                      NaN
# 481                      14                      NaN
# 482                       7                      NaN
# 483                      20                      NaN
# 484                       8                      NaN
# 485                      20                      NaN
# 486                      15                      NaN
# 487                      12                      NaN
# 488                      17                      NaN
# 489                      33                      NaN
# 490                       8                      NaN
# 491                       5                      NaN
# 492                       9                      NaN
# 493                      13                      NaN
# 494                      13                      NaN
# 495                      15                      NaN
# 496                      33                      NaN
# 497                      19                      NaN
# 498                      33                      NaN
# 499                      12                      NaN
# 500                      13                      NaN
# 501                      18                      NaN
# 502                      26                      NaN
# 503                       9                      NaN
# 504                       9                      NaN
# 505                      16                      NaN
# 506                       9                      NaN
# 507                      13                      NaN
# 508                      24                      NaN
# 509                      18                      NaN
# 510                      20                      NaN
# 511                      12                      NaN
# 512                       9                      NaN
# 513                      19                      NaN
# 514                      45                      NaN
# 515                       5                      NaN
# 516                      12                      NaN
# 517                      24                      NaN
# 518                      16                      NaN
# 519                      16                      NaN
# 520                      13                      NaN
# 521                      22                      NaN
# 522                      23                      NaN
# 523                      26                      NaN
# 524                      15                      NaN
# 525                      17                      NaN
# 526                      20                      NaN
# 527                      34                      NaN
# 528                      16                      NaN
# 529                      17                      NaN
# 530                       9                      NaN
# 531                      48                      NaN
# 532                      12                      NaN
# 533                      14                      NaN
# 534                      16                       17
# 535                      30                      NaN
# 536                      24                      NaN
# 537                      25                      NaN
# 538                      20                      NaN
# 539                      12                      NaN
# 540                      17                      NaN
# 541                      16                      NaN
# 542                       6                      NaN
# 543                                              NaN
# 544                      14                      NaN
# 545                      37                      NaN
# 546                      17                      NaN
# 547                       9                      NaN
# 548                      15                      NaN
# 549                      16                      NaN
# 550                      14                      NaN
# 551                      29                      NaN
# 552                      12                      NaN
# 553                       8                      NaN
# 554                      37                      NaN
# 555                      40                      NaN
# 556                      29                      NaN
# 557                      17                      NaN
# 558                      13                      NaN
# 559                      17                      NaN
# 560                      17                      NaN
# 561                      15                      NaN
# 562                      17                      NaN
# 563                      31                      NaN
# 564                      26                      NaN
# 565                      32                       32
# 566                      16                      NaN
# 567                      16                      NaN
# 568                      17                      NaN
# 569                      23                      NaN
# 570                      15                      NaN
# 571                      13                      NaN
# 572                      19                      NaN
# 573                      13                      NaN
# 574                      18                      NaN
# 575                      44                       44
# 576                      33                       33
# 577                      37                      NaN
# 578                      31                      NaN
# 579                      21                      NaN
# 580                      21                      NaN
# 581                      33                      NaN
# 582                      21                      NaN
# 583                      28                      NaN
# 584                      13                      NaN
# 585                      15                      NaN
# 586                      22                      NaN
# 587                      34                      NaN
# 588                      16                      NaN
# 589                      19                      NaN
# 590                      21                      NaN
# 591                      16                      NaN
# 592                       9                      NaN
# 593                      19                      NaN
# 594                      14                      NaN
# 595                      38                      NaN
# 596                      18                      NaN
# 597                      14                      NaN
# 598                      15                      NaN
# 599                      11                      NaN
# 600                      12                      NaN
# 601                      16                      NaN
# 602                      24                      NaN
# 603                      16                      NaN
# 604                       8                      NaN
# 605                      19                      NaN
# 606                      27                      NaN
# 607                      17                      NaN
# 608                      22                      NaN
# 609                      28                      NaN
# 610                       8                      NaN
# 611                      19                      NaN
# 612                      16                      NaN
# 613                      30                      NaN
# 614                      14                      NaN
# 615                      14                      NaN
# 616                      12                      NaN
# 617                      28                      NaN
# 618                      13                      NaN
# 619                      44                       44
# 620                      15                      NaN
# 621                      20                      NaN
# 622                       6                      NaN
# 623                      17                      NaN
# 624                      13                      NaN
# 625                      19                      NaN
# 626                      15                      NaN
# 627                      30                      NaN
# 628                      11                      NaN
# 629                      17                      NaN
# 630                      21                      NaN
# 631                      17                      NaN
# 632                      21                      NaN
# 633                      16                      NaN
# 634                      21                      NaN
# 635                      19                      NaN
# 636                       6                      NaN
# 637                      14                      NaN
# 638                      16                      NaN
# 639                      16                      NaN
# 640                       3                      NaN
# 641                      18                      NaN
# 642                      37                      NaN
# 643                      19                      NaN
# 644                      17                      NaN
# 645                      28                      NaN
# 646                      18                       17
# 647                       2                      NaN
# 648                      34                      NaN
# 649                      17                      NaN
# 650                      11                      NaN
# 651                      16                      NaN
# 652                      14                      NaN
# 653                      13                      NaN
# 654                      37                      NaN
# 655                      14                      NaN
# 656                      16                      NaN
# 657                      19                      NaN
# 658                      24                      NaN
# 659                      25                      NaN
# 660                       4                      NaN
# 661                      13                      NaN
# 662                       7                      NaN
# 663                      15                      NaN
# 664                      33                      NaN
# 665                      19                      NaN
# 666                      14                      NaN
# 667                      15                      NaN
# 668                      16                      NaN
# 669                      21                      NaN
# 670                       6                      NaN
# 671                      14                      NaN
# 672                      21                      NaN
# 673                      22                      NaN
# 674                      17                      NaN
# 675                      12                      NaN
# 676                      14                      NaN
# 677                      13                      NaN
# 678                      16                      NaN
# 679                      28                      NaN
# 680                      18                      NaN
# 681                      17                      NaN
# 682                      13                      NaN
# 683                      22                      NaN
# 684                      10                      NaN
# 685                      12                      NaN
# 686                       6                      NaN
# 687                      17                      NaN
# 688                      12                      NaN
# 689                      17                      NaN
# 690                      15                      NaN
# 691                      19                      NaN
# 692                     NaN                        6
# 693                     NaN                       20
# 694                     NaN                       23
# 695                     NaN                       21
# 696                     NaN                       29
# 697                     NaN                       14
# 698                     NaN                       16
# 699                     NaN                       13
# 700                     NaN                       19
# 701                     NaN                       14
# 702                     NaN                       14
# 703                     NaN                       19
# 704                     NaN                       23
# 705                     NaN                       40
# 706                     NaN                       16
# 707                     NaN                       14
# 708                     NaN                       17
# 709                     NaN                       10
# 710                     NaN                       15
# 711                     NaN                       15
# 712                     NaN                        4
# 713                     NaN                        7
# 714                     NaN                       10
# 715                     NaN                       23
# 716                     NaN                       13
# 717                     NaN                       17
# 718                     NaN                       13
# 719                     NaN                       16
# 720                     NaN                       19
# 721                     NaN                        8
# 722                     NaN                        7
# 723                     NaN                        6
# 724                     NaN                       18
# 725                     NaN                       18
# 726                     NaN                       21
# 727                     NaN                       22
# 728                     NaN                       12
# 729                     NaN                       16
# 730                     NaN                       14
# 731                     NaN                        9
# 732                     NaN                       21
# 733                     NaN                       14
# 734                     NaN                       18
# 735                     NaN                        4
# 736                     NaN                       17
# 737                     NaN                       10
# 738                     NaN                       16
# 739                     NaN                       18
# 740                     NaN                       20
# 741                     NaN                       17
# 742                     NaN                       17
# 743                     NaN                        9
# 744                     NaN                       20
# 745                     NaN                        8
# 746                     NaN                       11
# 747                     NaN                       14
# 748                     NaN                        1
# 749                     NaN                       10
# 750                     NaN                        9
# 751                     NaN                       19
# 752                     NaN                       18
# 753                     NaN                        5
# 754                     NaN                        6
# 755                     NaN                       14
# 756                     NaN                       17
# 757                     NaN                       16
# 758                     NaN                       22
# 759                     NaN                       13
# 760                     NaN                       12
# 761                     NaN                       16
# 762                     NaN                       14
# 763                     NaN                       19
# 764                     NaN                       10
# 765                     NaN                       20
# 766                     NaN                        1
# 767                     NaN                       11
# 768                     NaN                       15
# 769                     NaN                       17
# 770                     NaN                       22
# 771                     NaN                       14
# 772                     NaN                        9
# 773                     NaN                       13
# 774                     NaN                       18
# 775                     NaN                       35
# 776                     NaN                       25
# 777                     NaN                       14
# 778                     NaN                       19
# 779                     NaN                       11
# 780                     NaN                       22
# 781                     NaN                       13
# 782                     NaN                       23
# 783                     NaN                       19
# 784                     NaN                       21
# 785                     NaN                       18
# 786                     NaN                        9
# 787                     NaN                       19
# 788                     NaN                       10
# 789                     NaN                       23
# 790                     NaN                        4
# 791                     NaN                       15
# 792                     NaN                       16
# 793                     NaN                       13
# 794                     NaN                       20
# 795                     NaN                       23
# 796                     NaN                       15
# 797                     NaN                       20
# 798                     NaN                       18
# 799                     NaN                       18
# 800                     NaN                       14
# 801                     NaN                        7
# 802                     NaN                       14
# 803                     NaN                        8
# 804                     NaN                       18
# 805                     NaN                       17
# 806                     NaN                       15
# 807                     NaN                       17
# 808                     NaN                        6
# 809                     NaN                       16
# 810                     NaN                       17
# 811                     NaN                       13
# 812                     NaN                        8
# 813                     NaN                       22
# 814                     NaN                       21
# 815                     NaN                       20
# 816                     NaN                       24
# 817                     NaN                       21
# 818                     NaN                       21
# 819                     NaN                       19
# 820                     NaN                        2
# 821                     NaN                       14
# 822                     NaN                       19
# 823                     NaN                        6
# 824                     NaN                       21
# 825                     NaN                       12
# 826                     NaN                       13
# 827                     NaN                       24
# 828                     NaN                        9
# 829                     NaN                       15
# 830                     NaN                       17
# 831                     NaN                       16
# 832                     NaN                        5
# 833                     NaN                        2
# 834                     NaN                       17
# 835                     NaN                       19
# 836                     NaN                       10
# 837                     NaN                       11
# 838                     NaN                        8
# 839                     NaN                        6
# 840                     NaN                       19
# 841                     NaN                       12
# 842                     NaN                       15
# 843                     NaN                       12
# 844                     NaN                       15
# 845                     NaN                       14
# 846                     NaN                       11
# 847                     NaN                        0
# 848                     NaN                       24
# 849                     NaN                       15
# 850                     NaN                        8
# 851                     NaN                       17
# 852                     NaN                       16
# 853                     NaN                       22
# 854                     NaN                       14
# 855                     NaN                        2
# 856                     NaN                        7
# 857                     NaN                        9
# 858                     NaN                       18
# 859                     NaN                        5
# 860                     NaN                       18
# 861                     NaN                       15
# 862                     NaN                       18
# 863                     NaN                       21
# 864                     NaN                        5
# 865                     NaN                       16
# 866                     NaN                       16
# 867                     NaN                        2
# 868                     NaN                        4
# 869                     NaN                       23
# 870                     NaN                        9
# 871                     NaN                       10
# 872                     NaN                        8
# 873                     NaN                       15
# 874                     NaN                       10
# 875                     NaN                        8
# 876                     NaN                       17
# 877                     NaN                       17
# 878                     NaN                        5
# 879                     NaN                       17
# 880                     NaN                        6
# 881                     NaN                       13
# 882                     NaN                       16
# 883                     NaN                       12
# 884                     NaN                        8
# 885                     NaN                        7
# 886                     NaN                       17
# 887                     NaN                       18
# 888                     NaN                       28
# 889                     NaN                       12
# 890                     NaN                       18
# 891                     NaN                       19
# 892                     NaN                       21
# 893                     NaN                       16
# 894                     NaN                       19
# 895                     NaN                       16
# 896                     NaN                       18
# 897                     NaN                       20
# 898                     NaN                       17
# 899                     NaN                       16
# 900                     NaN                       17
# 901                     NaN                       15
# 902                     NaN                       19
# 903                     NaN                       15
# ...
# 1011                    NaN                       14
# 1012                    NaN                       27
# 1013                    NaN                        3
# 1014                    NaN                       19
# 1015                    NaN                       26
# 1016                    NaN                       22
# 1017                    NaN                       16
# 1018                    NaN                       24
# 1019                    NaN                       17
# 1020                    NaN                       15
# 1021                    NaN                       21
# 1022                    NaN                       16
# 1023                    NaN                       12
# 1024                    NaN                        9
# 1025                    NaN                       12
# 1026                    NaN                        1
# 1027                    NaN                       16
# 1028                    NaN                        3
# 1029                    NaN                       15
# 1030                    NaN                       14
# 1031                    NaN                       18
# 1032                    NaN                       10
# 1033                    NaN                        4
# 1034                    NaN                       20
# 1035                    NaN                        3
# 1036                    NaN                       10
# 1037                    NaN                       14
# 1038                    NaN                       13
# 1039                    NaN                       18
# 1040                    NaN                       13
# 1041                    NaN                       18
# 1042                    NaN                       18
# 1043                    NaN                       12
# 1044                    NaN                       10
# 1045                    NaN                       15
# 1046                    NaN                        6
# 1047                    NaN                        9
# 1048                    NaN                       16
# 1049                    NaN                       15
# 1050                    NaN                       22
# 1051                    NaN                       16
# 1052                    NaN                       15
# 1053                    NaN                        7
# 1054                    NaN                       14
# 1055                    NaN                       21
# 1056                    NaN                       10
# 1057                    NaN                       12
# 1058                    NaN                       18
# 1059                    NaN                       15
# 1060                    NaN                       16
# 1061                    NaN                        3
# 1062                    NaN                       21
# 1063                    NaN                       15
# 1064                    NaN                        5
# 1065                    NaN                       13
# 1066                    NaN                       14
# 1067                    NaN                       14
# 1068                    NaN                       18
# 1069                    NaN                       17
# 1070                    NaN                        0
# 1071                    NaN                       13
# 1072                    NaN                        2
# 1073                    NaN                       21
# 1074                    NaN                       13
# 1075                    NaN                       18
# 1076                    NaN                       29
# 1077                    NaN                       16
# 1078                    NaN                        4
# 1079                    NaN                       16
# 1080                    NaN                       17
# 1081                    NaN                       16
# 1082                    NaN                       15
# 1083                    NaN                       16
# 1084                    NaN                       18
# 1085                    NaN                        2
# 1086                    NaN                       25
# 1087                    NaN                       21
# 1088                    NaN                       19
# 1089                    NaN                       20
# 1090                    NaN                       13
# 1091                    NaN                       19
# 1092                    NaN                       18
# 1093                    NaN                       19
# 1094                    NaN                       17
# 1095                    NaN                       17
# 1096                    NaN                       16
# 1097                    NaN                       14
# 1098                    NaN                       18
# 1099                    NaN                       16
# 1100                    NaN                       17
# 1101                    NaN                       17
# 1102                    NaN                        8
# 1103                    NaN                       18
# 1104                    NaN                       15
# 1105                    NaN                       19
# 1106                    NaN                        6
# 1107                    NaN                       16
# 1108                    NaN                       18
# 1109                    NaN                       16
# 1110                    NaN                        5
# 1111                    NaN                       19
# 1112                    NaN                       15
# 1113                    NaN                       15
# 1114                    NaN                       18
# 1115                    NaN                       26
# 1116                    NaN                       26
# 1117                    NaN                       19
# 1118                    NaN                        9
# 1119                    NaN                       19
# 1120                    NaN                       16
# 1121                    NaN                       14
# 1122                    NaN                        3
# 1123                    NaN                       15
# 1124                    NaN                       15
# 1125                    NaN                        9
# 1126                    NaN                       23
# 1127                    NaN                       19
# 1128                    NaN                       17
# 1129                    NaN                       14
# 1130                    NaN                       13
# 1131                    NaN                       17
# 1132                    NaN                       19
# 1133                    NaN                        4
# 1134                    NaN                        9
# 1135                    NaN                       18
# 1136                    NaN                       16
# 1137                    NaN                        4
# 1138                    NaN                       24
# 1139                    NaN                       16
# 1140                    NaN                       15
# 1141                    NaN                       15
# 1142                    NaN                        3
# 1143                    NaN                        7
# 1144                    NaN                       18
# 1145                    NaN                       15
# 1146                    NaN                       15
# 1147                    NaN                       12
# 1148                    NaN                       11
# 1149                    NaN                       20
# 1150                    NaN                       15
# 1151                    NaN                       13
# 1152                    NaN                       14
# 1153                    NaN                       86
# 1154                    NaN                       16
# 1155                    NaN                        5
# 1156                    NaN                       23
# 1157                    NaN                       20
# 1158                    NaN                       15
# 1159                    NaN                       16
# 1160                    NaN                       17
# 1161                    NaN                       16
# 1162                    NaN                       16
# 1163                    NaN                        6
# 1164                    NaN                       16
# 1165                    NaN                       17
# 1166                    NaN                        9
# 1167                    NaN                       11
# 1168                    NaN                       12
# 1169                    NaN                       14
# 1170                    NaN                       20
# 1171                    NaN                        1
# 1172                    NaN                       10
# 1173                    NaN                       17
# 1174                    NaN                       18
# 1175                    NaN                       19
# 1176                    NaN                       13
# 1177                    NaN                       12
# 1178                    NaN                       12
# 1179                    NaN                       10
# 1180                    NaN                       17
# 1181                    NaN                        7
# 1182                    NaN                       25
# 1183                    NaN                       17
# 1184                    NaN                       16
# 1185                    NaN                       14
# 1186                    NaN                        5
# 1187                    NaN                       16
# 1188                    NaN                       21
# 1189                    NaN                       18
# 1190                    NaN                       16
# 1191                    NaN                       21
# 1192                    NaN                       11
# 1193                    NaN                        6
# 1194                    NaN                       22
# 1195                    NaN                       13
# 1196                    NaN                       84
# 1197                    NaN                       12
# 1198                    NaN                        9
# 1199                    NaN                       19
# 1200                    NaN                       15
# 1201                    NaN                       15
# 1202                    NaN                       17
# 1203                    NaN                        2
# 1204                    NaN                        9
# 1205                    NaN                       28
# 1206                    NaN                       12
# 1207                    NaN                       15
# 1208                    NaN                       12
# 1209                    NaN                       22
# 1210                    NaN                        3
# 1211                    NaN                        3
# 1212                    NaN                       23
# 1213                    NaN                        8
# 1214                    NaN                       15
# 1215                    NaN                        9
# 1216                    NaN                       21
# 1217                    NaN                       19
# 1218                    NaN                       21
# 1219                    NaN                       14
# 1220                    NaN                        9
# 1221                    NaN                        4
# 1222                    NaN                       10
# 1223                    NaN                       12
# 1224                    NaN                       13
# 1225                    NaN                        8
# 1226                    NaN                       15
# 1227                    NaN                        3
# 1228                    NaN                       16
# 1229                    NaN                        6
# 1230                    NaN                        1
# 1231                    NaN                       21
# 1232                    NaN                        8
# 1233                    NaN                       12
# 1234                    NaN                        9
# 1235                    NaN                       18
# 1236                    NaN                       16
# 1237                    NaN                       13
# 1238                    NaN                       15
# 1239                    NaN                        7
# 1240                    NaN                       17
# 1241                    NaN                       12
# 1242                    NaN                       15
# 1243                    NaN                       19
# 1244                    NaN                        5
# 1245                    NaN                       11
# 1246                    NaN                        6
# 1247                    NaN                       14
# 1248                    NaN                        9
# 1249                    NaN                       15
# 1250                    NaN                       17
# 1251                    NaN                       20
# 1252                    NaN                       11
# 1253                    NaN                       13
# 1254                    NaN                       21
# 1255                    NaN                        8
# 1256                    NaN                       21
# 1257                    NaN                       10
# 1258                    NaN                       17
# 1259                    NaN                       18
# 1260                    NaN                        6
# 1261                    NaN                       19
# 1262                    NaN                       15
# 1263                    NaN                       11
# 1264                    NaN                        3
# 1265                    NaN                       14
# 1266                    NaN                       29
# 1267                    NaN                       15
# 1268                    NaN                       20
# 1269                    NaN                       14
# 1270                    NaN                       13
# 1271                    NaN                       19
# 1272                    NaN                       26
# 1273                    NaN                       17
# 1274                    NaN                       23
# 1275                    NaN                       13
# 1276                    NaN                       39
# 1277                    NaN                       12
# 1278                    NaN                       11
# 1279                    NaN                        5
# 1280                    NaN                        9
# 1281                    NaN                       23
# 1282                    NaN                       11
# 1283                    NaN                       22
# 1284                    NaN                       18
# 1285                    NaN                       15
# 1286                    NaN                       18
# 1287                    NaN                       12
# 1288                    NaN                       11
# 1289                    NaN                       18
# 1290                    NaN                        5
# 1291                    NaN                       12
# 1292                    NaN                       13
# 1293                    NaN                       13
# 1294                    NaN                       13
# 1295                    NaN                       15
# 1296                    NaN                       16
# 1297                    NaN                       14
# 1298                    NaN                        4
# 1299                    NaN                        9
# 1300                    NaN                       26
# 1301                    NaN                       17
# 1302                    NaN                       18
# 1303                    NaN                       20
# 1304                    NaN                        8
# 1305                    NaN                       15
# 1306                    NaN                        0
# 1307                    NaN                        1
# 1308                    NaN                       14
# 1309                    NaN                       11
# 1310                    NaN                       16
# 1311                    NaN                       13

# %%
df_survivors.age_exposure_globalpeace.value_counts(dropna=False)
df_survivors['age_exposure_filled'] = df_survivors.age_exposure_globalpeace.combine_first(df_survivors.age_exposure_hiroshima)

# %%
df_survivors['name_filled'] = df_survivors.name_globalpeace.combine_first(df_survivors.name_hiroshima)
df_survivors['name_kana_filled'] = df_survivors.name_kana_globalpeace.combine_first(df_survivors.name_kana_hiroshima)

df_survivors['exposure_loc_filled'] = df_survivors.exposure_loc_globalpeace.combine_first(df_survivors.exposure_loc_hiroshima)
df_survivors['exposure_dist_filled'] = df_survivors.exposure_dist_globalpeace.combine_first(df_survivors.exposure_dist_hiroshima)

df_survivors['sex_filled'] = df_survivors.sex_globalpeace.combine_first(df_survivors.sex_hiroshima)
df_survivors['slug_filled'] = df_survivors.slug_globalpeace.combine_first(df_survivors.slug_hiroshima)

df_survivors['age_production_filled'] = df_survivors.age_production_globalpeace.combine_first(df_survivors.age_production_hiroshima)

df_survivors['status_then_filled'] = df_survivors.status_then_globalpeace.combine_first(df_survivors.status_then_hiroshima)
df_survivors['status_then_detail_filled'] = df_survivors.status_then_detail_globalpeace.combine_first(df_survivors.status_then_detail_hiroshima)

# %%
# drop columns

cols = ['age_production_hiroshima',
       'exposure_dist_hiroshima', 'exposure_loc_hiroshima',
       'name_kana_hiroshima', 'status_then_detail_hiroshima',
       'age_exposure_hiroshima', 'name_hiroshima',
       'sex_hiroshima', 'slug_hiroshima',
       'status_then_hiroshima', 'age_production_globalpeace',
       'exposure_loc_globalpeace', 'name_kana_globalpeace',
       'slug_globalpeace', 'status_then_globalpeace',
       'status_then_detail_globalpeace', 'age_exposure_globalpeace',
       'exposure_dist_globalpeace',
       'name_globalpeace', 'sex_globalpeace']

df_cleaned = df_survivors.drop(columns=cols)

# %%
df_cleaned[df_cleaned.exposure_dist_filled == '広島: 3.0km   長崎: 3.0km']
df_cleaned.loc[1266, 'exposure_dist_filled'] = '3.0km'
df_cleaned.loc[1266, 'details'] = 'TKTKTK'
df_cleaned.loc[1266, 'work_location'] = 'Hiroshima and Nagasaki'

# df_cleaned.iloc[1266]

# %%
# Get rid of 'km', turn empty values tp NaNs, turn into int
df_cleaned['exposure_dist_cleaned'] = df_cleaned.exposure_dist_filled.replace('',np.nan).str[:-2].astype(float)
df_cleaned['age_exposure_cleaned'] = df_cleaned.age_exposure_filled.replace('',np.nan).astype(float)

# %%
df_cleaned.sex_filled.value_counts(dropna=False)
# Out:
# 男性       768
# 女性       541
#            2
# 男性,女性      1
# Name: sex_filled, dtype: int64

# %%
# Fill in 男性 for 今井|敏郎, 女性 for 丸山|巴	

df_cleaned['sex_cleaned'] = df_cleaned.sex_filled
df_cleaned.loc[45, 'sex_cleaned'] = '男性'
df_cleaned.loc[578, 'sex_cleaned'] = '女性'


# df_cleaned[df_cleaned.sex_filled == '男性,女性']

# # Clean this manually in text editor, duplicating the row so that the husband and wife have a row each
# # CODE: VS00473
df_cleaned.loc[421, 'sex_cleaned'] = np.nan

# Turn sex into 0/1
df_cleaned['is_female'] = df_cleaned.sex_cleaned.replace({'女性':1, '男性':0})
df_cleaned.is_female.value_counts(dropna=False)
# Out:
# 男性    769
# 女性    542
# Name: sex_cleaned, dtype: int64

# %%
df_cleaned.dtypes
# Out:
# age_exposure_detail           object
# code                          object
# details                       object
# work_location                 object
# id_hiroshima                 float64
# production_date               object
# name_romaji                   object
# record_location               object
# exposure_pref                 object
# id_globalpeace               float64
# age_exposure_filled           object
# name_kana_filled              object
# exposure_loc_filled           object
# status_then_filled            object
# status_then_detail_filled     object
# name_filled                   object
# exposure_dist_filled          object
# sex_filled                    object
# slug_filled                   object
# age_production_filled         object
# exposure_dist_cleaned        float64
# age_exposure_cleaned         float64
# sex_cleaned                   object
# is_female                    float64
# dtype: object

# %% [markdown]
# ## Tsutomu Yamaguchi
#
# https://www.global-peace.go.jp/picture/pic_syousai.php?gbID=119&dt=190805151430
#
# He was 29. Worked as 設計技師 (ships) in Nagasaki. He was in Hiroshima for business.
# Severe burns on face, arms, etc from Hiroshima.
# Went back to Nagasaki two days later. Then the next day, bomb dropped, irradiated again.
# 1:37~
#
# TRANSCRIBE
# "XXXX"

# %%
df_cleaned.loc[1266, 'exposure_dist_filled'] = '3.0km'
df_cleaned.loc[1266, 'details'] = 'TKTKTK'
df_cleaned.loc[1266, 'work_location'] = 'Hiroshima and Nagasaki'

df_cleaned.iloc[1266]
# Out:
# age_exposure_detail                                               NaN
# code                                                              NaN
# details                                                        TKTKTK
# work_location                                  Hiroshima and Nagasaki
# id_hiroshima                                                      NaN
# production_date                                                   NaN
# name_romaji                                         yamaguchi|tsutomu
# record_location                                      国立長崎原爆死没者追悼平和祈念館
# exposure_pref                                                      両市
# id_globalpeace                                                    592
# age_exposure_filled                                                29
# name_kana_filled                                             やまぐち|つとむ
# exposure_loc_filled           広島:広島市江波町[現:広島市中区]長崎:長崎市水の浦町[現:長崎市飽の浦町]
# status_then_filled                                              一般就業者
# status_then_detail_filled                           三菱重工業㈱長崎造船所|造機設計部
# name_filled                                                      山口|疆
# exposure_dist_filled                                            3.0km
# sex_filled                                                         男性
# slug_filled                  pic_syousai.php?gbID=119&dt=190805151430
# age_production_filled                                       2004年7月1日
# exposure_dist_cleaned                                               3
# age_exposure_cleaned                                               29
# sex_cleaned                                                        男性
# is_female                                                           0
# Name: 1266, dtype: object

# %%
df_cleaned.columns
# Out:
# Index(['age_exposure_detail', 'code', 'details', 'work_location',
#        'id_hiroshima', 'production_date', 'name_romaji', 'record_location',
#        'exposure_pref', 'id_globalpeace', 'age_exposure_filled',
#        'name_kana_filled', 'exposure_loc_filled', 'status_then_filled',
#        'status_then_detail_filled', 'name_filled', 'exposure_dist_filled',
#        'sex_filled', 'slug_filled', 'age_production_filled',
#        'exposure_dist_cleaned', 'age_exposure_cleaned', 'sex_cleaned',
#        'is_female'],
#       dtype='object')

# %%
# Drop columns

cols = ['age_exposure_filled',
       'name_kana_filled',
       'sex_filled',
       'exposure_dist_filled',
       'sex_cleaned',
       'sex_filled']

df_final = df_cleaned.drop(columns=cols)
df_final.head(2)
# Out:
#   age_exposure_detail     code  \
# 0                  21  VS00366
# 1                  14  VS00678
#
#                                              details work_location  \
# 0  当日の朝、女学校（現吉田高校）職員室内から閃光を見、音を聞いた。南方にはきのこ雲。一日中生徒...       吉田高等女学校
# 1  作業中明るい光が走った。焼夷弾の直撃を受けたと思い、机の下に隠れたが気づくと下敷きになってい...       安田高等女学校
#
#    id_hiroshima production_date    name_romaji record_location exposure_pref  \
# 0           1.0      1993/08/01  aoyama|yasuko             NaN           NaN
# 1           2.0      2000/03/31   akita|sachie             NaN           NaN
#
#    id_globalpeace exposure_loc_filled status_then_filled  \
# 0             NaN                  入市                教職員
# 1             NaN                 三篠町                 学生
#
#   status_then_detail_filled name_filled          slug_filled  \
# 0                       教職員       青山|恭子  /pdbj/detail/207680
# 1                        学生      秋田|サチヱ  /pdbj/detail/207588
#
#   age_production_filled  exposure_dist_cleaned  age_exposure_cleaned  \
# 0                    69                    NaN                  21.0
# 1                    69                    2.5                  14.0
#
#    is_female
# 0        1.0
# 1        1.0

# %% [markdown]
# # TWO people who were irradiated twice
# https://www.global-peace.go.jp/picture/pic_syousai.php?gbID=119&dt=190805151430
#
# https://www.global-peace.go.jp/picture/pic_syousai.php?gbID=1151&dt=190805151412

# %%
df_final.exposure_pref.value_counts(dropna=False)
df_final[df_final.exposure_pref == '両市']
# Out:
#      age_exposure_detail code details           work_location  id_hiroshima  \
# 950                  NaN  NaN     NaN                     NaN           NaN
# 1266                 NaN  NaN  TKTKTK  Hiroshima and Nagasaki           NaN
#
#      production_date          name_romaji   record_location exposure_pref  \
# 950              NaN  shiraishi|shun'ichi  国立長崎原爆死没者追悼平和祈念館            両市
# 1266             NaN    yamaguchi|tsutomu  国立長崎原爆死没者追悼平和祈念館            両市
#
#       id_globalpeace                      exposure_loc_filled  \
# 950            264.0                                   広島:長崎:
# 1266           592.0  広島:広島市江波町[現:広島市中区]長崎:長崎市水の浦町[現:長崎市飽の浦町]
#
#      status_then_filled status_then_detail_filled name_filled  \
# 950               生徒・学生            東京教育農業専門学校 1年生       白石|俊一
# 1266              一般就業者         三菱重工業㈱長崎造船所|造機設計部        山口|疆
#
#                                     slug_filled age_production_filled  \
# 950   pic_syousai.php?gbID=1151&dt=190805151412            2017年5月11日
# 1266   pic_syousai.php?gbID=119&dt=190805151430             2004年7月1日
#
#       exposure_dist_cleaned  age_exposure_cleaned  is_female
# 950                     NaN                  17.0        0.0
# 1266                    3.0                  29.0        0.0

# %%
df_final.to_csv('data/survivors_bio_complete_cleaned.csv', index=False)
